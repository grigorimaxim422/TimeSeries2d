# %%
import pandas as pd
import numpy as np
import torch
import torch.nn as nn
from sklearn.preprocessing import MinMaxScaler
from torch.utils.data import DataLoader, TensorDataset
from stable_baselines3 import PPO
from gym import spaces, Env
import matplotlib.pyplot as plt
import random

# Set seed for reproducibility
SEED = 42
random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)
if torch.cuda.is_available():
    torch.cuda.manual_seed_all(SEED)

# Load and preprocess data
def load_and_preprocess(file_name):
    data = pd.read_csv(file_name)
    data["Date"] = pd.to_datetime(data["Date"])
    data = data.sort_values(by="Date")
    
    numeric_data = data.drop(columns=["Date"])
    numeric_data = numeric_data[['Close'] + [col for col in numeric_data.columns if col != 'Close']]
    
    scaler = MinMaxScaler()
    normalized_data = scaler.fit_transform(numeric_data)
    data[numeric_data.columns] = normalized_data
    
    return data, scaler

# Create sequences for time series modeling
def create_sequences(data, sequence_length=30):
    sequences = []
    targets = []
    for i in range(len(data) - sequence_length):
        seq = data[i:i+sequence_length]
        target = data[i+sequence_length, 0]  # Assuming the target is the first column (e.g., Close price)
        sequences.append(seq)
        targets.append(target)
    return np.array(sequences), np.array(targets)

# Define Bi-LSTM model
class BiLSTMModel(nn.Module):
    def __init__(self, input_dim, hidden_dim, num_layers, dropout):
        super(BiLSTMModel, self).__init__()
        self.bilstm = nn.LSTM(input_dim, hidden_dim, num_layers, batch_first=True, dropout=dropout, bidirectional=True)
        self.fc = nn.Linear(hidden_dim * 2, 1)

    def forward(self, x):
        bilstm_out, _ = self.bilstm(x)
        return self.fc(bilstm_out[:, -1, :])

# Custom trading environment
class TradingEnv(Env):
    def __init__(self, data, sequence_length=30):
        super(TradingEnv, self).__init__()
        self.data = data
        self.sequence_length = sequence_length
        self.current_step = 0
        self.total_steps = len(data) - sequence_length
        self.portfolio_value = 1.0

        # Action and observation space
        self.action_space = spaces.Discrete(3)  # 0: Hold, 1: Buy, 2: Sell
        self.observation_space = spaces.Box(low=0, high=1, shape=(sequence_length, data.shape[1]), dtype=np.float32)

    def reset(self):
        self.current_step = 0
        self.portfolio_value = 1.0
        return self._next_observation()

    def _next_observation(self):
        return self.data[self.current_step:self.current_step + self.sequence_length]

    def step(self, action):
        self.current_step += 1
        reward = 0
        done = self.current_step >= self.total_steps

        if not done:
            current_price = self.data[self.current_step, 0]
            prev_price = self.data[self.current_step - 1, 0]

            if action == 1:  # Buy
                reward = current_price - prev_price
            elif action == 2:  # Sell
                reward = prev_price - current_price

        self.portfolio_value += reward
        obs = self._next_observation() if not done else None
        return obs, reward, done, {"portfolio_value": self.portfolio_value}

# Evaluate trading strategy
def evaluate_trading_strategy(env, model):
    obs = env.reset()
    done = False
    portfolio_values = [1.0]

    while not done:
        action, _ = model.predict(obs, deterministic=True)
        obs, reward, done, info = env.step(action)
        portfolio_values.append(info.get("portfolio_value", 1.0))

    return portfolio_values

# Performance metrics
def calculate_metrics(portfolio_values):
    daily_returns = np.diff(portfolio_values) / portfolio_values[:-1]
    cumulative_return = portfolio_values[-1] / portfolio_values[0] - 1
    sharpe_ratio = np.mean(daily_returns) / np.std(daily_returns) if np.std(daily_returns) > 0 else 0
    sortino_ratio = np.mean(daily_returns) / np.std([r for r in daily_returns if r < 0]) if np.std([r for r in daily_returns if r < 0]) > 0 else 0
    max_drawdown = np.min(portfolio_values / np.maximum.accumulate(portfolio_values) - 1)
    return cumulative_return, sharpe_ratio, sortino_ratio, max_drawdown

# Main execution
if __name__ == "__main__":
    # Load data
    data, scaler = load_and_preprocess("Book1.csv")
    train_data = data[(data["Date"].dt.year >= 2017) & (data["Date"].dt.year <= 2022)].drop(columns=["Date"]).values
    test_data = data[data["Date"].dt.year == 2023].drop(columns=["Date"]).values

    X_train, y_train = create_sequences(train_data)
    X_test, y_test = create_sequences(test_data)

    # Train Bi-LSTM model
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    bilstm_model = BiLSTMModel(input_dim=X_train.shape[2], hidden_dim=224, num_layers=1, dropout=0.14).to(device)
    criterion = nn.MSELoss()
    optimizer = torch.optim.Adam(bilstm_model.parameters(), lr=0.0019)

    train_loader = DataLoader(TensorDataset(torch.tensor(X_train, dtype=torch.float32), torch.tensor(y_train, dtype=torch.float32)), batch_size=32, shuffle=True)

    for epoch in range(50):
        bilstm_model.train()
        train_loss = 0.0
        for X_batch, y_batch in train_loader:
            X_batch, y_batch = X_batch.to(device), y_batch.to(device)
            optimizer.zero_grad()
            predictions = bilstm_model(X_batch).squeeze()
            loss = criterion(predictions, y_batch)
            loss.backward()
            optimizer.step()
            train_loss += loss.item()

    # Create environments for PPO
    bilstm_env = TradingEnv(test_data)
    simple_env = TradingEnv(test_data)

    # Train PPO models
    ppo_bilstm_model = PPO("MlpPolicy", bilstm_env, learning_rate=0.0014, batch_size=160, n_steps=1280, gamma=0.9005911776350177, verbose=1)
    ppo_bilstm_model.learn(total_timesteps=50000)

    ppo_simple_model = PPO("MlpPolicy", simple_env, verbose=1)
    ppo_simple_model.learn(total_timesteps=50000)

    # Evaluate strategies
    portfolio_values_bilstm = evaluate_trading_strategy(bilstm_env, ppo_bilstm_model)
    portfolio_values_simple = evaluate_trading_strategy(simple_env, ppo_simple_model)

    cumulative_return_bilstm, sharpe_bilstm, sortino_bilstm, max_drawdown_bilstm = calculate_metrics(portfolio_values_bilstm)
    cumulative_return_simple, sharpe_simple, sortino_simple, max_drawdown_simple = calculate_metrics(portfolio_values_simple)

    # Buy-and-Hold strategy
    buy_hold_return = test_data[-1, 0] / test_data[0, 0] - 1

    # Generate date range for 2023
    test_dates = pd.date_range(start="2023-01-01", periods=len(portfolio_values_bilstm))

    # Calculate cumulative returns
    cumulative_returns_bilstm = np.cumprod([1 + r for r in np.diff(portfolio_values_bilstm) / portfolio_values_bilstm[:-1]])
    cumulative_returns_simple = np.cumprod([1 + r for r in np.diff(portfolio_values_simple) / portfolio_values_simple[:-1]])

    # Plot cumulative returns
    plt.figure(figsize=(12, 6))
    plt.plot(test_dates[1:], cumulative_returns_bilstm, label="Bi-LSTM PPO")
    plt.plot(test_dates[1:], cumulative_returns_simple, label="Simple PPO")
    plt.axhline(1 + buy_hold_return, color="orange", linestyle="--", label="Buy-and-Hold")

    plt.gca().xaxis.set_major_formatter(plt.matplotlib.dates.DateFormatter("%b %Y"))
    plt.gca().xaxis.set_major_locator(plt.matplotlib.dates.MonthLocator())

    plt.legend()
    plt.title("Cumulative Returns")
    plt.xlabel("Date")
    plt.ylabel("Cumulative Return")
    plt.grid()
    plt.show()

    # Print results
    results = pd.DataFrame({
        "Method": ["Bi-LSTM PPO", "Simple PPO", "Buy-and-Hold"],
        "Cumulative Return": [cumulative_returns_bilstm[-1], cumulative_returns_simple[-1], buy_hold_return],
        "Sharpe Ratio": [sharpe_bilstm, sharpe_simple, None],
        "Sortino Ratio": [sortino_bilstm, sortino_simple, None],
        "Max Drawdown": [max_drawdown_bilstm, max_drawdown_simple, None]
    })
    print(results)
# Out:
# C:\Users\User\anaconda3\envs\RL\Lib\site-packages\torch\nn\modules\rnn.py:123: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.14 and num_layers=1
#   warnings.warn(
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# C:\Users\User\anaconda3\envs\RL\Lib\site-packages\stable_baselines3\common\vec_env\patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 335      |
# |    ep_rew_mean     | 0.028    |
# | time/              |          |
# |    fps             | 1818     |
# |    iterations      | 1        |
# |    time_elapsed    | 0        |
# |    total_timesteps | 1280     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | -0.037      |
# | time/                   |             |
# |    fps                  | 1548        |
# |    iterations           | 2           |
# |    time_elapsed         | 1           |
# |    total_timesteps      | 2560        |
# | train/                  |             |
# |    approx_kl            | 0.009769501 |
# |    clip_fraction        | 0.0627      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | -7.96       |
# |    learning_rate        | 0.0014      |
# |    loss                 | -0.00714    |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.00467    |
# |    value_loss           | 0.0313      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | -0.0286     |
# | time/                   |             |
# |    fps                  | 1475        |
# |    iterations           | 3           |
# |    time_elapsed         | 2           |
# |    total_timesteps      | 3840        |
# | train/                  |             |
# |    approx_kl            | 0.012889562 |
# |    clip_fraction        | 0.105       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.06       |
# |    explained_variance   | -3.79       |
# |    learning_rate        | 0.0014      |
# |    loss                 | -0.00493    |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.00543    |
# |    value_loss           | 0.000649    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | -0.00965    |
# | time/                   |             |
# |    fps                  | 1450        |
# |    iterations           | 4           |
# |    time_elapsed         | 3           |
# |    total_timesteps      | 5120        |
# | train/                  |             |
# |    approx_kl            | 0.011087648 |
# |    clip_fraction        | 0.129       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.06       |
# |    explained_variance   | -1.05       |
# |    learning_rate        | 0.0014      |
# |    loss                 | -0.0148     |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0123     |
# |    value_loss           | 0.000159    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.0127      |
# | time/                   |             |
# |    fps                  | 1429        |
# |    iterations           | 5           |
# |    time_elapsed         | 4           |
# |    total_timesteps      | 6400        |
# | train/                  |             |
# |    approx_kl            | 0.011124679 |
# |    clip_fraction        | 0.172       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.05       |
# |    explained_variance   | -0.494      |
# |    learning_rate        | 0.0014      |
# |    loss                 | -0.0109     |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0123     |
# |    value_loss           | 0.00012     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.0195      |
# | time/                   |             |
# |    fps                  | 1422        |
# |    iterations           | 6           |
# |    time_elapsed         | 5           |
# |    total_timesteps      | 7680        |
# | train/                  |             |
# |    approx_kl            | 0.018583363 |
# |    clip_fraction        | 0.162       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.04       |
# |    explained_variance   | -0.475      |
# |    learning_rate        | 0.0014      |
# |    loss                 | -0.0138     |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.00956    |
# |    value_loss           | 8.9e-05     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.0504      |
# | time/                   |             |
# |    fps                  | 1400        |
# |    iterations           | 7           |
# |    time_elapsed         | 6           |
# |    total_timesteps      | 8960        |
# | train/                  |             |
# |    approx_kl            | 0.009462351 |
# |    clip_fraction        | 0.17        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.01       |
# |    explained_variance   | -0.156      |
# |    learning_rate        | 0.0014      |
# |    loss                 | 0.00013     |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0104     |
# |    value_loss           | 8.98e-05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.0713      |
# | time/                   |             |
# |    fps                  | 1362        |
# |    iterations           | 8           |
# |    time_elapsed         | 7           |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.014318374 |
# |    clip_fraction        | 0.26        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.984      |
# |    explained_variance   | 0.00533     |
# |    learning_rate        | 0.0014      |
# |    loss                 | -0.00394    |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.00983    |
# |    value_loss           | 6.75e-05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.0988      |
# | time/                   |             |
# |    fps                  | 1317        |
# |    iterations           | 9           |
# |    time_elapsed         | 8           |
# |    total_timesteps      | 11520       |
# | train/                  |             |
# |    approx_kl            | 0.015045108 |
# |    clip_fraction        | 0.191       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.942      |
# |    explained_variance   | 0.0473      |
# |    learning_rate        | 0.0014      |
# |    loss                 | -0.0263     |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.0163     |
# |    value_loss           | 8.47e-05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.124       |
# | time/                   |             |
# |    fps                  | 1308        |
# |    iterations           | 10          |
# |    time_elapsed         | 9           |
# |    total_timesteps      | 12800       |
# | train/                  |             |
# |    approx_kl            | 0.016188497 |
# |    clip_fraction        | 0.251       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.899      |
# |    explained_variance   | 0.118       |
# |    learning_rate        | 0.0014      |
# |    loss                 | -0.0383     |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.0144     |
# |    value_loss           | 0.00013     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.153       |
# | time/                   |             |
# |    fps                  | 1283        |
# |    iterations           | 11          |
# |    time_elapsed         | 10          |
# |    total_timesteps      | 14080       |
# | train/                  |             |
# |    approx_kl            | 0.018109161 |
# |    clip_fraction        | 0.308       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.838      |
# |    explained_variance   | 0.195       |
# |    learning_rate        | 0.0014      |
# |    loss                 | -0.0251     |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.0137     |
# |    value_loss           | 7.79e-05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.173       |
# | time/                   |             |
# |    fps                  | 1283        |
# |    iterations           | 12          |
# |    time_elapsed         | 11          |
# |    total_timesteps      | 15360       |
# | train/                  |             |
# |    approx_kl            | 0.027142301 |
# |    clip_fraction        | 0.287       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.771      |
# |    explained_variance   | 0.194       |
# |    learning_rate        | 0.0014      |
# |    loss                 | -0.017      |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.00679    |
# |    value_loss           | 6.56e-05    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 335        |
# |    ep_rew_mean          | 0.203      |
# | time/                   |            |
# |    fps                  | 1288       |
# |    iterations           | 13         |
# |    time_elapsed         | 12         |
# |    total_timesteps      | 16640      |
# | train/                  |            |
# |    approx_kl            | 0.02034342 |
# |    clip_fraction        | 0.185      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.698     |
# |    explained_variance   | 0.328      |
# |    learning_rate        | 0.0014     |
# |    loss                 | 0.00195    |
# |    n_updates            | 120        |
# |    policy_gradient_loss | -0.00857   |
# |    value_loss           | 7.78e-05   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.234       |
# | time/                   |             |
# |    fps                  | 1292        |
# |    iterations           | 14          |
# |    time_elapsed         | 13          |
# |    total_timesteps      | 17920       |
# | train/                  |             |
# |    approx_kl            | 0.031502265 |
# |    clip_fraction        | 0.195       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.624      |
# |    explained_variance   | 0.516       |
# |    learning_rate        | 0.0014      |
# |    loss                 | 0.0208      |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.00631    |
# |    value_loss           | 6.14e-05    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 335        |
# |    ep_rew_mean          | 0.259      |
# | time/                   |            |
# |    fps                  | 1298       |
# |    iterations           | 15         |
# |    time_elapsed         | 14         |
# |    total_timesteps      | 19200      |
# | train/                  |            |
# |    approx_kl            | 0.13211763 |
# |    clip_fraction        | 0.221      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.571     |
# |    explained_variance   | 0.559      |
# |    learning_rate        | 0.0014     |
# |    loss                 | -0.00786   |
# |    n_updates            | 140        |
# |    policy_gradient_loss | 0.00783    |
# |    value_loss           | 4.93e-05   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 335        |
# |    ep_rew_mean          | 0.282      |
# | time/                   |            |
# |    fps                  | 1302       |
# |    iterations           | 16         |
# |    time_elapsed         | 15         |
# |    total_timesteps      | 20480      |
# | train/                  |            |
# |    approx_kl            | 0.05907523 |
# |    clip_fraction        | 0.162      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.503     |
# |    explained_variance   | 0.56       |
# |    learning_rate        | 0.0014     |
# |    loss                 | -0.00521   |
# |    n_updates            | 150        |
# |    policy_gradient_loss | 0.00119    |
# |    value_loss           | 0.000381   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 335        |
# |    ep_rew_mean          | 0.301      |
# | time/                   |            |
# |    fps                  | 1306       |
# |    iterations           | 17         |
# |    time_elapsed         | 16         |
# |    total_timesteps      | 21760      |
# | train/                  |            |
# |    approx_kl            | 0.04707661 |
# |    clip_fraction        | 0.258      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.523     |
# |    explained_variance   | 0.561      |
# |    learning_rate        | 0.0014     |
# |    loss                 | -0.0157    |
# |    n_updates            | 160        |
# |    policy_gradient_loss | 0.0104     |
# |    value_loss           | 5.8e-05    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.326       |
# | time/                   |             |
# |    fps                  | 1311        |
# |    iterations           | 18          |
# |    time_elapsed         | 17          |
# |    total_timesteps      | 23040       |
# | train/                  |             |
# |    approx_kl            | 0.017700663 |
# |    clip_fraction        | 0.267       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.52       |
# |    explained_variance   | 0.505       |
# |    learning_rate        | 0.0014      |
# |    loss                 | 0.0173      |
# |    n_updates            | 170         |
# |    policy_gradient_loss | 0.0172      |
# |    value_loss           | 6.75e-05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.348       |
# | time/                   |             |
# |    fps                  | 1313        |
# |    iterations           | 19          |
# |    time_elapsed         | 18          |
# |    total_timesteps      | 24320       |
# | train/                  |             |
# |    approx_kl            | 0.054441214 |
# |    clip_fraction        | 0.251       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.515      |
# |    explained_variance   | 0.552       |
# |    learning_rate        | 0.0014      |
# |    loss                 | -0.0166     |
# |    n_updates            | 180         |
# |    policy_gradient_loss | 0.0221      |
# |    value_loss           | 5.77e-05    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 335        |
# |    ep_rew_mean          | 0.371      |
# | time/                   |            |
# |    fps                  | 1317       |
# |    iterations           | 20         |
# |    time_elapsed         | 19         |
# |    total_timesteps      | 25600      |
# | train/                  |            |
# |    approx_kl            | 0.01662432 |
# |    clip_fraction        | 0.257      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.456     |
# |    explained_variance   | 0.647      |
# |    learning_rate        | 0.0014     |
# |    loss                 | -0.0165    |
# |    n_updates            | 190        |
# |    policy_gradient_loss | 0.0172     |
# |    value_loss           | 0.000135   |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 335       |
# |    ep_rew_mean          | 0.387     |
# | time/                   |           |
# |    fps                  | 1319      |
# |    iterations           | 21        |
# |    time_elapsed         | 20        |
# |    total_timesteps      | 26880     |
# | train/                  |           |
# |    approx_kl            | 0.0994866 |
# |    clip_fraction        | 0.365     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.425    |
# |    explained_variance   | 0.578     |
# |    learning_rate        | 0.0014    |
# |    loss                 | 0.0441    |
# |    n_updates            | 200       |
# |    policy_gradient_loss | 0.0447    |
# |    value_loss           | 0.000519  |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.409       |
# | time/                   |             |
# |    fps                  | 1322        |
# |    iterations           | 22          |
# |    time_elapsed         | 21          |
# |    total_timesteps      | 28160       |
# | train/                  |             |
# |    approx_kl            | 0.027595282 |
# |    clip_fraction        | 0.295       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.516      |
# |    explained_variance   | 0.435       |
# |    learning_rate        | 0.0014      |
# |    loss                 | -0.0262     |
# |    n_updates            | 210         |
# |    policy_gradient_loss | 0.0142      |
# |    value_loss           | 0.000417    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 335        |
# |    ep_rew_mean          | 0.422      |
# | time/                   |            |
# |    fps                  | 1322       |
# |    iterations           | 23         |
# |    time_elapsed         | 22         |
# |    total_timesteps      | 29440      |
# | train/                  |            |
# |    approx_kl            | 0.06747358 |
# |    clip_fraction        | 0.213      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.441     |
# |    explained_variance   | 0.471      |
# |    learning_rate        | 0.0014     |
# |    loss                 | 0.142      |
# |    n_updates            | 220        |
# |    policy_gradient_loss | 0.00848    |
# |    value_loss           | 0.000202   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 335        |
# |    ep_rew_mean          | 0.437      |
# | time/                   |            |
# |    fps                  | 1325       |
# |    iterations           | 24         |
# |    time_elapsed         | 23         |
# |    total_timesteps      | 30720      |
# | train/                  |            |
# |    approx_kl            | 0.09185018 |
# |    clip_fraction        | 0.242      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.416     |
# |    explained_variance   | 0.575      |
# |    learning_rate        | 0.0014     |
# |    loss                 | 0.0417     |
# |    n_updates            | 230        |
# |    policy_gradient_loss | 0.0204     |
# |    value_loss           | 0.00121    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.449       |
# | time/                   |             |
# |    fps                  | 1311        |
# |    iterations           | 25          |
# |    time_elapsed         | 24          |
# |    total_timesteps      | 32000       |
# | train/                  |             |
# |    approx_kl            | 0.024611035 |
# |    clip_fraction        | 0.211       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.393      |
# |    explained_variance   | 0.258       |
# |    learning_rate        | 0.0014      |
# |    loss                 | 0.0362      |
# |    n_updates            | 240         |
# |    policy_gradient_loss | 0.0215      |
# |    value_loss           | 0.000866    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.458       |
# | time/                   |             |
# |    fps                  | 1300        |
# |    iterations           | 26          |
# |    time_elapsed         | 25          |
# |    total_timesteps      | 33280       |
# | train/                  |             |
# |    approx_kl            | 0.026112039 |
# |    clip_fraction        | 0.224       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.351      |
# |    explained_variance   | 0.44        |
# |    learning_rate        | 0.0014      |
# |    loss                 | 0.0383      |
# |    n_updates            | 250         |
# |    policy_gradient_loss | 0.0158      |
# |    value_loss           | 0.00205     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 335        |
# |    ep_rew_mean          | 0.485      |
# | time/                   |            |
# |    fps                  | 1290       |
# |    iterations           | 27         |
# |    time_elapsed         | 26         |
# |    total_timesteps      | 34560      |
# | train/                  |            |
# |    approx_kl            | 0.08768247 |
# |    clip_fraction        | 0.232      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.328     |
# |    explained_variance   | 0.243      |
# |    learning_rate        | 0.0014     |
# |    loss                 | 0.0398     |
# |    n_updates            | 260        |
# |    policy_gradient_loss | 0.0288     |
# |    value_loss           | 0.000878   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.515       |
# | time/                   |             |
# |    fps                  | 1288        |
# |    iterations           | 28          |
# |    time_elapsed         | 27          |
# |    total_timesteps      | 35840       |
# | train/                  |             |
# |    approx_kl            | 0.026102329 |
# |    clip_fraction        | 0.21        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.36       |
# |    explained_variance   | 0.33        |
# |    learning_rate        | 0.0014      |
# |    loss                 | 0.00796     |
# |    n_updates            | 270         |
# |    policy_gradient_loss | 0.0164      |
# |    value_loss           | 0.000313    |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 335       |
# |    ep_rew_mean          | 0.549     |
# | time/                   |           |
# |    fps                  | 1291      |
# |    iterations           | 29        |
# |    time_elapsed         | 28        |
# |    total_timesteps      | 37120     |
# | train/                  |           |
# |    approx_kl            | 0.1518743 |
# |    clip_fraction        | 0.203     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.348    |
# |    explained_variance   | 0.418     |
# |    learning_rate        | 0.0014    |
# |    loss                 | 0.0502    |
# |    n_updates            | 280       |
# |    policy_gradient_loss | 0.021     |
# |    value_loss           | 0.000239  |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.58        |
# | time/                   |             |
# |    fps                  | 1295        |
# |    iterations           | 30          |
# |    time_elapsed         | 29          |
# |    total_timesteps      | 38400       |
# | train/                  |             |
# |    approx_kl            | 0.099538155 |
# |    clip_fraction        | 0.21        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.304      |
# |    explained_variance   | 0.473       |
# |    learning_rate        | 0.0014      |
# |    loss                 | -0.00592    |
# |    n_updates            | 290         |
# |    policy_gradient_loss | 0.00995     |
# |    value_loss           | 6.21e-05    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 335        |
# |    ep_rew_mean          | 0.598      |
# | time/                   |            |
# |    fps                  | 1297       |
# |    iterations           | 31         |
# |    time_elapsed         | 30         |
# |    total_timesteps      | 39680      |
# | train/                  |            |
# |    approx_kl            | 0.10818135 |
# |    clip_fraction        | 0.221      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.282     |
# |    explained_variance   | 0.537      |
# |    learning_rate        | 0.0014     |
# |    loss                 | 0.122      |
# |    n_updates            | 300        |
# |    policy_gradient_loss | 0.0299     |
# |    value_loss           | 9.39e-05   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.622       |
# | time/                   |             |
# |    fps                  | 1300        |
# |    iterations           | 32          |
# |    time_elapsed         | 31          |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.043857608 |
# |    clip_fraction        | 0.2         |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.259      |
# |    explained_variance   | 0.321       |
# |    learning_rate        | 0.0014      |
# |    loss                 | -0.0215     |
# |    n_updates            | 310         |
# |    policy_gradient_loss | 0.0104      |
# |    value_loss           | 0.000131    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 335        |
# |    ep_rew_mean          | 0.642      |
# | time/                   |            |
# |    fps                  | 1298       |
# |    iterations           | 33         |
# |    time_elapsed         | 32         |
# |    total_timesteps      | 42240      |
# | train/                  |            |
# |    approx_kl            | 0.05654036 |
# |    clip_fraction        | 0.233      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.284     |
# |    explained_variance   | 0.503      |
# |    learning_rate        | 0.0014     |
# |    loss                 | -0.0194    |
# |    n_updates            | 320        |
# |    policy_gradient_loss | 0.0121     |
# |    value_loss           | 0.0015     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 335        |
# |    ep_rew_mean          | 0.663      |
# | time/                   |            |
# |    fps                  | 1298       |
# |    iterations           | 34         |
# |    time_elapsed         | 33         |
# |    total_timesteps      | 43520      |
# | train/                  |            |
# |    approx_kl            | 0.09220731 |
# |    clip_fraction        | 0.209      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.29      |
# |    explained_variance   | 0.212      |
# |    learning_rate        | 0.0014     |
# |    loss                 | 0.00496    |
# |    n_updates            | 330        |
# |    policy_gradient_loss | 0.00363    |
# |    value_loss           | 0.000121   |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 335       |
# |    ep_rew_mean          | 0.689     |
# | time/                   |           |
# |    fps                  | 1299      |
# |    iterations           | 35        |
# |    time_elapsed         | 34        |
# |    total_timesteps      | 44800     |
# | train/                  |           |
# |    approx_kl            | 0.0795505 |
# |    clip_fraction        | 0.229     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.255    |
# |    explained_variance   | 0.279     |
# |    learning_rate        | 0.0014    |
# |    loss                 | -0.000602 |
# |    n_updates            | 340       |
# |    policy_gradient_loss | 0.0405    |
# |    value_loss           | 0.000103  |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.711       |
# | time/                   |             |
# |    fps                  | 1301        |
# |    iterations           | 36          |
# |    time_elapsed         | 35          |
# |    total_timesteps      | 46080       |
# | train/                  |             |
# |    approx_kl            | 0.023920393 |
# |    clip_fraction        | 0.244       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.27       |
# |    explained_variance   | 0.43        |
# |    learning_rate        | 0.0014      |
# |    loss                 | 0.0535      |
# |    n_updates            | 350         |
# |    policy_gradient_loss | 0.0457      |
# |    value_loss           | 8.05e-05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.732       |
# | time/                   |             |
# |    fps                  | 1302        |
# |    iterations           | 37          |
# |    time_elapsed         | 36          |
# |    total_timesteps      | 47360       |
# | train/                  |             |
# |    approx_kl            | 0.030978922 |
# |    clip_fraction        | 0.196       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.26       |
# |    explained_variance   | 0.507       |
# |    learning_rate        | 0.0014      |
# |    loss                 | 0.00088     |
# |    n_updates            | 360         |
# |    policy_gradient_loss | 0.0206      |
# |    value_loss           | 0.000815    |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 335       |
# |    ep_rew_mean          | 0.751     |
# | time/                   |           |
# |    fps                  | 1305      |
# |    iterations           | 38        |
# |    time_elapsed         | 37        |
# |    total_timesteps      | 48640     |
# | train/                  |           |
# |    approx_kl            | 0.1000361 |
# |    clip_fraction        | 0.193     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.232    |
# |    explained_variance   | 0.4       |
# |    learning_rate        | 0.0014    |
# |    loss                 | -0.0139   |
# |    n_updates            | 370       |
# |    policy_gradient_loss | 0.0198    |
# |    value_loss           | 0.00131   |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.766       |
# | time/                   |             |
# |    fps                  | 1307        |
# |    iterations           | 39          |
# |    time_elapsed         | 38          |
# |    total_timesteps      | 49920       |
# | train/                  |             |
# |    approx_kl            | 0.053618386 |
# |    clip_fraction        | 0.168       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.233      |
# |    explained_variance   | 0.339       |
# |    learning_rate        | 0.0014      |
# |    loss                 | 0.0969      |
# |    n_updates            | 380         |
# |    policy_gradient_loss | 0.0118      |
# |    value_loss           | 0.000163    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 335        |
# |    ep_rew_mean          | 0.774      |
# | time/                   |            |
# |    fps                  | 1309       |
# |    iterations           | 40         |
# |    time_elapsed         | 39         |
# |    total_timesteps      | 51200      |
# | train/                  |            |
# |    approx_kl            | 0.08417055 |
# |    clip_fraction        | 0.244      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.254     |
# |    explained_variance   | 0.372      |
# |    learning_rate        | 0.0014     |
# |    loss                 | 0.0261     |
# |    n_updates            | 390        |
# |    policy_gradient_loss | 0.0268     |
# |    value_loss           | 0.000275   |
# ----------------------------------------
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 335      |
# |    ep_rew_mean     | 0.0338   |
# | time/              |          |
# |    fps             | 1503     |
# |    iterations      | 1        |
# |    time_elapsed    | 1        |
# |    total_timesteps | 2048     |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 335          |
# |    ep_rew_mean          | 0.00157      |
# | time/                   |              |
# |    fps                  | 1042         |
# |    iterations           | 2            |
# |    time_elapsed         | 3            |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0077249324 |
# |    clip_fraction        | 0.0343       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.09        |
# |    explained_variance   | -3.12        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0117       |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.00277     |
# |    value_loss           | 0.0029       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | -0.0294     |
# | time/                   |             |
# |    fps                  | 1003        |
# |    iterations           | 3           |
# |    time_elapsed         | 6           |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.005667554 |
# |    clip_fraction        | 0.0547      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.07       |
# |    explained_variance   | 0.0448      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.000751   |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.00201    |
# |    value_loss           | 0.000612    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | -0.0245     |
# | time/                   |             |
# |    fps                  | 965         |
# |    iterations           | 4           |
# |    time_elapsed         | 8           |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.006807959 |
# |    clip_fraction        | 0.0837      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.04       |
# |    explained_variance   | 0.642       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0164     |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.00504    |
# |    value_loss           | 0.00037     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | -0.0157     |
# | time/                   |             |
# |    fps                  | 958         |
# |    iterations           | 5           |
# |    time_elapsed         | 10          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.009282796 |
# |    clip_fraction        | 0.078       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.08       |
# |    explained_variance   | 0.744       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0205     |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.00769    |
# |    value_loss           | 0.000401    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | -0.0123     |
# | time/                   |             |
# |    fps                  | 966         |
# |    iterations           | 6           |
# |    time_elapsed         | 12          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.011498071 |
# |    clip_fraction        | 0.135       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.08       |
# |    explained_variance   | 0.805       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0065     |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.00883    |
# |    value_loss           | 0.000322    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | -0.00173    |
# | time/                   |             |
# |    fps                  | 966         |
# |    iterations           | 7           |
# |    time_elapsed         | 14          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.010337621 |
# |    clip_fraction        | 0.0943      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.08       |
# |    explained_variance   | 0.761       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00676    |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.00607    |
# |    value_loss           | 0.000364    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.00988     |
# | time/                   |             |
# |    fps                  | 941         |
# |    iterations           | 8           |
# |    time_elapsed         | 17          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.010792041 |
# |    clip_fraction        | 0.137       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.05       |
# |    explained_variance   | 0.771       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.012       |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0109     |
# |    value_loss           | 0.00029     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.0286      |
# | time/                   |             |
# |    fps                  | 917         |
# |    iterations           | 9           |
# |    time_elapsed         | 20          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.008667149 |
# |    clip_fraction        | 0.148       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.02       |
# |    explained_variance   | 0.743       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00914    |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.0119     |
# |    value_loss           | 0.000263    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.0556      |
# | time/                   |             |
# |    fps                  | 923         |
# |    iterations           | 10          |
# |    time_elapsed         | 22          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.012096041 |
# |    clip_fraction        | 0.167       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.97       |
# |    explained_variance   | 0.67        |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00659    |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.00936    |
# |    value_loss           | 0.000288    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 335          |
# |    ep_rew_mean          | 0.0842       |
# | time/                   |              |
# |    fps                  | 928          |
# |    iterations           | 11           |
# |    time_elapsed         | 24           |
# |    total_timesteps      | 22528        |
# | train/                  |              |
# |    approx_kl            | 0.0092219645 |
# |    clip_fraction        | 0.125        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.91        |
# |    explained_variance   | 0.649        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00215     |
# |    n_updates            | 100          |
# |    policy_gradient_loss | -0.00462     |
# |    value_loss           | 0.000238     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.111       |
# | time/                   |             |
# |    fps                  | 932         |
# |    iterations           | 12          |
# |    time_elapsed         | 26          |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.010566114 |
# |    clip_fraction        | 0.126       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.847      |
# |    explained_variance   | 0.481       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0172     |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.00871    |
# |    value_loss           | 0.000276    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.136       |
# | time/                   |             |
# |    fps                  | 934         |
# |    iterations           | 13          |
# |    time_elapsed         | 28          |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.008815374 |
# |    clip_fraction        | 0.135       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.798      |
# |    explained_variance   | 0.335       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00012    |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.0015     |
# |    value_loss           | 0.000258    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.161       |
# | time/                   |             |
# |    fps                  | 938         |
# |    iterations           | 14          |
# |    time_elapsed         | 30          |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.011810928 |
# |    clip_fraction        | 0.157       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.736      |
# |    explained_variance   | 0.402       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0238     |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.00573    |
# |    value_loss           | 0.000178    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.185       |
# | time/                   |             |
# |    fps                  | 935         |
# |    iterations           | 15          |
# |    time_elapsed         | 32          |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.014949222 |
# |    clip_fraction        | 0.149       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.725      |
# |    explained_variance   | 0.59        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.01        |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.00202    |
# |    value_loss           | 0.000158    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.211       |
# | time/                   |             |
# |    fps                  | 925         |
# |    iterations           | 16          |
# |    time_elapsed         | 35          |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.014121791 |
# |    clip_fraction        | 0.152       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.627      |
# |    explained_variance   | 0.674       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00615    |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.00685    |
# |    value_loss           | 0.000244    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 335          |
# |    ep_rew_mean          | 0.241        |
# | time/                   |              |
# |    fps                  | 926          |
# |    iterations           | 17           |
# |    time_elapsed         | 37           |
# |    total_timesteps      | 34816        |
# | train/                  |              |
# |    approx_kl            | 0.0076536513 |
# |    clip_fraction        | 0.128        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.591       |
# |    explained_variance   | 0.751        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.031       |
# |    n_updates            | 160          |
# |    policy_gradient_loss | -0.000674    |
# |    value_loss           | 0.000172     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.289       |
# | time/                   |             |
# |    fps                  | 930         |
# |    iterations           | 18          |
# |    time_elapsed         | 39          |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.009898257 |
# |    clip_fraction        | 0.129       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.587      |
# |    explained_variance   | 0.83        |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0142     |
# |    n_updates            | 170         |
# |    policy_gradient_loss | 0.000523    |
# |    value_loss           | 0.00014     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.332       |
# | time/                   |             |
# |    fps                  | 929         |
# |    iterations           | 19          |
# |    time_elapsed         | 41          |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.006871758 |
# |    clip_fraction        | 0.124       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.584      |
# |    explained_variance   | 0.86        |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00422    |
# |    n_updates            | 180         |
# |    policy_gradient_loss | 0.00265     |
# |    value_loss           | 0.000174    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.377       |
# | time/                   |             |
# |    fps                  | 931         |
# |    iterations           | 20          |
# |    time_elapsed         | 43          |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.008987637 |
# |    clip_fraction        | 0.114       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.573      |
# |    explained_variance   | 0.869       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00858    |
# |    n_updates            | 190         |
# |    policy_gradient_loss | 0.00322     |
# |    value_loss           | 0.000313    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.422       |
# | time/                   |             |
# |    fps                  | 934         |
# |    iterations           | 21          |
# |    time_elapsed         | 46          |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.017930072 |
# |    clip_fraction        | 0.156       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.534      |
# |    explained_variance   | 0.86        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0256      |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.00277    |
# |    value_loss           | 0.000148    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.466       |
# | time/                   |             |
# |    fps                  | 931         |
# |    iterations           | 22          |
# |    time_elapsed         | 48          |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.013140202 |
# |    clip_fraction        | 0.125       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.493      |
# |    explained_variance   | 0.853       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.01       |
# |    n_updates            | 210         |
# |    policy_gradient_loss | 0.00534     |
# |    value_loss           | 0.000255    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.51        |
# | time/                   |             |
# |    fps                  | 923         |
# |    iterations           | 23          |
# |    time_elapsed         | 50          |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.019041639 |
# |    clip_fraction        | 0.136       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.482      |
# |    explained_variance   | 0.876       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0033     |
# |    n_updates            | 220         |
# |    policy_gradient_loss | 0.00444     |
# |    value_loss           | 0.000218    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 335        |
# |    ep_rew_mean          | 0.557      |
# | time/                   |            |
# |    fps                  | 923        |
# |    iterations           | 24         |
# |    time_elapsed         | 53         |
# |    total_timesteps      | 49152      |
# | train/                  |            |
# |    approx_kl            | 0.02299912 |
# |    clip_fraction        | 0.143      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.451     |
# |    explained_variance   | 0.893      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.225      |
# |    n_updates            | 230        |
# |    policy_gradient_loss | 0.0053     |
# |    value_loss           | 9.86e-05   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.598       |
# | time/                   |             |
# |    fps                  | 926         |
# |    iterations           | 25          |
# |    time_elapsed         | 55          |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.014097875 |
# |    clip_fraction        | 0.147       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.45       |
# |    explained_variance   | 0.896       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0344      |
# |    n_updates            | 240         |
# |    policy_gradient_loss | 0.0105      |
# |    value_loss           | 0.000286    |
# -----------------------------------------
#          Method  Cumulative Return  Sharpe Ratio  Sortino Ratio  Max Drawdown
# 0   Bi-LSTM PPO           1.858912      0.485975       1.103435     -0.009313
# 1    Simple PPO           1.891417      0.492507       1.117175     -0.009223
# 2  Buy-and-Hold           1.634423           NaN            NaN           NaN

# %%
import pandas as pd
import numpy as np
import torch
import torch.nn as nn
from sklearn.preprocessing import MinMaxScaler
from torch.utils.data import DataLoader, TensorDataset
from stable_baselines3 import PPO
from gym import spaces, Env
import matplotlib.pyplot as plt
import random

# Set seed for reproducibility
SEED = 42
random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)
if torch.cuda.is_available():
    torch.cuda.manual_seed_all(SEED)

# Load and preprocess data
def load_and_preprocess(file_name):
    data = pd.read_csv(file_name)
    data["Date"] = pd.to_datetime(data["Date"])
    data = data.sort_values(by="Date")
    
    numeric_data = data.drop(columns=["Date"])
    numeric_data = numeric_data[['Close'] + [col for col in numeric_data.columns if col != 'Close']]
    
    scaler = MinMaxScaler()
    normalized_data = scaler.fit_transform(numeric_data)
    data[numeric_data.columns] = normalized_data
    
    return data, scaler

# Create sequences for time series modeling
def create_sequences(data, sequence_length=30):
    sequences = []
    targets = []
    for i in range(len(data) - sequence_length):
        seq = data[i:i+sequence_length]
        target = data[i+sequence_length, 0]  # Assuming the target is the first column (e.g., Close price)
        sequences.append(seq)
        targets.append(target)
    return np.array(sequences), np.array(targets)

# Define Bi-LSTM model
class BiLSTMModel(nn.Module):
    def __init__(self, input_dim, hidden_dim, num_layers, dropout):
        super(BiLSTMModel, self).__init__()
        self.bilstm = nn.LSTM(input_dim, hidden_dim, num_layers, batch_first=True, dropout=dropout, bidirectional=True)
        self.fc = nn.Linear(hidden_dim * 2, 1)

    def forward(self, x):
        bilstm_out, _ = self.bilstm(x)
        return self.fc(bilstm_out[:, -1, :])

# Custom trading environment
class TradingEnv(Env):
    def __init__(self, data, sequence_length=30):
        super(TradingEnv, self).__init__()
        self.data = data
        self.sequence_length = sequence_length
        self.current_step = 0
        self.total_steps = len(data) - sequence_length
        self.portfolio_value = 1.0

        # Action and observation space
        self.action_space = spaces.Discrete(3)  # 0: Hold, 1: Buy, 2: Sell
        self.observation_space = spaces.Box(low=0, high=1, shape=(sequence_length, data.shape[1]), dtype=np.float32)

    def reset(self):
        self.current_step = 0
        self.portfolio_value = 1.0
        return self._next_observation()

    def _next_observation(self):
        return self.data[self.current_step:self.current_step + self.sequence_length]

    def step(self, action):
        self.current_step += 1
        reward = 0
        done = self.current_step >= self.total_steps

        if not done:
            current_price = self.data[self.current_step, 0]
            prev_price = self.data[self.current_step - 1, 0]

            if action == 1:  # Buy
                reward = current_price - prev_price
            elif action == 2:  # Sell
                reward = prev_price - current_price

        self.portfolio_value += reward
        obs = self._next_observation() if not done else None
        return obs, reward, done, {"portfolio_value": self.portfolio_value}

# Evaluate trading strategy
def evaluate_trading_strategy(env, model):
    obs = env.reset()
    done = False
    portfolio_values = [1.0]

    while not done:
        action, _ = model.predict(obs, deterministic=True)
        obs, reward, done, info = env.step(action)
        portfolio_values.append(info.get("portfolio_value", 1.0))

    return portfolio_values

# Performance metrics
def calculate_metrics(portfolio_values):
    daily_returns = np.diff(portfolio_values) / portfolio_values[:-1]
    cumulative_return = portfolio_values[-1] / portfolio_values[0] - 1
    sharpe_ratio = np.mean(daily_returns) / np.std(daily_returns) if np.std(daily_returns) > 0 else 0
    sortino_ratio = np.mean(daily_returns) / np.std([r for r in daily_returns if r < 0]) if np.std([r for r in daily_returns if r < 0]) > 0 else 0
    max_drawdown = np.min(portfolio_values / np.maximum.accumulate(portfolio_values) - 1)
    return cumulative_return, sharpe_ratio, sortino_ratio, max_drawdown

# Main execution
if __name__ == "__main__":
    # Load data
    data, scaler = load_and_preprocess("Book1.csv")
    train_data = data[(data["Date"].dt.year >= 2017) & (data["Date"].dt.year <= 2022)].drop(columns=["Date"]).values
    test_data = data[data["Date"].dt.year == 2023].drop(columns=["Date"]).values

    X_train, y_train = create_sequences(train_data)
    X_test, y_test = create_sequences(test_data)

    # Train Bi-LSTM model
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    bilstm_model = BiLSTMModel(input_dim=X_train.shape[2], hidden_dim=224, num_layers=1, dropout=0.14).to(device)
    criterion = nn.MSELoss()
    optimizer = torch.optim.Adam(bilstm_model.parameters(), lr=0.0019)

    train_loader = DataLoader(TensorDataset(torch.tensor(X_train, dtype=torch.float32), torch.tensor(y_train, dtype=torch.float32)), batch_size=32, shuffle=True)

    for epoch in range(50):
        bilstm_model.train()
        train_loss = 0.0
        for X_batch, y_batch in train_loader:
            X_batch, y_batch = X_batch.to(device), y_batch.to(device)
            optimizer.zero_grad()
            predictions = bilstm_model(X_batch).squeeze()
            loss = criterion(predictions, y_batch)
            loss.backward()
            optimizer.step()
            train_loss += loss.item()

    # Create environments for PPO
    bilstm_env = TradingEnv(test_data)
    simple_env = TradingEnv(test_data)

    # Train PPO models
    ppo_bilstm_model = PPO("MlpPolicy", bilstm_env, learning_rate=0.0014, batch_size=160, n_steps=1280, gamma=0.9005911776350177, verbose=1)
    ppo_bilstm_model.learn(total_timesteps=50000)

    ppo_simple_model = PPO("MlpPolicy", simple_env, verbose=1)
    ppo_simple_model.learn(total_timesteps=50000)

    # Evaluate strategies
    portfolio_values_bilstm = evaluate_trading_strategy(bilstm_env, ppo_bilstm_model)
    portfolio_values_simple = evaluate_trading_strategy(simple_env, ppo_simple_model)

    cumulative_return_bilstm, sharpe_bilstm, sortino_bilstm, max_drawdown_bilstm = calculate_metrics(portfolio_values_bilstm)
    cumulative_return_simple, sharpe_simple, sortino_simple, max_drawdown_simple = calculate_metrics(portfolio_values_simple)

    # Buy-and-Hold strategy
    buy_hold_return = test_data[-1, 0] / test_data[0, 0] - 1

    # Generate date range for 2023
    test_dates = pd.date_range(start="2023-01-01", periods=len(portfolio_values_bilstm))

    # Calculate cumulative returns
    cumulative_returns_bilstm = np.cumprod([1 + r for r in np.diff(portfolio_values_bilstm) / portfolio_values_bilstm[:-1]])
    cumulative_returns_simple = np.cumprod([1 + r for r in np.diff(portfolio_values_simple) / portfolio_values_simple[:-1]])

    # Plot cumulative returns
    plt.figure(figsize=(12, 6))
    plt.plot(test_dates[1:], cumulative_returns_bilstm, label="Bi-LSTM PPO")
    plt.plot(test_dates[1:], cumulative_returns_simple, label="Simple PPO")

    plt.gca().xaxis.set_major_formatter(plt.matplotlib.dates.DateFormatter("%b %Y"))
    plt.gca().xaxis.set_major_locator(plt.matplotlib.dates.MonthLocator())

    plt.legend()
    plt.title("Cumulative Returns")
    plt.xlabel("Date")
    plt.ylabel("Cumulative Return")
    plt.grid()
    plt.show()

    # Print results
    results = pd.DataFrame({
        "Method": ["Bi-LSTM PPO", "Simple PPO", "Buy-and-Hold"],
        "Cumulative Return": [cumulative_returns_bilstm[-1], cumulative_returns_simple[-1], buy_hold_return],
        "Sharpe Ratio": [sharpe_bilstm, sharpe_simple, None],
        "Sortino Ratio": [sortino_bilstm, sortino_simple, None],
        "Max Drawdown": [max_drawdown_bilstm, max_drawdown_simple, None]
    })
    print(results)
# Out:
# C:\Users\User\anaconda3\envs\RL\Lib\site-packages\torch\nn\modules\rnn.py:123: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.14 and num_layers=1
#   warnings.warn(
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# C:\Users\User\anaconda3\envs\RL\Lib\site-packages\stable_baselines3\common\vec_env\patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 335      |
# |    ep_rew_mean     | 0.028    |
# | time/              |          |
# |    fps             | 991      |
# |    iterations      | 1        |
# |    time_elapsed    | 1        |
# |    total_timesteps | 1280     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | -0.037      |
# | time/                   |             |
# |    fps                  | 821         |
# |    iterations           | 2           |
# |    time_elapsed         | 3           |
# |    total_timesteps      | 2560        |
# | train/                  |             |
# |    approx_kl            | 0.009769501 |
# |    clip_fraction        | 0.0627      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | -7.96       |
# |    learning_rate        | 0.0014      |
# |    loss                 | -0.00714    |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.00467    |
# |    value_loss           | 0.0313      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | -0.0286     |
# | time/                   |             |
# |    fps                  | 781         |
# |    iterations           | 3           |
# |    time_elapsed         | 4           |
# |    total_timesteps      | 3840        |
# | train/                  |             |
# |    approx_kl            | 0.012889562 |
# |    clip_fraction        | 0.105       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.06       |
# |    explained_variance   | -3.79       |
# |    learning_rate        | 0.0014      |
# |    loss                 | -0.00493    |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.00543    |
# |    value_loss           | 0.000649    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | -0.00965    |
# | time/                   |             |
# |    fps                  | 746         |
# |    iterations           | 4           |
# |    time_elapsed         | 6           |
# |    total_timesteps      | 5120        |
# | train/                  |             |
# |    approx_kl            | 0.011087648 |
# |    clip_fraction        | 0.129       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.06       |
# |    explained_variance   | -1.05       |
# |    learning_rate        | 0.0014      |
# |    loss                 | -0.0148     |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0123     |
# |    value_loss           | 0.000159    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.0127      |
# | time/                   |             |
# |    fps                  | 708         |
# |    iterations           | 5           |
# |    time_elapsed         | 9           |
# |    total_timesteps      | 6400        |
# | train/                  |             |
# |    approx_kl            | 0.011124679 |
# |    clip_fraction        | 0.172       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.05       |
# |    explained_variance   | -0.494      |
# |    learning_rate        | 0.0014      |
# |    loss                 | -0.0109     |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0123     |
# |    value_loss           | 0.00012     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.0195      |
# | time/                   |             |
# |    fps                  | 695         |
# |    iterations           | 6           |
# |    time_elapsed         | 11          |
# |    total_timesteps      | 7680        |
# | train/                  |             |
# |    approx_kl            | 0.018583363 |
# |    clip_fraction        | 0.162       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.04       |
# |    explained_variance   | -0.475      |
# |    learning_rate        | 0.0014      |
# |    loss                 | -0.0138     |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.00956    |
# |    value_loss           | 8.9e-05     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.0504      |
# | time/                   |             |
# |    fps                  | 699         |
# |    iterations           | 7           |
# |    time_elapsed         | 12          |
# |    total_timesteps      | 8960        |
# | train/                  |             |
# |    approx_kl            | 0.009462351 |
# |    clip_fraction        | 0.17        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.01       |
# |    explained_variance   | -0.156      |
# |    learning_rate        | 0.0014      |
# |    loss                 | 0.00013     |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0104     |
# |    value_loss           | 8.98e-05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.0713      |
# | time/                   |             |
# |    fps                  | 721         |
# |    iterations           | 8           |
# |    time_elapsed         | 14          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.014318374 |
# |    clip_fraction        | 0.26        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.984      |
# |    explained_variance   | 0.00533     |
# |    learning_rate        | 0.0014      |
# |    loss                 | -0.00394    |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.00983    |
# |    value_loss           | 6.75e-05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.0988      |
# | time/                   |             |
# |    fps                  | 742         |
# |    iterations           | 9           |
# |    time_elapsed         | 15          |
# |    total_timesteps      | 11520       |
# | train/                  |             |
# |    approx_kl            | 0.015045108 |
# |    clip_fraction        | 0.191       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.942      |
# |    explained_variance   | 0.0473      |
# |    learning_rate        | 0.0014      |
# |    loss                 | -0.0263     |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.0163     |
# |    value_loss           | 8.47e-05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.124       |
# | time/                   |             |
# |    fps                  | 758         |
# |    iterations           | 10          |
# |    time_elapsed         | 16          |
# |    total_timesteps      | 12800       |
# | train/                  |             |
# |    approx_kl            | 0.016188497 |
# |    clip_fraction        | 0.251       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.899      |
# |    explained_variance   | 0.118       |
# |    learning_rate        | 0.0014      |
# |    loss                 | -0.0383     |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.0144     |
# |    value_loss           | 0.00013     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.153       |
# | time/                   |             |
# |    fps                  | 772         |
# |    iterations           | 11          |
# |    time_elapsed         | 18          |
# |    total_timesteps      | 14080       |
# | train/                  |             |
# |    approx_kl            | 0.018109161 |
# |    clip_fraction        | 0.308       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.838      |
# |    explained_variance   | 0.195       |
# |    learning_rate        | 0.0014      |
# |    loss                 | -0.0251     |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.0137     |
# |    value_loss           | 7.79e-05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.173       |
# | time/                   |             |
# |    fps                  | 784         |
# |    iterations           | 12          |
# |    time_elapsed         | 19          |
# |    total_timesteps      | 15360       |
# | train/                  |             |
# |    approx_kl            | 0.027142301 |
# |    clip_fraction        | 0.287       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.771      |
# |    explained_variance   | 0.194       |
# |    learning_rate        | 0.0014      |
# |    loss                 | -0.017      |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.00679    |
# |    value_loss           | 6.56e-05    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 335        |
# |    ep_rew_mean          | 0.203      |
# | time/                   |            |
# |    fps                  | 796        |
# |    iterations           | 13         |
# |    time_elapsed         | 20         |
# |    total_timesteps      | 16640      |
# | train/                  |            |
# |    approx_kl            | 0.02034342 |
# |    clip_fraction        | 0.185      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.698     |
# |    explained_variance   | 0.328      |
# |    learning_rate        | 0.0014     |
# |    loss                 | 0.00195    |
# |    n_updates            | 120        |
# |    policy_gradient_loss | -0.00857   |
# |    value_loss           | 7.78e-05   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.234       |
# | time/                   |             |
# |    fps                  | 803         |
# |    iterations           | 14          |
# |    time_elapsed         | 22          |
# |    total_timesteps      | 17920       |
# | train/                  |             |
# |    approx_kl            | 0.031502265 |
# |    clip_fraction        | 0.195       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.624      |
# |    explained_variance   | 0.516       |
# |    learning_rate        | 0.0014      |
# |    loss                 | 0.0208      |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.00631    |
# |    value_loss           | 6.14e-05    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 335        |
# |    ep_rew_mean          | 0.259      |
# | time/                   |            |
# |    fps                  | 799        |
# |    iterations           | 15         |
# |    time_elapsed         | 24         |
# |    total_timesteps      | 19200      |
# | train/                  |            |
# |    approx_kl            | 0.13211763 |
# |    clip_fraction        | 0.221      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.571     |
# |    explained_variance   | 0.559      |
# |    learning_rate        | 0.0014     |
# |    loss                 | -0.00786   |
# |    n_updates            | 140        |
# |    policy_gradient_loss | 0.00783    |
# |    value_loss           | 4.93e-05   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 335        |
# |    ep_rew_mean          | 0.282      |
# | time/                   |            |
# |    fps                  | 801        |
# |    iterations           | 16         |
# |    time_elapsed         | 25         |
# |    total_timesteps      | 20480      |
# | train/                  |            |
# |    approx_kl            | 0.05907523 |
# |    clip_fraction        | 0.162      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.503     |
# |    explained_variance   | 0.56       |
# |    learning_rate        | 0.0014     |
# |    loss                 | -0.00521   |
# |    n_updates            | 150        |
# |    policy_gradient_loss | 0.00119    |
# |    value_loss           | 0.000381   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 335        |
# |    ep_rew_mean          | 0.301      |
# | time/                   |            |
# |    fps                  | 801        |
# |    iterations           | 17         |
# |    time_elapsed         | 27         |
# |    total_timesteps      | 21760      |
# | train/                  |            |
# |    approx_kl            | 0.04707661 |
# |    clip_fraction        | 0.258      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.523     |
# |    explained_variance   | 0.561      |
# |    learning_rate        | 0.0014     |
# |    loss                 | -0.0157    |
# |    n_updates            | 160        |
# |    policy_gradient_loss | 0.0104     |
# |    value_loss           | 5.8e-05    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.326       |
# | time/                   |             |
# |    fps                  | 808         |
# |    iterations           | 18          |
# |    time_elapsed         | 28          |
# |    total_timesteps      | 23040       |
# | train/                  |             |
# |    approx_kl            | 0.017700663 |
# |    clip_fraction        | 0.267       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.52       |
# |    explained_variance   | 0.505       |
# |    learning_rate        | 0.0014      |
# |    loss                 | 0.0173      |
# |    n_updates            | 170         |
# |    policy_gradient_loss | 0.0172      |
# |    value_loss           | 6.75e-05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.348       |
# | time/                   |             |
# |    fps                  | 814         |
# |    iterations           | 19          |
# |    time_elapsed         | 29          |
# |    total_timesteps      | 24320       |
# | train/                  |             |
# |    approx_kl            | 0.054441214 |
# |    clip_fraction        | 0.251       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.515      |
# |    explained_variance   | 0.552       |
# |    learning_rate        | 0.0014      |
# |    loss                 | -0.0166     |
# |    n_updates            | 180         |
# |    policy_gradient_loss | 0.0221      |
# |    value_loss           | 5.77e-05    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 335        |
# |    ep_rew_mean          | 0.371      |
# | time/                   |            |
# |    fps                  | 820        |
# |    iterations           | 20         |
# |    time_elapsed         | 31         |
# |    total_timesteps      | 25600      |
# | train/                  |            |
# |    approx_kl            | 0.01662432 |
# |    clip_fraction        | 0.257      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.456     |
# |    explained_variance   | 0.647      |
# |    learning_rate        | 0.0014     |
# |    loss                 | -0.0165    |
# |    n_updates            | 190        |
# |    policy_gradient_loss | 0.0172     |
# |    value_loss           | 0.000135   |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 335       |
# |    ep_rew_mean          | 0.387     |
# | time/                   |           |
# |    fps                  | 824       |
# |    iterations           | 21        |
# |    time_elapsed         | 32        |
# |    total_timesteps      | 26880     |
# | train/                  |           |
# |    approx_kl            | 0.0994866 |
# |    clip_fraction        | 0.365     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.425    |
# |    explained_variance   | 0.578     |
# |    learning_rate        | 0.0014    |
# |    loss                 | 0.0441    |
# |    n_updates            | 200       |
# |    policy_gradient_loss | 0.0447    |
# |    value_loss           | 0.000519  |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.409       |
# | time/                   |             |
# |    fps                  | 829         |
# |    iterations           | 22          |
# |    time_elapsed         | 33          |
# |    total_timesteps      | 28160       |
# | train/                  |             |
# |    approx_kl            | 0.027595282 |
# |    clip_fraction        | 0.295       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.516      |
# |    explained_variance   | 0.435       |
# |    learning_rate        | 0.0014      |
# |    loss                 | -0.0262     |
# |    n_updates            | 210         |
# |    policy_gradient_loss | 0.0142      |
# |    value_loss           | 0.000417    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 335        |
# |    ep_rew_mean          | 0.422      |
# | time/                   |            |
# |    fps                  | 834        |
# |    iterations           | 23         |
# |    time_elapsed         | 35         |
# |    total_timesteps      | 29440      |
# | train/                  |            |
# |    approx_kl            | 0.06747358 |
# |    clip_fraction        | 0.213      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.441     |
# |    explained_variance   | 0.471      |
# |    learning_rate        | 0.0014     |
# |    loss                 | 0.142      |
# |    n_updates            | 220        |
# |    policy_gradient_loss | 0.00848    |
# |    value_loss           | 0.000202   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 335        |
# |    ep_rew_mean          | 0.437      |
# | time/                   |            |
# |    fps                  | 838        |
# |    iterations           | 24         |
# |    time_elapsed         | 36         |
# |    total_timesteps      | 30720      |
# | train/                  |            |
# |    approx_kl            | 0.09185018 |
# |    clip_fraction        | 0.242      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.416     |
# |    explained_variance   | 0.575      |
# |    learning_rate        | 0.0014     |
# |    loss                 | 0.0417     |
# |    n_updates            | 230        |
# |    policy_gradient_loss | 0.0204     |
# |    value_loss           | 0.00121    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.449       |
# | time/                   |             |
# |    fps                  | 843         |
# |    iterations           | 25          |
# |    time_elapsed         | 37          |
# |    total_timesteps      | 32000       |
# | train/                  |             |
# |    approx_kl            | 0.024611035 |
# |    clip_fraction        | 0.211       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.393      |
# |    explained_variance   | 0.258       |
# |    learning_rate        | 0.0014      |
# |    loss                 | 0.0362      |
# |    n_updates            | 240         |
# |    policy_gradient_loss | 0.0215      |
# |    value_loss           | 0.000866    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.458       |
# | time/                   |             |
# |    fps                  | 839         |
# |    iterations           | 26          |
# |    time_elapsed         | 39          |
# |    total_timesteps      | 33280       |
# | train/                  |             |
# |    approx_kl            | 0.026112039 |
# |    clip_fraction        | 0.224       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.351      |
# |    explained_variance   | 0.44        |
# |    learning_rate        | 0.0014      |
# |    loss                 | 0.0383      |
# |    n_updates            | 250         |
# |    policy_gradient_loss | 0.0158      |
# |    value_loss           | 0.00205     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 335        |
# |    ep_rew_mean          | 0.485      |
# | time/                   |            |
# |    fps                  | 838        |
# |    iterations           | 27         |
# |    time_elapsed         | 41         |
# |    total_timesteps      | 34560      |
# | train/                  |            |
# |    approx_kl            | 0.08768247 |
# |    clip_fraction        | 0.232      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.328     |
# |    explained_variance   | 0.243      |
# |    learning_rate        | 0.0014     |
# |    loss                 | 0.0398     |
# |    n_updates            | 260        |
# |    policy_gradient_loss | 0.0288     |
# |    value_loss           | 0.000878   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.515       |
# | time/                   |             |
# |    fps                  | 836         |
# |    iterations           | 28          |
# |    time_elapsed         | 42          |
# |    total_timesteps      | 35840       |
# | train/                  |             |
# |    approx_kl            | 0.026102329 |
# |    clip_fraction        | 0.21        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.36       |
# |    explained_variance   | 0.33        |
# |    learning_rate        | 0.0014      |
# |    loss                 | 0.00796     |
# |    n_updates            | 270         |
# |    policy_gradient_loss | 0.0164      |
# |    value_loss           | 0.000313    |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 335       |
# |    ep_rew_mean          | 0.549     |
# | time/                   |           |
# |    fps                  | 839       |
# |    iterations           | 29        |
# |    time_elapsed         | 44        |
# |    total_timesteps      | 37120     |
# | train/                  |           |
# |    approx_kl            | 0.1518743 |
# |    clip_fraction        | 0.203     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.348    |
# |    explained_variance   | 0.418     |
# |    learning_rate        | 0.0014    |
# |    loss                 | 0.0502    |
# |    n_updates            | 280       |
# |    policy_gradient_loss | 0.021     |
# |    value_loss           | 0.000239  |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.58        |
# | time/                   |             |
# |    fps                  | 841         |
# |    iterations           | 30          |
# |    time_elapsed         | 45          |
# |    total_timesteps      | 38400       |
# | train/                  |             |
# |    approx_kl            | 0.099538155 |
# |    clip_fraction        | 0.21        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.304      |
# |    explained_variance   | 0.473       |
# |    learning_rate        | 0.0014      |
# |    loss                 | -0.00592    |
# |    n_updates            | 290         |
# |    policy_gradient_loss | 0.00995     |
# |    value_loss           | 6.21e-05    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 335        |
# |    ep_rew_mean          | 0.598      |
# | time/                   |            |
# |    fps                  | 844        |
# |    iterations           | 31         |
# |    time_elapsed         | 46         |
# |    total_timesteps      | 39680      |
# | train/                  |            |
# |    approx_kl            | 0.10818135 |
# |    clip_fraction        | 0.221      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.282     |
# |    explained_variance   | 0.537      |
# |    learning_rate        | 0.0014     |
# |    loss                 | 0.122      |
# |    n_updates            | 300        |
# |    policy_gradient_loss | 0.0299     |
# |    value_loss           | 9.39e-05   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.622       |
# | time/                   |             |
# |    fps                  | 847         |
# |    iterations           | 32          |
# |    time_elapsed         | 48          |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.043857608 |
# |    clip_fraction        | 0.2         |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.259      |
# |    explained_variance   | 0.321       |
# |    learning_rate        | 0.0014      |
# |    loss                 | -0.0215     |
# |    n_updates            | 310         |
# |    policy_gradient_loss | 0.0104      |
# |    value_loss           | 0.000131    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 335        |
# |    ep_rew_mean          | 0.642      |
# | time/                   |            |
# |    fps                  | 850        |
# |    iterations           | 33         |
# |    time_elapsed         | 49         |
# |    total_timesteps      | 42240      |
# | train/                  |            |
# |    approx_kl            | 0.05654036 |
# |    clip_fraction        | 0.233      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.284     |
# |    explained_variance   | 0.503      |
# |    learning_rate        | 0.0014     |
# |    loss                 | -0.0194    |
# |    n_updates            | 320        |
# |    policy_gradient_loss | 0.0121     |
# |    value_loss           | 0.0015     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 335        |
# |    ep_rew_mean          | 0.663      |
# | time/                   |            |
# |    fps                  | 853        |
# |    iterations           | 34         |
# |    time_elapsed         | 50         |
# |    total_timesteps      | 43520      |
# | train/                  |            |
# |    approx_kl            | 0.09220731 |
# |    clip_fraction        | 0.209      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.29      |
# |    explained_variance   | 0.212      |
# |    learning_rate        | 0.0014     |
# |    loss                 | 0.00496    |
# |    n_updates            | 330        |
# |    policy_gradient_loss | 0.00363    |
# |    value_loss           | 0.000121   |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 335       |
# |    ep_rew_mean          | 0.689     |
# | time/                   |           |
# |    fps                  | 855       |
# |    iterations           | 35        |
# |    time_elapsed         | 52        |
# |    total_timesteps      | 44800     |
# | train/                  |           |
# |    approx_kl            | 0.0795505 |
# |    clip_fraction        | 0.229     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.255    |
# |    explained_variance   | 0.279     |
# |    learning_rate        | 0.0014    |
# |    loss                 | -0.000602 |
# |    n_updates            | 340       |
# |    policy_gradient_loss | 0.0405    |
# |    value_loss           | 0.000103  |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.711       |
# | time/                   |             |
# |    fps                  | 858         |
# |    iterations           | 36          |
# |    time_elapsed         | 53          |
# |    total_timesteps      | 46080       |
# | train/                  |             |
# |    approx_kl            | 0.023920393 |
# |    clip_fraction        | 0.244       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.27       |
# |    explained_variance   | 0.43        |
# |    learning_rate        | 0.0014      |
# |    loss                 | 0.0535      |
# |    n_updates            | 350         |
# |    policy_gradient_loss | 0.0457      |
# |    value_loss           | 8.05e-05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.732       |
# | time/                   |             |
# |    fps                  | 855         |
# |    iterations           | 37          |
# |    time_elapsed         | 55          |
# |    total_timesteps      | 47360       |
# | train/                  |             |
# |    approx_kl            | 0.030978922 |
# |    clip_fraction        | 0.196       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.26       |
# |    explained_variance   | 0.507       |
# |    learning_rate        | 0.0014      |
# |    loss                 | 0.00088     |
# |    n_updates            | 360         |
# |    policy_gradient_loss | 0.0206      |
# |    value_loss           | 0.000815    |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 335       |
# |    ep_rew_mean          | 0.751     |
# | time/                   |           |
# |    fps                  | 853       |
# |    iterations           | 38        |
# |    time_elapsed         | 56        |
# |    total_timesteps      | 48640     |
# | train/                  |           |
# |    approx_kl            | 0.1000361 |
# |    clip_fraction        | 0.193     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.232    |
# |    explained_variance   | 0.4       |
# |    learning_rate        | 0.0014    |
# |    loss                 | -0.0139   |
# |    n_updates            | 370       |
# |    policy_gradient_loss | 0.0198    |
# |    value_loss           | 0.00131   |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.766       |
# | time/                   |             |
# |    fps                  | 852         |
# |    iterations           | 39          |
# |    time_elapsed         | 58          |
# |    total_timesteps      | 49920       |
# | train/                  |             |
# |    approx_kl            | 0.053618386 |
# |    clip_fraction        | 0.168       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.233      |
# |    explained_variance   | 0.339       |
# |    learning_rate        | 0.0014      |
# |    loss                 | 0.0969      |
# |    n_updates            | 380         |
# |    policy_gradient_loss | 0.0118      |
# |    value_loss           | 0.000163    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 335        |
# |    ep_rew_mean          | 0.774      |
# | time/                   |            |
# |    fps                  | 853        |
# |    iterations           | 40         |
# |    time_elapsed         | 59         |
# |    total_timesteps      | 51200      |
# | train/                  |            |
# |    approx_kl            | 0.08417055 |
# |    clip_fraction        | 0.244      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.254     |
# |    explained_variance   | 0.372      |
# |    learning_rate        | 0.0014     |
# |    loss                 | 0.0261     |
# |    n_updates            | 390        |
# |    policy_gradient_loss | 0.0268     |
# |    value_loss           | 0.000275   |
# ----------------------------------------
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 335      |
# |    ep_rew_mean     | 0.0338   |
# | time/              |          |
# |    fps             | 1379     |
# |    iterations      | 1        |
# |    time_elapsed    | 1        |
# |    total_timesteps | 2048     |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 335          |
# |    ep_rew_mean          | 0.00157      |
# | time/                   |              |
# |    fps                  | 908          |
# |    iterations           | 2            |
# |    time_elapsed         | 4            |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0077249324 |
# |    clip_fraction        | 0.0343       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.09        |
# |    explained_variance   | -3.12        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0117       |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.00277     |
# |    value_loss           | 0.0029       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | -0.0294     |
# | time/                   |             |
# |    fps                  | 814         |
# |    iterations           | 3           |
# |    time_elapsed         | 7           |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.005667554 |
# |    clip_fraction        | 0.0547      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.07       |
# |    explained_variance   | 0.0448      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.000751   |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.00201    |
# |    value_loss           | 0.000612    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | -0.0245     |
# | time/                   |             |
# |    fps                  | 761         |
# |    iterations           | 4           |
# |    time_elapsed         | 10          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.006807959 |
# |    clip_fraction        | 0.0837      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.04       |
# |    explained_variance   | 0.642       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0164     |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.00504    |
# |    value_loss           | 0.00037     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | -0.0157     |
# | time/                   |             |
# |    fps                  | 716         |
# |    iterations           | 5           |
# |    time_elapsed         | 14          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.009282796 |
# |    clip_fraction        | 0.078       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.08       |
# |    explained_variance   | 0.744       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0205     |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.00769    |
# |    value_loss           | 0.000401    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | -0.0123     |
# | time/                   |             |
# |    fps                  | 706         |
# |    iterations           | 6           |
# |    time_elapsed         | 17          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.011498071 |
# |    clip_fraction        | 0.135       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.08       |
# |    explained_variance   | 0.805       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0065     |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.00883    |
# |    value_loss           | 0.000322    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | -0.00173    |
# | time/                   |             |
# |    fps                  | 703         |
# |    iterations           | 7           |
# |    time_elapsed         | 20          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.010337621 |
# |    clip_fraction        | 0.0943      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.08       |
# |    explained_variance   | 0.761       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00676    |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.00607    |
# |    value_loss           | 0.000364    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.00988     |
# | time/                   |             |
# |    fps                  | 702         |
# |    iterations           | 8           |
# |    time_elapsed         | 23          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.010792041 |
# |    clip_fraction        | 0.137       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.05       |
# |    explained_variance   | 0.771       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.012       |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0109     |
# |    value_loss           | 0.00029     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.0286      |
# | time/                   |             |
# |    fps                  | 697         |
# |    iterations           | 9           |
# |    time_elapsed         | 26          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.008667149 |
# |    clip_fraction        | 0.148       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.02       |
# |    explained_variance   | 0.743       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00914    |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.0119     |
# |    value_loss           | 0.000263    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.0556      |
# | time/                   |             |
# |    fps                  | 681         |
# |    iterations           | 10          |
# |    time_elapsed         | 30          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.012096041 |
# |    clip_fraction        | 0.167       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.97       |
# |    explained_variance   | 0.67        |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00659    |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.00936    |
# |    value_loss           | 0.000288    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 335          |
# |    ep_rew_mean          | 0.0842       |
# | time/                   |              |
# |    fps                  | 686          |
# |    iterations           | 11           |
# |    time_elapsed         | 32           |
# |    total_timesteps      | 22528        |
# | train/                  |              |
# |    approx_kl            | 0.0092219645 |
# |    clip_fraction        | 0.125        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.91        |
# |    explained_variance   | 0.649        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00215     |
# |    n_updates            | 100          |
# |    policy_gradient_loss | -0.00462     |
# |    value_loss           | 0.000238     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.111       |
# | time/                   |             |
# |    fps                  | 696         |
# |    iterations           | 12          |
# |    time_elapsed         | 35          |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.010566114 |
# |    clip_fraction        | 0.126       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.847      |
# |    explained_variance   | 0.481       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0172     |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.00871    |
# |    value_loss           | 0.000276    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.136       |
# | time/                   |             |
# |    fps                  | 705         |
# |    iterations           | 13          |
# |    time_elapsed         | 37          |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.008815374 |
# |    clip_fraction        | 0.135       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.798      |
# |    explained_variance   | 0.335       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00012    |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.0015     |
# |    value_loss           | 0.000258    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.161       |
# | time/                   |             |
# |    fps                  | 714         |
# |    iterations           | 14          |
# |    time_elapsed         | 40          |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.011810928 |
# |    clip_fraction        | 0.157       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.736      |
# |    explained_variance   | 0.402       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0238     |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.00573    |
# |    value_loss           | 0.000178    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.185       |
# | time/                   |             |
# |    fps                  | 717         |
# |    iterations           | 15          |
# |    time_elapsed         | 42          |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.014949222 |
# |    clip_fraction        | 0.149       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.725      |
# |    explained_variance   | 0.59        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.01        |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.00202    |
# |    value_loss           | 0.000158    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.211       |
# | time/                   |             |
# |    fps                  | 716         |
# |    iterations           | 16          |
# |    time_elapsed         | 45          |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.014121791 |
# |    clip_fraction        | 0.152       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.627      |
# |    explained_variance   | 0.674       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00615    |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.00685    |
# |    value_loss           | 0.000244    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 335          |
# |    ep_rew_mean          | 0.241        |
# | time/                   |              |
# |    fps                  | 721          |
# |    iterations           | 17           |
# |    time_elapsed         | 48           |
# |    total_timesteps      | 34816        |
# | train/                  |              |
# |    approx_kl            | 0.0076536513 |
# |    clip_fraction        | 0.128        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.591       |
# |    explained_variance   | 0.751        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.031       |
# |    n_updates            | 160          |
# |    policy_gradient_loss | -0.000674    |
# |    value_loss           | 0.000172     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.289       |
# | time/                   |             |
# |    fps                  | 727         |
# |    iterations           | 18          |
# |    time_elapsed         | 50          |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.009898257 |
# |    clip_fraction        | 0.129       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.587      |
# |    explained_variance   | 0.83        |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0142     |
# |    n_updates            | 170         |
# |    policy_gradient_loss | 0.000523    |
# |    value_loss           | 0.00014     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.332       |
# | time/                   |             |
# |    fps                  | 732         |
# |    iterations           | 19          |
# |    time_elapsed         | 53          |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.006871758 |
# |    clip_fraction        | 0.124       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.584      |
# |    explained_variance   | 0.86        |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00422    |
# |    n_updates            | 180         |
# |    policy_gradient_loss | 0.00265     |
# |    value_loss           | 0.000174    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.377       |
# | time/                   |             |
# |    fps                  | 736         |
# |    iterations           | 20          |
# |    time_elapsed         | 55          |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.008987637 |
# |    clip_fraction        | 0.114       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.573      |
# |    explained_variance   | 0.869       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00858    |
# |    n_updates            | 190         |
# |    policy_gradient_loss | 0.00322     |
# |    value_loss           | 0.000313    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.422       |
# | time/                   |             |
# |    fps                  | 738         |
# |    iterations           | 21          |
# |    time_elapsed         | 58          |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.017930072 |
# |    clip_fraction        | 0.156       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.534      |
# |    explained_variance   | 0.86        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0256      |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.00277    |
# |    value_loss           | 0.000148    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.466       |
# | time/                   |             |
# |    fps                  | 735         |
# |    iterations           | 22          |
# |    time_elapsed         | 61          |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.013140202 |
# |    clip_fraction        | 0.125       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.493      |
# |    explained_variance   | 0.853       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.01       |
# |    n_updates            | 210         |
# |    policy_gradient_loss | 0.00534     |
# |    value_loss           | 0.000255    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.51        |
# | time/                   |             |
# |    fps                  | 737         |
# |    iterations           | 23          |
# |    time_elapsed         | 63          |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.019041639 |
# |    clip_fraction        | 0.136       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.482      |
# |    explained_variance   | 0.876       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0033     |
# |    n_updates            | 220         |
# |    policy_gradient_loss | 0.00444     |
# |    value_loss           | 0.000218    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 335        |
# |    ep_rew_mean          | 0.557      |
# | time/                   |            |
# |    fps                  | 740        |
# |    iterations           | 24         |
# |    time_elapsed         | 66         |
# |    total_timesteps      | 49152      |
# | train/                  |            |
# |    approx_kl            | 0.02299912 |
# |    clip_fraction        | 0.143      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.451     |
# |    explained_variance   | 0.893      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.225      |
# |    n_updates            | 230        |
# |    policy_gradient_loss | 0.0053     |
# |    value_loss           | 9.86e-05   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.598       |
# | time/                   |             |
# |    fps                  | 742         |
# |    iterations           | 25          |
# |    time_elapsed         | 69          |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.014097875 |
# |    clip_fraction        | 0.147       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.45       |
# |    explained_variance   | 0.896       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0344      |
# |    n_updates            | 240         |
# |    policy_gradient_loss | 0.0105      |
# |    value_loss           | 0.000286    |
# -----------------------------------------
#          Method  Cumulative Return  Sharpe Ratio  Sortino Ratio  Max Drawdown
# 0   Bi-LSTM PPO           1.858912      0.485975       1.103435     -0.009313
# 1    Simple PPO           1.891417      0.492507       1.117175     -0.009223
# 2  Buy-and-Hold           1.634423           NaN            NaN           NaN
