# %%
import pandas as pd
import numpy as np
import torch
import torch.nn as nn
from sklearn.preprocessing import MinMaxScaler
from torch.utils.data import DataLoader, TensorDataset
from stable_baselines3 import PPO
from gym import spaces, Env
import matplotlib.pyplot as plt
import random

# Set seed for reproducibility
SEED = 42
random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)
if torch.cuda.is_available():
    torch.cuda.manual_seed_all(SEED)

# Load and preprocess data
def load_and_preprocess(file_name):
    data = pd.read_csv(file_name)
    data["Date"] = pd.to_datetime(data["Date"])
    data = data.sort_values(by="Date")
    
    numeric_data = data.drop(columns=["Date"])
    numeric_data = numeric_data[['Close'] + [col for col in numeric_data.columns if col != 'Close']]
    
    scaler = MinMaxScaler()
    normalized_data = scaler.fit_transform(numeric_data)
    data[numeric_data.columns] = normalized_data
    
    return data, scaler

# Create sequences for time series modeling
def create_sequences(data, sequence_length=30):
    sequences = []
    targets = []
    for i in range(len(data) - sequence_length):
        seq = data[i:i+sequence_length]
        target = data[i+sequence_length, 0]  # Assuming the target is the first column (e.g., Close price)
        sequences.append(seq)
        targets.append(target)
    return np.array(sequences), np.array(targets)

# Define Bi-LSTM model
class BiLSTMModel(nn.Module):
    def __init__(self, input_dim, hidden_dim, num_layers, dropout):
        super(BiLSTMModel, self).__init__()
        self.bilstm = nn.LSTM(input_dim, hidden_dim, num_layers, batch_first=True, dropout=dropout, bidirectional=True)
        self.fc = nn.Linear(hidden_dim * 2, 1)

    def forward(self, x):
        bilstm_out, _ = self.bilstm(x)
        return self.fc(bilstm_out[:, -1, :])

# Custom trading environment
class TradingEnv(Env):
    def __init__(self, data, sequence_length=30):
        super(TradingEnv, self).__init__()
        self.data = data
        self.sequence_length = sequence_length
        self.current_step = 0
        self.total_steps = len(data) - sequence_length
        self.portfolio_value = 1.0

        # Action and observation space
        self.action_space = spaces.Discrete(3)  # 0: Hold, 1: Buy, 2: Sell
        self.observation_space = spaces.Box(low=0, high=1, shape=(sequence_length, data.shape[1]), dtype=np.float32)

    def reset(self):
        self.current_step = 0
        self.portfolio_value = 1.0
        return self._next_observation()

    def _next_observation(self):
        return self.data[self.current_step:self.current_step + self.sequence_length]

    def step(self, action):
        self.current_step += 1
        reward = 0
        done = self.current_step >= self.total_steps

        if not done:
            current_price = self.data[self.current_step, 0]
            prev_price = self.data[self.current_step - 1, 0]

            if action == 1:  # Buy
                reward = current_price - prev_price
            elif action == 2:  # Sell
                reward = prev_price - current_price

        self.portfolio_value += reward
        obs = self._next_observation() if not done else None
        return obs, reward, done, {"portfolio_value": self.portfolio_value}

# Evaluate trading strategy
def evaluate_trading_strategy(env, model):
    obs = env.reset()
    done = False
    portfolio_values = [1.0]

    while not done:
        action, _ = model.predict(obs, deterministic=True)
        obs, reward, done, info = env.step(action)
        portfolio_values.append(info.get("portfolio_value", 1.0))

    return portfolio_values

# Performance metrics
def calculate_metrics(portfolio_values):
    daily_returns = np.diff(portfolio_values) / portfolio_values[:-1]
    cumulative_return = portfolio_values[-1] / portfolio_values[0] - 1
    sharpe_ratio = np.mean(daily_returns) / np.std(daily_returns) if np.std(daily_returns) > 0 else 0
    sortino_ratio = np.mean(daily_returns) / np.std([r for r in daily_returns if r < 0]) if np.std([r for r in daily_returns if r < 0]) > 0 else 0
    max_drawdown = np.min(portfolio_values / np.maximum.accumulate(portfolio_values) - 1)
    return cumulative_return, sharpe_ratio, sortino_ratio, max_drawdown

# Main execution
if __name__ == "__main__":
    # Load data
    data, scaler = load_and_preprocess("Book2.csv")
    train_data = data[(data["Date"].dt.year >= 2017) & (data["Date"].dt.year <= 2021)].drop(columns=["Date"]).values
    test_data = data[data["Date"].dt.year == 2022].drop(columns=["Date"]).values

    X_train, y_train = create_sequences(train_data)
    X_test, y_test = create_sequences(test_data)

    # Train Bi-LSTM model
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    bilstm_model = BiLSTMModel(input_dim=X_train.shape[2], hidden_dim=224, num_layers=1, dropout=0.14).to(device)
    criterion = nn.MSELoss()
    optimizer = torch.optim.Adam(bilstm_model.parameters(), lr=0.0019)

    train_loader = DataLoader(TensorDataset(torch.tensor(X_train, dtype=torch.float32), torch.tensor(y_train, dtype=torch.float32)), batch_size=32, shuffle=True)

    for epoch in range(50):
        bilstm_model.train()
        train_loss = 0.0
        for X_batch, y_batch in train_loader:
            X_batch, y_batch = X_batch.to(device), y_batch.to(device)
            optimizer.zero_grad()
            predictions = bilstm_model(X_batch).squeeze()
            loss = criterion(predictions, y_batch)
            loss.backward()
            optimizer.step()
            train_loss += loss.item()

    # Create environments for PPO
    bilstm_env = TradingEnv(test_data)
    simple_env = TradingEnv(test_data)

    # Train PPO models
    ppo_bilstm_model = PPO("MlpPolicy", bilstm_env, learning_rate=0.0014, batch_size=160, n_steps=1280, gamma=0.9005911776350177, verbose=1)
    ppo_bilstm_model.learn(total_timesteps=50000)

    ppo_simple_model = PPO("MlpPolicy", simple_env, verbose=1)
    ppo_simple_model.learn(total_timesteps=50000)

    # Evaluate strategies
    portfolio_values_bilstm = evaluate_trading_strategy(bilstm_env, ppo_bilstm_model)
    portfolio_values_simple = evaluate_trading_strategy(simple_env, ppo_simple_model)

    cumulative_return_bilstm, sharpe_bilstm, sortino_bilstm, max_drawdown_bilstm = calculate_metrics(portfolio_values_bilstm)
    cumulative_return_simple, sharpe_simple, sortino_simple, max_drawdown_simple = calculate_metrics(portfolio_values_simple)

    # Buy-and-Hold strategy
    buy_hold_return = test_data[-1, 0] / test_data[0, 0] - 1

    # Generate date range for 2022
    test_dates = pd.date_range(start="2022-01-01", periods=len(portfolio_values_bilstm))

    # Calculate cumulative returns
    cumulative_returns_bilstm = np.cumprod([1 + r for r in np.diff(portfolio_values_bilstm) / portfolio_values_bilstm[:-1]])
    cumulative_returns_simple = np.cumprod([1 + r for r in np.diff(portfolio_values_simple) / portfolio_values_simple[:-1]])

    # Plot cumulative returns
    plt.figure(figsize=(12, 6))
    plt.plot(test_dates[1:], cumulative_returns_bilstm, label="Bi-LSTM PPO")
    plt.plot(test_dates[1:], cumulative_returns_simple, label="Simple PPO")
    plt.gca().xaxis.set_major_formatter(plt.matplotlib.dates.DateFormatter("%b %Y"))
    plt.gca().xaxis.set_major_locator(plt.matplotlib.dates.MonthLocator())

    plt.legend()
    plt.title("Cumulative Returns")
    plt.xlabel("Date")
    plt.ylabel("Cumulative Return")
    plt.grid()
    plt.show()

    # Print results
    results = pd.DataFrame({
        "Method": ["Bi-LSTM PPO", "Simple PPO", "Buy-and-Hold"],
        "Cumulative Return": [cumulative_returns_bilstm[-1], cumulative_returns_simple[-1], buy_hold_return],
        "Sharpe Ratio": [sharpe_bilstm, sharpe_simple, None],
        "Sortino Ratio": [sortino_bilstm, sortino_simple, None],
        "Max Drawdown": [max_drawdown_bilstm, max_drawdown_simple, None]
    })
    print(results)
# Out:
# C:\Users\User\anaconda3\envs\RL\Lib\site-packages\torch\nn\modules\rnn.py:123: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.14 and num_layers=1
#   warnings.warn(
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# C:\Users\User\anaconda3\envs\RL\Lib\site-packages\stable_baselines3\common\vec_env\patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 335      |
# |    ep_rew_mean     | 0.0221   |
# | time/              |          |
# |    fps             | 907      |
# |    iterations      | 1        |
# |    time_elapsed    | 1        |
# |    total_timesteps | 1280     |
# ---------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 335        |
# |    ep_rew_mean          | -0.00963   |
# | time/                   |            |
# |    fps                  | 793        |
# |    iterations           | 2          |
# |    time_elapsed         | 3          |
# |    total_timesteps      | 2560       |
# | train/                  |            |
# |    approx_kl            | 0.01219992 |
# |    clip_fraction        | 0.135      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.09      |
# |    explained_variance   | -7.21      |
# |    learning_rate        | 0.0014     |
# |    loss                 | -0.0167    |
# |    n_updates            | 10         |
# |    policy_gradient_loss | -0.0108    |
# |    value_loss           | 0.0235     |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | -0.000874   |
# | time/                   |             |
# |    fps                  | 771         |
# |    iterations           | 3           |
# |    time_elapsed         | 4           |
# |    total_timesteps      | 3840        |
# | train/                  |             |
# |    approx_kl            | 0.009940486 |
# |    clip_fraction        | 0.128       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.07       |
# |    explained_variance   | -2.91       |
# |    learning_rate        | 0.0014      |
# |    loss                 | -0.00601    |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.00749    |
# |    value_loss           | 0.000524    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.0203      |
# | time/                   |             |
# |    fps                  | 786         |
# |    iterations           | 4           |
# |    time_elapsed         | 6           |
# |    total_timesteps      | 5120        |
# | train/                  |             |
# |    approx_kl            | 0.009738601 |
# |    clip_fraction        | 0.164       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.05       |
# |    explained_variance   | -0.871      |
# |    learning_rate        | 0.0014      |
# |    loss                 | -0.0399     |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0114     |
# |    value_loss           | 0.000253    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.0558      |
# | time/                   |             |
# |    fps                  | 794         |
# |    iterations           | 5           |
# |    time_elapsed         | 8           |
# |    total_timesteps      | 6400        |
# | train/                  |             |
# |    approx_kl            | 0.009765657 |
# |    clip_fraction        | 0.171       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.01       |
# |    explained_variance   | -0.585      |
# |    learning_rate        | 0.0014      |
# |    loss                 | -0.0198     |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0106     |
# |    value_loss           | 0.000187    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.0758      |
# | time/                   |             |
# |    fps                  | 799         |
# |    iterations           | 6           |
# |    time_elapsed         | 9           |
# |    total_timesteps      | 7680        |
# | train/                  |             |
# |    approx_kl            | 0.011450731 |
# |    clip_fraction        | 0.207       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.961      |
# |    explained_variance   | -0.379      |
# |    learning_rate        | 0.0014      |
# |    loss                 | -0.0296     |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0181     |
# |    value_loss           | 0.000141    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 335        |
# |    ep_rew_mean          | 0.103      |
# | time/                   |            |
# |    fps                  | 802        |
# |    iterations           | 7          |
# |    time_elapsed         | 11         |
# |    total_timesteps      | 8960       |
# | train/                  |            |
# |    approx_kl            | 0.01744982 |
# |    clip_fraction        | 0.24       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.877     |
# |    explained_variance   | -0.203     |
# |    learning_rate        | 0.0014     |
# |    loss                 | -0.0182    |
# |    n_updates            | 60         |
# |    policy_gradient_loss | -0.0148    |
# |    value_loss           | 0.000154   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.14        |
# | time/                   |             |
# |    fps                  | 804         |
# |    iterations           | 8           |
# |    time_elapsed         | 12          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.013552547 |
# |    clip_fraction        | 0.245       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.89       |
# |    explained_variance   | -0.139      |
# |    learning_rate        | 0.0014      |
# |    loss                 | -0.015      |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.015      |
# |    value_loss           | 0.000151    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.192       |
# | time/                   |             |
# |    fps                  | 806         |
# |    iterations           | 9           |
# |    time_elapsed         | 14          |
# |    total_timesteps      | 11520       |
# | train/                  |             |
# |    approx_kl            | 0.026047193 |
# |    clip_fraction        | 0.273       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.837      |
# |    explained_variance   | 0.0547      |
# |    learning_rate        | 0.0014      |
# |    loss                 | -0.0146     |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.0153     |
# |    value_loss           | 0.000121    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.246       |
# | time/                   |             |
# |    fps                  | 806         |
# |    iterations           | 10          |
# |    time_elapsed         | 15          |
# |    total_timesteps      | 12800       |
# | train/                  |             |
# |    approx_kl            | 0.022279877 |
# |    clip_fraction        | 0.254       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.789      |
# |    explained_variance   | 0.146       |
# |    learning_rate        | 0.0014      |
# |    loss                 | -0.00447    |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.00965    |
# |    value_loss           | 0.00276     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.297       |
# | time/                   |             |
# |    fps                  | 791         |
# |    iterations           | 11          |
# |    time_elapsed         | 17          |
# |    total_timesteps      | 14080       |
# | train/                  |             |
# |    approx_kl            | 0.034617737 |
# |    clip_fraction        | 0.276       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.739      |
# |    explained_variance   | -0.0061     |
# |    learning_rate        | 0.0014      |
# |    loss                 | -0.0264     |
# |    n_updates            | 100         |
# |    policy_gradient_loss | 0.00391     |
# |    value_loss           | 0.00023     |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 335       |
# |    ep_rew_mean          | 0.34      |
# | time/                   |           |
# |    fps                  | 787       |
# |    iterations           | 12        |
# |    time_elapsed         | 19        |
# |    total_timesteps      | 15360     |
# | train/                  |           |
# |    approx_kl            | 0.0437207 |
# |    clip_fraction        | 0.308     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.644    |
# |    explained_variance   | 0.368     |
# |    learning_rate        | 0.0014    |
# |    loss                 | 0.00868   |
# |    n_updates            | 110       |
# |    policy_gradient_loss | 0.0105    |
# |    value_loss           | 0.000191  |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.397       |
# | time/                   |             |
# |    fps                  | 784         |
# |    iterations           | 13          |
# |    time_elapsed         | 21          |
# |    total_timesteps      | 16640       |
# | train/                  |             |
# |    approx_kl            | 0.029835872 |
# |    clip_fraction        | 0.254       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.595      |
# |    explained_variance   | 0.51        |
# |    learning_rate        | 0.0014      |
# |    loss                 | 0.0018      |
# |    n_updates            | 120         |
# |    policy_gradient_loss | 0.00897     |
# |    value_loss           | 0.000128    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 335        |
# |    ep_rew_mean          | 0.445      |
# | time/                   |            |
# |    fps                  | 787        |
# |    iterations           | 14         |
# |    time_elapsed         | 22         |
# |    total_timesteps      | 17920      |
# | train/                  |            |
# |    approx_kl            | 0.13468221 |
# |    clip_fraction        | 0.279      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.55      |
# |    explained_variance   | 0.59       |
# |    learning_rate        | 0.0014     |
# |    loss                 | 0.0743     |
# |    n_updates            | 130        |
# |    policy_gradient_loss | 0.0153     |
# |    value_loss           | 0.000137   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.492       |
# | time/                   |             |
# |    fps                  | 789         |
# |    iterations           | 15          |
# |    time_elapsed         | 24          |
# |    total_timesteps      | 19200       |
# | train/                  |             |
# |    approx_kl            | 0.053056665 |
# |    clip_fraction        | 0.32        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.532      |
# |    explained_variance   | 0.645       |
# |    learning_rate        | 0.0014      |
# |    loss                 | 0.0297      |
# |    n_updates            | 140         |
# |    policy_gradient_loss | 0.0211      |
# |    value_loss           | 0.000109    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 335        |
# |    ep_rew_mean          | 0.523      |
# | time/                   |            |
# |    fps                  | 791        |
# |    iterations           | 16         |
# |    time_elapsed         | 25         |
# |    total_timesteps      | 20480      |
# | train/                  |            |
# |    approx_kl            | 0.12487298 |
# |    clip_fraction        | 0.365      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.485     |
# |    explained_variance   | 0.721      |
# |    learning_rate        | 0.0014     |
# |    loss                 | 0.104      |
# |    n_updates            | 150        |
# |    policy_gradient_loss | 0.0445     |
# |    value_loss           | 0.000105   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.549       |
# | time/                   |             |
# |    fps                  | 793         |
# |    iterations           | 17          |
# |    time_elapsed         | 27          |
# |    total_timesteps      | 21760       |
# | train/                  |             |
# |    approx_kl            | 0.026492644 |
# |    clip_fraction        | 0.295       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.466      |
# |    explained_variance   | 0.67        |
# |    learning_rate        | 0.0014      |
# |    loss                 | -0.00843    |
# |    n_updates            | 160         |
# |    policy_gradient_loss | 0.0236      |
# |    value_loss           | 0.000105    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 335        |
# |    ep_rew_mean          | 0.572      |
# | time/                   |            |
# |    fps                  | 795        |
# |    iterations           | 18         |
# |    time_elapsed         | 28         |
# |    total_timesteps      | 23040      |
# | train/                  |            |
# |    approx_kl            | 0.06510852 |
# |    clip_fraction        | 0.253      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.439     |
# |    explained_variance   | 0.715      |
# |    learning_rate        | 0.0014     |
# |    loss                 | 0.019      |
# |    n_updates            | 170        |
# |    policy_gradient_loss | 0.011      |
# |    value_loss           | 0.000125   |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 335       |
# |    ep_rew_mean          | 0.597     |
# | time/                   |           |
# |    fps                  | 797       |
# |    iterations           | 19        |
# |    time_elapsed         | 30        |
# |    total_timesteps      | 24320     |
# | train/                  |           |
# |    approx_kl            | 0.0620781 |
# |    clip_fraction        | 0.226     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.376    |
# |    explained_variance   | 0.656     |
# |    learning_rate        | 0.0014    |
# |    loss                 | -0.03     |
# |    n_updates            | 180       |
# |    policy_gradient_loss | -0.0102   |
# |    value_loss           | 0.000341  |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.619       |
# | time/                   |             |
# |    fps                  | 797         |
# |    iterations           | 20          |
# |    time_elapsed         | 32          |
# |    total_timesteps      | 25600       |
# | train/                  |             |
# |    approx_kl            | 0.045412444 |
# |    clip_fraction        | 0.265       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.355      |
# |    explained_variance   | 0.656       |
# |    learning_rate        | 0.0014      |
# |    loss                 | 0.0321      |
# |    n_updates            | 190         |
# |    policy_gradient_loss | 0.0313      |
# |    value_loss           | 0.00207     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.642       |
# | time/                   |             |
# |    fps                  | 789         |
# |    iterations           | 21          |
# |    time_elapsed         | 34          |
# |    total_timesteps      | 26880       |
# | train/                  |             |
# |    approx_kl            | 0.023102388 |
# |    clip_fraction        | 0.199       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.337      |
# |    explained_variance   | 0.597       |
# |    learning_rate        | 0.0014      |
# |    loss                 | -0.00388    |
# |    n_updates            | 200         |
# |    policy_gradient_loss | 0.00475     |
# |    value_loss           | 0.000661    |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 335       |
# |    ep_rew_mean          | 0.668     |
# | time/                   |           |
# |    fps                  | 787       |
# |    iterations           | 22        |
# |    time_elapsed         | 35        |
# |    total_timesteps      | 28160     |
# | train/                  |           |
# |    approx_kl            | 0.4046258 |
# |    clip_fraction        | 0.29      |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.329    |
# |    explained_variance   | 0.724     |
# |    learning_rate        | 0.0014    |
# |    loss                 | 0.0804    |
# |    n_updates            | 210       |
# |    policy_gradient_loss | 0.0105    |
# |    value_loss           | 0.000184  |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 335        |
# |    ep_rew_mean          | 0.689      |
# | time/                   |            |
# |    fps                  | 786        |
# |    iterations           | 23         |
# |    time_elapsed         | 37         |
# |    total_timesteps      | 29440      |
# | train/                  |            |
# |    approx_kl            | 0.07747854 |
# |    clip_fraction        | 0.285      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.316     |
# |    explained_variance   | 0.732      |
# |    learning_rate        | 0.0014     |
# |    loss                 | 0.0357     |
# |    n_updates            | 220        |
# |    policy_gradient_loss | 0.0511     |
# |    value_loss           | 0.000106   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.715       |
# | time/                   |             |
# |    fps                  | 787         |
# |    iterations           | 24          |
# |    time_elapsed         | 38          |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.026046632 |
# |    clip_fraction        | 0.195       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.298      |
# |    explained_variance   | 0.799       |
# |    learning_rate        | 0.0014      |
# |    loss                 | -0.0111     |
# |    n_updates            | 230         |
# |    policy_gradient_loss | 0.00796     |
# |    value_loss           | 8.33e-05    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 335        |
# |    ep_rew_mean          | 0.739      |
# | time/                   |            |
# |    fps                  | 786        |
# |    iterations           | 25         |
# |    time_elapsed         | 40         |
# |    total_timesteps      | 32000      |
# | train/                  |            |
# |    approx_kl            | 0.11927655 |
# |    clip_fraction        | 0.204      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.264     |
# |    explained_variance   | 0.824      |
# |    learning_rate        | 0.0014     |
# |    loss                 | 0.032      |
# |    n_updates            | 240        |
# |    policy_gradient_loss | 0.0287     |
# |    value_loss           | 9.36e-05   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 335        |
# |    ep_rew_mean          | 0.76       |
# | time/                   |            |
# |    fps                  | 793        |
# |    iterations           | 26         |
# |    time_elapsed         | 41         |
# |    total_timesteps      | 33280      |
# | train/                  |            |
# |    approx_kl            | 0.11834873 |
# |    clip_fraction        | 0.222      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.264     |
# |    explained_variance   | 0.835      |
# |    learning_rate        | 0.0014     |
# |    loss                 | -0.0103    |
# |    n_updates            | 250        |
# |    policy_gradient_loss | 0.0182     |
# |    value_loss           | 9.36e-05   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 335        |
# |    ep_rew_mean          | 0.802      |
# | time/                   |            |
# |    fps                  | 801        |
# |    iterations           | 27         |
# |    time_elapsed         | 43         |
# |    total_timesteps      | 34560      |
# | train/                  |            |
# |    approx_kl            | 0.14525872 |
# |    clip_fraction        | 0.265      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.268     |
# |    explained_variance   | 0.831      |
# |    learning_rate        | 0.0014     |
# |    loss                 | -0.00343   |
# |    n_updates            | 260        |
# |    policy_gradient_loss | 0.0495     |
# |    value_loss           | 7.83e-05   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 335        |
# |    ep_rew_mean          | 0.834      |
# | time/                   |            |
# |    fps                  | 809        |
# |    iterations           | 28         |
# |    time_elapsed         | 44         |
# |    total_timesteps      | 35840      |
# | train/                  |            |
# |    approx_kl            | 0.24091774 |
# |    clip_fraction        | 0.23       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.26      |
# |    explained_variance   | 0.857      |
# |    learning_rate        | 0.0014     |
# |    loss                 | 0.186      |
# |    n_updates            | 270        |
# |    policy_gradient_loss | 0.0297     |
# |    value_loss           | 8.5e-05    |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 335        |
# |    ep_rew_mean          | 0.868      |
# | time/                   |            |
# |    fps                  | 816        |
# |    iterations           | 29         |
# |    time_elapsed         | 45         |
# |    total_timesteps      | 37120      |
# | train/                  |            |
# |    approx_kl            | 0.06723066 |
# |    clip_fraction        | 0.249      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.252     |
# |    explained_variance   | 0.706      |
# |    learning_rate        | 0.0014     |
# |    loss                 | 0.0522     |
# |    n_updates            | 280        |
# |    policy_gradient_loss | 0.0148     |
# |    value_loss           | 9.96e-05   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 335        |
# |    ep_rew_mean          | 0.905      |
# | time/                   |            |
# |    fps                  | 823        |
# |    iterations           | 30         |
# |    time_elapsed         | 46         |
# |    total_timesteps      | 38400      |
# | train/                  |            |
# |    approx_kl            | 0.10417082 |
# |    clip_fraction        | 0.202      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.243     |
# |    explained_variance   | 0.624      |
# |    learning_rate        | 0.0014     |
# |    loss                 | -0.026     |
# |    n_updates            | 290        |
# |    policy_gradient_loss | -0.00556   |
# |    value_loss           | 0.000176   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.95        |
# | time/                   |             |
# |    fps                  | 829         |
# |    iterations           | 31          |
# |    time_elapsed         | 47          |
# |    total_timesteps      | 39680       |
# | train/                  |             |
# |    approx_kl            | 0.091366895 |
# |    clip_fraction        | 0.254       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.292      |
# |    explained_variance   | 0.74        |
# |    learning_rate        | 0.0014      |
# |    loss                 | 0.0226      |
# |    n_updates            | 300         |
# |    policy_gradient_loss | 0.00716     |
# |    value_loss           | 0.000359    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 335        |
# |    ep_rew_mean          | 0.997      |
# | time/                   |            |
# |    fps                  | 830        |
# |    iterations           | 32         |
# |    time_elapsed         | 49         |
# |    total_timesteps      | 40960      |
# | train/                  |            |
# |    approx_kl            | 0.08857386 |
# |    clip_fraction        | 0.263      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.302     |
# |    explained_variance   | 0.727      |
# |    learning_rate        | 0.0014     |
# |    loss                 | 0.0383     |
# |    n_updates            | 310        |
# |    policy_gradient_loss | 0.0252     |
# |    value_loss           | 0.00299    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 1.04        |
# | time/                   |             |
# |    fps                  | 833         |
# |    iterations           | 33          |
# |    time_elapsed         | 50          |
# |    total_timesteps      | 42240       |
# | train/                  |             |
# |    approx_kl            | 0.040379256 |
# |    clip_fraction        | 0.254       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.3        |
# |    explained_variance   | 0.704       |
# |    learning_rate        | 0.0014      |
# |    loss                 | -0.00114    |
# |    n_updates            | 320         |
# |    policy_gradient_loss | 0.0432      |
# |    value_loss           | 0.000222    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 1.07        |
# | time/                   |             |
# |    fps                  | 836         |
# |    iterations           | 34          |
# |    time_elapsed         | 52          |
# |    total_timesteps      | 43520       |
# | train/                  |             |
# |    approx_kl            | 0.057967074 |
# |    clip_fraction        | 0.22        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.305      |
# |    explained_variance   | 0.762       |
# |    learning_rate        | 0.0014      |
# |    loss                 | 0.0255      |
# |    n_updates            | 330         |
# |    policy_gradient_loss | 0.00741     |
# |    value_loss           | 0.000128    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 1.1         |
# | time/                   |             |
# |    fps                  | 842         |
# |    iterations           | 35          |
# |    time_elapsed         | 53          |
# |    total_timesteps      | 44800       |
# | train/                  |             |
# |    approx_kl            | 0.056664784 |
# |    clip_fraction        | 0.214       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.271      |
# |    explained_variance   | 0.797       |
# |    learning_rate        | 0.0014      |
# |    loss                 | 0.0039      |
# |    n_updates            | 340         |
# |    policy_gradient_loss | 0.0247      |
# |    value_loss           | 0.000577    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 335        |
# |    ep_rew_mean          | 1.12       |
# | time/                   |            |
# |    fps                  | 847        |
# |    iterations           | 36         |
# |    time_elapsed         | 54         |
# |    total_timesteps      | 46080      |
# | train/                  |            |
# |    approx_kl            | 0.12823546 |
# |    clip_fraction        | 0.267      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.26      |
# |    explained_variance   | 0.546      |
# |    learning_rate        | 0.0014     |
# |    loss                 | 0.0345     |
# |    n_updates            | 350        |
# |    policy_gradient_loss | 0.0299     |
# |    value_loss           | 0.000284   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 1.14        |
# | time/                   |             |
# |    fps                  | 852         |
# |    iterations           | 37          |
# |    time_elapsed         | 55          |
# |    total_timesteps      | 47360       |
# | train/                  |             |
# |    approx_kl            | 0.060890596 |
# |    clip_fraction        | 0.235       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.304      |
# |    explained_variance   | 0.641       |
# |    learning_rate        | 0.0014      |
# |    loss                 | -0.0178     |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.00435    |
# |    value_loss           | 0.000565    |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 335       |
# |    ep_rew_mean          | 1.16      |
# | time/                   |           |
# |    fps                  | 857       |
# |    iterations           | 38        |
# |    time_elapsed         | 56        |
# |    total_timesteps      | 48640     |
# | train/                  |           |
# |    approx_kl            | 0.0658359 |
# |    clip_fraction        | 0.22      |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.3      |
# |    explained_variance   | 0.705     |
# |    learning_rate        | 0.0014    |
# |    loss                 | 0.0359    |
# |    n_updates            | 370       |
# |    policy_gradient_loss | 0.0201    |
# |    value_loss           | 0.000899  |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 335        |
# |    ep_rew_mean          | 1.17       |
# | time/                   |            |
# |    fps                  | 861        |
# |    iterations           | 39         |
# |    time_elapsed         | 57         |
# |    total_timesteps      | 49920      |
# | train/                  |            |
# |    approx_kl            | 0.09610483 |
# |    clip_fraction        | 0.248      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.284     |
# |    explained_variance   | 0.797      |
# |    learning_rate        | 0.0014     |
# |    loss                 | 0.0466     |
# |    n_updates            | 380        |
# |    policy_gradient_loss | 0.0555     |
# |    value_loss           | 0.000239   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 335        |
# |    ep_rew_mean          | 1.18       |
# | time/                   |            |
# |    fps                  | 866        |
# |    iterations           | 40         |
# |    time_elapsed         | 59         |
# |    total_timesteps      | 51200      |
# | train/                  |            |
# |    approx_kl            | 0.08693738 |
# |    clip_fraction        | 0.243      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.274     |
# |    explained_variance   | 0.824      |
# |    learning_rate        | 0.0014     |
# |    loss                 | 0.0824     |
# |    n_updates            | 390        |
# |    policy_gradient_loss | 0.0468     |
# |    value_loss           | 0.00035    |
# ----------------------------------------
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 335      |
# |    ep_rew_mean     | 0.0359   |
# | time/              |          |
# |    fps             | 1547     |
# |    iterations      | 1        |
# |    time_elapsed    | 1        |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.0551      |
# | time/                   |             |
# |    fps                  | 1008        |
# |    iterations           | 2           |
# |    time_elapsed         | 4           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.010869434 |
# |    clip_fraction        | 0.0962      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | -4.82       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00522    |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.00418    |
# |    value_loss           | 0.00217     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.0413      |
# | time/                   |             |
# |    fps                  | 862         |
# |    iterations           | 3           |
# |    time_elapsed         | 7           |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.011452543 |
# |    clip_fraction        | 0.0919      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.1        |
# |    explained_variance   | -0.415      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0254     |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.00888    |
# |    value_loss           | 0.000509    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.065       |
# | time/                   |             |
# |    fps                  | 826         |
# |    iterations           | 4           |
# |    time_elapsed         | 9           |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.010413656 |
# |    clip_fraction        | 0.0921      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.08       |
# |    explained_variance   | 0.183       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.51e-05    |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0058     |
# |    value_loss           | 0.000368    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.0732      |
# | time/                   |             |
# |    fps                  | 820         |
# |    iterations           | 5           |
# |    time_elapsed         | 12          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.010806628 |
# |    clip_fraction        | 0.139       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.06       |
# |    explained_variance   | 0.135       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.027      |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0127     |
# |    value_loss           | 0.000402    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.0962      |
# | time/                   |             |
# |    fps                  | 813         |
# |    iterations           | 6           |
# |    time_elapsed         | 15          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.007883825 |
# |    clip_fraction        | 0.0757      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.03       |
# |    explained_variance   | 0.151       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00642     |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.00401    |
# |    value_loss           | 0.000366    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.125       |
# | time/                   |             |
# |    fps                  | 809         |
# |    iterations           | 7           |
# |    time_elapsed         | 17          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.010603511 |
# |    clip_fraction        | 0.0979      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.98       |
# |    explained_variance   | 0.129       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.01        |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0087     |
# |    value_loss           | 0.000437    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 335          |
# |    ep_rew_mean          | 0.152        |
# | time/                   |              |
# |    fps                  | 808          |
# |    iterations           | 8            |
# |    time_elapsed         | 20           |
# |    total_timesteps      | 16384        |
# | train/                  |              |
# |    approx_kl            | 0.0137174055 |
# |    clip_fraction        | 0.153        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.924       |
# |    explained_variance   | 0.117        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00882      |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -0.00947     |
# |    value_loss           | 0.000446     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.184       |
# | time/                   |             |
# |    fps                  | 789         |
# |    iterations           | 9           |
# |    time_elapsed         | 23          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.008794598 |
# |    clip_fraction        | 0.121       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.881      |
# |    explained_variance   | 0.0954      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00857    |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.00925    |
# |    value_loss           | 0.0004      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.225       |
# | time/                   |             |
# |    fps                  | 784         |
# |    iterations           | 10          |
# |    time_elapsed         | 26          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.012298625 |
# |    clip_fraction        | 0.132       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.806      |
# |    explained_variance   | 0.337       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.024      |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.00832    |
# |    value_loss           | 0.000274    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 335        |
# |    ep_rew_mean          | 0.26       |
# | time/                   |            |
# |    fps                  | 785        |
# |    iterations           | 11         |
# |    time_elapsed         | 28         |
# |    total_timesteps      | 22528      |
# | train/                  |            |
# |    approx_kl            | 0.00944822 |
# |    clip_fraction        | 0.123      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.733     |
# |    explained_variance   | 0.495      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.00272    |
# |    n_updates            | 100        |
# |    policy_gradient_loss | -0.0085    |
# |    value_loss           | 0.000447   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.297       |
# | time/                   |             |
# |    fps                  | 784         |
# |    iterations           | 12          |
# |    time_elapsed         | 31          |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.009013199 |
# |    clip_fraction        | 0.121       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.692      |
# |    explained_variance   | 0.728       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0106      |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.0029     |
# |    value_loss           | 0.000318    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.332       |
# | time/                   |             |
# |    fps                  | 785         |
# |    iterations           | 13          |
# |    time_elapsed         | 33          |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.009127928 |
# |    clip_fraction        | 0.122       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.626      |
# |    explained_variance   | 0.829       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0302     |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.00359    |
# |    value_loss           | 0.000297    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.364       |
# | time/                   |             |
# |    fps                  | 784         |
# |    iterations           | 14          |
# |    time_elapsed         | 36          |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.017072475 |
# |    clip_fraction        | 0.132       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.596      |
# |    explained_variance   | 0.869       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.02       |
# |    n_updates            | 130         |
# |    policy_gradient_loss | 0.00129     |
# |    value_loss           | 0.000509    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 335        |
# |    ep_rew_mean          | 0.399      |
# | time/                   |            |
# |    fps                  | 775        |
# |    iterations           | 15         |
# |    time_elapsed         | 39         |
# |    total_timesteps      | 30720      |
# | train/                  |            |
# |    approx_kl            | 0.01885913 |
# |    clip_fraction        | 0.148      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.572     |
# |    explained_variance   | 0.899      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.00397   |
# |    n_updates            | 140        |
# |    policy_gradient_loss | -0.00094   |
# |    value_loss           | 0.000293   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.428       |
# | time/                   |             |
# |    fps                  | 774         |
# |    iterations           | 16          |
# |    time_elapsed         | 42          |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.008716431 |
# |    clip_fraction        | 0.17        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.553      |
# |    explained_variance   | 0.911       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00881    |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.00123    |
# |    value_loss           | 0.000293    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 335        |
# |    ep_rew_mean          | 0.472      |
# | time/                   |            |
# |    fps                  | 776        |
# |    iterations           | 17         |
# |    time_elapsed         | 44         |
# |    total_timesteps      | 34816      |
# | train/                  |            |
# |    approx_kl            | 0.01824443 |
# |    clip_fraction        | 0.188      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.537     |
# |    explained_variance   | 0.93       |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.00576   |
# |    n_updates            | 160        |
# |    policy_gradient_loss | 0.00464    |
# |    value_loss           | 0.000429   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.536       |
# | time/                   |             |
# |    fps                  | 778         |
# |    iterations           | 18          |
# |    time_elapsed         | 47          |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.009641536 |
# |    clip_fraction        | 0.132       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.516      |
# |    explained_variance   | 0.949       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.000887    |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.00252    |
# |    value_loss           | 0.00021     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.599       |
# | time/                   |             |
# |    fps                  | 779         |
# |    iterations           | 19          |
# |    time_elapsed         | 49          |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.011012408 |
# |    clip_fraction        | 0.147       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.492      |
# |    explained_variance   | 0.965       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0169      |
# |    n_updates            | 180         |
# |    policy_gradient_loss | 0.00325     |
# |    value_loss           | 0.000496    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.658       |
# | time/                   |             |
# |    fps                  | 779         |
# |    iterations           | 20          |
# |    time_elapsed         | 52          |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.018831309 |
# |    clip_fraction        | 0.184       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.469      |
# |    explained_variance   | 0.967       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00751     |
# |    n_updates            | 190         |
# |    policy_gradient_loss | 0.00437     |
# |    value_loss           | 0.000208    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.717       |
# | time/                   |             |
# |    fps                  | 774         |
# |    iterations           | 21          |
# |    time_elapsed         | 55          |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.012176575 |
# |    clip_fraction        | 0.156       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.472      |
# |    explained_variance   | 0.978       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00342     |
# |    n_updates            | 200         |
# |    policy_gradient_loss | 0.0078      |
# |    value_loss           | 0.000856    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.771       |
# | time/                   |             |
# |    fps                  | 772         |
# |    iterations           | 22          |
# |    time_elapsed         | 58          |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.012362383 |
# |    clip_fraction        | 0.151       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.442      |
# |    explained_variance   | 0.981       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0182      |
# |    n_updates            | 210         |
# |    policy_gradient_loss | 0.00558     |
# |    value_loss           | 0.000152    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.824       |
# | time/                   |             |
# |    fps                  | 771         |
# |    iterations           | 23          |
# |    time_elapsed         | 61          |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.028437681 |
# |    clip_fraction        | 0.154       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.406      |
# |    explained_variance   | 0.975       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0113      |
# |    n_updates            | 220         |
# |    policy_gradient_loss | 0.00107     |
# |    value_loss           | 0.000414    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.874       |
# | time/                   |             |
# |    fps                  | 769         |
# |    iterations           | 24          |
# |    time_elapsed         | 63          |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.016603671 |
# |    clip_fraction        | 0.146       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.386      |
# |    explained_variance   | 0.98        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0156      |
# |    n_updates            | 230         |
# |    policy_gradient_loss | 0.0072      |
# |    value_loss           | 0.000138    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.922       |
# | time/                   |             |
# |    fps                  | 768         |
# |    iterations           | 25          |
# |    time_elapsed         | 66          |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.027786538 |
# |    clip_fraction        | 0.15        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.385      |
# |    explained_variance   | 0.985       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0031     |
# |    n_updates            | 240         |
# |    policy_gradient_loss | 0.00793     |
# |    value_loss           | 0.000121    |
# -----------------------------------------
#          Method  Cumulative Return  Sharpe Ratio  Sortino Ratio  Max Drawdown
# 0   Bi-LSTM PPO           2.477425      0.612757       2.340484     -0.010331
# 1    Simple PPO           2.374364      0.557284       1.510235     -0.013156
# 2  Buy-and-Hold          -0.717831           NaN            NaN           NaN
