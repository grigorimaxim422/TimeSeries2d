# %%
import pandas as pd
import numpy as np
import torch
import torch.nn as nn
from sklearn.preprocessing import MinMaxScaler
from torch.utils.data import DataLoader, TensorDataset
from stable_baselines3 import PPO
from gym import spaces, Env
import matplotlib.pyplot as plt
import random

# Set seed for reproducibility
SEED = 42
random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)
if torch.cuda.is_available():
    torch.cuda.manual_seed_all(SEED)

# Load and preprocess data
def load_and_preprocess(file_name):
    data = pd.read_csv(file_name)
    data["Date"] = pd.to_datetime(data["Date"])
    data = data.sort_values(by="Date")
    
    numeric_data = data.drop(columns=["Date"])
    numeric_data = numeric_data[['Close'] + [col for col in numeric_data.columns if col != 'Close']]
    
    scaler = MinMaxScaler()
    normalized_data = scaler.fit_transform(numeric_data)
    data[numeric_data.columns] = normalized_data
    
    return data, scaler

# Create sequences for time series modeling
def create_sequences(data, sequence_length=30):
    sequences = []
    targets = []
    for i in range(len(data) - sequence_length):
        seq = data[i:i+sequence_length]
        target = data[i+sequence_length, 0]  # Assuming the target is the first column (e.g., Close price)
        sequences.append(seq)
        targets.append(target)
    return np.array(sequences), np.array(targets)

# Define Bi-LSTM model
class BiLSTMModel(nn.Module):
    def __init__(self, input_dim, hidden_dim, num_layers, dropout):
        super(BiLSTMModel, self).__init__()
        self.bilstm = nn.LSTM(input_dim, hidden_dim, num_layers, batch_first=True, dropout=dropout, bidirectional=True)
        self.fc = nn.Linear(hidden_dim * 2, 1)

    def forward(self, x):
        bilstm_out, _ = self.bilstm(x)
        return self.fc(bilstm_out[:, -1, :])

# Custom trading environment
class TradingEnv(Env):
    def __init__(self, data, sequence_length=30):
        super(TradingEnv, self).__init__()
        self.data = data
        self.sequence_length = sequence_length
        self.current_step = 0
        self.total_steps = len(data) - sequence_length
        self.portfolio_value = 1.0

        # Action and observation space
        self.action_space = spaces.Discrete(3)  # 0: Hold, 1: Buy, 2: Sell
        self.observation_space = spaces.Box(low=0, high=1, shape=(sequence_length, data.shape[1]), dtype=np.float32)

    def reset(self):
        self.current_step = 0
        self.portfolio_value = 1.0
        return self._next_observation()

    def _next_observation(self):
        return self.data[self.current_step:self.current_step + self.sequence_length]

    def step(self, action):
        self.current_step += 1
        reward = 0
        done = self.current_step >= self.total_steps

        if not done:
            current_price = self.data[self.current_step, 0]
            prev_price = self.data[self.current_step - 1, 0]

            if action == 1:  # Buy
                reward = current_price - prev_price
            elif action == 2:  # Sell
                reward = prev_price - current_price

        self.portfolio_value += reward
        obs = self._next_observation() if not done else None
        return obs, reward, done, {"portfolio_value": self.portfolio_value}

# Evaluate trading strategy
def evaluate_trading_strategy(env, model):
    obs = env.reset()
    done = False
    portfolio_values = [1.0]

    while not done:
        action, _ = model.predict(obs, deterministic=True)
        obs, reward, done, info = env.step(action)
        portfolio_values.append(info.get("portfolio_value", 1.0))

    return portfolio_values

# Performance metrics
def calculate_metrics(portfolio_values):
    daily_returns = np.diff(portfolio_values) / portfolio_values[:-1]
    cumulative_return = portfolio_values[-1] / portfolio_values[0] - 1
    sharpe_ratio = np.mean(daily_returns) / np.std(daily_returns) if np.std(daily_returns) > 0 else 0
    sortino_ratio = np.mean(daily_returns) / np.std([r for r in daily_returns if r < 0]) if np.std([r for r in daily_returns if r < 0]) > 0 else 0
    max_drawdown = np.min(portfolio_values / np.maximum.accumulate(portfolio_values) - 1)
    return cumulative_return, sharpe_ratio, sortino_ratio, max_drawdown

# Main execution
if __name__ == "__main__":
    # Load data
    data, scaler = load_and_preprocess("Book3.csv")
    train_data = data[(data["Date"].dt.year >= 2017) & (data["Date"].dt.year <= 2022)].drop(columns=["Date"]).values
    test_data = data[data["Date"].dt.year == 2023].drop(columns=["Date"]).values

    X_train, y_train = create_sequences(train_data)
    X_test, y_test = create_sequences(test_data)

    # Train Bi-LSTM model
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    bilstm_model = BiLSTMModel(input_dim=X_train.shape[2], hidden_dim=224, num_layers=1, dropout=0.14).to(device)
    criterion = nn.MSELoss()
    optimizer = torch.optim.Adam(bilstm_model.parameters(), lr=0.0019)

    train_loader = DataLoader(TensorDataset(torch.tensor(X_train, dtype=torch.float32), torch.tensor(y_train, dtype=torch.float32)), batch_size=32, shuffle=True)

    for epoch in range(50):
        bilstm_model.train()
        train_loss = 0.0
        for X_batch, y_batch in train_loader:
            X_batch, y_batch = X_batch.to(device), y_batch.to(device)
            optimizer.zero_grad()
            predictions = bilstm_model(X_batch).squeeze()
            loss = criterion(predictions, y_batch)
            loss.backward()
            optimizer.step()
            train_loss += loss.item()

    # Create environments for PPO
    bilstm_env = TradingEnv(test_data)
    simple_env = TradingEnv(test_data)

    # Train PPO models
    ppo_bilstm_model = PPO("MlpPolicy", bilstm_env, learning_rate=0.0014, batch_size=160, n_steps=1280, gamma=0.9005911776350177, verbose=1)
    ppo_bilstm_model.learn(total_timesteps=50000)

    ppo_simple_model = PPO("MlpPolicy", simple_env, verbose=1)
    ppo_simple_model.learn(total_timesteps=50000)

    # Evaluate strategies
    portfolio_values_bilstm = evaluate_trading_strategy(bilstm_env, ppo_bilstm_model)
    portfolio_values_simple = evaluate_trading_strategy(simple_env, ppo_simple_model)

    cumulative_return_bilstm, sharpe_bilstm, sortino_bilstm, max_drawdown_bilstm = calculate_metrics(portfolio_values_bilstm)
    cumulative_return_simple, sharpe_simple, sortino_simple, max_drawdown_simple = calculate_metrics(portfolio_values_simple)

    # Buy-and-Hold strategy
    buy_hold_return = test_data[-1, 0] / test_data[0, 0] - 1

    # Generate date range for 2022
    test_dates = pd.date_range(start="2023-01-01", periods=len(portfolio_values_bilstm))

    # Calculate cumulative returns
    cumulative_returns_bilstm = np.cumprod([1 + r for r in np.diff(portfolio_values_bilstm) / portfolio_values_bilstm[:-1]])
    cumulative_returns_simple = np.cumprod([1 + r for r in np.diff(portfolio_values_simple) / portfolio_values_simple[:-1]])

    # Plot cumulative returns
    plt.figure(figsize=(12, 6))
    plt.plot(test_dates[1:], cumulative_returns_bilstm, label="Bi-LSTM PPO")
    plt.plot(test_dates[1:], cumulative_returns_simple, label="Simple PPO")
    plt.gca().xaxis.set_major_formatter(plt.matplotlib.dates.DateFormatter("%b %Y"))
    plt.gca().xaxis.set_major_locator(plt.matplotlib.dates.MonthLocator())

    plt.legend()
    plt.title("Cumulative Returns")
    plt.xlabel("Date")
    plt.ylabel("Cumulative Return")
    plt.grid()
    plt.show()

    # Print results
    results = pd.DataFrame({
        "Method": ["Bi-LSTM PPO", "Simple PPO", "Buy-and-Hold"],
        "Cumulative Return": [cumulative_returns_bilstm[-1], cumulative_returns_simple[-1], buy_hold_return],
        "Sharpe Ratio": [sharpe_bilstm, sharpe_simple, None],
        "Sortino Ratio": [sortino_bilstm, sortino_simple, None],
        "Max Drawdown": [max_drawdown_bilstm, max_drawdown_simple, None]
    })
    print(results)
# Out:
# C:\Users\User\anaconda3\envs\RL\Lib\site-packages\torch\nn\modules\rnn.py:123: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.14 and num_layers=1
#   warnings.warn(
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# C:\Users\User\anaconda3\envs\RL\Lib\site-packages\stable_baselines3\common\vec_env\patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 335      |
# |    ep_rew_mean     | -0.00469 |
# | time/              |          |
# |    fps             | 1085     |
# |    iterations      | 1        |
# |    time_elapsed    | 1        |
# |    total_timesteps | 1280     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | -0.00288    |
# | time/                   |             |
# |    fps                  | 914         |
# |    iterations           | 2           |
# |    time_elapsed         | 2           |
# |    total_timesteps      | 2560        |
# | train/                  |             |
# |    approx_kl            | 0.008294452 |
# |    clip_fraction        | 0.0362      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | -6.35       |
# |    learning_rate        | 0.0014      |
# |    loss                 | -0.0124     |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.00312    |
# |    value_loss           | 0.0234      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.00947     |
# | time/                   |             |
# |    fps                  | 855         |
# |    iterations           | 3           |
# |    time_elapsed         | 4           |
# |    total_timesteps      | 3840        |
# | train/                  |             |
# |    approx_kl            | 0.014364196 |
# |    clip_fraction        | 0.154       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.08       |
# |    explained_variance   | -4.04       |
# |    learning_rate        | 0.0014      |
# |    loss                 | 0.00329     |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.00726    |
# |    value_loss           | 0.000433    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 335        |
# |    ep_rew_mean          | 0.0116     |
# | time/                   |            |
# |    fps                  | 840        |
# |    iterations           | 4          |
# |    time_elapsed         | 6          |
# |    total_timesteps      | 5120       |
# | train/                  |            |
# |    approx_kl            | 0.01150897 |
# |    clip_fraction        | 0.139      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.07      |
# |    explained_variance   | -2.13      |
# |    learning_rate        | 0.0014     |
# |    loss                 | -0.0215    |
# |    n_updates            | 30         |
# |    policy_gradient_loss | -0.00914   |
# |    value_loss           | 0.000123   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.0235      |
# | time/                   |             |
# |    fps                  | 834         |
# |    iterations           | 5           |
# |    time_elapsed         | 7           |
# |    total_timesteps      | 6400        |
# | train/                  |             |
# |    approx_kl            | 0.008020108 |
# |    clip_fraction        | 0.115       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.04       |
# |    explained_variance   | -2.06       |
# |    learning_rate        | 0.0014      |
# |    loss                 | 0.000174    |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.00484    |
# |    value_loss           | 8.06e-05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.0332      |
# | time/                   |             |
# |    fps                  | 815         |
# |    iterations           | 6           |
# |    time_elapsed         | 9           |
# |    total_timesteps      | 7680        |
# | train/                  |             |
# |    approx_kl            | 0.007475636 |
# |    clip_fraction        | 0.117       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.03       |
# |    explained_variance   | -1.24       |
# |    learning_rate        | 0.0014      |
# |    loss                 | -0.012      |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.00529    |
# |    value_loss           | 6.23e-05    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 335        |
# |    ep_rew_mean          | 0.0456     |
# | time/                   |            |
# |    fps                  | 784        |
# |    iterations           | 7          |
# |    time_elapsed         | 11         |
# |    total_timesteps      | 8960       |
# | train/                  |            |
# |    approx_kl            | 0.00962599 |
# |    clip_fraction        | 0.173      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.02      |
# |    explained_variance   | -1.03      |
# |    learning_rate        | 0.0014     |
# |    loss                 | -0.0209    |
# |    n_updates            | 60         |
# |    policy_gradient_loss | -0.0125    |
# |    value_loss           | 5.9e-05    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.055       |
# | time/                   |             |
# |    fps                  | 781         |
# |    iterations           | 8           |
# |    time_elapsed         | 13          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.009872718 |
# |    clip_fraction        | 0.207       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.997      |
# |    explained_variance   | -0.426      |
# |    learning_rate        | 0.0014      |
# |    loss                 | -0.0207     |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.00864    |
# |    value_loss           | 5.12e-05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.0638      |
# | time/                   |             |
# |    fps                  | 765         |
# |    iterations           | 9           |
# |    time_elapsed         | 15          |
# |    total_timesteps      | 11520       |
# | train/                  |             |
# |    approx_kl            | 0.008794811 |
# |    clip_fraction        | 0.184       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.956      |
# |    explained_variance   | -0.299      |
# |    learning_rate        | 0.0014      |
# |    loss                 | -0.0224     |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.00606    |
# |    value_loss           | 4.83e-05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.0755      |
# | time/                   |             |
# |    fps                  | 767         |
# |    iterations           | 10          |
# |    time_elapsed         | 16          |
# |    total_timesteps      | 12800       |
# | train/                  |             |
# |    approx_kl            | 0.020675734 |
# |    clip_fraction        | 0.187       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.883      |
# |    explained_variance   | -0.439      |
# |    learning_rate        | 0.0014      |
# |    loss                 | -0.0321     |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.0179     |
# |    value_loss           | 3.64e-05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.0911      |
# | time/                   |             |
# |    fps                  | 771         |
# |    iterations           | 11          |
# |    time_elapsed         | 18          |
# |    total_timesteps      | 14080       |
# | train/                  |             |
# |    approx_kl            | 0.015461637 |
# |    clip_fraction        | 0.267       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.888      |
# |    explained_variance   | -0.227      |
# |    learning_rate        | 0.0014      |
# |    loss                 | -0.0179     |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.00498    |
# |    value_loss           | 3.69e-05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.103       |
# | time/                   |             |
# |    fps                  | 768         |
# |    iterations           | 12          |
# |    time_elapsed         | 19          |
# |    total_timesteps      | 15360       |
# | train/                  |             |
# |    approx_kl            | 0.033974316 |
# |    clip_fraction        | 0.24        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.822      |
# |    explained_variance   | -0.0639     |
# |    learning_rate        | 0.0014      |
# |    loss                 | -0.0207     |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.0126     |
# |    value_loss           | 0.000103    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.12        |
# | time/                   |             |
# |    fps                  | 768         |
# |    iterations           | 13          |
# |    time_elapsed         | 21          |
# |    total_timesteps      | 16640       |
# | train/                  |             |
# |    approx_kl            | 0.047282428 |
# |    clip_fraction        | 0.399       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.77       |
# |    explained_variance   | 0.126       |
# |    learning_rate        | 0.0014      |
# |    loss                 | -0.0128     |
# |    n_updates            | 120         |
# |    policy_gradient_loss | 0.0223      |
# |    value_loss           | 3.25e-05    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 335        |
# |    ep_rew_mean          | 0.136      |
# | time/                   |            |
# |    fps                  | 768        |
# |    iterations           | 14         |
# |    time_elapsed         | 23         |
# |    total_timesteps      | 17920      |
# | train/                  |            |
# |    approx_kl            | 0.02994287 |
# |    clip_fraction        | 0.377      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.724     |
# |    explained_variance   | 0.209      |
# |    learning_rate        | 0.0014     |
# |    loss                 | -0.0196    |
# |    n_updates            | 130        |
# |    policy_gradient_loss | 0.0188     |
# |    value_loss           | 2.96e-05   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.151       |
# | time/                   |             |
# |    fps                  | 767         |
# |    iterations           | 15          |
# |    time_elapsed         | 25          |
# |    total_timesteps      | 19200       |
# | train/                  |             |
# |    approx_kl            | 0.021647807 |
# |    clip_fraction        | 0.322       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.705      |
# |    explained_variance   | 0.276       |
# |    learning_rate        | 0.0014      |
# |    loss                 | -0.00806    |
# |    n_updates            | 140         |
# |    policy_gradient_loss | 0.00266     |
# |    value_loss           | 3.12e-05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.167       |
# | time/                   |             |
# |    fps                  | 754         |
# |    iterations           | 16          |
# |    time_elapsed         | 27          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.019972755 |
# |    clip_fraction        | 0.25        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.666      |
# |    explained_variance   | 0.26        |
# |    learning_rate        | 0.0014      |
# |    loss                 | -0.018      |
# |    n_updates            | 150         |
# |    policy_gradient_loss | 0.00231     |
# |    value_loss           | 0.00254     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.18        |
# | time/                   |             |
# |    fps                  | 752         |
# |    iterations           | 17          |
# |    time_elapsed         | 28          |
# |    total_timesteps      | 21760       |
# | train/                  |             |
# |    approx_kl            | 0.022108737 |
# |    clip_fraction        | 0.239       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.611      |
# |    explained_variance   | -0.091      |
# |    learning_rate        | 0.0014      |
# |    loss                 | -0.0121     |
# |    n_updates            | 160         |
# |    policy_gradient_loss | 0.00241     |
# |    value_loss           | 0.000377    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.198       |
# | time/                   |             |
# |    fps                  | 748         |
# |    iterations           | 18          |
# |    time_elapsed         | 30          |
# |    total_timesteps      | 23040       |
# | train/                  |             |
# |    approx_kl            | 0.019057345 |
# |    clip_fraction        | 0.208       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.587      |
# |    explained_variance   | 0.389       |
# |    learning_rate        | 0.0014      |
# |    loss                 | -0.00421    |
# |    n_updates            | 170         |
# |    policy_gradient_loss | 0.0089      |
# |    value_loss           | 3.22e-05    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 335        |
# |    ep_rew_mean          | 0.214      |
# | time/                   |            |
# |    fps                  | 748        |
# |    iterations           | 19         |
# |    time_elapsed         | 32         |
# |    total_timesteps      | 24320      |
# | train/                  |            |
# |    approx_kl            | 0.03911735 |
# |    clip_fraction        | 0.215      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.566     |
# |    explained_variance   | 0.496      |
# |    learning_rate        | 0.0014     |
# |    loss                 | 0.0228     |
# |    n_updates            | 180        |
# |    policy_gradient_loss | 0.00156    |
# |    value_loss           | 2.73e-05   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.23        |
# | time/                   |             |
# |    fps                  | 751         |
# |    iterations           | 20          |
# |    time_elapsed         | 34          |
# |    total_timesteps      | 25600       |
# | train/                  |             |
# |    approx_kl            | 0.022085644 |
# |    clip_fraction        | 0.261       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.535      |
# |    explained_variance   | 0.529       |
# |    learning_rate        | 0.0014      |
# |    loss                 | 0.00543     |
# |    n_updates            | 190         |
# |    policy_gradient_loss | 0.0185      |
# |    value_loss           | 4.84e-05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.246       |
# | time/                   |             |
# |    fps                  | 752         |
# |    iterations           | 21          |
# |    time_elapsed         | 35          |
# |    total_timesteps      | 26880       |
# | train/                  |             |
# |    approx_kl            | 0.056467574 |
# |    clip_fraction        | 0.319       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.491      |
# |    explained_variance   | 0.574       |
# |    learning_rate        | 0.0014      |
# |    loss                 | -0.000731   |
# |    n_updates            | 200         |
# |    policy_gradient_loss | 0.0457      |
# |    value_loss           | 0.00246     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.262       |
# | time/                   |             |
# |    fps                  | 753         |
# |    iterations           | 22          |
# |    time_elapsed         | 37          |
# |    total_timesteps      | 28160       |
# | train/                  |             |
# |    approx_kl            | 0.031473354 |
# |    clip_fraction        | 0.26        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.485      |
# |    explained_variance   | 0.15        |
# |    learning_rate        | 0.0014      |
# |    loss                 | 0.00016     |
# |    n_updates            | 210         |
# |    policy_gradient_loss | 0.0209      |
# |    value_loss           | 0.00355     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 335        |
# |    ep_rew_mean          | 0.271      |
# | time/                   |            |
# |    fps                  | 755        |
# |    iterations           | 23         |
# |    time_elapsed         | 38         |
# |    total_timesteps      | 29440      |
# | train/                  |            |
# |    approx_kl            | 0.11641216 |
# |    clip_fraction        | 0.344      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.481     |
# |    explained_variance   | 0.411      |
# |    learning_rate        | 0.0014     |
# |    loss                 | 0.198      |
# |    n_updates            | 220        |
# |    policy_gradient_loss | 0.0403     |
# |    value_loss           | 5.15e-05   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.283       |
# | time/                   |             |
# |    fps                  | 757         |
# |    iterations           | 24          |
# |    time_elapsed         | 40          |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.052465197 |
# |    clip_fraction        | 0.265       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.422      |
# |    explained_variance   | 0.317       |
# |    learning_rate        | 0.0014      |
# |    loss                 | -0.00441    |
# |    n_updates            | 230         |
# |    policy_gradient_loss | 0.0193      |
# |    value_loss           | 3.46e-05    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 335        |
# |    ep_rew_mean          | 0.295      |
# | time/                   |            |
# |    fps                  | 750        |
# |    iterations           | 25         |
# |    time_elapsed         | 42         |
# |    total_timesteps      | 32000      |
# | train/                  |            |
# |    approx_kl            | 0.07858342 |
# |    clip_fraction        | 0.277      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.435     |
# |    explained_variance   | 0.407      |
# |    learning_rate        | 0.0014     |
# |    loss                 | 0.00171    |
# |    n_updates            | 240        |
# |    policy_gradient_loss | 0.0255     |
# |    value_loss           | 3.58e-05   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.305       |
# | time/                   |             |
# |    fps                  | 749         |
# |    iterations           | 26          |
# |    time_elapsed         | 44          |
# |    total_timesteps      | 33280       |
# | train/                  |             |
# |    approx_kl            | 0.031850915 |
# |    clip_fraction        | 0.213       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.439      |
# |    explained_variance   | 0.429       |
# |    learning_rate        | 0.0014      |
# |    loss                 | 0.0621      |
# |    n_updates            | 250         |
# |    policy_gradient_loss | 0.0131      |
# |    value_loss           | 3.96e-05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.326       |
# | time/                   |             |
# |    fps                  | 746         |
# |    iterations           | 27          |
# |    time_elapsed         | 46          |
# |    total_timesteps      | 34560       |
# | train/                  |             |
# |    approx_kl            | 0.012896811 |
# |    clip_fraction        | 0.139       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.411      |
# |    explained_variance   | 0.464       |
# |    learning_rate        | 0.0014      |
# |    loss                 | -0.00598    |
# |    n_updates            | 260         |
# |    policy_gradient_loss | 0.00186     |
# |    value_loss           | 3.18e-05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.344       |
# | time/                   |             |
# |    fps                  | 747         |
# |    iterations           | 28          |
# |    time_elapsed         | 47          |
# |    total_timesteps      | 35840       |
# | train/                  |             |
# |    approx_kl            | 0.017040195 |
# |    clip_fraction        | 0.243       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.416      |
# |    explained_variance   | 0.522       |
# |    learning_rate        | 0.0014      |
# |    loss                 | -0.0121     |
# |    n_updates            | 270         |
# |    policy_gradient_loss | 0.0209      |
# |    value_loss           | 3.21e-05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.368       |
# | time/                   |             |
# |    fps                  | 748         |
# |    iterations           | 29          |
# |    time_elapsed         | 49          |
# |    total_timesteps      | 37120       |
# | train/                  |             |
# |    approx_kl            | 0.016333422 |
# |    clip_fraction        | 0.234       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.383      |
# |    explained_variance   | 0.539       |
# |    learning_rate        | 0.0014      |
# |    loss                 | -0.013      |
# |    n_updates            | 280         |
# |    policy_gradient_loss | 0.0252      |
# |    value_loss           | 3.24e-05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.39        |
# | time/                   |             |
# |    fps                  | 750         |
# |    iterations           | 30          |
# |    time_elapsed         | 51          |
# |    total_timesteps      | 38400       |
# | train/                  |             |
# |    approx_kl            | 0.050744805 |
# |    clip_fraction        | 0.241       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.341      |
# |    explained_variance   | 0.533       |
# |    learning_rate        | 0.0014      |
# |    loss                 | -0.0134     |
# |    n_updates            | 290         |
# |    policy_gradient_loss | 0.0217      |
# |    value_loss           | 3.67e-05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.409       |
# | time/                   |             |
# |    fps                  | 752         |
# |    iterations           | 31          |
# |    time_elapsed         | 52          |
# |    total_timesteps      | 39680       |
# | train/                  |             |
# |    approx_kl            | 0.097377546 |
# |    clip_fraction        | 0.285       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.349      |
# |    explained_variance   | 0.529       |
# |    learning_rate        | 0.0014      |
# |    loss                 | 0.0111      |
# |    n_updates            | 300         |
# |    policy_gradient_loss | 0.0565      |
# |    value_loss           | 3.42e-05    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 335        |
# |    ep_rew_mean          | 0.427      |
# | time/                   |            |
# |    fps                  | 755        |
# |    iterations           | 32         |
# |    time_elapsed         | 54         |
# |    total_timesteps      | 40960      |
# | train/                  |            |
# |    approx_kl            | 0.11742328 |
# |    clip_fraction        | 0.169      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.286     |
# |    explained_variance   | 0.533      |
# |    learning_rate        | 0.0014     |
# |    loss                 | 0.0236     |
# |    n_updates            | 310        |
# |    policy_gradient_loss | 0.0142     |
# |    value_loss           | 3.92e-05   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 335        |
# |    ep_rew_mean          | 0.442      |
# | time/                   |            |
# |    fps                  | 757        |
# |    iterations           | 33         |
# |    time_elapsed         | 55         |
# |    total_timesteps      | 42240      |
# | train/                  |            |
# |    approx_kl            | 0.13807243 |
# |    clip_fraction        | 0.159      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.256     |
# |    explained_variance   | 0.553      |
# |    learning_rate        | 0.0014     |
# |    loss                 | 0.0592     |
# |    n_updates            | 320        |
# |    policy_gradient_loss | 0.0127     |
# |    value_loss           | 4.17e-05   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 335        |
# |    ep_rew_mean          | 0.455      |
# | time/                   |            |
# |    fps                  | 757        |
# |    iterations           | 34         |
# |    time_elapsed         | 57         |
# |    total_timesteps      | 43520      |
# | train/                  |            |
# |    approx_kl            | 0.20994276 |
# |    clip_fraction        | 0.191      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.238     |
# |    explained_variance   | 0.493      |
# |    learning_rate        | 0.0014     |
# |    loss                 | 0.139      |
# |    n_updates            | 330        |
# |    policy_gradient_loss | 0.0221     |
# |    value_loss           | 0.00056    |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 335        |
# |    ep_rew_mean          | 0.476      |
# | time/                   |            |
# |    fps                  | 753        |
# |    iterations           | 35         |
# |    time_elapsed         | 59         |
# |    total_timesteps      | 44800      |
# | train/                  |            |
# |    approx_kl            | 0.04780042 |
# |    clip_fraction        | 0.25       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.242     |
# |    explained_variance   | 0.378      |
# |    learning_rate        | 0.0014     |
# |    loss                 | 0.00491    |
# |    n_updates            | 340        |
# |    policy_gradient_loss | 0.0442     |
# |    value_loss           | 4.7e-05    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.495       |
# | time/                   |             |
# |    fps                  | 752         |
# |    iterations           | 36          |
# |    time_elapsed         | 61          |
# |    total_timesteps      | 46080       |
# | train/                  |             |
# |    approx_kl            | 0.016840145 |
# |    clip_fraction        | 0.159       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.256      |
# |    explained_variance   | 0.532       |
# |    learning_rate        | 0.0014      |
# |    loss                 | 0.00675     |
# |    n_updates            | 350         |
# |    policy_gradient_loss | 0.0129      |
# |    value_loss           | 3.67e-05    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 335        |
# |    ep_rew_mean          | 0.506      |
# | time/                   |            |
# |    fps                  | 753        |
# |    iterations           | 37         |
# |    time_elapsed         | 62         |
# |    total_timesteps      | 47360      |
# | train/                  |            |
# |    approx_kl            | 0.33059126 |
# |    clip_fraction        | 0.201      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.228     |
# |    explained_variance   | 0.57       |
# |    learning_rate        | 0.0014     |
# |    loss                 | -0.00766   |
# |    n_updates            | 360        |
# |    policy_gradient_loss | 0.0451     |
# |    value_loss           | 6.26e-05   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 335        |
# |    ep_rew_mean          | 0.507      |
# | time/                   |            |
# |    fps                  | 755        |
# |    iterations           | 38         |
# |    time_elapsed         | 64         |
# |    total_timesteps      | 48640      |
# | train/                  |            |
# |    approx_kl            | 0.14518076 |
# |    clip_fraction        | 0.22       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.2       |
# |    explained_variance   | 0.459      |
# |    learning_rate        | 0.0014     |
# |    loss                 | 0.112      |
# |    n_updates            | 370        |
# |    policy_gradient_loss | 0.0378     |
# |    value_loss           | 0.00149    |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 335        |
# |    ep_rew_mean          | 0.512      |
# | time/                   |            |
# |    fps                  | 756        |
# |    iterations           | 39         |
# |    time_elapsed         | 65         |
# |    total_timesteps      | 49920      |
# | train/                  |            |
# |    approx_kl            | 0.07008901 |
# |    clip_fraction        | 0.175      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.183     |
# |    explained_variance   | 0.105      |
# |    learning_rate        | 0.0014     |
# |    loss                 | 0.0927     |
# |    n_updates            | 380        |
# |    policy_gradient_loss | 0.00859    |
# |    value_loss           | 8.29e-05   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 335        |
# |    ep_rew_mean          | 0.518      |
# | time/                   |            |
# |    fps                  | 757        |
# |    iterations           | 40         |
# |    time_elapsed         | 67         |
# |    total_timesteps      | 51200      |
# | train/                  |            |
# |    approx_kl            | 0.04460064 |
# |    clip_fraction        | 0.272      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.279     |
# |    explained_variance   | 0.343      |
# |    learning_rate        | 0.0014     |
# |    loss                 | -0.0365    |
# |    n_updates            | 390        |
# |    policy_gradient_loss | -0.00488   |
# |    value_loss           | 0.000125   |
# ----------------------------------------
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 335      |
# |    ep_rew_mean     | 0.0172   |
# | time/              |          |
# |    fps             | 1214     |
# |    iterations      | 1        |
# |    time_elapsed    | 1        |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.0173      |
# | time/                   |             |
# |    fps                  | 781         |
# |    iterations           | 2           |
# |    time_elapsed         | 5           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.011394659 |
# |    clip_fraction        | 0.092       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | -6.06       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0526      |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.00438    |
# |    value_loss           | 0.00206     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 335          |
# |    ep_rew_mean          | -0.00206     |
# | time/                   |              |
# |    fps                  | 665          |
# |    iterations           | 3            |
# |    time_elapsed         | 9            |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.0091687795 |
# |    clip_fraction        | 0.00947      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.09        |
# |    explained_variance   | -1.17        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0106       |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.000899    |
# |    value_loss           | 0.000323     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.00375     |
# | time/                   |             |
# |    fps                  | 641         |
# |    iterations           | 4           |
# |    time_elapsed         | 12          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.008516844 |
# |    clip_fraction        | 0.0626      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | 0.098       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0154     |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.00257    |
# |    value_loss           | 0.000151    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.00297     |
# | time/                   |             |
# |    fps                  | 655         |
# |    iterations           | 5           |
# |    time_elapsed         | 15          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.005150142 |
# |    clip_fraction        | 0.039       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | 0.189       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0112      |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.003      |
# |    value_loss           | 0.000124    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 335          |
# |    ep_rew_mean          | 0.00904      |
# | time/                   |              |
# |    fps                  | 674          |
# |    iterations           | 6            |
# |    time_elapsed         | 18           |
# |    total_timesteps      | 12288        |
# | train/                  |              |
# |    approx_kl            | 0.0073352084 |
# |    clip_fraction        | 0.057        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.08        |
# |    explained_variance   | 0.132        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00187      |
# |    n_updates            | 50           |
# |    policy_gradient_loss | -0.00279     |
# |    value_loss           | 9.61e-05     |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 335        |
# |    ep_rew_mean          | 0.0175     |
# | time/                   |            |
# |    fps                  | 687        |
# |    iterations           | 7          |
# |    time_elapsed         | 20         |
# |    total_timesteps      | 14336      |
# | train/                  |            |
# |    approx_kl            | 0.01178443 |
# |    clip_fraction        | 0.0912     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.07      |
# |    explained_variance   | 0.225      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.00159    |
# |    n_updates            | 60         |
# |    policy_gradient_loss | -0.00649   |
# |    value_loss           | 0.000116   |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 335          |
# |    ep_rew_mean          | 0.0229       |
# | time/                   |              |
# |    fps                  | 684          |
# |    iterations           | 8            |
# |    time_elapsed         | 23           |
# |    total_timesteps      | 16384        |
# | train/                  |              |
# |    approx_kl            | 0.0078797545 |
# |    clip_fraction        | 0.0723       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.06        |
# |    explained_variance   | 0.165        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0223      |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -0.00376     |
# |    value_loss           | 0.000116     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.0336      |
# | time/                   |             |
# |    fps                  | 691         |
# |    iterations           | 9           |
# |    time_elapsed         | 26          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.013009677 |
# |    clip_fraction        | 0.172       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.04       |
# |    explained_variance   | 0.168       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00347    |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.0121     |
# |    value_loss           | 9.84e-05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.0474      |
# | time/                   |             |
# |    fps                  | 701         |
# |    iterations           | 10          |
# |    time_elapsed         | 29          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.009600819 |
# |    clip_fraction        | 0.151       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1          |
# |    explained_variance   | 0.236       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0342     |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.00854    |
# |    value_loss           | 0.000122    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 335        |
# |    ep_rew_mean          | 0.0618     |
# | time/                   |            |
# |    fps                  | 709        |
# |    iterations           | 11         |
# |    time_elapsed         | 31         |
# |    total_timesteps      | 22528      |
# | train/                  |            |
# |    approx_kl            | 0.01119547 |
# |    clip_fraction        | 0.151      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.951     |
# |    explained_variance   | 0.162      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0167     |
# |    n_updates            | 100        |
# |    policy_gradient_loss | -0.0102    |
# |    value_loss           | 0.000108   |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 335          |
# |    ep_rew_mean          | 0.0786       |
# | time/                   |              |
# |    fps                  | 717          |
# |    iterations           | 12           |
# |    time_elapsed         | 34           |
# |    total_timesteps      | 24576        |
# | train/                  |              |
# |    approx_kl            | 0.0105271805 |
# |    clip_fraction        | 0.118        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.899       |
# |    explained_variance   | 0.328        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0212      |
# |    n_updates            | 110          |
# |    policy_gradient_loss | -0.00804     |
# |    value_loss           | 0.000166     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.0938      |
# | time/                   |             |
# |    fps                  | 723         |
# |    iterations           | 13          |
# |    time_elapsed         | 36          |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.015526725 |
# |    clip_fraction        | 0.118       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.871      |
# |    explained_variance   | 0.385       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0151     |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.00938    |
# |    value_loss           | 0.000209    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.112       |
# | time/                   |             |
# |    fps                  | 719         |
# |    iterations           | 14          |
# |    time_elapsed         | 39          |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.014001006 |
# |    clip_fraction        | 0.169       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.817      |
# |    explained_variance   | 0.469       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.036      |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.00314    |
# |    value_loss           | 0.000367    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.128       |
# | time/                   |             |
# |    fps                  | 720         |
# |    iterations           | 15          |
# |    time_elapsed         | 42          |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.013964078 |
# |    clip_fraction        | 0.19        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.766      |
# |    explained_variance   | 0.469       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00307    |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.00106    |
# |    value_loss           | 9.99e-05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.144       |
# | time/                   |             |
# |    fps                  | 725         |
# |    iterations           | 16          |
# |    time_elapsed         | 45          |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.017503256 |
# |    clip_fraction        | 0.198       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.711      |
# |    explained_variance   | 0.552       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00775    |
# |    n_updates            | 150         |
# |    policy_gradient_loss | 0.0067      |
# |    value_loss           | 0.00019     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.164       |
# | time/                   |             |
# |    fps                  | 730         |
# |    iterations           | 17          |
# |    time_elapsed         | 47          |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.011940836 |
# |    clip_fraction        | 0.165       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.71       |
# |    explained_variance   | 0.608       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0133     |
# |    n_updates            | 160         |
# |    policy_gradient_loss | 0.0044      |
# |    value_loss           | 0.000163    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.193       |
# | time/                   |             |
# |    fps                  | 733         |
# |    iterations           | 18          |
# |    time_elapsed         | 50          |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.009771998 |
# |    clip_fraction        | 0.162       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.694      |
# |    explained_variance   | 0.701       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0102      |
# |    n_updates            | 170         |
# |    policy_gradient_loss | 0.00459     |
# |    value_loss           | 0.000334    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.218       |
# | time/                   |             |
# |    fps                  | 734         |
# |    iterations           | 19          |
# |    time_elapsed         | 52          |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.010130971 |
# |    clip_fraction        | 0.136       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.604      |
# |    explained_variance   | 0.75        |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.012      |
# |    n_updates            | 180         |
# |    policy_gradient_loss | 0.000193    |
# |    value_loss           | 0.000202    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.241       |
# | time/                   |             |
# |    fps                  | 730         |
# |    iterations           | 20          |
# |    time_elapsed         | 56          |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.013130177 |
# |    clip_fraction        | 0.189       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.587      |
# |    explained_variance   | 0.778       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0146     |
# |    n_updates            | 190         |
# |    policy_gradient_loss | 0.00441     |
# |    value_loss           | 0.000579    |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 335       |
# |    ep_rew_mean          | 0.264     |
# | time/                   |           |
# |    fps                  | 731       |
# |    iterations           | 21        |
# |    time_elapsed         | 58        |
# |    total_timesteps      | 43008     |
# | train/                  |           |
# |    approx_kl            | 0.0474654 |
# |    clip_fraction        | 0.182     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.533    |
# |    explained_variance   | 0.745     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.0449    |
# |    n_updates            | 200       |
# |    policy_gradient_loss | 0.00831   |
# |    value_loss           | 0.000116  |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.288       |
# | time/                   |             |
# |    fps                  | 733         |
# |    iterations           | 22          |
# |    time_elapsed         | 61          |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.019422881 |
# |    clip_fraction        | 0.162       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.484      |
# |    explained_variance   | 0.771       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0224     |
# |    n_updates            | 210         |
# |    policy_gradient_loss | 0.000217    |
# |    value_loss           | 0.000145    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 335        |
# |    ep_rew_mean          | 0.31       |
# | time/                   |            |
# |    fps                  | 735        |
# |    iterations           | 23         |
# |    time_elapsed         | 64         |
# |    total_timesteps      | 47104      |
# | train/                  |            |
# |    approx_kl            | 0.05695708 |
# |    clip_fraction        | 0.16       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.472     |
# |    explained_variance   | 0.796      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.031     |
# |    n_updates            | 220        |
# |    policy_gradient_loss | 0.00725    |
# |    value_loss           | 0.000313   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.335       |
# | time/                   |             |
# |    fps                  | 737         |
# |    iterations           | 24          |
# |    time_elapsed         | 66          |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.012510184 |
# |    clip_fraction        | 0.149       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.485      |
# |    explained_variance   | 0.697       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0871      |
# |    n_updates            | 230         |
# |    policy_gradient_loss | 0.00813     |
# |    value_loss           | 0.000591    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.359       |
# | time/                   |             |
# |    fps                  | 739         |
# |    iterations           | 25          |
# |    time_elapsed         | 69          |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.027630337 |
# |    clip_fraction        | 0.145       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.468      |
# |    explained_variance   | 0.737       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00176    |
# |    n_updates            | 240         |
# |    policy_gradient_loss | 0.00666     |
# |    value_loss           | 0.00015     |
# -----------------------------------------
#          Method  Cumulative Return  Sharpe Ratio  Sortino Ratio  Max Drawdown
# 0   Bi-LSTM PPO           1.658700      0.616852       1.689079     -0.004952
# 1    Simple PPO           1.533760      0.468419       1.000540     -0.006661
# 2  Buy-and-Hold           0.280209           NaN            NaN           NaN
