# %%
import pandas as pd
import numpy as np
import torch
import torch.nn as nn
from sklearn.preprocessing import MinMaxScaler
from torch.utils.data import DataLoader, TensorDataset
from stable_baselines3 import PPO
from gym import spaces, Env
import matplotlib.pyplot as plt
import random

# Set seed for reproducibility
SEED = 42
random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)
if torch.cuda.is_available():
    torch.cuda.manual_seed_all(SEED)

# Load and preprocess data
def load_and_preprocess(file_name):
    data = pd.read_csv(file_name)
    data["Date"] = pd.to_datetime(data["Date"])
    data = data.sort_values(by="Date")

    numeric_data = data.drop(columns=["Date"])
    numeric_data = numeric_data[['Close'] + [col for col in numeric_data.columns if col != 'Close']]

    scaler = MinMaxScaler()
    normalized_data = scaler.fit_transform(numeric_data)
    data[numeric_data.columns] = normalized_data

    return data, scaler

# Create sequences for time series modeling
def create_sequences(data, sequence_length=30):
    sequences = []
    targets = []
    for i in range(len(data) - sequence_length):
        seq = data[i:i+sequence_length]
        target = data[i+sequence_length, 0]  # Assuming the target is the first column (e.g., Close price)
        sequences.append(seq)
        targets.append(target)
    return np.array(sequences), np.array(targets)

# Define Bi-LSTM model
class BiLSTMModel(nn.Module):
    def __init__(self, input_dim, hidden_dim, num_layers, dropout):
        super(BiLSTMModel, self).__init__()
        self.bilstm = nn.LSTM(input_dim, hidden_dim, num_layers, batch_first=True, dropout=dropout, bidirectional=True)
        self.fc = nn.Linear(hidden_dim * 2, 1)

    def forward(self, x):
        bilstm_out, _ = self.bilstm(x)
        return self.fc(bilstm_out[:, -1, :])

# Custom trading environment
class TradingEnv(Env):
    def __init__(self, data, sequence_length=30):
        super(TradingEnv, self).__init__()
        self.data = data
        self.sequence_length = sequence_length
        self.current_step = 0
        self.total_steps = len(data) - sequence_length
        self.portfolio_value = 1.0

        # Action and observation space
        self.action_space = spaces.Discrete(3)  # 0: Hold, 1: Buy, 2: Sell
        self.observation_space = spaces.Box(low=0, high=1, shape=(sequence_length, data.shape[1]), dtype=np.float32)

    def reset(self):
        self.current_step = 0
        self.portfolio_value = 1.0
        return self._next_observation()

    def _next_observation(self):
        return self.data[self.current_step:self.current_step + self.sequence_length]

    def step(self, action):
        self.current_step += 1
        reward = 0
        done = self.current_step >= self.total_steps

        if not done:
            current_price = self.data[self.current_step, 0]
            prev_price = self.data[self.current_step - 1, 0]

            if action == 1:  # Buy
                reward = current_price - prev_price
            elif action == 2:  # Sell
                reward = prev_price - current_price

        self.portfolio_value += reward
        obs = self._next_observation() if not done else None
        return obs, reward, done, {"portfolio_value": self.portfolio_value}

# Evaluate trading strategy
def evaluate_trading_strategy(env, model):
    obs = env.reset()
    done = False
    portfolio_values = [1.0]

    while not done:
        action, _ = model.predict(obs, deterministic=True)
        obs, reward, done, info = env.step(action)
        portfolio_values.append(info.get("portfolio_value", 1.0))

    return portfolio_values

# Performance metrics
def calculate_metrics(portfolio_values):
    daily_returns = np.diff(portfolio_values) / portfolio_values[:-1]
    cumulative_return = portfolio_values[-1] / portfolio_values[0] - 1
    sharpe_ratio = np.mean(daily_returns) / np.std(daily_returns) if np.std(daily_returns) > 0 else 0
    sortino_ratio = np.mean(daily_returns) / np.std([r for r in daily_returns if r < 0]) if np.std([r for r in daily_returns if r < 0]) > 0 else 0
    max_drawdown = np.min(portfolio_values / np.maximum.accumulate(portfolio_values) - 1)
    return cumulative_return, sharpe_ratio, sortino_ratio, max_drawdown

# Main execution
if __name__ == "__main__":
    # Load data
    data, scaler = load_and_preprocess("Book1.csv")
    train_data = data[(data["Date"].dt.year >= 2017) & (data["Date"].dt.year <= 2023)].drop(columns=["Date"]).values
    test_data = data[data["Date"].dt.year == 2024].drop(columns=["Date"]).values

    X_train, y_train = create_sequences(train_data)
    X_test, y_test = create_sequences(test_data)

    # Train Bi-LSTM model
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    bilstm_model = BiLSTMModel(input_dim=X_train.shape[2], hidden_dim=224, num_layers=1, dropout=0.14).to(device)
    criterion = nn.MSELoss()
    optimizer = torch.optim.Adam(bilstm_model.parameters(), lr=0.0019)

    train_loader = DataLoader(TensorDataset(torch.tensor(X_train, dtype=torch.float32), torch.tensor(y_train, dtype=torch.float32)), batch_size=32, shuffle=True)

    for epoch in range(50):
        bilstm_model.train()
        train_loss = 0.0
        for X_batch, y_batch in train_loader:
            X_batch, y_batch = X_batch.to(device), y_batch.to(device)
            optimizer.zero_grad()
            predictions = bilstm_model(X_batch).squeeze()
            loss = criterion(predictions, y_batch)
            loss.backward()
            optimizer.step()
            train_loss += loss.item()

    # Create environments for PPO
    bilstm_env = TradingEnv(test_data)
    simple_env = TradingEnv(test_data)

    # Train PPO models
    ppo_bilstm_model = PPO("MlpPolicy", bilstm_env, learning_rate=0.0014, batch_size=160, n_steps=1280, gamma=0.9005911776350177, verbose=1)
    ppo_bilstm_model.learn(total_timesteps=50000)

    ppo_simple_model = PPO("MlpPolicy", simple_env, verbose=1)
    ppo_simple_model.learn(total_timesteps=50000)

    # Evaluate strategies
    portfolio_values_bilstm = evaluate_trading_strategy(bilstm_env, ppo_bilstm_model)
    portfolio_values_simple = evaluate_trading_strategy(simple_env, ppo_simple_model)

    cumulative_return_bilstm, sharpe_bilstm, sortino_bilstm, max_drawdown_bilstm = calculate_metrics(portfolio_values_bilstm)
    cumulative_return_simple, sharpe_simple, sortino_simple, max_drawdown_simple = calculate_metrics(portfolio_values_simple)

    # Buy-and-Hold strategy
    buy_hold_return = test_data[-1, 0] / test_data[0, 0] - 1

    # Print results
    results = pd.DataFrame({
        "Method": ["Bi-LSTM PPO", "Simple PPO", "Buy-and-Hold"],
        "Cumulative Return": [cumulative_return_bilstm, cumulative_return_simple, buy_hold_return],
        "Sharpe Ratio": [sharpe_bilstm, sharpe_simple, None],
        "Sortino Ratio": [sortino_bilstm, sortino_simple, None],
        "Max Drawdown": [max_drawdown_bilstm, max_drawdown_simple, None]
    })
    print(results)

    # Plot cumulative returns
    test_dates = pd.date_range(start="2024-01-01", periods=len(portfolio_values_bilstm))

    plt.figure(figsize=(12, 6))
    plt.plot(test_dates, np.cumprod([1 + r for r in np.diff(portfolio_values_bilstm) / portfolio_values_bilstm[:-1]]), label="Bi-LSTM PPO")
    plt.plot(test_dates, np.cumprod([1 + r for r in np.diff(portfolio_values_simple) / portfolio_values_simple[:-1]]), label="Simple PPO")
    plt.axhline(1 + buy_hold_return, color="orange", linestyle="--", label="Buy-and-Hold")
    plt.legend()
    plt.title("Cumulative Returns")
    plt.show()
# Out:
# C:\Users\User\anaconda3\envs\RL\Lib\site-packages\torch\nn\modules\rnn.py:123: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.14 and num_layers=1
#   warnings.warn(
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# C:\Users\User\anaconda3\envs\RL\Lib\site-packages\stable_baselines3\common\vec_env\patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 335      |
# |    ep_rew_mean     | -0.0278  |
# | time/              |          |
# |    fps             | 927      |
# |    iterations      | 1        |
# |    time_elapsed    | 1        |
# |    total_timesteps | 1280     |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 335          |
# |    ep_rew_mean          | 0.0264       |
# | time/                   |              |
# |    fps                  | 734          |
# |    iterations           | 2            |
# |    time_elapsed         | 3            |
# |    total_timesteps      | 2560         |
# | train/                  |              |
# |    approx_kl            | 0.0096405195 |
# |    clip_fraction        | 0.089        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.09        |
# |    explained_variance   | -5.04        |
# |    learning_rate        | 0.0014       |
# |    loss                 | -0.0268      |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.0051      |
# |    value_loss           | 0.0542       |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 335        |
# |    ep_rew_mean          | 0.0699     |
# | time/                   |            |
# |    fps                  | 716        |
# |    iterations           | 3          |
# |    time_elapsed         | 5          |
# |    total_timesteps      | 3840       |
# | train/                  |            |
# |    approx_kl            | 0.01519819 |
# |    clip_fraction        | 0.131      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.09      |
# |    explained_variance   | -0.113     |
# |    learning_rate        | 0.0014     |
# |    loss                 | -0.00469   |
# |    n_updates            | 20         |
# |    policy_gradient_loss | -0.006     |
# |    value_loss           | 0.00135    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.163       |
# | time/                   |             |
# |    fps                  | 698         |
# |    iterations           | 4           |
# |    time_elapsed         | 7           |
# |    total_timesteps      | 5120        |
# | train/                  |             |
# |    approx_kl            | 0.013502781 |
# |    clip_fraction        | 0.206       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.06       |
# |    explained_variance   | -0.151      |
# |    learning_rate        | 0.0014      |
# |    loss                 | 0.0157      |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0129     |
# |    value_loss           | 0.00094     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.29        |
# | time/                   |             |
# |    fps                  | 685         |
# |    iterations           | 5           |
# |    time_elapsed         | 9           |
# |    total_timesteps      | 6400        |
# | train/                  |             |
# |    approx_kl            | 0.017312646 |
# |    clip_fraction        | 0.268       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.01       |
# |    explained_variance   | 0.0222      |
# |    learning_rate        | 0.0014      |
# |    loss                 | -0.0343     |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0136     |
# |    value_loss           | 0.000608    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.35        |
# | time/                   |             |
# |    fps                  | 674         |
# |    iterations           | 6           |
# |    time_elapsed         | 11          |
# |    total_timesteps      | 7680        |
# | train/                  |             |
# |    approx_kl            | 0.016656905 |
# |    clip_fraction        | 0.216       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.972      |
# |    explained_variance   | -0.0378     |
# |    learning_rate        | 0.0014      |
# |    loss                 | 0.00606     |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.00462    |
# |    value_loss           | 0.00087     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.43        |
# | time/                   |             |
# |    fps                  | 669         |
# |    iterations           | 7           |
# |    time_elapsed         | 13          |
# |    total_timesteps      | 8960        |
# | train/                  |             |
# |    approx_kl            | 0.018649418 |
# |    clip_fraction        | 0.284       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.868      |
# |    explained_variance   | 0.0536      |
# |    learning_rate        | 0.0014      |
# |    loss                 | -0.0238     |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.011      |
# |    value_loss           | 0.000787    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.566       |
# | time/                   |             |
# |    fps                  | 666         |
# |    iterations           | 8           |
# |    time_elapsed         | 15          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.012199754 |
# |    clip_fraction        | 0.218       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.793      |
# |    explained_variance   | 0.217       |
# |    learning_rate        | 0.0014      |
# |    loss                 | -0.0271     |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0037     |
# |    value_loss           | 0.000634    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.659       |
# | time/                   |             |
# |    fps                  | 664         |
# |    iterations           | 9           |
# |    time_elapsed         | 17          |
# |    total_timesteps      | 11520       |
# | train/                  |             |
# |    approx_kl            | 0.013150966 |
# |    clip_fraction        | 0.216       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.692      |
# |    explained_variance   | 0.0478      |
# |    learning_rate        | 0.0014      |
# |    loss                 | -0.0163     |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.00355    |
# |    value_loss           | 0.000813    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.767       |
# | time/                   |             |
# |    fps                  | 647         |
# |    iterations           | 10          |
# |    time_elapsed         | 19          |
# |    total_timesteps      | 12800       |
# | train/                  |             |
# |    approx_kl            | 0.022190686 |
# |    clip_fraction        | 0.229       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.636      |
# |    explained_variance   | 0.17        |
# |    learning_rate        | 0.0014      |
# |    loss                 | -0.0187     |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.00602    |
# |    value_loss           | 0.000581    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.84        |
# | time/                   |             |
# |    fps                  | 639         |
# |    iterations           | 11          |
# |    time_elapsed         | 22          |
# |    total_timesteps      | 14080       |
# | train/                  |             |
# |    approx_kl            | 0.022602301 |
# |    clip_fraction        | 0.299       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.572      |
# |    explained_variance   | 0.246       |
# |    learning_rate        | 0.0014      |
# |    loss                 | 0.0224      |
# |    n_updates            | 100         |
# |    policy_gradient_loss | 0.0176      |
# |    value_loss           | 0.000618    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.905       |
# | time/                   |             |
# |    fps                  | 636         |
# |    iterations           | 12          |
# |    time_elapsed         | 24          |
# |    total_timesteps      | 15360       |
# | train/                  |             |
# |    approx_kl            | 0.048066843 |
# |    clip_fraction        | 0.231       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.561      |
# |    explained_variance   | 0.195       |
# |    learning_rate        | 0.0014      |
# |    loss                 | 0.0112      |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.00561    |
# |    value_loss           | 0.00134     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 335        |
# |    ep_rew_mean          | 0.998      |
# | time/                   |            |
# |    fps                  | 635        |
# |    iterations           | 13         |
# |    time_elapsed         | 26         |
# |    total_timesteps      | 16640      |
# | train/                  |            |
# |    approx_kl            | 0.03354552 |
# |    clip_fraction        | 0.303      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.488     |
# |    explained_variance   | 0.223      |
# |    learning_rate        | 0.0014     |
# |    loss                 | 0.00755    |
# |    n_updates            | 120        |
# |    policy_gradient_loss | 0.0347     |
# |    value_loss           | 0.000589   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 335        |
# |    ep_rew_mean          | 1.08       |
# | time/                   |            |
# |    fps                  | 635        |
# |    iterations           | 14         |
# |    time_elapsed         | 28         |
# |    total_timesteps      | 17920      |
# | train/                  |            |
# |    approx_kl            | 0.06684271 |
# |    clip_fraction        | 0.174      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.493     |
# |    explained_variance   | 0.4        |
# |    learning_rate        | 0.0014     |
# |    loss                 | 0.0991     |
# |    n_updates            | 130        |
# |    policy_gradient_loss | -0.00141   |
# |    value_loss           | 0.00112    |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 335        |
# |    ep_rew_mean          | 1.16       |
# | time/                   |            |
# |    fps                  | 635        |
# |    iterations           | 15         |
# |    time_elapsed         | 30         |
# |    total_timesteps      | 19200      |
# | train/                  |            |
# |    approx_kl            | 0.12697163 |
# |    clip_fraction        | 0.16       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.38      |
# |    explained_variance   | 0.376      |
# |    learning_rate        | 0.0014     |
# |    loss                 | 0.0111     |
# |    n_updates            | 140        |
# |    policy_gradient_loss | 0.0123     |
# |    value_loss           | 0.000952   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 335        |
# |    ep_rew_mean          | 1.23       |
# | time/                   |            |
# |    fps                  | 635        |
# |    iterations           | 16         |
# |    time_elapsed         | 32         |
# |    total_timesteps      | 20480      |
# | train/                  |            |
# |    approx_kl            | 0.07213907 |
# |    clip_fraction        | 0.234      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.378     |
# |    explained_variance   | 0.421      |
# |    learning_rate        | 0.0014     |
# |    loss                 | -0.0108    |
# |    n_updates            | 150        |
# |    policy_gradient_loss | 0.0215     |
# |    value_loss           | 0.000396   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 1.28        |
# | time/                   |             |
# |    fps                  | 631         |
# |    iterations           | 17          |
# |    time_elapsed         | 34          |
# |    total_timesteps      | 21760       |
# | train/                  |             |
# |    approx_kl            | 0.057218995 |
# |    clip_fraction        | 0.23        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.332      |
# |    explained_variance   | 0.444       |
# |    learning_rate        | 0.0014      |
# |    loss                 | 0.0536      |
# |    n_updates            | 160         |
# |    policy_gradient_loss | 0.0372      |
# |    value_loss           | 0.000537    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 1.34        |
# | time/                   |             |
# |    fps                  | 627         |
# |    iterations           | 18          |
# |    time_elapsed         | 36          |
# |    total_timesteps      | 23040       |
# | train/                  |             |
# |    approx_kl            | 0.062915996 |
# |    clip_fraction        | 0.165       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.263      |
# |    explained_variance   | 0.522       |
# |    learning_rate        | 0.0014      |
# |    loss                 | 0.0512      |
# |    n_updates            | 170         |
# |    policy_gradient_loss | 0.0207      |
# |    value_loss           | 0.000485    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 335        |
# |    ep_rew_mean          | 1.41       |
# | time/                   |            |
# |    fps                  | 623        |
# |    iterations           | 19         |
# |    time_elapsed         | 39         |
# |    total_timesteps      | 24320      |
# | train/                  |            |
# |    approx_kl            | 0.19506525 |
# |    clip_fraction        | 0.21       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.296     |
# |    explained_variance   | 0.493      |
# |    learning_rate        | 0.0014     |
# |    loss                 | 0.048      |
# |    n_updates            | 180        |
# |    policy_gradient_loss | -0.00333   |
# |    value_loss           | 0.000464   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 335        |
# |    ep_rew_mean          | 1.47       |
# | time/                   |            |
# |    fps                  | 623        |
# |    iterations           | 20         |
# |    time_elapsed         | 41         |
# |    total_timesteps      | 25600      |
# | train/                  |            |
# |    approx_kl            | 0.03493669 |
# |    clip_fraction        | 0.205      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.275     |
# |    explained_variance   | 0.57       |
# |    learning_rate        | 0.0014     |
# |    loss                 | -0.00259   |
# |    n_updates            | 190        |
# |    policy_gradient_loss | 0.0344     |
# |    value_loss           | 0.00218    |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 335        |
# |    ep_rew_mean          | 1.51       |
# | time/                   |            |
# |    fps                  | 624        |
# |    iterations           | 21         |
# |    time_elapsed         | 43         |
# |    total_timesteps      | 26880      |
# | train/                  |            |
# |    approx_kl            | 0.06408526 |
# |    clip_fraction        | 0.234      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.292     |
# |    explained_variance   | 0.179      |
# |    learning_rate        | 0.0014     |
# |    loss                 | -0.019     |
# |    n_updates            | 200        |
# |    policy_gradient_loss | 0.0224     |
# |    value_loss           | 0.00413    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 1.55        |
# | time/                   |             |
# |    fps                  | 625         |
# |    iterations           | 22          |
# |    time_elapsed         | 45          |
# |    total_timesteps      | 28160       |
# | train/                  |             |
# |    approx_kl            | 0.036365118 |
# |    clip_fraction        | 0.22        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.263      |
# |    explained_variance   | 0.102       |
# |    learning_rate        | 0.0014      |
# |    loss                 | 0.0132      |
# |    n_updates            | 210         |
# |    policy_gradient_loss | 0.0227      |
# |    value_loss           | 0.00107     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 335        |
# |    ep_rew_mean          | 1.58       |
# | time/                   |            |
# |    fps                  | 626        |
# |    iterations           | 23         |
# |    time_elapsed         | 46         |
# |    total_timesteps      | 29440      |
# | train/                  |            |
# |    approx_kl            | 0.10742902 |
# |    clip_fraction        | 0.245      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.262     |
# |    explained_variance   | 0.254      |
# |    learning_rate        | 0.0014     |
# |    loss                 | 0.0295     |
# |    n_updates            | 220        |
# |    policy_gradient_loss | 0.0274     |
# |    value_loss           | 0.000547   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 1.61        |
# | time/                   |             |
# |    fps                  | 628         |
# |    iterations           | 24          |
# |    time_elapsed         | 48          |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.110548034 |
# |    clip_fraction        | 0.275       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.246      |
# |    explained_variance   | 0.406       |
# |    learning_rate        | 0.0014      |
# |    loss                 | 0.0345      |
# |    n_updates            | 230         |
# |    policy_gradient_loss | 0.0523      |
# |    value_loss           | 0.000517    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 1.65        |
# | time/                   |             |
# |    fps                  | 625         |
# |    iterations           | 25          |
# |    time_elapsed         | 51          |
# |    total_timesteps      | 32000       |
# | train/                  |             |
# |    approx_kl            | 0.044562444 |
# |    clip_fraction        | 0.19        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.236      |
# |    explained_variance   | 0.564       |
# |    learning_rate        | 0.0014      |
# |    loss                 | -0.00286    |
# |    n_updates            | 240         |
# |    policy_gradient_loss | 0.0182      |
# |    value_loss           | 0.00152     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 335        |
# |    ep_rew_mean          | 1.7        |
# | time/                   |            |
# |    fps                  | 622        |
# |    iterations           | 26         |
# |    time_elapsed         | 53         |
# |    total_timesteps      | 33280      |
# | train/                  |            |
# |    approx_kl            | 0.05302924 |
# |    clip_fraction        | 0.193      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.224     |
# |    explained_variance   | 0.105      |
# |    learning_rate        | 0.0014     |
# |    loss                 | 0.0115     |
# |    n_updates            | 250        |
# |    policy_gradient_loss | 0.0227     |
# |    value_loss           | 0.000924   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 335        |
# |    ep_rew_mean          | 1.8        |
# | time/                   |            |
# |    fps                  | 621        |
# |    iterations           | 27         |
# |    time_elapsed         | 55         |
# |    total_timesteps      | 34560      |
# | train/                  |            |
# |    approx_kl            | 0.03997394 |
# |    clip_fraction        | 0.182      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.222     |
# |    explained_variance   | 0.44       |
# |    learning_rate        | 0.0014     |
# |    loss                 | 0.018      |
# |    n_updates            | 260        |
# |    policy_gradient_loss | 0.0236     |
# |    value_loss           | 0.000458   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 1.88        |
# | time/                   |             |
# |    fps                  | 621         |
# |    iterations           | 28          |
# |    time_elapsed         | 57          |
# |    total_timesteps      | 35840       |
# | train/                  |             |
# |    approx_kl            | 0.015574612 |
# |    clip_fraction        | 0.158       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.229      |
# |    explained_variance   | 0.601       |
# |    learning_rate        | 0.0014      |
# |    loss                 | -0.013      |
# |    n_updates            | 270         |
# |    policy_gradient_loss | 0.0184      |
# |    value_loss           | 0.000459    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 335        |
# |    ep_rew_mean          | 1.99       |
# | time/                   |            |
# |    fps                  | 622        |
# |    iterations           | 29         |
# |    time_elapsed         | 59         |
# |    total_timesteps      | 37120      |
# | train/                  |            |
# |    approx_kl            | 0.04974191 |
# |    clip_fraction        | 0.196      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.215     |
# |    explained_variance   | 0.613      |
# |    learning_rate        | 0.0014     |
# |    loss                 | -0.017     |
# |    n_updates            | 280        |
# |    policy_gradient_loss | 0.054      |
# |    value_loss           | 0.00128    |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 335        |
# |    ep_rew_mean          | 2.09       |
# | time/                   |            |
# |    fps                  | 622        |
# |    iterations           | 30         |
# |    time_elapsed         | 61         |
# |    total_timesteps      | 38400      |
# | train/                  |            |
# |    approx_kl            | 0.02354309 |
# |    clip_fraction        | 0.166      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.194     |
# |    explained_variance   | 0.492      |
# |    learning_rate        | 0.0014     |
# |    loss                 | -0.000993  |
# |    n_updates            | 290        |
# |    policy_gradient_loss | 0.0228     |
# |    value_loss           | 0.0032     |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 2.18        |
# | time/                   |             |
# |    fps                  | 623         |
# |    iterations           | 31          |
# |    time_elapsed         | 63          |
# |    total_timesteps      | 39680       |
# | train/                  |             |
# |    approx_kl            | 0.030626941 |
# |    clip_fraction        | 0.154       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.187      |
# |    explained_variance   | 0.282       |
# |    learning_rate        | 0.0014      |
# |    loss                 | 0.0097      |
# |    n_updates            | 300         |
# |    policy_gradient_loss | 0.0144      |
# |    value_loss           | 0.000553    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 335        |
# |    ep_rew_mean          | 2.25       |
# | time/                   |            |
# |    fps                  | 622        |
# |    iterations           | 32         |
# |    time_elapsed         | 65         |
# |    total_timesteps      | 40960      |
# | train/                  |            |
# |    approx_kl            | 0.12684558 |
# |    clip_fraction        | 0.168      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.161     |
# |    explained_variance   | 0.604      |
# |    learning_rate        | 0.0014     |
# |    loss                 | 0.0356     |
# |    n_updates            | 310        |
# |    policy_gradient_loss | 0.0345     |
# |    value_loss           | 0.000424   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 335        |
# |    ep_rew_mean          | 2.33       |
# | time/                   |            |
# |    fps                  | 619        |
# |    iterations           | 33         |
# |    time_elapsed         | 68         |
# |    total_timesteps      | 42240      |
# | train/                  |            |
# |    approx_kl            | 0.06290579 |
# |    clip_fraction        | 0.294      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.259     |
# |    explained_variance   | 0.432      |
# |    learning_rate        | 0.0014     |
# |    loss                 | -0.0183    |
# |    n_updates            | 320        |
# |    policy_gradient_loss | 0.0319     |
# |    value_loss           | 0.00171    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 2.38        |
# | time/                   |             |
# |    fps                  | 617         |
# |    iterations           | 34          |
# |    time_elapsed         | 70          |
# |    total_timesteps      | 43520       |
# | train/                  |             |
# |    approx_kl            | 0.040600687 |
# |    clip_fraction        | 0.221       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.223      |
# |    explained_variance   | 0.549       |
# |    learning_rate        | 0.0014      |
# |    loss                 | 0.0655      |
# |    n_updates            | 330         |
# |    policy_gradient_loss | 0.0334      |
# |    value_loss           | 0.000896    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 335        |
# |    ep_rew_mean          | 2.43       |
# | time/                   |            |
# |    fps                  | 617        |
# |    iterations           | 35         |
# |    time_elapsed         | 72         |
# |    total_timesteps      | 44800      |
# | train/                  |            |
# |    approx_kl            | 0.17196882 |
# |    clip_fraction        | 0.267      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.202     |
# |    explained_variance   | 0.633      |
# |    learning_rate        | 0.0014     |
# |    loss                 | 0.151      |
# |    n_updates            | 340        |
# |    policy_gradient_loss | 0.0719     |
# |    value_loss           | 0.000585   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 335        |
# |    ep_rew_mean          | 2.45       |
# | time/                   |            |
# |    fps                  | 619        |
# |    iterations           | 36         |
# |    time_elapsed         | 74         |
# |    total_timesteps      | 46080      |
# | train/                  |            |
# |    approx_kl            | 0.10896496 |
# |    clip_fraction        | 0.224      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.229     |
# |    explained_variance   | 0.613      |
# |    learning_rate        | 0.0014     |
# |    loss                 | 0.14       |
# |    n_updates            | 350        |
# |    policy_gradient_loss | 0.0121     |
# |    value_loss           | 0.00185    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 2.48        |
# | time/                   |             |
# |    fps                  | 620         |
# |    iterations           | 37          |
# |    time_elapsed         | 76          |
# |    total_timesteps      | 47360       |
# | train/                  |             |
# |    approx_kl            | 0.085934535 |
# |    clip_fraction        | 0.199       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.251      |
# |    explained_variance   | 0.296       |
# |    learning_rate        | 0.0014      |
# |    loss                 | 0.025       |
# |    n_updates            | 360         |
# |    policy_gradient_loss | 0.00627     |
# |    value_loss           | 0.00224     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 2.51        |
# | time/                   |             |
# |    fps                  | 621         |
# |    iterations           | 38          |
# |    time_elapsed         | 78          |
# |    total_timesteps      | 48640       |
# | train/                  |             |
# |    approx_kl            | 0.063243285 |
# |    clip_fraction        | 0.226       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.255      |
# |    explained_variance   | 0.379       |
# |    learning_rate        | 0.0014      |
# |    loss                 | 0.03        |
# |    n_updates            | 370         |
# |    policy_gradient_loss | 0.00458     |
# |    value_loss           | 0.000543    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 335        |
# |    ep_rew_mean          | 2.55       |
# | time/                   |            |
# |    fps                  | 623        |
# |    iterations           | 39         |
# |    time_elapsed         | 80         |
# |    total_timesteps      | 49920      |
# | train/                  |            |
# |    approx_kl            | 0.15375704 |
# |    clip_fraction        | 0.278      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.231     |
# |    explained_variance   | 0.467      |
# |    learning_rate        | 0.0014     |
# |    loss                 | -0.000358  |
# |    n_updates            | 380        |
# |    policy_gradient_loss | 0.0492     |
# |    value_loss           | 0.00064    |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 335        |
# |    ep_rew_mean          | 2.57       |
# | time/                   |            |
# |    fps                  | 625        |
# |    iterations           | 40         |
# |    time_elapsed         | 81         |
# |    total_timesteps      | 51200      |
# | train/                  |            |
# |    approx_kl            | 0.15087233 |
# |    clip_fraction        | 0.199      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.195     |
# |    explained_variance   | 0.609      |
# |    learning_rate        | 0.0014     |
# |    loss                 | 0.176      |
# |    n_updates            | 390        |
# |    policy_gradient_loss | 0.0435     |
# |    value_loss           | 0.000392   |
# ----------------------------------------
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 335      |
# |    ep_rew_mean     | 0.0017   |
# | time/              |          |
# |    fps             | 1115     |
# |    iterations      | 1        |
# |    time_elapsed    | 1        |
# |    total_timesteps | 2048     |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 335          |
# |    ep_rew_mean          | -0.0196      |
# | time/                   |              |
# |    fps                  | 839          |
# |    iterations           | 2            |
# |    time_elapsed         | 4            |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0066558756 |
# |    clip_fraction        | 0.018        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.09        |
# |    explained_variance   | -2.1         |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.000899    |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.00205     |
# |    value_loss           | 0.00426      |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 335        |
# |    ep_rew_mean          | 0.0393     |
# | time/                   |            |
# |    fps                  | 808        |
# |    iterations           | 3          |
# |    time_elapsed         | 7          |
# |    total_timesteps      | 6144       |
# | train/                  |            |
# |    approx_kl            | 0.00924431 |
# |    clip_fraction        | 0.0611     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.09      |
# |    explained_variance   | 0.252      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0115    |
# |    n_updates            | 20         |
# |    policy_gradient_loss | -0.00285   |
# |    value_loss           | 0.0023     |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 335          |
# |    ep_rew_mean          | 0.046        |
# | time/                   |              |
# |    fps                  | 791          |
# |    iterations           | 4            |
# |    time_elapsed         | 10           |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 0.0076363287 |
# |    clip_fraction        | 0.0703       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.08        |
# |    explained_variance   | 0.639        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0153       |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.00586     |
# |    value_loss           | 0.00184      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.066       |
# | time/                   |             |
# |    fps                  | 784         |
# |    iterations           | 5           |
# |    time_elapsed         | 13          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.009892174 |
# |    clip_fraction        | 0.107       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.06       |
# |    explained_variance   | 0.619       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00632    |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.00988    |
# |    value_loss           | 0.00206     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.144       |
# | time/                   |             |
# |    fps                  | 763         |
# |    iterations           | 6           |
# |    time_elapsed         | 16          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.009320978 |
# |    clip_fraction        | 0.132       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.03       |
# |    explained_variance   | 0.613       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00483    |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.00743    |
# |    value_loss           | 0.00233     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.21        |
# | time/                   |             |
# |    fps                  | 737         |
# |    iterations           | 7           |
# |    time_elapsed         | 19          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.013384804 |
# |    clip_fraction        | 0.206       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.99       |
# |    explained_variance   | 0.58        |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00515    |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.00978    |
# |    value_loss           | 0.00183     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 335        |
# |    ep_rew_mean          | 0.292      |
# | time/                   |            |
# |    fps                  | 737        |
# |    iterations           | 8          |
# |    time_elapsed         | 22         |
# |    total_timesteps      | 16384      |
# | train/                  |            |
# |    approx_kl            | 0.01464111 |
# |    clip_fraction        | 0.176      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.951     |
# |    explained_variance   | 0.337      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0176    |
# |    n_updates            | 70         |
# |    policy_gradient_loss | -0.00812   |
# |    value_loss           | 0.00158    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.386       |
# | time/                   |             |
# |    fps                  | 739         |
# |    iterations           | 9           |
# |    time_elapsed         | 24          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.005838404 |
# |    clip_fraction        | 0.137       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.889      |
# |    explained_variance   | 0.492       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0132     |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.00504    |
# |    value_loss           | 0.0016      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.476       |
# | time/                   |             |
# |    fps                  | 741         |
# |    iterations           | 10          |
# |    time_elapsed         | 27          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.007901406 |
# |    clip_fraction        | 0.142       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.862      |
# |    explained_variance   | 0.112       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0259      |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.00533    |
# |    value_loss           | 0.00189     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.559       |
# | time/                   |             |
# |    fps                  | 745         |
# |    iterations           | 11          |
# |    time_elapsed         | 30          |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.013463319 |
# |    clip_fraction        | 0.156       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.81       |
# |    explained_variance   | 0.456       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.022       |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.0025     |
# |    value_loss           | 0.00123     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.636       |
# | time/                   |             |
# |    fps                  | 734         |
# |    iterations           | 12          |
# |    time_elapsed         | 33          |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.023676448 |
# |    clip_fraction        | 0.173       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.72       |
# |    explained_variance   | 0.442       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0149     |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.00416    |
# |    value_loss           | 0.00164     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 335        |
# |    ep_rew_mean          | 0.71       |
# | time/                   |            |
# |    fps                  | 731        |
# |    iterations           | 13         |
# |    time_elapsed         | 36         |
# |    total_timesteps      | 26624      |
# | train/                  |            |
# |    approx_kl            | 0.01767848 |
# |    clip_fraction        | 0.128      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.686     |
# |    explained_variance   | 0.559      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.00618    |
# |    n_updates            | 120        |
# |    policy_gradient_loss | -0.000373  |
# |    value_loss           | 0.0014     |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.785       |
# | time/                   |             |
# |    fps                  | 730         |
# |    iterations           | 14          |
# |    time_elapsed         | 39          |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.018502554 |
# |    clip_fraction        | 0.15        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.636      |
# |    explained_variance   | 0.622       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.04       |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.00565    |
# |    value_loss           | 0.00136     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.86        |
# | time/                   |             |
# |    fps                  | 733         |
# |    iterations           | 15          |
# |    time_elapsed         | 41          |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.013445814 |
# |    clip_fraction        | 0.145       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.625      |
# |    explained_variance   | 0.743       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0284     |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.00416    |
# |    value_loss           | 0.000939    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.933       |
# | time/                   |             |
# |    fps                  | 735         |
# |    iterations           | 16          |
# |    time_elapsed         | 44          |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.024921646 |
# |    clip_fraction        | 0.199       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.576      |
# |    explained_variance   | 0.791       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.011      |
# |    n_updates            | 150         |
# |    policy_gradient_loss | 0.0138      |
# |    value_loss           | 0.00112     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 1.03        |
# | time/                   |             |
# |    fps                  | 734         |
# |    iterations           | 17          |
# |    time_elapsed         | 47          |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.017496547 |
# |    clip_fraction        | 0.174       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.537      |
# |    explained_variance   | 0.836       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0285     |
# |    n_updates            | 160         |
# |    policy_gradient_loss | 0.00706     |
# |    value_loss           | 0.00094     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 1.18        |
# | time/                   |             |
# |    fps                  | 725         |
# |    iterations           | 18          |
# |    time_elapsed         | 50          |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.012731498 |
# |    clip_fraction        | 0.18        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.529      |
# |    explained_variance   | 0.855       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00841     |
# |    n_updates            | 170         |
# |    policy_gradient_loss | 0.0124      |
# |    value_loss           | 0.00132     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 1.31        |
# | time/                   |             |
# |    fps                  | 719         |
# |    iterations           | 19          |
# |    time_elapsed         | 54          |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.025889628 |
# |    clip_fraction        | 0.182       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.504      |
# |    explained_variance   | 0.883       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0247     |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.00126    |
# |    value_loss           | 0.00103     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 1.43        |
# | time/                   |             |
# |    fps                  | 714         |
# |    iterations           | 20          |
# |    time_elapsed         | 57          |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.011336903 |
# |    clip_fraction        | 0.138       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.456      |
# |    explained_variance   | 0.885       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0162     |
# |    n_updates            | 190         |
# |    policy_gradient_loss | 0.00136     |
# |    value_loss           | 0.00182     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 1.58        |
# | time/                   |             |
# |    fps                  | 716         |
# |    iterations           | 21          |
# |    time_elapsed         | 60          |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.026630977 |
# |    clip_fraction        | 0.163       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.42       |
# |    explained_variance   | 0.891       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0118     |
# |    n_updates            | 200         |
# |    policy_gradient_loss | 0.0105      |
# |    value_loss           | 0.000918    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 1.7         |
# | time/                   |             |
# |    fps                  | 711         |
# |    iterations           | 22          |
# |    time_elapsed         | 63          |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.021649582 |
# |    clip_fraction        | 0.167       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.388      |
# |    explained_variance   | 0.925       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0132     |
# |    n_updates            | 210         |
# |    policy_gradient_loss | 0.016       |
# |    value_loss           | 0.0022      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 1.81        |
# | time/                   |             |
# |    fps                  | 701         |
# |    iterations           | 23          |
# |    time_elapsed         | 67          |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.022438608 |
# |    clip_fraction        | 0.166       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.396      |
# |    explained_variance   | 0.944       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0069      |
# |    n_updates            | 220         |
# |    policy_gradient_loss | 0.00527     |
# |    value_loss           | 0.000811    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 1.92        |
# | time/                   |             |
# |    fps                  | 696         |
# |    iterations           | 24          |
# |    time_elapsed         | 70          |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.030780988 |
# |    clip_fraction        | 0.189       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.379      |
# |    explained_variance   | 0.935       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0453      |
# |    n_updates            | 230         |
# |    policy_gradient_loss | 0.0289      |
# |    value_loss           | 0.00127     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 2.02        |
# | time/                   |             |
# |    fps                  | 691         |
# |    iterations           | 25          |
# |    time_elapsed         | 74          |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.019446807 |
# |    clip_fraction        | 0.164       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.356      |
# |    explained_variance   | 0.955       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0173      |
# |    n_updates            | 240         |
# |    policy_gradient_loss | 0.0181      |
# |    value_loss           | 0.00171     |
# -----------------------------------------
#          Method  Cumulative Return  Sharpe Ratio  Sortino Ratio  Max Drawdown
# 0   Bi-LSTM PPO           3.257826      0.621625       1.645524     -0.017483
# 1    Simple PPO           2.494986      0.454871       0.824064     -0.034865
# 2  Buy-and-Hold           1.121353           NaN            NaN           NaN
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 184
#     181 test_dates = pd.date_range(start="2024-01-01", periods=len(portfolio_values_bilstm))
#     183 plt.figure(figsize=(12, 6))
# --> 184 plt.plot(test_dates, np.cumprod([1 + r for r in np.diff(portfolio_values_bilstm) / portfolio_values_bilstm[:-1]]), label="Bi-LSTM PPO")
#     185 plt.plot(test_dates, np.cumprod([1 + r for r in np.diff(portfolio_values_simple) / portfolio_values_simple[:-1]]), label="Simple PPO")
#     186 plt.axhline(1 + buy_hold_return, color="orange", linestyle="--", label="Buy-and-Hold")
#
# File ~\anaconda3\envs\RL\Lib\site-packages\matplotlib\pyplot.py:3794, in plot(scalex, scaley, data, *args, **kwargs)
#    3786 @_copy_docstring_and_deprecators(Axes.plot)
#    3787 def plot(
#    3788     *args: float | ArrayLike | str,
#    (...)
#    3792     **kwargs,
#    3793 ) -> list[Line2D]:
# -> 3794     return gca().plot(
#    3795         *args,
#    3796         scalex=scalex,
#    3797         scaley=scaley,
#    3798         **({"data": data} if data is not None else {}),
#    3799         **kwargs,
#    3800     )
#
# File ~\anaconda3\envs\RL\Lib\site-packages\matplotlib\axes\_axes.py:1779, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1536 """
#    1537 Plot y versus x as lines and/or markers.
#    1538
#    (...)
#    1776 (``'green'``) or hex strings (``'#008000'``).
#    1777 """
#    1778 kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1779 lines = [*self._get_lines(self, *args, data=data, **kwargs)]
#    1780 for line in lines:
#    1781     self.add_line(line)
#
# File ~\anaconda3\envs\RL\Lib\site-packages\matplotlib\axes\_base.py:296, in _process_plot_var_args.__call__(self, axes, data, *args, **kwargs)
#     294     this += args[0],
#     295     args = args[1:]
# --> 296 yield from self._plot_args(
#     297     axes, this, kwargs, ambiguous_fmt_datakey=ambiguous_fmt_datakey)
#
# File ~\anaconda3\envs\RL\Lib\site-packages\matplotlib\axes\_base.py:486, in _process_plot_var_args._plot_args(self, axes, tup, kwargs, return_kwargs, ambiguous_fmt_datakey)
#     483     axes.yaxis.update_units(y)
#     485 if x.shape[0] != y.shape[0]:
# --> 486     raise ValueError(f"x and y must have same first dimension, but "
#     487                      f"have shapes {x.shape} and {y.shape}")
#     488 if x.ndim > 2 or y.ndim > 2:
#     489     raise ValueError(f"x and y can be no greater than 2D, but have "
#     490                      f"shapes {x.shape} and {y.shape}")
#
# ValueError: x and y must have same first dimension, but have shapes (336,) and (335,)
