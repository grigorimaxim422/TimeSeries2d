# %%
import pandas as pd
import numpy as np
import torch
import torch.nn as nn
from sklearn.preprocessing import MinMaxScaler
from torch.utils.data import DataLoader, TensorDataset
from stable_baselines3 import PPO
from gym import spaces, Env
import matplotlib.pyplot as plt
import random

# Set seed for reproducibility
SEED = 42
random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)
if torch.cuda.is_available():
    torch.cuda.manual_seed_all(SEED)

# Load and preprocess data
def load_and_preprocess(file_name):
    data = pd.read_csv(file_name)
    data["Date"] = pd.to_datetime(data["Date"])
    data = data.sort_values(by="Date")
    
    numeric_data = data.drop(columns=["Date"])
    numeric_data = numeric_data[['Close'] + [col for col in numeric_data.columns if col != 'Close']]
    
    scaler = MinMaxScaler()
    normalized_data = scaler.fit_transform(numeric_data)
    data[numeric_data.columns] = normalized_data
    
    return data, scaler

# Create sequences for time series modeling
def create_sequences(data, sequence_length=30):
    sequences = []
    targets = []
    for i in range(len(data) - sequence_length):
        seq = data[i:i+sequence_length]
        target = data[i+sequence_length, 0]  # Assuming the target is the first column (e.g., Close price)
        sequences.append(seq)
        targets.append(target)
    return np.array(sequences), np.array(targets)

# Define Bi-LSTM model
class BiLSTMModel(nn.Module):
    def __init__(self, input_dim, hidden_dim, num_layers, dropout):
        super(BiLSTMModel, self).__init__()
        self.bilstm = nn.LSTM(input_dim, hidden_dim, num_layers, batch_first=True, dropout=dropout, bidirectional=True)
        self.fc = nn.Linear(hidden_dim * 2, 1)

    def forward(self, x):
        bilstm_out, _ = self.bilstm(x)
        return self.fc(bilstm_out[:, -1, :])

# Custom trading environment
class TradingEnv(Env):
    def __init__(self, data, sequence_length=30):
        super(TradingEnv, self).__init__()
        self.data = data
        self.sequence_length = sequence_length
        self.current_step = 0
        self.total_steps = len(data) - sequence_length
        self.portfolio_value = 1.0

        # Action and observation space
        self.action_space = spaces.Discrete(3)  # 0: Hold, 1: Buy, 2: Sell
        self.observation_space = spaces.Box(low=0, high=1, shape=(sequence_length, data.shape[1]), dtype=np.float32)

    def reset(self):
        self.current_step = 0
        self.portfolio_value = 1.0
        return self._next_observation()

    def _next_observation(self):
        return self.data[self.current_step:self.current_step + self.sequence_length]

    def step(self, action):
        self.current_step += 1
        reward = 0
        done = self.current_step >= self.total_steps

        if not done:
            current_price = self.data[self.current_step, 0]
            prev_price = self.data[self.current_step - 1, 0]

            if action == 1:  # Buy
                reward = current_price - prev_price
            elif action == 2:  # Sell
                reward = prev_price - current_price

        self.portfolio_value += reward
        obs = self._next_observation() if not done else None
        return obs, reward, done, {"portfolio_value": self.portfolio_value}

# Evaluate trading strategy
def evaluate_trading_strategy(env, model):
    obs = env.reset()
    done = False
    portfolio_values = [1.0]

    while not done:
        action, _ = model.predict(obs, deterministic=True)
        obs, reward, done, info = env.step(action)
        portfolio_values.append(info.get("portfolio_value", 1.0))

    return portfolio_values

# Performance metrics
def calculate_metrics(portfolio_values):
    daily_returns = np.diff(portfolio_values) / portfolio_values[:-1]
    cumulative_return = portfolio_values[-1] / portfolio_values[0] - 1
    sharpe_ratio = np.mean(daily_returns) / np.std(daily_returns) if np.std(daily_returns) > 0 else 0
    sortino_ratio = np.mean(daily_returns) / np.std([r for r in daily_returns if r < 0]) if np.std([r for r in daily_returns if r < 0]) > 0 else 0
    max_drawdown = np.min(portfolio_values / np.maximum.accumulate(portfolio_values) - 1)
    return cumulative_return, sharpe_ratio, sortino_ratio, max_drawdown

# Main execution
if __name__ == "__main__":
    # Load data
    data, scaler = load_and_preprocess("Book3.csv")
    train_data = data[(data["Date"].dt.year >= 2017) & (data["Date"].dt.year <= 2023)].drop(columns=["Date"]).values
    test_data = data[data["Date"].dt.year == 2024].drop(columns=["Date"]).values

    X_train, y_train = create_sequences(train_data)
    X_test, y_test = create_sequences(test_data)

    # Train Bi-LSTM model
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    bilstm_model = BiLSTMModel(input_dim=X_train.shape[2], hidden_dim=224, num_layers=1, dropout=0.14).to(device)
    criterion = nn.MSELoss()
    optimizer = torch.optim.Adam(bilstm_model.parameters(), lr=0.0019)

    train_loader = DataLoader(TensorDataset(torch.tensor(X_train, dtype=torch.float32), torch.tensor(y_train, dtype=torch.float32)), batch_size=32, shuffle=True)

    for epoch in range(50):
        bilstm_model.train()
        train_loss = 0.0
        for X_batch, y_batch in train_loader:
            X_batch, y_batch = X_batch.to(device), y_batch.to(device)
            optimizer.zero_grad()
            predictions = bilstm_model(X_batch).squeeze()
            loss = criterion(predictions, y_batch)
            loss.backward()
            optimizer.step()
            train_loss += loss.item()

    # Create environments for PPO
    bilstm_env = TradingEnv(test_data)
    simple_env = TradingEnv(test_data)

    # Train PPO models
    ppo_bilstm_model = PPO("MlpPolicy", bilstm_env, learning_rate=0.0014, batch_size=160, n_steps=1280, gamma=0.9005911776350177, verbose=1)
    ppo_bilstm_model.learn(total_timesteps=50000)

    ppo_simple_model = PPO("MlpPolicy", simple_env, verbose=1)
    ppo_simple_model.learn(total_timesteps=50000)

    # Evaluate strategies
    portfolio_values_bilstm = evaluate_trading_strategy(bilstm_env, ppo_bilstm_model)
    portfolio_values_simple = evaluate_trading_strategy(simple_env, ppo_simple_model)

    cumulative_return_bilstm, sharpe_bilstm, sortino_bilstm, max_drawdown_bilstm = calculate_metrics(portfolio_values_bilstm)
    cumulative_return_simple, sharpe_simple, sortino_simple, max_drawdown_simple = calculate_metrics(portfolio_values_simple)

    # Buy-and-Hold strategy
    buy_hold_return = test_data[-1, 0] / test_data[0, 0] - 1

    # Generate date range for 2022
    test_dates = pd.date_range(start="2024-01-01", periods=len(portfolio_values_bilstm))

    # Calculate cumulative returns
    cumulative_returns_bilstm = np.cumprod([1 + r for r in np.diff(portfolio_values_bilstm) / portfolio_values_bilstm[:-1]])
    cumulative_returns_simple = np.cumprod([1 + r for r in np.diff(portfolio_values_simple) / portfolio_values_simple[:-1]])

    # Plot cumulative returns
    plt.figure(figsize=(12, 6))
    plt.plot(test_dates[1:], cumulative_returns_bilstm, label="Bi-LSTM PPO")
    plt.plot(test_dates[1:], cumulative_returns_simple, label="Simple PPO")
    plt.gca().xaxis.set_major_formatter(plt.matplotlib.dates.DateFormatter("%b %Y"))
    plt.gca().xaxis.set_major_locator(plt.matplotlib.dates.MonthLocator())

    plt.legend()
    plt.title("Cumulative Returns")
    plt.xlabel("Date")
    plt.ylabel("Cumulative Return")
    plt.grid()
    plt.show()

    # Print results
    results = pd.DataFrame({
        "Method": ["Bi-LSTM PPO", "Simple PPO", "Buy-and-Hold"],
        "Cumulative Return": [cumulative_returns_bilstm[-1], cumulative_returns_simple[-1], buy_hold_return],
        "Sharpe Ratio": [sharpe_bilstm, sharpe_simple, None],
        "Sortino Ratio": [sortino_bilstm, sortino_simple, None],
        "Max Drawdown": [max_drawdown_bilstm, max_drawdown_simple, None]
    })
    print(results)
# Out:
# C:\Users\User\anaconda3\envs\RL\Lib\site-packages\torch\nn\modules\rnn.py:123: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.14 and num_layers=1
#   warnings.warn(
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# C:\Users\User\anaconda3\envs\RL\Lib\site-packages\stable_baselines3\common\vec_env\patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 335      |
# |    ep_rew_mean     | -0.105   |
# | time/              |          |
# |    fps             | 1651     |
# |    iterations      | 1        |
# |    time_elapsed    | 0        |
# |    total_timesteps | 1280     |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 335          |
# |    ep_rew_mean          | -0.00996     |
# | time/                   |              |
# |    fps                  | 1372         |
# |    iterations           | 2            |
# |    time_elapsed         | 1            |
# |    total_timesteps      | 2560         |
# | train/                  |              |
# |    approx_kl            | 0.0059233475 |
# |    clip_fraction        | 0.0323       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.09        |
# |    explained_variance   | -6.47        |
# |    learning_rate        | 0.0014       |
# |    loss                 | -0.0106      |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.00345     |
# |    value_loss           | 0.0286       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 335          |
# |    ep_rew_mean          | -0.0308      |
# | time/                   |              |
# |    fps                  | 1293         |
# |    iterations           | 3            |
# |    time_elapsed         | 2            |
# |    total_timesteps      | 3840         |
# | train/                  |              |
# |    approx_kl            | 0.0095668025 |
# |    clip_fraction        | 0.12         |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.08        |
# |    explained_variance   | -0.931       |
# |    learning_rate        | 0.0014       |
# |    loss                 | -0.0296      |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.0042      |
# |    value_loss           | 0.0013       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.0366      |
# | time/                   |             |
# |    fps                  | 1260        |
# |    iterations           | 4           |
# |    time_elapsed         | 4           |
# |    total_timesteps      | 5120        |
# | train/                  |             |
# |    approx_kl            | 0.009936532 |
# |    clip_fraction        | 0.16        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.07       |
# |    explained_variance   | -0.295      |
# |    learning_rate        | 0.0014      |
# |    loss                 | 0.00975     |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0115     |
# |    value_loss           | 0.000609    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.127       |
# | time/                   |             |
# |    fps                  | 1223        |
# |    iterations           | 5           |
# |    time_elapsed         | 5           |
# |    total_timesteps      | 6400        |
# | train/                  |             |
# |    approx_kl            | 0.012133678 |
# |    clip_fraction        | 0.201       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.04       |
# |    explained_variance   | -0.299      |
# |    learning_rate        | 0.0014      |
# |    loss                 | -0.00561    |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0141     |
# |    value_loss           | 0.00054     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.187       |
# | time/                   |             |
# |    fps                  | 1159        |
# |    iterations           | 6           |
# |    time_elapsed         | 6           |
# |    total_timesteps      | 7680        |
# | train/                  |             |
# |    approx_kl            | 0.014126191 |
# |    clip_fraction        | 0.192       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.01       |
# |    explained_variance   | 0.132       |
# |    learning_rate        | 0.0014      |
# |    loss                 | -0.0222     |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0142     |
# |    value_loss           | 0.000519    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.268       |
# | time/                   |             |
# |    fps                  | 1134        |
# |    iterations           | 7           |
# |    time_elapsed         | 7           |
# |    total_timesteps      | 8960        |
# | train/                  |             |
# |    approx_kl            | 0.017613735 |
# |    clip_fraction        | 0.246       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.956      |
# |    explained_variance   | 0.349       |
# |    learning_rate        | 0.0014      |
# |    loss                 | -0.00874    |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0143     |
# |    value_loss           | 0.000524    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.338       |
# | time/                   |             |
# |    fps                  | 1111        |
# |    iterations           | 8           |
# |    time_elapsed         | 9           |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.015007632 |
# |    clip_fraction        | 0.205       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.893      |
# |    explained_variance   | 0.571       |
# |    learning_rate        | 0.0014      |
# |    loss                 | -0.0263     |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0112     |
# |    value_loss           | 0.000404    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.43        |
# | time/                   |             |
# |    fps                  | 1114        |
# |    iterations           | 9           |
# |    time_elapsed         | 10          |
# |    total_timesteps      | 11520       |
# | train/                  |             |
# |    approx_kl            | 0.027966458 |
# |    clip_fraction        | 0.252       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.797      |
# |    explained_variance   | 0.451       |
# |    learning_rate        | 0.0014      |
# |    loss                 | -0.0365     |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.0211     |
# |    value_loss           | 0.000408    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.527       |
# | time/                   |             |
# |    fps                  | 1119        |
# |    iterations           | 10          |
# |    time_elapsed         | 11          |
# |    total_timesteps      | 12800       |
# | train/                  |             |
# |    approx_kl            | 0.023617096 |
# |    clip_fraction        | 0.305       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.717      |
# |    explained_variance   | 0.585       |
# |    learning_rate        | 0.0014      |
# |    loss                 | -0.00697    |
# |    n_updates            | 90          |
# |    policy_gradient_loss | 0.00862     |
# |    value_loss           | 0.000361    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 335        |
# |    ep_rew_mean          | 0.621      |
# | time/                   |            |
# |    fps                  | 1118       |
# |    iterations           | 11         |
# |    time_elapsed         | 12         |
# |    total_timesteps      | 14080      |
# | train/                  |            |
# |    approx_kl            | 0.02917562 |
# |    clip_fraction        | 0.291      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.635     |
# |    explained_variance   | 0.732      |
# |    learning_rate        | 0.0014     |
# |    loss                 | -0.0265    |
# |    n_updates            | 100        |
# |    policy_gradient_loss | -0.00752   |
# |    value_loss           | 0.00035    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.684       |
# | time/                   |             |
# |    fps                  | 1112        |
# |    iterations           | 12          |
# |    time_elapsed         | 13          |
# |    total_timesteps      | 15360       |
# | train/                  |             |
# |    approx_kl            | 0.022369653 |
# |    clip_fraction        | 0.198       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.566      |
# |    explained_variance   | 0.801       |
# |    learning_rate        | 0.0014      |
# |    loss                 | 0.0112      |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.00402    |
# |    value_loss           | 0.000394    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.77        |
# | time/                   |             |
# |    fps                  | 1108        |
# |    iterations           | 13          |
# |    time_elapsed         | 15          |
# |    total_timesteps      | 16640       |
# | train/                  |             |
# |    approx_kl            | 0.022736536 |
# |    clip_fraction        | 0.222       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.529      |
# |    explained_variance   | 0.863       |
# |    learning_rate        | 0.0014      |
# |    loss                 | -0.0346     |
# |    n_updates            | 120         |
# |    policy_gradient_loss | 0.00257     |
# |    value_loss           | 0.00276     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 335        |
# |    ep_rew_mean          | 0.853      |
# | time/                   |            |
# |    fps                  | 1108       |
# |    iterations           | 14         |
# |    time_elapsed         | 16         |
# |    total_timesteps      | 17920      |
# | train/                  |            |
# |    approx_kl            | 0.04475799 |
# |    clip_fraction        | 0.254      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.505     |
# |    explained_variance   | 0.828      |
# |    learning_rate        | 0.0014     |
# |    loss                 | 0.0153     |
# |    n_updates            | 130        |
# |    policy_gradient_loss | 0.0212     |
# |    value_loss           | 0.0021     |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.918       |
# | time/                   |             |
# |    fps                  | 1100        |
# |    iterations           | 15          |
# |    time_elapsed         | 17          |
# |    total_timesteps      | 19200       |
# | train/                  |             |
# |    approx_kl            | 0.071953714 |
# |    clip_fraction        | 0.291       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.477      |
# |    explained_variance   | 0.889       |
# |    learning_rate        | 0.0014      |
# |    loss                 | 0.0453      |
# |    n_updates            | 140         |
# |    policy_gradient_loss | 0.0385      |
# |    value_loss           | 0.000308    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.977       |
# | time/                   |             |
# |    fps                  | 1101        |
# |    iterations           | 16          |
# |    time_elapsed         | 18          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.014179601 |
# |    clip_fraction        | 0.225       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.463      |
# |    explained_variance   | 0.887       |
# |    learning_rate        | 0.0014      |
# |    loss                 | -0.00707    |
# |    n_updates            | 150         |
# |    policy_gradient_loss | 0.011       |
# |    value_loss           | 0.000283    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 335        |
# |    ep_rew_mean          | 1.02       |
# | time/                   |            |
# |    fps                  | 1100       |
# |    iterations           | 17         |
# |    time_elapsed         | 19         |
# |    total_timesteps      | 21760      |
# | train/                  |            |
# |    approx_kl            | 0.03278929 |
# |    clip_fraction        | 0.196      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.437     |
# |    explained_variance   | 0.897      |
# |    learning_rate        | 0.0014     |
# |    loss                 | -0.027     |
# |    n_updates            | 160        |
# |    policy_gradient_loss | -0.00143   |
# |    value_loss           | 0.000248   |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 335       |
# |    ep_rew_mean          | 1.08      |
# | time/                   |           |
# |    fps                  | 1097      |
# |    iterations           | 18        |
# |    time_elapsed         | 20        |
# |    total_timesteps      | 23040     |
# | train/                  |           |
# |    approx_kl            | 0.0329382 |
# |    clip_fraction        | 0.226     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.385    |
# |    explained_variance   | 0.927     |
# |    learning_rate        | 0.0014    |
# |    loss                 | -0.000192 |
# |    n_updates            | 170       |
# |    policy_gradient_loss | 0.00964   |
# |    value_loss           | 0.000202  |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 335       |
# |    ep_rew_mean          | 1.12      |
# | time/                   |           |
# |    fps                  | 1085      |
# |    iterations           | 19        |
# |    time_elapsed         | 22        |
# |    total_timesteps      | 24320     |
# | train/                  |           |
# |    approx_kl            | 0.1078416 |
# |    clip_fraction        | 0.264     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.362    |
# |    explained_variance   | 0.934     |
# |    learning_rate        | 0.0014    |
# |    loss                 | 0.0723    |
# |    n_updates            | 180       |
# |    policy_gradient_loss | 0.0352    |
# |    value_loss           | 0.000162  |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 1.17        |
# | time/                   |             |
# |    fps                  | 1079        |
# |    iterations           | 20          |
# |    time_elapsed         | 23          |
# |    total_timesteps      | 25600       |
# | train/                  |             |
# |    approx_kl            | 0.030907752 |
# |    clip_fraction        | 0.184       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.345      |
# |    explained_variance   | 0.935       |
# |    learning_rate        | 0.0014      |
# |    loss                 | -0.024      |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.00575    |
# |    value_loss           | 0.000417    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 1.2         |
# | time/                   |             |
# |    fps                  | 1072        |
# |    iterations           | 21          |
# |    time_elapsed         | 25          |
# |    total_timesteps      | 26880       |
# | train/                  |             |
# |    approx_kl            | 0.032635406 |
# |    clip_fraction        | 0.269       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.346      |
# |    explained_variance   | 0.941       |
# |    learning_rate        | 0.0014      |
# |    loss                 | 0.031       |
# |    n_updates            | 200         |
# |    policy_gradient_loss | 0.0285      |
# |    value_loss           | 0.000205    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 1.24        |
# | time/                   |             |
# |    fps                  | 1072        |
# |    iterations           | 22          |
# |    time_elapsed         | 26          |
# |    total_timesteps      | 28160       |
# | train/                  |             |
# |    approx_kl            | 0.037190437 |
# |    clip_fraction        | 0.2         |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.35       |
# |    explained_variance   | 0.928       |
# |    learning_rate        | 0.0014      |
# |    loss                 | 0.0144      |
# |    n_updates            | 210         |
# |    policy_gradient_loss | 0.00774     |
# |    value_loss           | 0.000181    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 335        |
# |    ep_rew_mean          | 1.27       |
# | time/                   |            |
# |    fps                  | 1073       |
# |    iterations           | 23         |
# |    time_elapsed         | 27         |
# |    total_timesteps      | 29440      |
# | train/                  |            |
# |    approx_kl            | 0.03082814 |
# |    clip_fraction        | 0.187      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.32      |
# |    explained_variance   | 0.906      |
# |    learning_rate        | 0.0014     |
# |    loss                 | -0.0201    |
# |    n_updates            | 220        |
# |    policy_gradient_loss | 0.00797    |
# |    value_loss           | 0.000217   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 1.32        |
# | time/                   |             |
# |    fps                  | 1072        |
# |    iterations           | 24          |
# |    time_elapsed         | 28          |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.028382262 |
# |    clip_fraction        | 0.145       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.291      |
# |    explained_variance   | 0.928       |
# |    learning_rate        | 0.0014      |
# |    loss                 | 0.0103      |
# |    n_updates            | 230         |
# |    policy_gradient_loss | 0.00244     |
# |    value_loss           | 0.000167    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 1.35        |
# | time/                   |             |
# |    fps                  | 1072        |
# |    iterations           | 25          |
# |    time_elapsed         | 29          |
# |    total_timesteps      | 32000       |
# | train/                  |             |
# |    approx_kl            | 0.018604297 |
# |    clip_fraction        | 0.203       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.283      |
# |    explained_variance   | 0.961       |
# |    learning_rate        | 0.0014      |
# |    loss                 | -0.0116     |
# |    n_updates            | 240         |
# |    policy_gradient_loss | 0.0368      |
# |    value_loss           | 0.00012     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 335        |
# |    ep_rew_mean          | 1.38       |
# | time/                   |            |
# |    fps                  | 1069       |
# |    iterations           | 26         |
# |    time_elapsed         | 31         |
# |    total_timesteps      | 33280      |
# | train/                  |            |
# |    approx_kl            | 0.09362058 |
# |    clip_fraction        | 0.235      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.278     |
# |    explained_variance   | 0.95       |
# |    learning_rate        | 0.0014     |
# |    loss                 | 0.076      |
# |    n_updates            | 250        |
# |    policy_gradient_loss | 0.0187     |
# |    value_loss           | 0.000156   |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 335       |
# |    ep_rew_mean          | 1.45      |
# | time/                   |           |
# |    fps                  | 1069      |
# |    iterations           | 27        |
# |    time_elapsed         | 32        |
# |    total_timesteps      | 34560     |
# | train/                  |           |
# |    approx_kl            | 0.0528685 |
# |    clip_fraction        | 0.271     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.327    |
# |    explained_variance   | 0.915     |
# |    learning_rate        | 0.0014    |
# |    loss                 | 0.0221    |
# |    n_updates            | 260       |
# |    policy_gradient_loss | 0.0324    |
# |    value_loss           | 0.000177  |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 1.51        |
# | time/                   |             |
# |    fps                  | 1068        |
# |    iterations           | 28          |
# |    time_elapsed         | 33          |
# |    total_timesteps      | 35840       |
# | train/                  |             |
# |    approx_kl            | 0.114922464 |
# |    clip_fraction        | 0.228       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.291      |
# |    explained_variance   | 0.945       |
# |    learning_rate        | 0.0014      |
# |    loss                 | -0.014      |
# |    n_updates            | 270         |
# |    policy_gradient_loss | 0.0186      |
# |    value_loss           | 0.00021     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 335        |
# |    ep_rew_mean          | 1.61       |
# | time/                   |            |
# |    fps                  | 1069       |
# |    iterations           | 29         |
# |    time_elapsed         | 34         |
# |    total_timesteps      | 37120      |
# | train/                  |            |
# |    approx_kl            | 0.01860416 |
# |    clip_fraction        | 0.227      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.289     |
# |    explained_variance   | 0.92       |
# |    learning_rate        | 0.0014     |
# |    loss                 | -0.019     |
# |    n_updates            | 280        |
# |    policy_gradient_loss | 0.0189     |
# |    value_loss           | 0.006      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 1.69        |
# | time/                   |             |
# |    fps                  | 1068        |
# |    iterations           | 30          |
# |    time_elapsed         | 35          |
# |    total_timesteps      | 38400       |
# | train/                  |             |
# |    approx_kl            | 0.032828156 |
# |    clip_fraction        | 0.197       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.289      |
# |    explained_variance   | 0.799       |
# |    learning_rate        | 0.0014      |
# |    loss                 | 0.0206      |
# |    n_updates            | 290         |
# |    policy_gradient_loss | 0.0109      |
# |    value_loss           | 0.000371    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 335        |
# |    ep_rew_mean          | 1.77       |
# | time/                   |            |
# |    fps                  | 1066       |
# |    iterations           | 31         |
# |    time_elapsed         | 37         |
# |    total_timesteps      | 39680      |
# | train/                  |            |
# |    approx_kl            | 0.10946174 |
# |    clip_fraction        | 0.266      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.279     |
# |    explained_variance   | 0.891      |
# |    learning_rate        | 0.0014     |
# |    loss                 | 0.0411     |
# |    n_updates            | 300        |
# |    policy_gradient_loss | 0.0395     |
# |    value_loss           | 0.000253   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 1.84        |
# | time/                   |             |
# |    fps                  | 1059        |
# |    iterations           | 32          |
# |    time_elapsed         | 38          |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.030645015 |
# |    clip_fraction        | 0.2         |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.269      |
# |    explained_variance   | 0.934       |
# |    learning_rate        | 0.0014      |
# |    loss                 | 0.00791     |
# |    n_updates            | 310         |
# |    policy_gradient_loss | 0.0244      |
# |    value_loss           | 0.000645    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 335        |
# |    ep_rew_mean          | 1.9        |
# | time/                   |            |
# |    fps                  | 1056       |
# |    iterations           | 33         |
# |    time_elapsed         | 39         |
# |    total_timesteps      | 42240      |
# | train/                  |            |
# |    approx_kl            | 0.15667632 |
# |    clip_fraction        | 0.223      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.28      |
# |    explained_variance   | 0.944      |
# |    learning_rate        | 0.0014     |
# |    loss                 | 0.0568     |
# |    n_updates            | 320        |
# |    policy_gradient_loss | 0.0425     |
# |    value_loss           | 0.000202   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 1.95        |
# | time/                   |             |
# |    fps                  | 1050        |
# |    iterations           | 34          |
# |    time_elapsed         | 41          |
# |    total_timesteps      | 43520       |
# | train/                  |             |
# |    approx_kl            | 0.019917957 |
# |    clip_fraction        | 0.192       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.29       |
# |    explained_variance   | 0.95        |
# |    learning_rate        | 0.0014      |
# |    loss                 | 0.00901     |
# |    n_updates            | 330         |
# |    policy_gradient_loss | 0.025       |
# |    value_loss           | 0.000391    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 335        |
# |    ep_rew_mean          | 2          |
# | time/                   |            |
# |    fps                  | 1051       |
# |    iterations           | 35         |
# |    time_elapsed         | 42         |
# |    total_timesteps      | 44800      |
# | train/                  |            |
# |    approx_kl            | 0.05133238 |
# |    clip_fraction        | 0.18       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.258     |
# |    explained_variance   | 0.946      |
# |    learning_rate        | 0.0014     |
# |    loss                 | -0.00742   |
# |    n_updates            | 340        |
# |    policy_gradient_loss | 0.012      |
# |    value_loss           | 0.000262   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 335        |
# |    ep_rew_mean          | 2.03       |
# | time/                   |            |
# |    fps                  | 1048       |
# |    iterations           | 36         |
# |    time_elapsed         | 43         |
# |    total_timesteps      | 46080      |
# | train/                  |            |
# |    approx_kl            | 0.19229817 |
# |    clip_fraction        | 0.208      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.256     |
# |    explained_variance   | 0.955      |
# |    learning_rate        | 0.0014     |
# |    loss                 | 0.0237     |
# |    n_updates            | 350        |
# |    policy_gradient_loss | 0.0467     |
# |    value_loss           | 0.000272   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 335        |
# |    ep_rew_mean          | 2.06       |
# | time/                   |            |
# |    fps                  | 1049       |
# |    iterations           | 37         |
# |    time_elapsed         | 45         |
# |    total_timesteps      | 47360      |
# | train/                  |            |
# |    approx_kl            | 0.07353683 |
# |    clip_fraction        | 0.22       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.218     |
# |    explained_variance   | 0.905      |
# |    learning_rate        | 0.0014     |
# |    loss                 | -0.0333    |
# |    n_updates            | 360        |
# |    policy_gradient_loss | 0.00769    |
# |    value_loss           | 0.000259   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 2.09        |
# | time/                   |             |
# |    fps                  | 1049        |
# |    iterations           | 38          |
# |    time_elapsed         | 46          |
# |    total_timesteps      | 48640       |
# | train/                  |             |
# |    approx_kl            | 0.071940154 |
# |    clip_fraction        | 0.196       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.216      |
# |    explained_variance   | 0.94        |
# |    learning_rate        | 0.0014      |
# |    loss                 | 0.00532     |
# |    n_updates            | 370         |
# |    policy_gradient_loss | 0.0104      |
# |    value_loss           | 0.000156    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 2.11        |
# | time/                   |             |
# |    fps                  | 1048        |
# |    iterations           | 39          |
# |    time_elapsed         | 47          |
# |    total_timesteps      | 49920       |
# | train/                  |             |
# |    approx_kl            | 0.110319495 |
# |    clip_fraction        | 0.174       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.209      |
# |    explained_variance   | 0.964       |
# |    learning_rate        | 0.0014      |
# |    loss                 | 0.156       |
# |    n_updates            | 380         |
# |    policy_gradient_loss | 0.0434      |
# |    value_loss           | 0.000121    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 2.13        |
# | time/                   |             |
# |    fps                  | 1048        |
# |    iterations           | 40          |
# |    time_elapsed         | 48          |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.061140664 |
# |    clip_fraction        | 0.215       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.22       |
# |    explained_variance   | 0.953       |
# |    learning_rate        | 0.0014      |
# |    loss                 | 0.0189      |
# |    n_updates            | 390         |
# |    policy_gradient_loss | 0.0289      |
# |    value_loss           | 0.000133    |
# -----------------------------------------
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 335      |
# |    ep_rew_mean     | 0.00137  |
# | time/              |          |
# |    fps             | 1609     |
# |    iterations      | 1        |
# |    time_elapsed    | 1        |
# |    total_timesteps | 2048     |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 335          |
# |    ep_rew_mean          | 0.0867       |
# | time/                   |              |
# |    fps                  | 1019         |
# |    iterations           | 2            |
# |    time_elapsed         | 4            |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0052537518 |
# |    clip_fraction        | 0.0148       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.1         |
# |    explained_variance   | -1.98        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00524     |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.00112     |
# |    value_loss           | 0.0029       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 335          |
# |    ep_rew_mean          | 0.0931       |
# | time/                   |              |
# |    fps                  | 862          |
# |    iterations           | 3            |
# |    time_elapsed         | 7            |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.0054875338 |
# |    clip_fraction        | 0.0131       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.09        |
# |    explained_variance   | -0.476       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00567      |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.000738    |
# |    value_loss           | 0.00202      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.0758      |
# | time/                   |             |
# |    fps                  | 819         |
# |    iterations           | 4           |
# |    time_elapsed         | 10          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.008568577 |
# |    clip_fraction        | 0.0716      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | 0.0116      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0208     |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.00975    |
# |    value_loss           | 0.00128     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.0986      |
# | time/                   |             |
# |    fps                  | 807         |
# |    iterations           | 5           |
# |    time_elapsed         | 12          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.009060737 |
# |    clip_fraction        | 0.0866      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | 0.143       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0162     |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.00875    |
# |    value_loss           | 0.00129     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.112       |
# | time/                   |             |
# |    fps                  | 801         |
# |    iterations           | 6           |
# |    time_elapsed         | 15          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.008275242 |
# |    clip_fraction        | 0.087       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.07       |
# |    explained_variance   | 0.278       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0212     |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.00698    |
# |    value_loss           | 0.00144     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.138       |
# | time/                   |             |
# |    fps                  | 797         |
# |    iterations           | 7           |
# |    time_elapsed         | 17          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.012335351 |
# |    clip_fraction        | 0.128       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.05       |
# |    explained_variance   | 0.245       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0285     |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0098     |
# |    value_loss           | 0.00151     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.186       |
# | time/                   |             |
# |    fps                  | 785         |
# |    iterations           | 8           |
# |    time_elapsed         | 20          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.013343603 |
# |    clip_fraction        | 0.129       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.02       |
# |    explained_variance   | 0.227       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0123     |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0122     |
# |    value_loss           | 0.00105     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.234       |
# | time/                   |             |
# |    fps                  | 773         |
# |    iterations           | 9           |
# |    time_elapsed         | 23          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.008178324 |
# |    clip_fraction        | 0.132       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.974      |
# |    explained_variance   | 0.406       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0216     |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.00645    |
# |    value_loss           | 0.00115     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.295       |
# | time/                   |             |
# |    fps                  | 789         |
# |    iterations           | 10          |
# |    time_elapsed         | 25          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.016777616 |
# |    clip_fraction        | 0.197       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.912      |
# |    explained_variance   | 0.331       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00979    |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.00707    |
# |    value_loss           | 0.00135     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.351       |
# | time/                   |             |
# |    fps                  | 803         |
# |    iterations           | 11          |
# |    time_elapsed         | 28          |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.017388605 |
# |    clip_fraction        | 0.118       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.889      |
# |    explained_variance   | 0.593       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0242      |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.00834    |
# |    value_loss           | 0.00113     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.391       |
# | time/                   |             |
# |    fps                  | 815         |
# |    iterations           | 12          |
# |    time_elapsed         | 30          |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.010837501 |
# |    clip_fraction        | 0.123       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.835      |
# |    explained_variance   | 0.708       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0204     |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.00421    |
# |    value_loss           | 0.00112     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.44        |
# | time/                   |             |
# |    fps                  | 822         |
# |    iterations           | 13          |
# |    time_elapsed         | 32          |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.009874139 |
# |    clip_fraction        | 0.174       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.754      |
# |    explained_variance   | 0.701       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00161    |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.00308    |
# |    value_loss           | 0.00143     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.505       |
# | time/                   |             |
# |    fps                  | 834         |
# |    iterations           | 14          |
# |    time_elapsed         | 34          |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.011297528 |
# |    clip_fraction        | 0.148       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.728      |
# |    explained_variance   | 0.805       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0206     |
# |    n_updates            | 130         |
# |    policy_gradient_loss | 0.000762    |
# |    value_loss           | 0.000851    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.569       |
# | time/                   |             |
# |    fps                  | 838         |
# |    iterations           | 15          |
# |    time_elapsed         | 36          |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.011707389 |
# |    clip_fraction        | 0.115       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.672      |
# |    explained_variance   | 0.888       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0109     |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.0102     |
# |    value_loss           | 0.0007      |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 335        |
# |    ep_rew_mean          | 0.632      |
# | time/                   |            |
# |    fps                  | 833        |
# |    iterations           | 16         |
# |    time_elapsed         | 39         |
# |    total_timesteps      | 32768      |
# | train/                  |            |
# |    approx_kl            | 0.01171393 |
# |    clip_fraction        | 0.131      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.647     |
# |    explained_variance   | 0.908      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.00642    |
# |    n_updates            | 150        |
# |    policy_gradient_loss | 0.00053    |
# |    value_loss           | 0.000963   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.71        |
# | time/                   |             |
# |    fps                  | 835         |
# |    iterations           | 17          |
# |    time_elapsed         | 41          |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.010382516 |
# |    clip_fraction        | 0.144       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.625      |
# |    explained_variance   | 0.935       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0252     |
# |    n_updates            | 160         |
# |    policy_gradient_loss | 0.000357    |
# |    value_loss           | 0.000637    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.82        |
# | time/                   |             |
# |    fps                  | 837         |
# |    iterations           | 18          |
# |    time_elapsed         | 44          |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.009972987 |
# |    clip_fraction        | 0.154       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.607      |
# |    explained_variance   | 0.936       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0255      |
# |    n_updates            | 170         |
# |    policy_gradient_loss | 0.000643    |
# |    value_loss           | 0.000485    |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 335       |
# |    ep_rew_mean          | 0.907     |
# | time/                   |           |
# |    fps                  | 843       |
# |    iterations           | 19        |
# |    time_elapsed         | 46        |
# |    total_timesteps      | 38912     |
# | train/                  |           |
# |    approx_kl            | 0.0208699 |
# |    clip_fraction        | 0.165     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.552    |
# |    explained_variance   | 0.921     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.0574    |
# |    n_updates            | 180       |
# |    policy_gradient_loss | 0.00107   |
# |    value_loss           | 0.000697  |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 848         |
# |    iterations           | 20          |
# |    time_elapsed         | 48          |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.017367931 |
# |    clip_fraction        | 0.151       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.497      |
# |    explained_variance   | 0.932       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0115      |
# |    n_updates            | 190         |
# |    policy_gradient_loss | 0.00291     |
# |    value_loss           | 0.00067     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 1.1         |
# | time/                   |             |
# |    fps                  | 848         |
# |    iterations           | 21          |
# |    time_elapsed         | 50          |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.008399434 |
# |    clip_fraction        | 0.132       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.455      |
# |    explained_variance   | 0.929       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00911    |
# |    n_updates            | 200         |
# |    policy_gradient_loss | 0.00286     |
# |    value_loss           | 0.00106     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 1.19        |
# | time/                   |             |
# |    fps                  | 845         |
# |    iterations           | 22          |
# |    time_elapsed         | 53          |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.017738692 |
# |    clip_fraction        | 0.128       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.432      |
# |    explained_variance   | 0.93        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0148      |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.000767   |
# |    value_loss           | 0.00046     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 1.29        |
# | time/                   |             |
# |    fps                  | 840         |
# |    iterations           | 23          |
# |    time_elapsed         | 56          |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.019396868 |
# |    clip_fraction        | 0.157       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.408      |
# |    explained_variance   | 0.947       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00136     |
# |    n_updates            | 220         |
# |    policy_gradient_loss | 0.00466     |
# |    value_loss           | 0.000408    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 335        |
# |    ep_rew_mean          | 1.39       |
# | time/                   |            |
# |    fps                  | 842        |
# |    iterations           | 24         |
# |    time_elapsed         | 58         |
# |    total_timesteps      | 49152      |
# | train/                  |            |
# |    approx_kl            | 0.01401416 |
# |    clip_fraction        | 0.146      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.392     |
# |    explained_variance   | 0.948      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0405    |
# |    n_updates            | 230        |
# |    policy_gradient_loss | 0.00845    |
# |    value_loss           | 0.000594   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 1.48        |
# | time/                   |             |
# |    fps                  | 846         |
# |    iterations           | 25          |
# |    time_elapsed         | 60          |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.015696581 |
# |    clip_fraction        | 0.126       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.392      |
# |    explained_variance   | 0.968       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0268      |
# |    n_updates            | 240         |
# |    policy_gradient_loss | 0.00266     |
# |    value_loss           | 0.000406    |
# -----------------------------------------
#          Method  Cumulative Return  Sharpe Ratio  Sortino Ratio  Max Drawdown
# 0   Bi-LSTM PPO           3.348497      0.561236       1.470157     -0.013472
# 1    Simple PPO           3.337095      0.553846       1.277627     -0.019624
# 2  Buy-and-Hold           2.447755           NaN            NaN           NaN
