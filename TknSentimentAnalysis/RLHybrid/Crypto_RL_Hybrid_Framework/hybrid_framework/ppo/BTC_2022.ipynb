# %%
import pandas as pd
import numpy as np
import torch
import torch.nn as nn
from sklearn.preprocessing import MinMaxScaler
from torch.utils.data import DataLoader, TensorDataset
from stable_baselines3 import PPO
from gym import spaces, Env
import matplotlib.pyplot as plt
import random

# Set seed for reproducibility
SEED = 42
random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)
if torch.cuda.is_available():
    torch.cuda.manual_seed_all(SEED)

# Load and preprocess data
def load_and_preprocess(file_name):
    data = pd.read_csv(file_name)
    data["Date"] = pd.to_datetime(data["Date"])
    data = data.sort_values(by="Date")
    
    numeric_data = data.drop(columns=["Date"])
    numeric_data = numeric_data[['Close'] + [col for col in numeric_data.columns if col != 'Close']]
    
    scaler = MinMaxScaler()
    normalized_data = scaler.fit_transform(numeric_data)
    data[numeric_data.columns] = normalized_data
    
    return data, scaler

# Create sequences for time series modeling
def create_sequences(data, sequence_length=30):
    sequences = []
    targets = []
    for i in range(len(data) - sequence_length):
        seq = data[i:i+sequence_length]
        target = data[i+sequence_length, 0]  # Assuming the target is the first column (e.g., Close price)
        sequences.append(seq)
        targets.append(target)
    return np.array(sequences), np.array(targets)

# Define Bi-LSTM model
class BiLSTMModel(nn.Module):
    def __init__(self, input_dim, hidden_dim, num_layers, dropout):
        super(BiLSTMModel, self).__init__()
        self.bilstm = nn.LSTM(input_dim, hidden_dim, num_layers, batch_first=True, dropout=dropout, bidirectional=True)
        self.fc = nn.Linear(hidden_dim * 2, 1)

    def forward(self, x):
        bilstm_out, _ = self.bilstm(x)
        return self.fc(bilstm_out[:, -1, :])

# Custom trading environment
class TradingEnv(Env):
    def __init__(self, data, sequence_length=30):
        super(TradingEnv, self).__init__()
        self.data = data
        self.sequence_length = sequence_length
        self.current_step = 0
        self.total_steps = len(data) - sequence_length
        self.portfolio_value = 1.0

        # Action and observation space
        self.action_space = spaces.Discrete(3)  # 0: Hold, 1: Buy, 2: Sell
        self.observation_space = spaces.Box(low=0, high=1, shape=(sequence_length, data.shape[1]), dtype=np.float32)

    def reset(self):
        self.current_step = 0
        self.portfolio_value = 1.0
        return self._next_observation()

    def _next_observation(self):
        return self.data[self.current_step:self.current_step + self.sequence_length]

    def step(self, action):
        self.current_step += 1
        reward = 0
        done = self.current_step >= self.total_steps

        if not done:
            current_price = self.data[self.current_step, 0]
            prev_price = self.data[self.current_step - 1, 0]

            if action == 1:  # Buy
                reward = current_price - prev_price
            elif action == 2:  # Sell
                reward = prev_price - current_price

        self.portfolio_value += reward
        obs = self._next_observation() if not done else None
        return obs, reward, done, {"portfolio_value": self.portfolio_value}

# Evaluate trading strategy
def evaluate_trading_strategy(env, model):
    obs = env.reset()
    done = False
    portfolio_values = [1.0]

    while not done:
        action, _ = model.predict(obs, deterministic=True)
        obs, reward, done, info = env.step(action)
        portfolio_values.append(info.get("portfolio_value", 1.0))

    return portfolio_values

# Performance metrics
def calculate_metrics(portfolio_values):
    daily_returns = np.diff(portfolio_values) / portfolio_values[:-1]
    cumulative_return = portfolio_values[-1] / portfolio_values[0] - 1
    sharpe_ratio = np.mean(daily_returns) / np.std(daily_returns) if np.std(daily_returns) > 0 else 0
    sortino_ratio = np.mean(daily_returns) / np.std([r for r in daily_returns if r < 0]) if np.std([r for r in daily_returns if r < 0]) > 0 else 0
    max_drawdown = np.min(portfolio_values / np.maximum.accumulate(portfolio_values) - 1)
    return cumulative_return, sharpe_ratio, sortino_ratio, max_drawdown

# Main execution
if __name__ == "__main__":
    # Load data
    data, scaler = load_and_preprocess("Book1.csv")
    train_data = data[(data["Date"].dt.year >= 2017) & (data["Date"].dt.year <= 2021)].drop(columns=["Date"]).values
    test_data = data[data["Date"].dt.year == 2022].drop(columns=["Date"]).values

    X_train, y_train = create_sequences(train_data)
    X_test, y_test = create_sequences(test_data)

    # Train Bi-LSTM model
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    bilstm_model = BiLSTMModel(input_dim=X_train.shape[2], hidden_dim=224, num_layers=1, dropout=0.14).to(device)
    criterion = nn.MSELoss()
    optimizer = torch.optim.Adam(bilstm_model.parameters(), lr=0.0019)

    train_loader = DataLoader(TensorDataset(torch.tensor(X_train, dtype=torch.float32), torch.tensor(y_train, dtype=torch.float32)), batch_size=32, shuffle=True)

    for epoch in range(50):
        bilstm_model.train()
        train_loss = 0.0
        for X_batch, y_batch in train_loader:
            X_batch, y_batch = X_batch.to(device), y_batch.to(device)
            optimizer.zero_grad()
            predictions = bilstm_model(X_batch).squeeze()
            loss = criterion(predictions, y_batch)
            loss.backward()
            optimizer.step()
            train_loss += loss.item()

    # Create environments for PPO
    bilstm_env = TradingEnv(test_data)
    simple_env = TradingEnv(test_data)

    # Train PPO models
    ppo_bilstm_model = PPO("MlpPolicy", bilstm_env, learning_rate=0.0014, batch_size=160, n_steps=1280, gamma=0.9005911776350177, verbose=1)
    ppo_bilstm_model.learn(total_timesteps=50000)

    ppo_simple_model = PPO("MlpPolicy", simple_env, verbose=1)
    ppo_simple_model.learn(total_timesteps=50000)

    # Evaluate strategies
    portfolio_values_bilstm = evaluate_trading_strategy(bilstm_env, ppo_bilstm_model)
    portfolio_values_simple = evaluate_trading_strategy(simple_env, ppo_simple_model)

    cumulative_return_bilstm, sharpe_bilstm, sortino_bilstm, max_drawdown_bilstm = calculate_metrics(portfolio_values_bilstm)
    cumulative_return_simple, sharpe_simple, sortino_simple, max_drawdown_simple = calculate_metrics(portfolio_values_simple)

    # Buy-and-Hold strategy
    buy_hold_return = test_data[-1, 0] / test_data[0, 0] - 1

    # Generate date range for 2022
    test_dates = pd.date_range(start="2022-01-01", periods=len(portfolio_values_bilstm))

    # Calculate cumulative returns
    cumulative_returns_bilstm = np.cumprod([1 + r for r in np.diff(portfolio_values_bilstm) / portfolio_values_bilstm[:-1]])
    cumulative_returns_simple = np.cumprod([1 + r for r in np.diff(portfolio_values_simple) / portfolio_values_simple[:-1]])

    # Plot cumulative returns
    plt.figure(figsize=(12, 6))
    plt.plot(test_dates[1:], cumulative_returns_bilstm, label="Bi-LSTM PPO")
    plt.plot(test_dates[1:], cumulative_returns_simple, label="Simple PPO")
    plt.axhline(1 + buy_hold_return, color="orange", linestyle="--", label="Buy-and-Hold")

    plt.gca().xaxis.set_major_formatter(plt.matplotlib.dates.DateFormatter("%b %Y"))
    plt.gca().xaxis.set_major_locator(plt.matplotlib.dates.MonthLocator())

    plt.legend()
    plt.title("Cumulative Returns")
    plt.xlabel("Date")
    plt.ylabel("Cumulative Return")
    plt.grid()
    plt.show()

    # Print results
    results = pd.DataFrame({
        "Method": ["Bi-LSTM PPO", "Simple PPO", "Buy-and-Hold"],
        "Cumulative Return": [cumulative_returns_bilstm[-1], cumulative_returns_simple[-1], buy_hold_return],
        "Sharpe Ratio": [sharpe_bilstm, sharpe_simple, None],
        "Sortino Ratio": [sortino_bilstm, sortino_simple, None],
        "Max Drawdown": [max_drawdown_bilstm, max_drawdown_simple, None]
    })
    print(results)
# Out:
# C:\Users\User\anaconda3\envs\RL\Lib\site-packages\torch\nn\modules\rnn.py:123: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.14 and num_layers=1
#   warnings.warn(
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# C:\Users\User\anaconda3\envs\RL\Lib\site-packages\stable_baselines3\common\vec_env\patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 335      |
# |    ep_rew_mean     | 0.00348  |
# | time/              |          |
# |    fps             | 1849     |
# |    iterations      | 1        |
# |    time_elapsed    | 0        |
# |    total_timesteps | 1280     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.0488      |
# | time/                   |             |
# |    fps                  | 1545        |
# |    iterations           | 2           |
# |    time_elapsed         | 1           |
# |    total_timesteps      | 2560        |
# | train/                  |             |
# |    approx_kl            | 0.009146687 |
# |    clip_fraction        | 0.0755      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | -4.86       |
# |    learning_rate        | 0.0014      |
# |    loss                 | -0.00363    |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.00639    |
# |    value_loss           | 0.0293      |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 335        |
# |    ep_rew_mean          | 0.0779     |
# | time/                   |            |
# |    fps                  | 1430       |
# |    iterations           | 3          |
# |    time_elapsed         | 2          |
# |    total_timesteps      | 3840       |
# | train/                  |            |
# |    approx_kl            | 0.00984605 |
# |    clip_fraction        | 0.127      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.07      |
# |    explained_variance   | -1.24      |
# |    learning_rate        | 0.0014     |
# |    loss                 | 0.00591    |
# |    n_updates            | 20         |
# |    policy_gradient_loss | -0.00928   |
# |    value_loss           | 0.000973   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.127       |
# | time/                   |             |
# |    fps                  | 1408        |
# |    iterations           | 4           |
# |    time_elapsed         | 3           |
# |    total_timesteps      | 5120        |
# | train/                  |             |
# |    approx_kl            | 0.011497049 |
# |    clip_fraction        | 0.211       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.04       |
# |    explained_variance   | -0.403      |
# |    learning_rate        | 0.0014      |
# |    loss                 | -0.0231     |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0196     |
# |    value_loss           | 0.000417    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.193       |
# | time/                   |             |
# |    fps                  | 1396        |
# |    iterations           | 5           |
# |    time_elapsed         | 4           |
# |    total_timesteps      | 6400        |
# | train/                  |             |
# |    approx_kl            | 0.013531568 |
# |    clip_fraction        | 0.226       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.997      |
# |    explained_variance   | -0.097      |
# |    learning_rate        | 0.0014      |
# |    loss                 | -0.00313    |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0123     |
# |    value_loss           | 0.000268    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 335        |
# |    ep_rew_mean          | 0.246      |
# | time/                   |            |
# |    fps                  | 1390       |
# |    iterations           | 6          |
# |    time_elapsed         | 5          |
# |    total_timesteps      | 7680       |
# | train/                  |            |
# |    approx_kl            | 0.01935076 |
# |    clip_fraction        | 0.226      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.955     |
# |    explained_variance   | 0.039      |
# |    learning_rate        | 0.0014     |
# |    loss                 | 0.0081     |
# |    n_updates            | 50         |
# |    policy_gradient_loss | -0.0186    |
# |    value_loss           | 0.000239   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.304       |
# | time/                   |             |
# |    fps                  | 1381        |
# |    iterations           | 7           |
# |    time_elapsed         | 6           |
# |    total_timesteps      | 8960        |
# | train/                  |             |
# |    approx_kl            | 0.022379909 |
# |    clip_fraction        | 0.217       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.843      |
# |    explained_variance   | 0.175       |
# |    learning_rate        | 0.0014      |
# |    loss                 | -0.0185     |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.00766    |
# |    value_loss           | 0.000227    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.37        |
# | time/                   |             |
# |    fps                  | 1363        |
# |    iterations           | 8           |
# |    time_elapsed         | 7           |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.007462381 |
# |    clip_fraction        | 0.165       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.753      |
# |    explained_variance   | 0.33        |
# |    learning_rate        | 0.0014      |
# |    loss                 | -0.00976    |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.00065    |
# |    value_loss           | 0.000228    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.428       |
# | time/                   |             |
# |    fps                  | 1324        |
# |    iterations           | 9           |
# |    time_elapsed         | 8           |
# |    total_timesteps      | 11520       |
# | train/                  |             |
# |    approx_kl            | 0.012593955 |
# |    clip_fraction        | 0.238       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.72       |
# |    explained_variance   | 0.535       |
# |    learning_rate        | 0.0014      |
# |    loss                 | -0.0113     |
# |    n_updates            | 80          |
# |    policy_gradient_loss | 0.000112    |
# |    value_loss           | 0.000154    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.48        |
# | time/                   |             |
# |    fps                  | 1279        |
# |    iterations           | 10          |
# |    time_elapsed         | 10          |
# |    total_timesteps      | 12800       |
# | train/                  |             |
# |    approx_kl            | 0.016472884 |
# |    clip_fraction        | 0.22        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.74       |
# |    explained_variance   | 0.516       |
# |    learning_rate        | 0.0014      |
# |    loss                 | -0.0226     |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.00535    |
# |    value_loss           | 0.000175    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.538       |
# | time/                   |             |
# |    fps                  | 1238        |
# |    iterations           | 11          |
# |    time_elapsed         | 11          |
# |    total_timesteps      | 14080       |
# | train/                  |             |
# |    approx_kl            | 0.024923364 |
# |    clip_fraction        | 0.326       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.692      |
# |    explained_variance   | 0.557       |
# |    learning_rate        | 0.0014      |
# |    loss                 | 0.0075      |
# |    n_updates            | 100         |
# |    policy_gradient_loss | 0.019       |
# |    value_loss           | 0.000267    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.575       |
# | time/                   |             |
# |    fps                  | 1217        |
# |    iterations           | 12          |
# |    time_elapsed         | 12          |
# |    total_timesteps      | 15360       |
# | train/                  |             |
# |    approx_kl            | 0.024326894 |
# |    clip_fraction        | 0.25        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.629      |
# |    explained_variance   | 0.651       |
# |    learning_rate        | 0.0014      |
# |    loss                 | 0.0337      |
# |    n_updates            | 110         |
# |    policy_gradient_loss | 0.00943     |
# |    value_loss           | 0.000333    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 335        |
# |    ep_rew_mean          | 0.63       |
# | time/                   |            |
# |    fps                  | 1226       |
# |    iterations           | 13         |
# |    time_elapsed         | 13         |
# |    total_timesteps      | 16640      |
# | train/                  |            |
# |    approx_kl            | 0.04544209 |
# |    clip_fraction        | 0.249      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.579     |
# |    explained_variance   | 0.663      |
# |    learning_rate        | 0.0014     |
# |    loss                 | 0.00102    |
# |    n_updates            | 120        |
# |    policy_gradient_loss | 0.00565    |
# |    value_loss           | 0.000158   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.679       |
# | time/                   |             |
# |    fps                  | 1227        |
# |    iterations           | 14          |
# |    time_elapsed         | 14          |
# |    total_timesteps      | 17920       |
# | train/                  |             |
# |    approx_kl            | 0.027528787 |
# |    clip_fraction        | 0.284       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.56       |
# |    explained_variance   | 0.747       |
# |    learning_rate        | 0.0014      |
# |    loss                 | 0.00556     |
# |    n_updates            | 130         |
# |    policy_gradient_loss | 0.0238      |
# |    value_loss           | 0.000144    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 335        |
# |    ep_rew_mean          | 0.729      |
# | time/                   |            |
# |    fps                  | 1233       |
# |    iterations           | 15         |
# |    time_elapsed         | 15         |
# |    total_timesteps      | 19200      |
# | train/                  |            |
# |    approx_kl            | 0.03261461 |
# |    clip_fraction        | 0.291      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.547     |
# |    explained_variance   | 0.778      |
# |    learning_rate        | 0.0014     |
# |    loss                 | -0.00442   |
# |    n_updates            | 140        |
# |    policy_gradient_loss | 0.0374     |
# |    value_loss           | 0.000401   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 335        |
# |    ep_rew_mean          | 0.764      |
# | time/                   |            |
# |    fps                  | 1239       |
# |    iterations           | 16         |
# |    time_elapsed         | 16         |
# |    total_timesteps      | 20480      |
# | train/                  |            |
# |    approx_kl            | 0.07857958 |
# |    clip_fraction        | 0.262      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.533     |
# |    explained_variance   | 0.769      |
# |    learning_rate        | 0.0014     |
# |    loss                 | 0.0376     |
# |    n_updates            | 150        |
# |    policy_gradient_loss | 0.0131     |
# |    value_loss           | 0.000261   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.795       |
# | time/                   |             |
# |    fps                  | 1245        |
# |    iterations           | 17          |
# |    time_elapsed         | 17          |
# |    total_timesteps      | 21760       |
# | train/                  |             |
# |    approx_kl            | 0.021680837 |
# |    clip_fraction        | 0.267       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.514      |
# |    explained_variance   | 0.735       |
# |    learning_rate        | 0.0014      |
# |    loss                 | -0.00213    |
# |    n_updates            | 160         |
# |    policy_gradient_loss | 0.0203      |
# |    value_loss           | 0.00439     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.833       |
# | time/                   |             |
# |    fps                  | 1247        |
# |    iterations           | 18          |
# |    time_elapsed         | 18          |
# |    total_timesteps      | 23040       |
# | train/                  |             |
# |    approx_kl            | 0.026307257 |
# |    clip_fraction        | 0.231       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.482      |
# |    explained_variance   | 0.0785      |
# |    learning_rate        | 0.0014      |
# |    loss                 | 0.00263     |
# |    n_updates            | 170         |
# |    policy_gradient_loss | 0.0148      |
# |    value_loss           | 0.000747    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.87        |
# | time/                   |             |
# |    fps                  | 1249        |
# |    iterations           | 19          |
# |    time_elapsed         | 19          |
# |    total_timesteps      | 24320       |
# | train/                  |             |
# |    approx_kl            | 0.085114986 |
# |    clip_fraction        | 0.23        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.437      |
# |    explained_variance   | 0.69        |
# |    learning_rate        | 0.0014      |
# |    loss                 | 0.0481      |
# |    n_updates            | 180         |
# |    policy_gradient_loss | 0.01        |
# |    value_loss           | 0.000188    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.897       |
# | time/                   |             |
# |    fps                  | 1250        |
# |    iterations           | 20          |
# |    time_elapsed         | 20          |
# |    total_timesteps      | 25600       |
# | train/                  |             |
# |    approx_kl            | 0.114390545 |
# |    clip_fraction        | 0.224       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.443      |
# |    explained_variance   | 0.782       |
# |    learning_rate        | 0.0014      |
# |    loss                 | 0.0411      |
# |    n_updates            | 190         |
# |    policy_gradient_loss | 0.0303      |
# |    value_loss           | 0.000152    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 335        |
# |    ep_rew_mean          | 0.924      |
# | time/                   |            |
# |    fps                  | 1254       |
# |    iterations           | 21         |
# |    time_elapsed         | 21         |
# |    total_timesteps      | 26880      |
# | train/                  |            |
# |    approx_kl            | 0.04323478 |
# |    clip_fraction        | 0.224      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.436     |
# |    explained_variance   | 0.741      |
# |    learning_rate        | 0.0014     |
# |    loss                 | -0.0122    |
# |    n_updates            | 200        |
# |    policy_gradient_loss | 0.0169     |
# |    value_loss           | 0.000155   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 335        |
# |    ep_rew_mean          | 0.952      |
# | time/                   |            |
# |    fps                  | 1258       |
# |    iterations           | 22         |
# |    time_elapsed         | 22         |
# |    total_timesteps      | 28160      |
# | train/                  |            |
# |    approx_kl            | 0.07004781 |
# |    clip_fraction        | 0.223      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.396     |
# |    explained_variance   | 0.799      |
# |    learning_rate        | 0.0014     |
# |    loss                 | -0.0115    |
# |    n_updates            | 210        |
# |    policy_gradient_loss | 0.0263     |
# |    value_loss           | 0.000137   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 335        |
# |    ep_rew_mean          | 0.974      |
# | time/                   |            |
# |    fps                  | 1261       |
# |    iterations           | 23         |
# |    time_elapsed         | 23         |
# |    total_timesteps      | 29440      |
# | train/                  |            |
# |    approx_kl            | 0.04625307 |
# |    clip_fraction        | 0.189      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.368     |
# |    explained_variance   | 0.8        |
# |    learning_rate        | 0.0014     |
# |    loss                 | -0.000661  |
# |    n_updates            | 220        |
# |    policy_gradient_loss | 0.0153     |
# |    value_loss           | 0.00101    |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 335       |
# |    ep_rew_mean          | 0.999     |
# | time/                   |           |
# |    fps                  | 1263      |
# |    iterations           | 24        |
# |    time_elapsed         | 24        |
# |    total_timesteps      | 30720     |
# | train/                  |           |
# |    approx_kl            | 0.0282627 |
# |    clip_fraction        | 0.226     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.353    |
# |    explained_variance   | 0.718     |
# |    learning_rate        | 0.0014    |
# |    loss                 | -0.00212  |
# |    n_updates            | 230       |
# |    policy_gradient_loss | 0.0261    |
# |    value_loss           | 0.00028   |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 1.03        |
# | time/                   |             |
# |    fps                  | 1247        |
# |    iterations           | 25          |
# |    time_elapsed         | 25          |
# |    total_timesteps      | 32000       |
# | train/                  |             |
# |    approx_kl            | 0.036117643 |
# |    clip_fraction        | 0.222       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.361      |
# |    explained_variance   | 0.776       |
# |    learning_rate        | 0.0014      |
# |    loss                 | -0.00828    |
# |    n_updates            | 240         |
# |    policy_gradient_loss | 0.0283      |
# |    value_loss           | 0.000259    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 1.05        |
# | time/                   |             |
# |    fps                  | 1240        |
# |    iterations           | 26          |
# |    time_elapsed         | 26          |
# |    total_timesteps      | 33280       |
# | train/                  |             |
# |    approx_kl            | 0.028149437 |
# |    clip_fraction        | 0.172       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.344      |
# |    explained_variance   | 0.825       |
# |    learning_rate        | 0.0014      |
# |    loss                 | -0.0179     |
# |    n_updates            | 250         |
# |    policy_gradient_loss | 0.00729     |
# |    value_loss           | 0.000117    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 335        |
# |    ep_rew_mean          | 1.1        |
# | time/                   |            |
# |    fps                  | 1230       |
# |    iterations           | 27         |
# |    time_elapsed         | 28         |
# |    total_timesteps      | 34560      |
# | train/                  |            |
# |    approx_kl            | 0.07667554 |
# |    clip_fraction        | 0.231      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.297     |
# |    explained_variance   | 0.797      |
# |    learning_rate        | 0.0014     |
# |    loss                 | -0.0104    |
# |    n_updates            | 260        |
# |    policy_gradient_loss | 0.0297     |
# |    value_loss           | 0.000129   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 1.15        |
# | time/                   |             |
# |    fps                  | 1234        |
# |    iterations           | 28          |
# |    time_elapsed         | 29          |
# |    total_timesteps      | 35840       |
# | train/                  |             |
# |    approx_kl            | 0.066126436 |
# |    clip_fraction        | 0.233       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.324      |
# |    explained_variance   | 0.851       |
# |    learning_rate        | 0.0014      |
# |    loss                 | -0.0069     |
# |    n_updates            | 270         |
# |    policy_gradient_loss | 0.0381      |
# |    value_loss           | 0.000104    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 335        |
# |    ep_rew_mean          | 1.22       |
# | time/                   |            |
# |    fps                  | 1234       |
# |    iterations           | 29         |
# |    time_elapsed         | 30         |
# |    total_timesteps      | 37120      |
# | train/                  |            |
# |    approx_kl            | 0.08913866 |
# |    clip_fraction        | 0.228      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.3       |
# |    explained_variance   | 0.861      |
# |    learning_rate        | 0.0014     |
# |    loss                 | 0.0834     |
# |    n_updates            | 280        |
# |    policy_gradient_loss | 0.0336     |
# |    value_loss           | 0.00036    |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 335       |
# |    ep_rew_mean          | 1.27      |
# | time/                   |           |
# |    fps                  | 1238      |
# |    iterations           | 30        |
# |    time_elapsed         | 31        |
# |    total_timesteps      | 38400     |
# | train/                  |           |
# |    approx_kl            | 0.1594195 |
# |    clip_fraction        | 0.239     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.25     |
# |    explained_variance   | 0.82      |
# |    learning_rate        | 0.0014    |
# |    loss                 | 0.0199    |
# |    n_updates            | 290       |
# |    policy_gradient_loss | 0.0922    |
# |    value_loss           | 0.000261  |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 335        |
# |    ep_rew_mean          | 1.32       |
# | time/                   |            |
# |    fps                  | 1242       |
# |    iterations           | 31         |
# |    time_elapsed         | 31         |
# |    total_timesteps      | 39680      |
# | train/                  |            |
# |    approx_kl            | 0.05559762 |
# |    clip_fraction        | 0.186      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.231     |
# |    explained_variance   | 0.857      |
# |    learning_rate        | 0.0014     |
# |    loss                 | -0.0074    |
# |    n_updates            | 300        |
# |    policy_gradient_loss | 0.0134     |
# |    value_loss           | 0.000229   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 335        |
# |    ep_rew_mean          | 1.37       |
# | time/                   |            |
# |    fps                  | 1244       |
# |    iterations           | 32         |
# |    time_elapsed         | 32         |
# |    total_timesteps      | 40960      |
# | train/                  |            |
# |    approx_kl            | 0.03501942 |
# |    clip_fraction        | 0.176      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.219     |
# |    explained_variance   | 0.866      |
# |    learning_rate        | 0.0014     |
# |    loss                 | 0.0531     |
# |    n_updates            | 310        |
# |    policy_gradient_loss | 0.0299     |
# |    value_loss           | 0.000556   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 1.41        |
# | time/                   |             |
# |    fps                  | 1248        |
# |    iterations           | 33          |
# |    time_elapsed         | 33          |
# |    total_timesteps      | 42240       |
# | train/                  |             |
# |    approx_kl            | 0.076079205 |
# |    clip_fraction        | 0.296       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.214      |
# |    explained_variance   | 0.809       |
# |    learning_rate        | 0.0014      |
# |    loss                 | 0.0563      |
# |    n_updates            | 320         |
# |    policy_gradient_loss | 0.131       |
# |    value_loss           | 0.000379    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 335        |
# |    ep_rew_mean          | 1.43       |
# | time/                   |            |
# |    fps                  | 1250       |
# |    iterations           | 34         |
# |    time_elapsed         | 34         |
# |    total_timesteps      | 43520      |
# | train/                  |            |
# |    approx_kl            | 0.07460469 |
# |    clip_fraction        | 0.229      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.247     |
# |    explained_variance   | 0.825      |
# |    learning_rate        | 0.0014     |
# |    loss                 | 0.051      |
# |    n_updates            | 330        |
# |    policy_gradient_loss | 0.0329     |
# |    value_loss           | 0.000129   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 335        |
# |    ep_rew_mean          | 1.46       |
# | time/                   |            |
# |    fps                  | 1251       |
# |    iterations           | 35         |
# |    time_elapsed         | 35         |
# |    total_timesteps      | 44800      |
# | train/                  |            |
# |    approx_kl            | 0.07732675 |
# |    clip_fraction        | 0.224      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.216     |
# |    explained_variance   | 0.747      |
# |    learning_rate        | 0.0014     |
# |    loss                 | -0.0224    |
# |    n_updates            | 340        |
# |    policy_gradient_loss | 0.0344     |
# |    value_loss           | 0.000176   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 335        |
# |    ep_rew_mean          | 1.49       |
# | time/                   |            |
# |    fps                  | 1253       |
# |    iterations           | 36         |
# |    time_elapsed         | 36         |
# |    total_timesteps      | 46080      |
# | train/                  |            |
# |    approx_kl            | 0.66723156 |
# |    clip_fraction        | 0.232      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.203     |
# |    explained_variance   | 0.78       |
# |    learning_rate        | 0.0014     |
# |    loss                 | 0.11       |
# |    n_updates            | 350        |
# |    policy_gradient_loss | 0.0519     |
# |    value_loss           | 0.000503   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 1.51        |
# | time/                   |             |
# |    fps                  | 1252        |
# |    iterations           | 37          |
# |    time_elapsed         | 37          |
# |    total_timesteps      | 47360       |
# | train/                  |             |
# |    approx_kl            | 0.054653052 |
# |    clip_fraction        | 0.168       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.195      |
# |    explained_variance   | 0.784       |
# |    learning_rate        | 0.0014      |
# |    loss                 | -0.0316     |
# |    n_updates            | 360         |
# |    policy_gradient_loss | 0.00774     |
# |    value_loss           | 0.000184    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 1.54        |
# | time/                   |             |
# |    fps                  | 1252        |
# |    iterations           | 38          |
# |    time_elapsed         | 38          |
# |    total_timesteps      | 48640       |
# | train/                  |             |
# |    approx_kl            | 0.047073938 |
# |    clip_fraction        | 0.198       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.196      |
# |    explained_variance   | 0.787       |
# |    learning_rate        | 0.0014      |
# |    loss                 | -0.00325    |
# |    n_updates            | 370         |
# |    policy_gradient_loss | 0.0396      |
# |    value_loss           | 0.000128    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 1.56        |
# | time/                   |             |
# |    fps                  | 1253        |
# |    iterations           | 39          |
# |    time_elapsed         | 39          |
# |    total_timesteps      | 49920       |
# | train/                  |             |
# |    approx_kl            | 0.025900431 |
# |    clip_fraction        | 0.198       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.192      |
# |    explained_variance   | 0.828       |
# |    learning_rate        | 0.0014      |
# |    loss                 | 0.00305     |
# |    n_updates            | 380         |
# |    policy_gradient_loss | 0.0476      |
# |    value_loss           | 0.000108    |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 335       |
# |    ep_rew_mean          | 1.57      |
# | time/                   |           |
# |    fps                  | 1247      |
# |    iterations           | 40        |
# |    time_elapsed         | 41        |
# |    total_timesteps      | 51200     |
# | train/                  |           |
# |    approx_kl            | 0.0948724 |
# |    clip_fraction        | 0.154     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.181    |
# |    explained_variance   | 0.865     |
# |    learning_rate        | 0.0014    |
# |    loss                 | 0.0244    |
# |    n_updates            | 390       |
# |    policy_gradient_loss | 0.0274    |
# |    value_loss           | 8.07e-05  |
# ---------------------------------------
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 335      |
# |    ep_rew_mean     | 0.0271   |
# | time/              |          |
# |    fps             | 1545     |
# |    iterations      | 1        |
# |    time_elapsed    | 1        |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.0349      |
# | time/                   |             |
# |    fps                  | 1089        |
# |    iterations           | 2           |
# |    time_elapsed         | 3           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.009027935 |
# |    clip_fraction        | 0.0572      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | -5.58       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0321      |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.00244    |
# |    value_loss           | 0.00261     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.0462      |
# | time/                   |             |
# |    fps                  | 1063        |
# |    iterations           | 3           |
# |    time_elapsed         | 5           |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.006988464 |
# |    clip_fraction        | 0.0383      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.1        |
# |    explained_variance   | 0.207       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0108     |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.00304    |
# |    value_loss           | 0.00071     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.0908      |
# | time/                   |             |
# |    fps                  | 1043        |
# |    iterations           | 4           |
# |    time_elapsed         | 7           |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.008670771 |
# |    clip_fraction        | 0.0956      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.08       |
# |    explained_variance   | 0.668       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00559     |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.00743    |
# |    value_loss           | 0.000593    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.114       |
# | time/                   |             |
# |    fps                  | 1033        |
# |    iterations           | 5           |
# |    time_elapsed         | 9           |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.011117466 |
# |    clip_fraction        | 0.112       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.08       |
# |    explained_variance   | 0.464       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0319     |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0122     |
# |    value_loss           | 0.000588    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.141       |
# | time/                   |             |
# |    fps                  | 1029        |
# |    iterations           | 6           |
# |    time_elapsed         | 11          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.008151069 |
# |    clip_fraction        | 0.114       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.07       |
# |    explained_variance   | 0.501       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0195     |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0104     |
# |    value_loss           | 0.000524    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.176       |
# | time/                   |             |
# |    fps                  | 1026        |
# |    iterations           | 7           |
# |    time_elapsed         | 13          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.009979991 |
# |    clip_fraction        | 0.144       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.05       |
# |    explained_variance   | 0.32        |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00938    |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0127     |
# |    value_loss           | 0.000669    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.211       |
# | time/                   |             |
# |    fps                  | 997         |
# |    iterations           | 8           |
# |    time_elapsed         | 16          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.010752556 |
# |    clip_fraction        | 0.123       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.01       |
# |    explained_variance   | 0.293       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00801     |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.00796    |
# |    value_loss           | 0.000442    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 335        |
# |    ep_rew_mean          | 0.252      |
# | time/                   |            |
# |    fps                  | 966        |
# |    iterations           | 9          |
# |    time_elapsed         | 19         |
# |    total_timesteps      | 18432      |
# | train/                  |            |
# |    approx_kl            | 0.01417541 |
# |    clip_fraction        | 0.217      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.928     |
# |    explained_variance   | -0.0246    |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0401    |
# |    n_updates            | 80         |
# |    policy_gradient_loss | -0.0182    |
# |    value_loss           | 0.000753   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.308       |
# | time/                   |             |
# |    fps                  | 962         |
# |    iterations           | 10          |
# |    time_elapsed         | 21          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.008848282 |
# |    clip_fraction        | 0.113       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.889      |
# |    explained_variance   | -0.0786     |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0253     |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.00676    |
# |    value_loss           | 0.000453    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.362       |
# | time/                   |             |
# |    fps                  | 961         |
# |    iterations           | 11          |
# |    time_elapsed         | 23          |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.015634255 |
# |    clip_fraction        | 0.156       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.811      |
# |    explained_variance   | 0.37        |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0234     |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.00893    |
# |    value_loss           | 0.000532    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 335        |
# |    ep_rew_mean          | 0.408      |
# | time/                   |            |
# |    fps                  | 964        |
# |    iterations           | 12         |
# |    time_elapsed         | 25         |
# |    total_timesteps      | 24576      |
# | train/                  |            |
# |    approx_kl            | 0.01401293 |
# |    clip_fraction        | 0.154      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.758     |
# |    explained_variance   | 0.722      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.00555   |
# |    n_updates            | 110        |
# |    policy_gradient_loss | -0.00433   |
# |    value_loss           | 0.000499   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.459       |
# | time/                   |             |
# |    fps                  | 965         |
# |    iterations           | 13          |
# |    time_elapsed         | 27          |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.014303165 |
# |    clip_fraction        | 0.172       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.701      |
# |    explained_variance   | 0.845       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.025       |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.00131    |
# |    value_loss           | 0.000366    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 335        |
# |    ep_rew_mean          | 0.502      |
# | time/                   |            |
# |    fps                  | 968        |
# |    iterations           | 14         |
# |    time_elapsed         | 29         |
# |    total_timesteps      | 28672      |
# | train/                  |            |
# |    approx_kl            | 0.01464038 |
# |    clip_fraction        | 0.153      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.682     |
# |    explained_variance   | 0.906      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0332    |
# |    n_updates            | 130        |
# |    policy_gradient_loss | -0.00527   |
# |    value_loss           | 0.000498   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.544       |
# | time/                   |             |
# |    fps                  | 958         |
# |    iterations           | 15          |
# |    time_elapsed         | 32          |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.020663055 |
# |    clip_fraction        | 0.159       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.652      |
# |    explained_variance   | 0.945       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0272     |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.00461    |
# |    value_loss           | 0.000337    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.58        |
# | time/                   |             |
# |    fps                  | 943         |
# |    iterations           | 16          |
# |    time_elapsed         | 34          |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.011927894 |
# |    clip_fraction        | 0.14        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.642      |
# |    explained_variance   | 0.967       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0131     |
# |    n_updates            | 150         |
# |    policy_gradient_loss | 0.00112     |
# |    value_loss           | 0.000675    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.636       |
# | time/                   |             |
# |    fps                  | 947         |
# |    iterations           | 17          |
# |    time_elapsed         | 36          |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.010087706 |
# |    clip_fraction        | 0.137       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.596      |
# |    explained_variance   | 0.968       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0178      |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.0006     |
# |    value_loss           | 0.000293    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.726       |
# | time/                   |             |
# |    fps                  | 949         |
# |    iterations           | 18          |
# |    time_elapsed         | 38          |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.013604503 |
# |    clip_fraction        | 0.0985      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.57       |
# |    explained_variance   | 0.97        |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00309    |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.000949   |
# |    value_loss           | 0.000427    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.804       |
# | time/                   |             |
# |    fps                  | 949         |
# |    iterations           | 19          |
# |    time_elapsed         | 40          |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.010728444 |
# |    clip_fraction        | 0.14        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.52       |
# |    explained_variance   | 0.981       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0011      |
# |    n_updates            | 180         |
# |    policy_gradient_loss | 0.00284     |
# |    value_loss           | 0.000281    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.876       |
# | time/                   |             |
# |    fps                  | 948         |
# |    iterations           | 20          |
# |    time_elapsed         | 43          |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.013026451 |
# |    clip_fraction        | 0.131       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.487      |
# |    explained_variance   | 0.985       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00079    |
# |    n_updates            | 190         |
# |    policy_gradient_loss | 0.000558    |
# |    value_loss           | 0.000326    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.948       |
# | time/                   |             |
# |    fps                  | 951         |
# |    iterations           | 21          |
# |    time_elapsed         | 45          |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.018851642 |
# |    clip_fraction        | 0.134       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.468      |
# |    explained_variance   | 0.989       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.002      |
# |    n_updates            | 200         |
# |    policy_gradient_loss | 0.00353     |
# |    value_loss           | 0.000174    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 335        |
# |    ep_rew_mean          | 1.02       |
# | time/                   |            |
# |    fps                  | 948        |
# |    iterations           | 22         |
# |    time_elapsed         | 47         |
# |    total_timesteps      | 45056      |
# | train/                  |            |
# |    approx_kl            | 0.01691238 |
# |    clip_fraction        | 0.168      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.456     |
# |    explained_variance   | 0.991      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.00743   |
# |    n_updates            | 210        |
# |    policy_gradient_loss | 0.00925    |
# |    value_loss           | 0.000574   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 1.08        |
# | time/                   |             |
# |    fps                  | 938         |
# |    iterations           | 23          |
# |    time_elapsed         | 50          |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.020301897 |
# |    clip_fraction        | 0.146       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.418      |
# |    explained_variance   | 0.991       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0153      |
# |    n_updates            | 220         |
# |    policy_gradient_loss | 0.00726     |
# |    value_loss           | 0.000879    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 1.14        |
# | time/                   |             |
# |    fps                  | 937         |
# |    iterations           | 24          |
# |    time_elapsed         | 52          |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.027069794 |
# |    clip_fraction        | 0.156       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.394      |
# |    explained_variance   | 0.99        |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.000962   |
# |    n_updates            | 230         |
# |    policy_gradient_loss | 0.0127      |
# |    value_loss           | 0.000399    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 1.21        |
# | time/                   |             |
# |    fps                  | 940         |
# |    iterations           | 25          |
# |    time_elapsed         | 54          |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.014662846 |
# |    clip_fraction        | 0.143       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.378      |
# |    explained_variance   | 0.992       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.000101   |
# |    n_updates            | 240         |
# |    policy_gradient_loss | 0.00805     |
# |    value_loss           | 0.000184    |
# -----------------------------------------
#          Method  Cumulative Return  Sharpe Ratio  Sortino Ratio  Max Drawdown
# 0   Bi-LSTM PPO           2.779165      0.553744       1.533731     -0.011937
# 1    Simple PPO           2.661433      0.508544       1.217007     -0.014248
# 2  Buy-and-Hold          -0.666092           NaN            NaN           NaN

# %%
import pandas as pd
import numpy as np
import torch
import torch.nn as nn
from sklearn.preprocessing import MinMaxScaler
from torch.utils.data import DataLoader, TensorDataset
from stable_baselines3 import PPO
from gym import spaces, Env
import matplotlib.pyplot as plt
import random

# Set seed for reproducibility
SEED = 42
random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)
if torch.cuda.is_available():
    torch.cuda.manual_seed_all(SEED)

# Load and preprocess data
def load_and_preprocess(file_name):
    data = pd.read_csv(file_name)
    data["Date"] = pd.to_datetime(data["Date"])
    data = data.sort_values(by="Date")
    
    numeric_data = data.drop(columns=["Date"])
    numeric_data = numeric_data[['Close'] + [col for col in numeric_data.columns if col != 'Close']]
    
    scaler = MinMaxScaler()
    normalized_data = scaler.fit_transform(numeric_data)
    data[numeric_data.columns] = normalized_data
    
    return data, scaler

# Create sequences for time series modeling
def create_sequences(data, sequence_length=30):
    sequences = []
    targets = []
    for i in range(len(data) - sequence_length):
        seq = data[i:i+sequence_length]
        target = data[i+sequence_length, 0]  # Assuming the target is the first column (e.g., Close price)
        sequences.append(seq)
        targets.append(target)
    return np.array(sequences), np.array(targets)

# Define Bi-LSTM model
class BiLSTMModel(nn.Module):
    def __init__(self, input_dim, hidden_dim, num_layers, dropout):
        super(BiLSTMModel, self).__init__()
        self.bilstm = nn.LSTM(input_dim, hidden_dim, num_layers, batch_first=True, dropout=dropout, bidirectional=True)
        self.fc = nn.Linear(hidden_dim * 2, 1)

    def forward(self, x):
        bilstm_out, _ = self.bilstm(x)
        return self.fc(bilstm_out[:, -1, :])

# Custom trading environment
class TradingEnv(Env):
    def __init__(self, data, sequence_length=30):
        super(TradingEnv, self).__init__()
        self.data = data
        self.sequence_length = sequence_length
        self.current_step = 0
        self.total_steps = len(data) - sequence_length
        self.portfolio_value = 1.0

        # Action and observation space
        self.action_space = spaces.Discrete(3)  # 0: Hold, 1: Buy, 2: Sell
        self.observation_space = spaces.Box(low=0, high=1, shape=(sequence_length, data.shape[1]), dtype=np.float32)

    def reset(self):
        self.current_step = 0
        self.portfolio_value = 1.0
        return self._next_observation()

    def _next_observation(self):
        return self.data[self.current_step:self.current_step + self.sequence_length]

    def step(self, action):
        self.current_step += 1
        reward = 0
        done = self.current_step >= self.total_steps

        if not done:
            current_price = self.data[self.current_step, 0]
            prev_price = self.data[self.current_step - 1, 0]

            if action == 1:  # Buy
                reward = current_price - prev_price
            elif action == 2:  # Sell
                reward = prev_price - current_price

        self.portfolio_value += reward
        obs = self._next_observation() if not done else None
        return obs, reward, done, {"portfolio_value": self.portfolio_value}

# Evaluate trading strategy
def evaluate_trading_strategy(env, model):
    obs = env.reset()
    done = False
    portfolio_values = [1.0]

    while not done:
        action, _ = model.predict(obs, deterministic=True)
        obs, reward, done, info = env.step(action)
        portfolio_values.append(info.get("portfolio_value", 1.0))

    return portfolio_values

# Performance metrics
def calculate_metrics(portfolio_values):
    daily_returns = np.diff(portfolio_values) / portfolio_values[:-1]
    cumulative_return = portfolio_values[-1] / portfolio_values[0] - 1
    sharpe_ratio = np.mean(daily_returns) / np.std(daily_returns) if np.std(daily_returns) > 0 else 0
    sortino_ratio = np.mean(daily_returns) / np.std([r for r in daily_returns if r < 0]) if np.std([r for r in daily_returns if r < 0]) > 0 else 0
    max_drawdown = np.min(portfolio_values / np.maximum.accumulate(portfolio_values) - 1)
    return cumulative_return, sharpe_ratio, sortino_ratio, max_drawdown

# Main execution
if __name__ == "__main__":
    # Load data
    data, scaler = load_and_preprocess("Book1.csv")
    train_data = data[(data["Date"].dt.year >= 2017) & (data["Date"].dt.year <= 2021)].drop(columns=["Date"]).values
    test_data = data[data["Date"].dt.year == 2022].drop(columns=["Date"]).values

    X_train, y_train = create_sequences(train_data)
    X_test, y_test = create_sequences(test_data)

    # Train Bi-LSTM model
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    bilstm_model = BiLSTMModel(input_dim=X_train.shape[2], hidden_dim=224, num_layers=1, dropout=0.14).to(device)
    criterion = nn.MSELoss()
    optimizer = torch.optim.Adam(bilstm_model.parameters(), lr=0.0019)

    train_loader = DataLoader(TensorDataset(torch.tensor(X_train, dtype=torch.float32), torch.tensor(y_train, dtype=torch.float32)), batch_size=32, shuffle=True)

    for epoch in range(50):
        bilstm_model.train()
        train_loss = 0.0
        for X_batch, y_batch in train_loader:
            X_batch, y_batch = X_batch.to(device), y_batch.to(device)
            optimizer.zero_grad()
            predictions = bilstm_model(X_batch).squeeze()
            loss = criterion(predictions, y_batch)
            loss.backward()
            optimizer.step()
            train_loss += loss.item()

    # Create environments for PPO
    bilstm_env = TradingEnv(test_data)
    simple_env = TradingEnv(test_data)

    # Train PPO models
    ppo_bilstm_model = PPO("MlpPolicy", bilstm_env, learning_rate=0.0014, batch_size=160, n_steps=1280, gamma=0.9005911776350177, verbose=1)
    ppo_bilstm_model.learn(total_timesteps=50000)

    ppo_simple_model = PPO("MlpPolicy", simple_env, verbose=1)
    ppo_simple_model.learn(total_timesteps=50000)

    # Evaluate strategies
    portfolio_values_bilstm = evaluate_trading_strategy(bilstm_env, ppo_bilstm_model)
    portfolio_values_simple = evaluate_trading_strategy(simple_env, ppo_simple_model)

    cumulative_return_bilstm, sharpe_bilstm, sortino_bilstm, max_drawdown_bilstm = calculate_metrics(portfolio_values_bilstm)
    cumulative_return_simple, sharpe_simple, sortino_simple, max_drawdown_simple = calculate_metrics(portfolio_values_simple)

    # Buy-and-Hold strategy
    buy_hold_return = test_data[-1, 0] / test_data[0, 0] - 1

    # Generate date range for 2022
    test_dates = pd.date_range(start="2022-01-01", periods=len(portfolio_values_bilstm))

    # Calculate cumulative returns
    cumulative_returns_bilstm = np.cumprod([1 + r for r in np.diff(portfolio_values_bilstm) / portfolio_values_bilstm[:-1]])
    cumulative_returns_simple = np.cumprod([1 + r for r in np.diff(portfolio_values_simple) / portfolio_values_simple[:-1]])

    # Plot cumulative returns
    plt.figure(figsize=(12, 6))
    plt.plot(test_dates[1:], cumulative_returns_bilstm, label="Bi-LSTM PPO")
    plt.plot(test_dates[1:], cumulative_returns_simple, label="Simple PPO")

    plt.gca().xaxis.set_major_formatter(plt.matplotlib.dates.DateFormatter("%b %Y"))
    plt.gca().xaxis.set_major_locator(plt.matplotlib.dates.MonthLocator())

    plt.legend()
    plt.title("Cumulative Returns")
    plt.xlabel("Date")
    plt.ylabel("Cumulative Return")
    plt.grid()
    plt.show()

    # Print results
    results = pd.DataFrame({
        "Method": ["Bi-LSTM PPO", "Simple PPO", "Buy-and-Hold"],
        "Cumulative Return": [cumulative_returns_bilstm[-1], cumulative_returns_simple[-1], buy_hold_return],
        "Sharpe Ratio": [sharpe_bilstm, sharpe_simple, None],
        "Sortino Ratio": [sortino_bilstm, sortino_simple, None],
        "Max Drawdown": [max_drawdown_bilstm, max_drawdown_simple, None]
    })
    print(results)
# Out:
# C:\Users\User\anaconda3\envs\RL\Lib\site-packages\torch\nn\modules\rnn.py:123: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.14 and num_layers=1
#   warnings.warn(
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# C:\Users\User\anaconda3\envs\RL\Lib\site-packages\stable_baselines3\common\vec_env\patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 335      |
# |    ep_rew_mean     | 0.00348  |
# | time/              |          |
# |    fps             | 1299     |
# |    iterations      | 1        |
# |    time_elapsed    | 0        |
# |    total_timesteps | 1280     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.0488      |
# | time/                   |             |
# |    fps                  | 1085        |
# |    iterations           | 2           |
# |    time_elapsed         | 2           |
# |    total_timesteps      | 2560        |
# | train/                  |             |
# |    approx_kl            | 0.009146687 |
# |    clip_fraction        | 0.0755      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | -4.86       |
# |    learning_rate        | 0.0014      |
# |    loss                 | -0.00363    |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.00639    |
# |    value_loss           | 0.0293      |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 335        |
# |    ep_rew_mean          | 0.0779     |
# | time/                   |            |
# |    fps                  | 1032       |
# |    iterations           | 3          |
# |    time_elapsed         | 3          |
# |    total_timesteps      | 3840       |
# | train/                  |            |
# |    approx_kl            | 0.00984605 |
# |    clip_fraction        | 0.127      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.07      |
# |    explained_variance   | -1.24      |
# |    learning_rate        | 0.0014     |
# |    loss                 | 0.00591    |
# |    n_updates            | 20         |
# |    policy_gradient_loss | -0.00928   |
# |    value_loss           | 0.000973   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.127       |
# | time/                   |             |
# |    fps                  | 1003        |
# |    iterations           | 4           |
# |    time_elapsed         | 5           |
# |    total_timesteps      | 5120        |
# | train/                  |             |
# |    approx_kl            | 0.011497049 |
# |    clip_fraction        | 0.211       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.04       |
# |    explained_variance   | -0.403      |
# |    learning_rate        | 0.0014      |
# |    loss                 | -0.0231     |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0196     |
# |    value_loss           | 0.000417    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.193       |
# | time/                   |             |
# |    fps                  | 993         |
# |    iterations           | 5           |
# |    time_elapsed         | 6           |
# |    total_timesteps      | 6400        |
# | train/                  |             |
# |    approx_kl            | 0.013531568 |
# |    clip_fraction        | 0.226       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.997      |
# |    explained_variance   | -0.097      |
# |    learning_rate        | 0.0014      |
# |    loss                 | -0.00313    |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0123     |
# |    value_loss           | 0.000268    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 335        |
# |    ep_rew_mean          | 0.246      |
# | time/                   |            |
# |    fps                  | 980        |
# |    iterations           | 6          |
# |    time_elapsed         | 7          |
# |    total_timesteps      | 7680       |
# | train/                  |            |
# |    approx_kl            | 0.01935076 |
# |    clip_fraction        | 0.226      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.955     |
# |    explained_variance   | 0.039      |
# |    learning_rate        | 0.0014     |
# |    loss                 | 0.0081     |
# |    n_updates            | 50         |
# |    policy_gradient_loss | -0.0186    |
# |    value_loss           | 0.000239   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.304       |
# | time/                   |             |
# |    fps                  | 976         |
# |    iterations           | 7           |
# |    time_elapsed         | 9           |
# |    total_timesteps      | 8960        |
# | train/                  |             |
# |    approx_kl            | 0.022379909 |
# |    clip_fraction        | 0.217       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.843      |
# |    explained_variance   | 0.175       |
# |    learning_rate        | 0.0014      |
# |    loss                 | -0.0185     |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.00766    |
# |    value_loss           | 0.000227    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.37        |
# | time/                   |             |
# |    fps                  | 949         |
# |    iterations           | 8           |
# |    time_elapsed         | 10          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.007462381 |
# |    clip_fraction        | 0.165       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.753      |
# |    explained_variance   | 0.33        |
# |    learning_rate        | 0.0014      |
# |    loss                 | -0.00976    |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.00065    |
# |    value_loss           | 0.000228    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.428       |
# | time/                   |             |
# |    fps                  | 929         |
# |    iterations           | 9           |
# |    time_elapsed         | 12          |
# |    total_timesteps      | 11520       |
# | train/                  |             |
# |    approx_kl            | 0.012593955 |
# |    clip_fraction        | 0.238       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.72       |
# |    explained_variance   | 0.535       |
# |    learning_rate        | 0.0014      |
# |    loss                 | -0.0113     |
# |    n_updates            | 80          |
# |    policy_gradient_loss | 0.000112    |
# |    value_loss           | 0.000154    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.48        |
# | time/                   |             |
# |    fps                  | 915         |
# |    iterations           | 10          |
# |    time_elapsed         | 13          |
# |    total_timesteps      | 12800       |
# | train/                  |             |
# |    approx_kl            | 0.016472884 |
# |    clip_fraction        | 0.22        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.74       |
# |    explained_variance   | 0.516       |
# |    learning_rate        | 0.0014      |
# |    loss                 | -0.0226     |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.00535    |
# |    value_loss           | 0.000175    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.538       |
# | time/                   |             |
# |    fps                  | 910         |
# |    iterations           | 11          |
# |    time_elapsed         | 15          |
# |    total_timesteps      | 14080       |
# | train/                  |             |
# |    approx_kl            | 0.024923364 |
# |    clip_fraction        | 0.326       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.692      |
# |    explained_variance   | 0.557       |
# |    learning_rate        | 0.0014      |
# |    loss                 | 0.0075      |
# |    n_updates            | 100         |
# |    policy_gradient_loss | 0.019       |
# |    value_loss           | 0.000267    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.575       |
# | time/                   |             |
# |    fps                  | 913         |
# |    iterations           | 12          |
# |    time_elapsed         | 16          |
# |    total_timesteps      | 15360       |
# | train/                  |             |
# |    approx_kl            | 0.024326894 |
# |    clip_fraction        | 0.25        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.629      |
# |    explained_variance   | 0.651       |
# |    learning_rate        | 0.0014      |
# |    loss                 | 0.0337      |
# |    n_updates            | 110         |
# |    policy_gradient_loss | 0.00943     |
# |    value_loss           | 0.000333    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 335        |
# |    ep_rew_mean          | 0.63       |
# | time/                   |            |
# |    fps                  | 914        |
# |    iterations           | 13         |
# |    time_elapsed         | 18         |
# |    total_timesteps      | 16640      |
# | train/                  |            |
# |    approx_kl            | 0.04544209 |
# |    clip_fraction        | 0.249      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.579     |
# |    explained_variance   | 0.663      |
# |    learning_rate        | 0.0014     |
# |    loss                 | 0.00102    |
# |    n_updates            | 120        |
# |    policy_gradient_loss | 0.00565    |
# |    value_loss           | 0.000158   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.679       |
# | time/                   |             |
# |    fps                  | 914         |
# |    iterations           | 14          |
# |    time_elapsed         | 19          |
# |    total_timesteps      | 17920       |
# | train/                  |             |
# |    approx_kl            | 0.027528787 |
# |    clip_fraction        | 0.284       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.56       |
# |    explained_variance   | 0.747       |
# |    learning_rate        | 0.0014      |
# |    loss                 | 0.00556     |
# |    n_updates            | 130         |
# |    policy_gradient_loss | 0.0238      |
# |    value_loss           | 0.000144    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 335        |
# |    ep_rew_mean          | 0.729      |
# | time/                   |            |
# |    fps                  | 915        |
# |    iterations           | 15         |
# |    time_elapsed         | 20         |
# |    total_timesteps      | 19200      |
# | train/                  |            |
# |    approx_kl            | 0.03261461 |
# |    clip_fraction        | 0.291      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.547     |
# |    explained_variance   | 0.778      |
# |    learning_rate        | 0.0014     |
# |    loss                 | -0.00442   |
# |    n_updates            | 140        |
# |    policy_gradient_loss | 0.0374     |
# |    value_loss           | 0.000401   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 335        |
# |    ep_rew_mean          | 0.764      |
# | time/                   |            |
# |    fps                  | 917        |
# |    iterations           | 16         |
# |    time_elapsed         | 22         |
# |    total_timesteps      | 20480      |
# | train/                  |            |
# |    approx_kl            | 0.07857958 |
# |    clip_fraction        | 0.262      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.533     |
# |    explained_variance   | 0.769      |
# |    learning_rate        | 0.0014     |
# |    loss                 | 0.0376     |
# |    n_updates            | 150        |
# |    policy_gradient_loss | 0.0131     |
# |    value_loss           | 0.000261   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.795       |
# | time/                   |             |
# |    fps                  | 918         |
# |    iterations           | 17          |
# |    time_elapsed         | 23          |
# |    total_timesteps      | 21760       |
# | train/                  |             |
# |    approx_kl            | 0.021680837 |
# |    clip_fraction        | 0.267       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.514      |
# |    explained_variance   | 0.735       |
# |    learning_rate        | 0.0014      |
# |    loss                 | -0.00213    |
# |    n_updates            | 160         |
# |    policy_gradient_loss | 0.0203      |
# |    value_loss           | 0.00439     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.833       |
# | time/                   |             |
# |    fps                  | 920         |
# |    iterations           | 18          |
# |    time_elapsed         | 25          |
# |    total_timesteps      | 23040       |
# | train/                  |             |
# |    approx_kl            | 0.026307257 |
# |    clip_fraction        | 0.231       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.482      |
# |    explained_variance   | 0.0785      |
# |    learning_rate        | 0.0014      |
# |    loss                 | 0.00263     |
# |    n_updates            | 170         |
# |    policy_gradient_loss | 0.0148      |
# |    value_loss           | 0.000747    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.87        |
# | time/                   |             |
# |    fps                  | 913         |
# |    iterations           | 19          |
# |    time_elapsed         | 26          |
# |    total_timesteps      | 24320       |
# | train/                  |             |
# |    approx_kl            | 0.085114986 |
# |    clip_fraction        | 0.23        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.437      |
# |    explained_variance   | 0.69        |
# |    learning_rate        | 0.0014      |
# |    loss                 | 0.0481      |
# |    n_updates            | 180         |
# |    policy_gradient_loss | 0.01        |
# |    value_loss           | 0.000188    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.897       |
# | time/                   |             |
# |    fps                  | 905         |
# |    iterations           | 20          |
# |    time_elapsed         | 28          |
# |    total_timesteps      | 25600       |
# | train/                  |             |
# |    approx_kl            | 0.114390545 |
# |    clip_fraction        | 0.224       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.443      |
# |    explained_variance   | 0.782       |
# |    learning_rate        | 0.0014      |
# |    loss                 | 0.0411      |
# |    n_updates            | 190         |
# |    policy_gradient_loss | 0.0303      |
# |    value_loss           | 0.000152    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 335        |
# |    ep_rew_mean          | 0.924      |
# | time/                   |            |
# |    fps                  | 899        |
# |    iterations           | 21         |
# |    time_elapsed         | 29         |
# |    total_timesteps      | 26880      |
# | train/                  |            |
# |    approx_kl            | 0.04323478 |
# |    clip_fraction        | 0.224      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.436     |
# |    explained_variance   | 0.741      |
# |    learning_rate        | 0.0014     |
# |    loss                 | -0.0122    |
# |    n_updates            | 200        |
# |    policy_gradient_loss | 0.0169     |
# |    value_loss           | 0.000155   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 335        |
# |    ep_rew_mean          | 0.952      |
# | time/                   |            |
# |    fps                  | 897        |
# |    iterations           | 22         |
# |    time_elapsed         | 31         |
# |    total_timesteps      | 28160      |
# | train/                  |            |
# |    approx_kl            | 0.07004781 |
# |    clip_fraction        | 0.223      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.396     |
# |    explained_variance   | 0.799      |
# |    learning_rate        | 0.0014     |
# |    loss                 | -0.0115    |
# |    n_updates            | 210        |
# |    policy_gradient_loss | 0.0263     |
# |    value_loss           | 0.000137   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 335        |
# |    ep_rew_mean          | 0.974      |
# | time/                   |            |
# |    fps                  | 898        |
# |    iterations           | 23         |
# |    time_elapsed         | 32         |
# |    total_timesteps      | 29440      |
# | train/                  |            |
# |    approx_kl            | 0.04625307 |
# |    clip_fraction        | 0.189      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.368     |
# |    explained_variance   | 0.8        |
# |    learning_rate        | 0.0014     |
# |    loss                 | -0.000661  |
# |    n_updates            | 220        |
# |    policy_gradient_loss | 0.0153     |
# |    value_loss           | 0.00101    |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 335       |
# |    ep_rew_mean          | 0.999     |
# | time/                   |           |
# |    fps                  | 899       |
# |    iterations           | 24        |
# |    time_elapsed         | 34        |
# |    total_timesteps      | 30720     |
# | train/                  |           |
# |    approx_kl            | 0.0282627 |
# |    clip_fraction        | 0.226     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.353    |
# |    explained_variance   | 0.718     |
# |    learning_rate        | 0.0014    |
# |    loss                 | -0.00212  |
# |    n_updates            | 230       |
# |    policy_gradient_loss | 0.0261    |
# |    value_loss           | 0.00028   |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 1.03        |
# | time/                   |             |
# |    fps                  | 900         |
# |    iterations           | 25          |
# |    time_elapsed         | 35          |
# |    total_timesteps      | 32000       |
# | train/                  |             |
# |    approx_kl            | 0.036117643 |
# |    clip_fraction        | 0.222       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.361      |
# |    explained_variance   | 0.776       |
# |    learning_rate        | 0.0014      |
# |    loss                 | -0.00828    |
# |    n_updates            | 240         |
# |    policy_gradient_loss | 0.0283      |
# |    value_loss           | 0.000259    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 1.05        |
# | time/                   |             |
# |    fps                  | 902         |
# |    iterations           | 26          |
# |    time_elapsed         | 36          |
# |    total_timesteps      | 33280       |
# | train/                  |             |
# |    approx_kl            | 0.028149437 |
# |    clip_fraction        | 0.172       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.344      |
# |    explained_variance   | 0.825       |
# |    learning_rate        | 0.0014      |
# |    loss                 | -0.0179     |
# |    n_updates            | 250         |
# |    policy_gradient_loss | 0.00729     |
# |    value_loss           | 0.000117    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 335        |
# |    ep_rew_mean          | 1.1        |
# | time/                   |            |
# |    fps                  | 904        |
# |    iterations           | 27         |
# |    time_elapsed         | 38         |
# |    total_timesteps      | 34560      |
# | train/                  |            |
# |    approx_kl            | 0.07667554 |
# |    clip_fraction        | 0.231      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.297     |
# |    explained_variance   | 0.797      |
# |    learning_rate        | 0.0014     |
# |    loss                 | -0.0104    |
# |    n_updates            | 260        |
# |    policy_gradient_loss | 0.0297     |
# |    value_loss           | 0.000129   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 1.15        |
# | time/                   |             |
# |    fps                  | 905         |
# |    iterations           | 28          |
# |    time_elapsed         | 39          |
# |    total_timesteps      | 35840       |
# | train/                  |             |
# |    approx_kl            | 0.066126436 |
# |    clip_fraction        | 0.233       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.324      |
# |    explained_variance   | 0.851       |
# |    learning_rate        | 0.0014      |
# |    loss                 | -0.0069     |
# |    n_updates            | 270         |
# |    policy_gradient_loss | 0.0381      |
# |    value_loss           | 0.000104    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 335        |
# |    ep_rew_mean          | 1.22       |
# | time/                   |            |
# |    fps                  | 906        |
# |    iterations           | 29         |
# |    time_elapsed         | 40         |
# |    total_timesteps      | 37120      |
# | train/                  |            |
# |    approx_kl            | 0.08913866 |
# |    clip_fraction        | 0.228      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.3       |
# |    explained_variance   | 0.861      |
# |    learning_rate        | 0.0014     |
# |    loss                 | 0.0834     |
# |    n_updates            | 280        |
# |    policy_gradient_loss | 0.0336     |
# |    value_loss           | 0.00036    |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 335       |
# |    ep_rew_mean          | 1.27      |
# | time/                   |           |
# |    fps                  | 903       |
# |    iterations           | 30        |
# |    time_elapsed         | 42        |
# |    total_timesteps      | 38400     |
# | train/                  |           |
# |    approx_kl            | 0.1594195 |
# |    clip_fraction        | 0.239     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.25     |
# |    explained_variance   | 0.82      |
# |    learning_rate        | 0.0014    |
# |    loss                 | 0.0199    |
# |    n_updates            | 290       |
# |    policy_gradient_loss | 0.0922    |
# |    value_loss           | 0.000261  |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 335        |
# |    ep_rew_mean          | 1.32       |
# | time/                   |            |
# |    fps                  | 897        |
# |    iterations           | 31         |
# |    time_elapsed         | 44         |
# |    total_timesteps      | 39680      |
# | train/                  |            |
# |    approx_kl            | 0.05559762 |
# |    clip_fraction        | 0.186      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.231     |
# |    explained_variance   | 0.857      |
# |    learning_rate        | 0.0014     |
# |    loss                 | -0.0074    |
# |    n_updates            | 300        |
# |    policy_gradient_loss | 0.0134     |
# |    value_loss           | 0.000229   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 335        |
# |    ep_rew_mean          | 1.37       |
# | time/                   |            |
# |    fps                  | 894        |
# |    iterations           | 32         |
# |    time_elapsed         | 45         |
# |    total_timesteps      | 40960      |
# | train/                  |            |
# |    approx_kl            | 0.03501942 |
# |    clip_fraction        | 0.176      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.219     |
# |    explained_variance   | 0.866      |
# |    learning_rate        | 0.0014     |
# |    loss                 | 0.0531     |
# |    n_updates            | 310        |
# |    policy_gradient_loss | 0.0299     |
# |    value_loss           | 0.000556   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 1.41        |
# | time/                   |             |
# |    fps                  | 893         |
# |    iterations           | 33          |
# |    time_elapsed         | 47          |
# |    total_timesteps      | 42240       |
# | train/                  |             |
# |    approx_kl            | 0.076079205 |
# |    clip_fraction        | 0.296       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.214      |
# |    explained_variance   | 0.809       |
# |    learning_rate        | 0.0014      |
# |    loss                 | 0.0563      |
# |    n_updates            | 320         |
# |    policy_gradient_loss | 0.131       |
# |    value_loss           | 0.000379    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 335        |
# |    ep_rew_mean          | 1.43       |
# | time/                   |            |
# |    fps                  | 895        |
# |    iterations           | 34         |
# |    time_elapsed         | 48         |
# |    total_timesteps      | 43520      |
# | train/                  |            |
# |    approx_kl            | 0.07460469 |
# |    clip_fraction        | 0.229      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.247     |
# |    explained_variance   | 0.825      |
# |    learning_rate        | 0.0014     |
# |    loss                 | 0.051      |
# |    n_updates            | 330        |
# |    policy_gradient_loss | 0.0329     |
# |    value_loss           | 0.000129   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 335        |
# |    ep_rew_mean          | 1.46       |
# | time/                   |            |
# |    fps                  | 896        |
# |    iterations           | 35         |
# |    time_elapsed         | 49         |
# |    total_timesteps      | 44800      |
# | train/                  |            |
# |    approx_kl            | 0.07732675 |
# |    clip_fraction        | 0.224      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.216     |
# |    explained_variance   | 0.747      |
# |    learning_rate        | 0.0014     |
# |    loss                 | -0.0224    |
# |    n_updates            | 340        |
# |    policy_gradient_loss | 0.0344     |
# |    value_loss           | 0.000176   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 335        |
# |    ep_rew_mean          | 1.49       |
# | time/                   |            |
# |    fps                  | 897        |
# |    iterations           | 36         |
# |    time_elapsed         | 51         |
# |    total_timesteps      | 46080      |
# | train/                  |            |
# |    approx_kl            | 0.66723156 |
# |    clip_fraction        | 0.232      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.203     |
# |    explained_variance   | 0.78       |
# |    learning_rate        | 0.0014     |
# |    loss                 | 0.11       |
# |    n_updates            | 350        |
# |    policy_gradient_loss | 0.0519     |
# |    value_loss           | 0.000503   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 1.51        |
# | time/                   |             |
# |    fps                  | 897         |
# |    iterations           | 37          |
# |    time_elapsed         | 52          |
# |    total_timesteps      | 47360       |
# | train/                  |             |
# |    approx_kl            | 0.054653052 |
# |    clip_fraction        | 0.168       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.195      |
# |    explained_variance   | 0.784       |
# |    learning_rate        | 0.0014      |
# |    loss                 | -0.0316     |
# |    n_updates            | 360         |
# |    policy_gradient_loss | 0.00774     |
# |    value_loss           | 0.000184    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 1.54        |
# | time/                   |             |
# |    fps                  | 898         |
# |    iterations           | 38          |
# |    time_elapsed         | 54          |
# |    total_timesteps      | 48640       |
# | train/                  |             |
# |    approx_kl            | 0.047073938 |
# |    clip_fraction        | 0.198       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.196      |
# |    explained_variance   | 0.787       |
# |    learning_rate        | 0.0014      |
# |    loss                 | -0.00325    |
# |    n_updates            | 370         |
# |    policy_gradient_loss | 0.0396      |
# |    value_loss           | 0.000128    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 1.56        |
# | time/                   |             |
# |    fps                  | 899         |
# |    iterations           | 39          |
# |    time_elapsed         | 55          |
# |    total_timesteps      | 49920       |
# | train/                  |             |
# |    approx_kl            | 0.025900431 |
# |    clip_fraction        | 0.198       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.192      |
# |    explained_variance   | 0.828       |
# |    learning_rate        | 0.0014      |
# |    loss                 | 0.00305     |
# |    n_updates            | 380         |
# |    policy_gradient_loss | 0.0476      |
# |    value_loss           | 0.000108    |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 335       |
# |    ep_rew_mean          | 1.57      |
# | time/                   |           |
# |    fps                  | 900       |
# |    iterations           | 40        |
# |    time_elapsed         | 56        |
# |    total_timesteps      | 51200     |
# | train/                  |           |
# |    approx_kl            | 0.0948724 |
# |    clip_fraction        | 0.154     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.181    |
# |    explained_variance   | 0.865     |
# |    learning_rate        | 0.0014    |
# |    loss                 | 0.0244    |
# |    n_updates            | 390       |
# |    policy_gradient_loss | 0.0274    |
# |    value_loss           | 8.07e-05  |
# ---------------------------------------
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 335      |
# |    ep_rew_mean     | 0.0271   |
# | time/              |          |
# |    fps             | 1148     |
# |    iterations      | 1        |
# |    time_elapsed    | 1        |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.0349      |
# | time/                   |             |
# |    fps                  | 774         |
# |    iterations           | 2           |
# |    time_elapsed         | 5           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.009027935 |
# |    clip_fraction        | 0.0572      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | -5.58       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0321      |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.00244    |
# |    value_loss           | 0.00261     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.0462      |
# | time/                   |             |
# |    fps                  | 731         |
# |    iterations           | 3           |
# |    time_elapsed         | 8           |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.006988464 |
# |    clip_fraction        | 0.0383      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.1        |
# |    explained_variance   | 0.207       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0108     |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.00304    |
# |    value_loss           | 0.00071     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.0908      |
# | time/                   |             |
# |    fps                  | 718         |
# |    iterations           | 4           |
# |    time_elapsed         | 11          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.008670771 |
# |    clip_fraction        | 0.0956      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.08       |
# |    explained_variance   | 0.668       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00559     |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.00743    |
# |    value_loss           | 0.000593    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.114       |
# | time/                   |             |
# |    fps                  | 710         |
# |    iterations           | 5           |
# |    time_elapsed         | 14          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.011117466 |
# |    clip_fraction        | 0.112       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.08       |
# |    explained_variance   | 0.464       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0319     |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0122     |
# |    value_loss           | 0.000588    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.141       |
# | time/                   |             |
# |    fps                  | 694         |
# |    iterations           | 6           |
# |    time_elapsed         | 17          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.008151069 |
# |    clip_fraction        | 0.114       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.07       |
# |    explained_variance   | 0.501       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0195     |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0104     |
# |    value_loss           | 0.000524    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.176       |
# | time/                   |             |
# |    fps                  | 673         |
# |    iterations           | 7           |
# |    time_elapsed         | 21          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.009979991 |
# |    clip_fraction        | 0.144       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.05       |
# |    explained_variance   | 0.32        |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00938    |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0127     |
# |    value_loss           | 0.000669    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.211       |
# | time/                   |             |
# |    fps                  | 683         |
# |    iterations           | 8           |
# |    time_elapsed         | 23          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.010752556 |
# |    clip_fraction        | 0.123       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.01       |
# |    explained_variance   | 0.293       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00801     |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.00796    |
# |    value_loss           | 0.000442    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 335        |
# |    ep_rew_mean          | 0.252      |
# | time/                   |            |
# |    fps                  | 694        |
# |    iterations           | 9          |
# |    time_elapsed         | 26         |
# |    total_timesteps      | 18432      |
# | train/                  |            |
# |    approx_kl            | 0.01417541 |
# |    clip_fraction        | 0.217      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.928     |
# |    explained_variance   | -0.0246    |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0401    |
# |    n_updates            | 80         |
# |    policy_gradient_loss | -0.0182    |
# |    value_loss           | 0.000753   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.308       |
# | time/                   |             |
# |    fps                  | 705         |
# |    iterations           | 10          |
# |    time_elapsed         | 29          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.008848282 |
# |    clip_fraction        | 0.113       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.889      |
# |    explained_variance   | -0.0786     |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0253     |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.00676    |
# |    value_loss           | 0.000453    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.362       |
# | time/                   |             |
# |    fps                  | 713         |
# |    iterations           | 11          |
# |    time_elapsed         | 31          |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.015634255 |
# |    clip_fraction        | 0.156       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.811      |
# |    explained_variance   | 0.37        |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0234     |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.00893    |
# |    value_loss           | 0.000532    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 335        |
# |    ep_rew_mean          | 0.408      |
# | time/                   |            |
# |    fps                  | 711        |
# |    iterations           | 12         |
# |    time_elapsed         | 34         |
# |    total_timesteps      | 24576      |
# | train/                  |            |
# |    approx_kl            | 0.01401293 |
# |    clip_fraction        | 0.154      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.758     |
# |    explained_variance   | 0.722      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.00555   |
# |    n_updates            | 110        |
# |    policy_gradient_loss | -0.00433   |
# |    value_loss           | 0.000499   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.459       |
# | time/                   |             |
# |    fps                  | 712         |
# |    iterations           | 13          |
# |    time_elapsed         | 37          |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.014303165 |
# |    clip_fraction        | 0.172       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.701      |
# |    explained_variance   | 0.845       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.025       |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.00131    |
# |    value_loss           | 0.000366    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 335        |
# |    ep_rew_mean          | 0.502      |
# | time/                   |            |
# |    fps                  | 717        |
# |    iterations           | 14         |
# |    time_elapsed         | 39         |
# |    total_timesteps      | 28672      |
# | train/                  |            |
# |    approx_kl            | 0.01464038 |
# |    clip_fraction        | 0.153      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.682     |
# |    explained_variance   | 0.906      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0332    |
# |    n_updates            | 130        |
# |    policy_gradient_loss | -0.00527   |
# |    value_loss           | 0.000498   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.544       |
# | time/                   |             |
# |    fps                  | 722         |
# |    iterations           | 15          |
# |    time_elapsed         | 42          |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.020663055 |
# |    clip_fraction        | 0.159       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.652      |
# |    explained_variance   | 0.945       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0272     |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.00461    |
# |    value_loss           | 0.000337    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.58        |
# | time/                   |             |
# |    fps                  | 728         |
# |    iterations           | 16          |
# |    time_elapsed         | 44          |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.011927894 |
# |    clip_fraction        | 0.14        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.642      |
# |    explained_variance   | 0.967       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0131     |
# |    n_updates            | 150         |
# |    policy_gradient_loss | 0.00112     |
# |    value_loss           | 0.000675    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.636       |
# | time/                   |             |
# |    fps                  | 733         |
# |    iterations           | 17          |
# |    time_elapsed         | 47          |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.010087706 |
# |    clip_fraction        | 0.137       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.596      |
# |    explained_variance   | 0.968       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0178      |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.0006     |
# |    value_loss           | 0.000293    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.726       |
# | time/                   |             |
# |    fps                  | 731         |
# |    iterations           | 18          |
# |    time_elapsed         | 50          |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.013604503 |
# |    clip_fraction        | 0.0985      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.57       |
# |    explained_variance   | 0.97        |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00309    |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.000949   |
# |    value_loss           | 0.000427    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.804       |
# | time/                   |             |
# |    fps                  | 729         |
# |    iterations           | 19          |
# |    time_elapsed         | 53          |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.010728444 |
# |    clip_fraction        | 0.14        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.52       |
# |    explained_variance   | 0.981       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0011      |
# |    n_updates            | 180         |
# |    policy_gradient_loss | 0.00284     |
# |    value_loss           | 0.000281    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.876       |
# | time/                   |             |
# |    fps                  | 732         |
# |    iterations           | 20          |
# |    time_elapsed         | 55          |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.013026451 |
# |    clip_fraction        | 0.131       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.487      |
# |    explained_variance   | 0.985       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00079    |
# |    n_updates            | 190         |
# |    policy_gradient_loss | 0.000558    |
# |    value_loss           | 0.000326    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.948       |
# | time/                   |             |
# |    fps                  | 734         |
# |    iterations           | 21          |
# |    time_elapsed         | 58          |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.018851642 |
# |    clip_fraction        | 0.134       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.468      |
# |    explained_variance   | 0.989       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.002      |
# |    n_updates            | 200         |
# |    policy_gradient_loss | 0.00353     |
# |    value_loss           | 0.000174    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 335        |
# |    ep_rew_mean          | 1.02       |
# | time/                   |            |
# |    fps                  | 735        |
# |    iterations           | 22         |
# |    time_elapsed         | 61         |
# |    total_timesteps      | 45056      |
# | train/                  |            |
# |    approx_kl            | 0.01691238 |
# |    clip_fraction        | 0.168      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.456     |
# |    explained_variance   | 0.991      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.00743   |
# |    n_updates            | 210        |
# |    policy_gradient_loss | 0.00925    |
# |    value_loss           | 0.000574   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 1.08        |
# | time/                   |             |
# |    fps                  | 740         |
# |    iterations           | 23          |
# |    time_elapsed         | 63          |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.020301897 |
# |    clip_fraction        | 0.146       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.418      |
# |    explained_variance   | 0.991       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0153      |
# |    n_updates            | 220         |
# |    policy_gradient_loss | 0.00726     |
# |    value_loss           | 0.000879    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 1.14        |
# | time/                   |             |
# |    fps                  | 741         |
# |    iterations           | 24          |
# |    time_elapsed         | 66          |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.027069794 |
# |    clip_fraction        | 0.156       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.394      |
# |    explained_variance   | 0.99        |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.000962   |
# |    n_updates            | 230         |
# |    policy_gradient_loss | 0.0127      |
# |    value_loss           | 0.000399    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 1.21        |
# | time/                   |             |
# |    fps                  | 737         |
# |    iterations           | 25          |
# |    time_elapsed         | 69          |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.014662846 |
# |    clip_fraction        | 0.143       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.378      |
# |    explained_variance   | 0.992       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.000101   |
# |    n_updates            | 240         |
# |    policy_gradient_loss | 0.00805     |
# |    value_loss           | 0.000184    |
# -----------------------------------------
#          Method  Cumulative Return  Sharpe Ratio  Sortino Ratio  Max Drawdown
# 0   Bi-LSTM PPO           2.779165      0.553744       1.533731     -0.011937
# 1    Simple PPO           2.661433      0.508544       1.217007     -0.014248
# 2  Buy-and-Hold          -0.666092           NaN            NaN           NaN
