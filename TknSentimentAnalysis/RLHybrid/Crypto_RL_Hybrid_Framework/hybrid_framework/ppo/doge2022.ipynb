# %%
import pandas as pd
import numpy as np
import torch
import torch.nn as nn
from sklearn.preprocessing import MinMaxScaler
from torch.utils.data import DataLoader, TensorDataset
from stable_baselines3 import PPO
from gym import spaces, Env
import matplotlib.pyplot as plt
import random

# Set seed for reproducibility
SEED = 42
random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)
if torch.cuda.is_available():
    torch.cuda.manual_seed_all(SEED)

# Load and preprocess data
def load_and_preprocess(file_name):
    data = pd.read_csv(file_name)
    data["Date"] = pd.to_datetime(data["Date"])
    data = data.sort_values(by="Date")
    
    numeric_data = data.drop(columns=["Date"])
    numeric_data = numeric_data[['Close'] + [col for col in numeric_data.columns if col != 'Close']]
    
    scaler = MinMaxScaler()
    normalized_data = scaler.fit_transform(numeric_data)
    data[numeric_data.columns] = normalized_data
    
    return data, scaler

# Create sequences for time series modeling
def create_sequences(data, sequence_length=30):
    sequences = []
    targets = []
    for i in range(len(data) - sequence_length):
        seq = data[i:i+sequence_length]
        target = data[i+sequence_length, 0]  # Assuming the target is the first column (e.g., Close price)
        sequences.append(seq)
        targets.append(target)
    return np.array(sequences), np.array(targets)

# Define Bi-LSTM model
class BiLSTMModel(nn.Module):
    def __init__(self, input_dim, hidden_dim, num_layers, dropout):
        super(BiLSTMModel, self).__init__()
        self.bilstm = nn.LSTM(input_dim, hidden_dim, num_layers, batch_first=True, dropout=dropout, bidirectional=True)
        self.fc = nn.Linear(hidden_dim * 2, 1)

    def forward(self, x):
        bilstm_out, _ = self.bilstm(x)
        return self.fc(bilstm_out[:, -1, :])

# Custom trading environment
class TradingEnv(Env):
    def __init__(self, data, sequence_length=30):
        super(TradingEnv, self).__init__()
        self.data = data
        self.sequence_length = sequence_length
        self.current_step = 0
        self.total_steps = len(data) - sequence_length
        self.portfolio_value = 1.0

        # Action and observation space
        self.action_space = spaces.Discrete(3)  # 0: Hold, 1: Buy, 2: Sell
        self.observation_space = spaces.Box(low=0, high=1, shape=(sequence_length, data.shape[1]), dtype=np.float32)

    def reset(self):
        self.current_step = 0
        self.portfolio_value = 1.0
        return self._next_observation()

    def _next_observation(self):
        return self.data[self.current_step:self.current_step + self.sequence_length]

    def step(self, action):
        self.current_step += 1
        reward = 0
        done = self.current_step >= self.total_steps

        if not done:
            current_price = self.data[self.current_step, 0]
            prev_price = self.data[self.current_step - 1, 0]

            if action == 1:  # Buy
                reward = current_price - prev_price
            elif action == 2:  # Sell
                reward = prev_price - current_price

        self.portfolio_value += reward
        obs = self._next_observation() if not done else None
        return obs, reward, done, {"portfolio_value": self.portfolio_value}

# Evaluate trading strategy
def evaluate_trading_strategy(env, model):
    obs = env.reset()
    done = False
    portfolio_values = [1.0]

    while not done:
        action, _ = model.predict(obs, deterministic=True)
        obs, reward, done, info = env.step(action)
        portfolio_values.append(info.get("portfolio_value", 1.0))

    return portfolio_values

# Performance metrics
def calculate_metrics(portfolio_values):
    daily_returns = np.diff(portfolio_values) / portfolio_values[:-1]
    cumulative_return = portfolio_values[-1] / portfolio_values[0] - 1
    sharpe_ratio = np.mean(daily_returns) / np.std(daily_returns) if np.std(daily_returns) > 0 else 0
    sortino_ratio = np.mean(daily_returns) / np.std([r for r in daily_returns if r < 0]) if np.std([r for r in daily_returns if r < 0]) > 0 else 0
    max_drawdown = np.min(portfolio_values / np.maximum.accumulate(portfolio_values) - 1)
    return cumulative_return, sharpe_ratio, sortino_ratio, max_drawdown

# Main execution
if __name__ == "__main__":
    # Load data
    data, scaler = load_and_preprocess("Book3.csv")
    train_data = data[(data["Date"].dt.year >= 2017) & (data["Date"].dt.year <= 2021)].drop(columns=["Date"]).values
    test_data = data[data["Date"].dt.year == 2022].drop(columns=["Date"]).values

    X_train, y_train = create_sequences(train_data)
    X_test, y_test = create_sequences(test_data)

    # Train Bi-LSTM model
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    bilstm_model = BiLSTMModel(input_dim=X_train.shape[2], hidden_dim=224, num_layers=1, dropout=0.14).to(device)
    criterion = nn.MSELoss()
    optimizer = torch.optim.Adam(bilstm_model.parameters(), lr=0.0019)

    train_loader = DataLoader(TensorDataset(torch.tensor(X_train, dtype=torch.float32), torch.tensor(y_train, dtype=torch.float32)), batch_size=32, shuffle=True)

    for epoch in range(50):
        bilstm_model.train()
        train_loss = 0.0
        for X_batch, y_batch in train_loader:
            X_batch, y_batch = X_batch.to(device), y_batch.to(device)
            optimizer.zero_grad()
            predictions = bilstm_model(X_batch).squeeze()
            loss = criterion(predictions, y_batch)
            loss.backward()
            optimizer.step()
            train_loss += loss.item()

    # Create environments for PPO
    bilstm_env = TradingEnv(test_data)
    simple_env = TradingEnv(test_data)

    # Train PPO models
    ppo_bilstm_model = PPO("MlpPolicy", bilstm_env, learning_rate=0.0014, batch_size=160, n_steps=1280, gamma=0.9005911776350177, verbose=1)
    ppo_bilstm_model.learn(total_timesteps=50000)

    ppo_simple_model = PPO("MlpPolicy", simple_env, verbose=1)
    ppo_simple_model.learn(total_timesteps=50000)

    # Evaluate strategies
    portfolio_values_bilstm = evaluate_trading_strategy(bilstm_env, ppo_bilstm_model)
    portfolio_values_simple = evaluate_trading_strategy(simple_env, ppo_simple_model)

    cumulative_return_bilstm, sharpe_bilstm, sortino_bilstm, max_drawdown_bilstm = calculate_metrics(portfolio_values_bilstm)
    cumulative_return_simple, sharpe_simple, sortino_simple, max_drawdown_simple = calculate_metrics(portfolio_values_simple)

    # Buy-and-Hold strategy
    buy_hold_return = test_data[-1, 0] / test_data[0, 0] - 1

    # Generate date range for 2022
    test_dates = pd.date_range(start="2022-01-01", periods=len(portfolio_values_bilstm))

    # Calculate cumulative returns
    cumulative_returns_bilstm = np.cumprod([1 + r for r in np.diff(portfolio_values_bilstm) / portfolio_values_bilstm[:-1]])
    cumulative_returns_simple = np.cumprod([1 + r for r in np.diff(portfolio_values_simple) / portfolio_values_simple[:-1]])

    # Plot cumulative returns
    plt.figure(figsize=(12, 6))
    plt.plot(test_dates[1:], cumulative_returns_bilstm, label="Bi-LSTM PPO")
    plt.plot(test_dates[1:], cumulative_returns_simple, label="Simple PPO")
    plt.gca().xaxis.set_major_formatter(plt.matplotlib.dates.DateFormatter("%b %Y"))
    plt.gca().xaxis.set_major_locator(plt.matplotlib.dates.MonthLocator())

    plt.legend()
    plt.title("Cumulative Returns")
    plt.xlabel("Date")
    plt.ylabel("Cumulative Return")
    plt.grid()
    plt.show()

    # Print results
    results = pd.DataFrame({
        "Method": ["Bi-LSTM PPO", "Simple PPO", "Buy-and-Hold"],
        "Cumulative Return": [cumulative_returns_bilstm[-1], cumulative_returns_simple[-1], buy_hold_return],
        "Sharpe Ratio": [sharpe_bilstm, sharpe_simple, None],
        "Sortino Ratio": [sortino_bilstm, sortino_simple, None],
        "Max Drawdown": [max_drawdown_bilstm, max_drawdown_simple, None]
    })
    print(results)
# Out:
# C:\Users\User\anaconda3\envs\RL\Lib\site-packages\torch\nn\modules\rnn.py:123: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.14 and num_layers=1
#   warnings.warn(
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# C:\Users\User\anaconda3\envs\RL\Lib\site-packages\stable_baselines3\common\vec_env\patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 335      |
# |    ep_rew_mean     | 0.0225   |
# | time/              |          |
# |    fps             | 1485     |
# |    iterations      | 1        |
# |    time_elapsed    | 0        |
# |    total_timesteps | 1280     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.0159      |
# | time/                   |             |
# |    fps                  | 1236        |
# |    iterations           | 2           |
# |    time_elapsed         | 2           |
# |    total_timesteps      | 2560        |
# | train/                  |             |
# |    approx_kl            | 0.011495583 |
# |    clip_fraction        | 0.11        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | -8.92       |
# |    learning_rate        | 0.0014      |
# |    loss                 | -0.00457    |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.00769    |
# |    value_loss           | 0.0237      |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 335        |
# |    ep_rew_mean          | 0.0648     |
# | time/                   |            |
# |    fps                  | 1180       |
# |    iterations           | 3          |
# |    time_elapsed         | 3          |
# |    total_timesteps      | 3840       |
# | train/                  |            |
# |    approx_kl            | 0.00833329 |
# |    clip_fraction        | 0.0645     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.09      |
# |    explained_variance   | -1.35      |
# |    learning_rate        | 0.0014     |
# |    loss                 | -0.00976   |
# |    n_updates            | 20         |
# |    policy_gradient_loss | -0.00498   |
# |    value_loss           | 0.000624   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.104       |
# | time/                   |             |
# |    fps                  | 1145        |
# |    iterations           | 4           |
# |    time_elapsed         | 4           |
# |    total_timesteps      | 5120        |
# | train/                  |             |
# |    approx_kl            | 0.008122191 |
# |    clip_fraction        | 0.119       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.07       |
# |    explained_variance   | -0.595      |
# |    learning_rate        | 0.0014      |
# |    loss                 | -0.0165     |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.00984    |
# |    value_loss           | 0.000288    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.164       |
# | time/                   |             |
# |    fps                  | 1133        |
# |    iterations           | 5           |
# |    time_elapsed         | 5           |
# |    total_timesteps      | 6400        |
# | train/                  |             |
# |    approx_kl            | 0.012163475 |
# |    clip_fraction        | 0.195       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.04       |
# |    explained_variance   | -0.22       |
# |    learning_rate        | 0.0014      |
# |    loss                 | -0.00532    |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0127     |
# |    value_loss           | 0.000214    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.199       |
# | time/                   |             |
# |    fps                  | 1123        |
# |    iterations           | 6           |
# |    time_elapsed         | 6           |
# |    total_timesteps      | 7680        |
# | train/                  |             |
# |    approx_kl            | 0.013065955 |
# |    clip_fraction        | 0.227       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.994      |
# |    explained_variance   | 0.132       |
# |    learning_rate        | 0.0014      |
# |    loss                 | -0.0168     |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0136     |
# |    value_loss           | 0.00018     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 335        |
# |    ep_rew_mean          | 0.259      |
# | time/                   |            |
# |    fps                  | 1080       |
# |    iterations           | 7          |
# |    time_elapsed         | 8          |
# |    total_timesteps      | 8960       |
# | train/                  |            |
# |    approx_kl            | 0.01722867 |
# |    clip_fraction        | 0.226      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.936     |
# |    explained_variance   | 0.243      |
# |    learning_rate        | 0.0014     |
# |    loss                 | -0.0369    |
# |    n_updates            | 60         |
# |    policy_gradient_loss | -0.0198    |
# |    value_loss           | 0.000164   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.32        |
# | time/                   |             |
# |    fps                  | 1059        |
# |    iterations           | 8           |
# |    time_elapsed         | 9           |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.016757878 |
# |    clip_fraction        | 0.245       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.867      |
# |    explained_variance   | 0.416       |
# |    learning_rate        | 0.0014      |
# |    loss                 | -0.0325     |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0114     |
# |    value_loss           | 0.000137    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.379       |
# | time/                   |             |
# |    fps                  | 1042        |
# |    iterations           | 9           |
# |    time_elapsed         | 11          |
# |    total_timesteps      | 11520       |
# | train/                  |             |
# |    approx_kl            | 0.022466125 |
# |    clip_fraction        | 0.241       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.779      |
# |    explained_variance   | 0.599       |
# |    learning_rate        | 0.0014      |
# |    loss                 | -0.0187     |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.00878    |
# |    value_loss           | 0.000309    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.435       |
# | time/                   |             |
# |    fps                  | 1047        |
# |    iterations           | 10          |
# |    time_elapsed         | 12          |
# |    total_timesteps      | 12800       |
# | train/                  |             |
# |    approx_kl            | 0.026615346 |
# |    clip_fraction        | 0.239       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.759      |
# |    explained_variance   | 0.616       |
# |    learning_rate        | 0.0014      |
# |    loss                 | -0.0214     |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.00912    |
# |    value_loss           | 0.000193    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.489       |
# | time/                   |             |
# |    fps                  | 1052        |
# |    iterations           | 11          |
# |    time_elapsed         | 13          |
# |    total_timesteps      | 14080       |
# | train/                  |             |
# |    approx_kl            | 0.037911166 |
# |    clip_fraction        | 0.335       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.715      |
# |    explained_variance   | 0.672       |
# |    learning_rate        | 0.0014      |
# |    loss                 | -0.0124     |
# |    n_updates            | 100         |
# |    policy_gradient_loss | 0.0152      |
# |    value_loss           | 0.000157    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.526       |
# | time/                   |             |
# |    fps                  | 1054        |
# |    iterations           | 12          |
# |    time_elapsed         | 14          |
# |    total_timesteps      | 15360       |
# | train/                  |             |
# |    approx_kl            | 0.017638693 |
# |    clip_fraction        | 0.205       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.64       |
# |    explained_variance   | 0.752       |
# |    learning_rate        | 0.0014      |
# |    loss                 | -0.0207     |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.0119     |
# |    value_loss           | 0.000146    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.58        |
# | time/                   |             |
# |    fps                  | 1056        |
# |    iterations           | 13          |
# |    time_elapsed         | 15          |
# |    total_timesteps      | 16640       |
# | train/                  |             |
# |    approx_kl            | 0.030189034 |
# |    clip_fraction        | 0.22        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.57       |
# |    explained_variance   | 0.756       |
# |    learning_rate        | 0.0014      |
# |    loss                 | -0.0185     |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.00167    |
# |    value_loss           | 0.000207    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.626       |
# | time/                   |             |
# |    fps                  | 1057        |
# |    iterations           | 14          |
# |    time_elapsed         | 16          |
# |    total_timesteps      | 17920       |
# | train/                  |             |
# |    approx_kl            | 0.035585724 |
# |    clip_fraction        | 0.292       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.53       |
# |    explained_variance   | 0.835       |
# |    learning_rate        | 0.0014      |
# |    loss                 | -0.00648    |
# |    n_updates            | 130         |
# |    policy_gradient_loss | 0.0269      |
# |    value_loss           | 0.00016     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 335        |
# |    ep_rew_mean          | 0.673      |
# | time/                   |            |
# |    fps                  | 1058       |
# |    iterations           | 15         |
# |    time_elapsed         | 18         |
# |    total_timesteps      | 19200      |
# | train/                  |            |
# |    approx_kl            | 0.05102226 |
# |    clip_fraction        | 0.307      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.511     |
# |    explained_variance   | 0.847      |
# |    learning_rate        | 0.0014     |
# |    loss                 | -0.0372    |
# |    n_updates            | 140        |
# |    policy_gradient_loss | 0.0208     |
# |    value_loss           | 0.000725   |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 335       |
# |    ep_rew_mean          | 0.71      |
# | time/                   |           |
# |    fps                  | 1060      |
# |    iterations           | 16        |
# |    time_elapsed         | 19        |
# |    total_timesteps      | 20480     |
# | train/                  |           |
# |    approx_kl            | 0.0316454 |
# |    clip_fraction        | 0.327     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.487    |
# |    explained_variance   | 0.819     |
# |    learning_rate        | 0.0014    |
# |    loss                 | 0.00559   |
# |    n_updates            | 150       |
# |    policy_gradient_loss | 0.0346    |
# |    value_loss           | 0.00582   |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 335       |
# |    ep_rew_mean          | 0.738     |
# | time/                   |           |
# |    fps                  | 1060      |
# |    iterations           | 17        |
# |    time_elapsed         | 20        |
# |    total_timesteps      | 21760     |
# | train/                  |           |
# |    approx_kl            | 0.0899518 |
# |    clip_fraction        | 0.28      |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.515    |
# |    explained_variance   | 0.502     |
# |    learning_rate        | 0.0014    |
# |    loss                 | 0.0207    |
# |    n_updates            | 160       |
# |    policy_gradient_loss | 0.0279    |
# |    value_loss           | 0.00118   |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.772       |
# | time/                   |             |
# |    fps                  | 1061        |
# |    iterations           | 18          |
# |    time_elapsed         | 21          |
# |    total_timesteps      | 23040       |
# | train/                  |             |
# |    approx_kl            | 0.015558284 |
# |    clip_fraction        | 0.225       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.466      |
# |    explained_variance   | 0.74        |
# |    learning_rate        | 0.0014      |
# |    loss                 | -0.0107     |
# |    n_updates            | 170         |
# |    policy_gradient_loss | 0.00919     |
# |    value_loss           | 0.000123    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.802       |
# | time/                   |             |
# |    fps                  | 1057        |
# |    iterations           | 19          |
# |    time_elapsed         | 22          |
# |    total_timesteps      | 24320       |
# | train/                  |             |
# |    approx_kl            | 0.032087456 |
# |    clip_fraction        | 0.32        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.412      |
# |    explained_variance   | 0.797       |
# |    learning_rate        | 0.0014      |
# |    loss                 | -0.00131    |
# |    n_updates            | 180         |
# |    policy_gradient_loss | 0.0422      |
# |    value_loss           | 0.000104    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.83        |
# | time/                   |             |
# |    fps                  | 1046        |
# |    iterations           | 20          |
# |    time_elapsed         | 24          |
# |    total_timesteps      | 25600       |
# | train/                  |             |
# |    approx_kl            | 0.024368703 |
# |    clip_fraction        | 0.236       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.443      |
# |    explained_variance   | 0.8         |
# |    learning_rate        | 0.0014      |
# |    loss                 | -0.03       |
# |    n_updates            | 190         |
# |    policy_gradient_loss | 0.00932     |
# |    value_loss           | 0.000112    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.859       |
# | time/                   |             |
# |    fps                  | 1041        |
# |    iterations           | 21          |
# |    time_elapsed         | 25          |
# |    total_timesteps      | 26880       |
# | train/                  |             |
# |    approx_kl            | 0.057029113 |
# |    clip_fraction        | 0.264       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.434      |
# |    explained_variance   | 0.839       |
# |    learning_rate        | 0.0014      |
# |    loss                 | -0.0193     |
# |    n_updates            | 200         |
# |    policy_gradient_loss | 0.0228      |
# |    value_loss           | 9.92e-05    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 335        |
# |    ep_rew_mean          | 0.882      |
# | time/                   |            |
# |    fps                  | 1036       |
# |    iterations           | 22         |
# |    time_elapsed         | 27         |
# |    total_timesteps      | 28160      |
# | train/                  |            |
# |    approx_kl            | 0.04406096 |
# |    clip_fraction        | 0.241      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.421     |
# |    explained_variance   | 0.863      |
# |    learning_rate        | 0.0014     |
# |    loss                 | 0.0232     |
# |    n_updates            | 210        |
# |    policy_gradient_loss | 0.0221     |
# |    value_loss           | 9.21e-05   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 335        |
# |    ep_rew_mean          | 0.898      |
# | time/                   |            |
# |    fps                  | 1039       |
# |    iterations           | 23         |
# |    time_elapsed         | 28         |
# |    total_timesteps      | 29440      |
# | train/                  |            |
# |    approx_kl            | 0.10790456 |
# |    clip_fraction        | 0.242      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.4       |
# |    explained_variance   | 0.843      |
# |    learning_rate        | 0.0014     |
# |    loss                 | 0.0156     |
# |    n_updates            | 220        |
# |    policy_gradient_loss | 0.0181     |
# |    value_loss           | 0.000201   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.919       |
# | time/                   |             |
# |    fps                  | 1041        |
# |    iterations           | 24          |
# |    time_elapsed         | 29          |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.040345848 |
# |    clip_fraction        | 0.256       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.362      |
# |    explained_variance   | 0.834       |
# |    learning_rate        | 0.0014      |
# |    loss                 | 0.0314      |
# |    n_updates            | 230         |
# |    policy_gradient_loss | 0.0259      |
# |    value_loss           | 9.42e-05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.941       |
# | time/                   |             |
# |    fps                  | 1042        |
# |    iterations           | 25          |
# |    time_elapsed         | 30          |
# |    total_timesteps      | 32000       |
# | train/                  |             |
# |    approx_kl            | 0.052725688 |
# |    clip_fraction        | 0.236       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.382      |
# |    explained_variance   | 0.869       |
# |    learning_rate        | 0.0014      |
# |    loss                 | -0.00834    |
# |    n_updates            | 240         |
# |    policy_gradient_loss | 0.021       |
# |    value_loss           | 8.35e-05    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 335        |
# |    ep_rew_mean          | 0.963      |
# | time/                   |            |
# |    fps                  | 1043       |
# |    iterations           | 26         |
# |    time_elapsed         | 31         |
# |    total_timesteps      | 33280      |
# | train/                  |            |
# |    approx_kl            | 0.04961465 |
# |    clip_fraction        | 0.229      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.376     |
# |    explained_variance   | 0.863      |
# |    learning_rate        | 0.0014     |
# |    loss                 | -0.0179    |
# |    n_updates            | 250        |
# |    policy_gradient_loss | 0.0206     |
# |    value_loss           | 0.000704   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 335        |
# |    ep_rew_mean          | 1.01       |
# | time/                   |            |
# |    fps                  | 1044       |
# |    iterations           | 27         |
# |    time_elapsed         | 33         |
# |    total_timesteps      | 34560      |
# | train/                  |            |
# |    approx_kl            | 0.02543522 |
# |    clip_fraction        | 0.206      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.355     |
# |    explained_variance   | 0.874      |
# |    learning_rate        | 0.0014     |
# |    loss                 | 0.0335     |
# |    n_updates            | 260        |
# |    policy_gradient_loss | 0.0221     |
# |    value_loss           | 9.09e-05   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 335        |
# |    ep_rew_mean          | 1.06       |
# | time/                   |            |
# |    fps                  | 1045       |
# |    iterations           | 28         |
# |    time_elapsed         | 34         |
# |    total_timesteps      | 35840      |
# | train/                  |            |
# |    approx_kl            | 0.22591045 |
# |    clip_fraction        | 0.232      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.33      |
# |    explained_variance   | 0.9        |
# |    learning_rate        | 0.0014     |
# |    loss                 | 0.0454     |
# |    n_updates            | 270        |
# |    policy_gradient_loss | 0.0379     |
# |    value_loss           | 9.74e-05   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 335        |
# |    ep_rew_mean          | 1.11       |
# | time/                   |            |
# |    fps                  | 1047       |
# |    iterations           | 29         |
# |    time_elapsed         | 35         |
# |    total_timesteps      | 37120      |
# | train/                  |            |
# |    approx_kl            | 0.06583261 |
# |    clip_fraction        | 0.236      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.316     |
# |    explained_variance   | 0.901      |
# |    learning_rate        | 0.0014     |
# |    loss                 | 0.0224     |
# |    n_updates            | 280        |
# |    policy_gradient_loss | 0.0218     |
# |    value_loss           | 6.23e-05   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 335        |
# |    ep_rew_mean          | 1.16       |
# | time/                   |            |
# |    fps                  | 1048       |
# |    iterations           | 30         |
# |    time_elapsed         | 36         |
# |    total_timesteps      | 38400      |
# | train/                  |            |
# |    approx_kl            | 0.20988028 |
# |    clip_fraction        | 0.231      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.326     |
# |    explained_variance   | 0.877      |
# |    learning_rate        | 0.0014     |
# |    loss                 | 0.00232    |
# |    n_updates            | 290        |
# |    policy_gradient_loss | 0.0204     |
# |    value_loss           | 8.4e-05    |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 335        |
# |    ep_rew_mean          | 1.2        |
# | time/                   |            |
# |    fps                  | 1049       |
# |    iterations           | 31         |
# |    time_elapsed         | 37         |
# |    total_timesteps      | 39680      |
# | train/                  |            |
# |    approx_kl            | 0.08283438 |
# |    clip_fraction        | 0.252      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.32      |
# |    explained_variance   | 0.873      |
# |    learning_rate        | 0.0014     |
# |    loss                 | 0.0748     |
# |    n_updates            | 300        |
# |    policy_gradient_loss | 0.0314     |
# |    value_loss           | 8.11e-05   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 1.25        |
# | time/                   |             |
# |    fps                  | 1050        |
# |    iterations           | 32          |
# |    time_elapsed         | 38          |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.029927846 |
# |    clip_fraction        | 0.22        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.29       |
# |    explained_variance   | 0.883       |
# |    learning_rate        | 0.0014      |
# |    loss                 | -0.0132     |
# |    n_updates            | 310         |
# |    policy_gradient_loss | 0.0117      |
# |    value_loss           | 8.24e-05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 1.28        |
# | time/                   |             |
# |    fps                  | 1044        |
# |    iterations           | 33          |
# |    time_elapsed         | 40          |
# |    total_timesteps      | 42240       |
# | train/                  |             |
# |    approx_kl            | 0.106621295 |
# |    clip_fraction        | 0.206       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.268      |
# |    explained_variance   | 0.905       |
# |    learning_rate        | 0.0014      |
# |    loss                 | 0.294       |
# |    n_updates            | 320         |
# |    policy_gradient_loss | 0.0227      |
# |    value_loss           | 7.09e-05    |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 335       |
# |    ep_rew_mean          | 1.31      |
# | time/                   |           |
# |    fps                  | 1041      |
# |    iterations           | 34        |
# |    time_elapsed         | 41        |
# |    total_timesteps      | 43520     |
# | train/                  |           |
# |    approx_kl            | 0.1241806 |
# |    clip_fraction        | 0.247     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.257    |
# |    explained_variance   | 0.891     |
# |    learning_rate        | 0.0014    |
# |    loss                 | 0.021     |
# |    n_updates            | 330       |
# |    policy_gradient_loss | 0.0178    |
# |    value_loss           | 0.000307  |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 1.34        |
# | time/                   |             |
# |    fps                  | 1037        |
# |    iterations           | 35          |
# |    time_elapsed         | 43          |
# |    total_timesteps      | 44800       |
# | train/                  |             |
# |    approx_kl            | 0.026281603 |
# |    clip_fraction        | 0.214       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.25       |
# |    explained_variance   | 0.862       |
# |    learning_rate        | 0.0014      |
# |    loss                 | 0.0118      |
# |    n_updates            | 340         |
# |    policy_gradient_loss | 0.0348      |
# |    value_loss           | 0.000347    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 335        |
# |    ep_rew_mean          | 1.36       |
# | time/                   |            |
# |    fps                  | 1039       |
# |    iterations           | 36         |
# |    time_elapsed         | 44         |
# |    total_timesteps      | 46080      |
# | train/                  |            |
# |    approx_kl            | 0.02196189 |
# |    clip_fraction        | 0.197      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.258     |
# |    explained_variance   | 0.896      |
# |    learning_rate        | 0.0014     |
# |    loss                 | 0.0253     |
# |    n_updates            | 350        |
# |    policy_gradient_loss | 0.0234     |
# |    value_loss           | 8e-05      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 335        |
# |    ep_rew_mean          | 1.38       |
# | time/                   |            |
# |    fps                  | 1041       |
# |    iterations           | 37         |
# |    time_elapsed         | 45         |
# |    total_timesteps      | 47360      |
# | train/                  |            |
# |    approx_kl            | 0.13505888 |
# |    clip_fraction        | 0.192      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.25      |
# |    explained_variance   | 0.918      |
# |    learning_rate        | 0.0014     |
# |    loss                 | 0.0646     |
# |    n_updates            | 360        |
# |    policy_gradient_loss | 0.0164     |
# |    value_loss           | 6.58e-05   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 1.39        |
# | time/                   |             |
# |    fps                  | 1042        |
# |    iterations           | 38          |
# |    time_elapsed         | 46          |
# |    total_timesteps      | 48640       |
# | train/                  |             |
# |    approx_kl            | 0.111675546 |
# |    clip_fraction        | 0.187       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.226      |
# |    explained_variance   | 0.894       |
# |    learning_rate        | 0.0014      |
# |    loss                 | -0.000206   |
# |    n_updates            | 370         |
# |    policy_gradient_loss | 0.0065      |
# |    value_loss           | 0.00146     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 335        |
# |    ep_rew_mean          | 1.4        |
# | time/                   |            |
# |    fps                  | 1042       |
# |    iterations           | 39         |
# |    time_elapsed         | 47         |
# |    total_timesteps      | 49920      |
# | train/                  |            |
# |    approx_kl            | 0.11253598 |
# |    clip_fraction        | 0.228      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.219     |
# |    explained_variance   | 0.798      |
# |    learning_rate        | 0.0014     |
# |    loss                 | -0.00309   |
# |    n_updates            | 380        |
# |    policy_gradient_loss | 0.0146     |
# |    value_loss           | 0.000168   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 335        |
# |    ep_rew_mean          | 1.41       |
# | time/                   |            |
# |    fps                  | 1043       |
# |    iterations           | 40         |
# |    time_elapsed         | 49         |
# |    total_timesteps      | 51200      |
# | train/                  |            |
# |    approx_kl            | 0.04363928 |
# |    clip_fraction        | 0.225      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.25      |
# |    explained_variance   | 0.869      |
# |    learning_rate        | 0.0014     |
# |    loss                 | 0.00844    |
# |    n_updates            | 390        |
# |    policy_gradient_loss | 0.0265     |
# |    value_loss           | 0.0002     |
# ----------------------------------------
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 335      |
# |    ep_rew_mean     | 0.0309   |
# | time/              |          |
# |    fps             | 1517     |
# |    iterations      | 1        |
# |    time_elapsed    | 1        |
# |    total_timesteps | 2048     |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 335          |
# |    ep_rew_mean          | 0.0483       |
# | time/                   |              |
# |    fps                  | 1045         |
# |    iterations           | 2            |
# |    time_elapsed         | 3            |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0065363487 |
# |    clip_fraction        | 0.014        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.09        |
# |    explained_variance   | -4.88        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00524     |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.00254     |
# |    value_loss           | 0.00254      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 335          |
# |    ep_rew_mean          | 0.0394       |
# | time/                   |              |
# |    fps                  | 904          |
# |    iterations           | 3            |
# |    time_elapsed         | 6            |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.0055035474 |
# |    clip_fraction        | 0.0474       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.09        |
# |    explained_variance   | -0.749       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0196      |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.00409     |
# |    value_loss           | 0.000791     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.0562      |
# | time/                   |             |
# |    fps                  | 836         |
# |    iterations           | 4           |
# |    time_elapsed         | 9           |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.012623246 |
# |    clip_fraction        | 0.117       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.08       |
# |    explained_variance   | 0.0668      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0219     |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0108     |
# |    value_loss           | 0.000636    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.0913      |
# | time/                   |             |
# |    fps                  | 827         |
# |    iterations           | 5           |
# |    time_elapsed         | 12          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.008273529 |
# |    clip_fraction        | 0.125       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.05       |
# |    explained_variance   | 0.0414      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0212      |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0121     |
# |    value_loss           | 0.000559    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.126       |
# | time/                   |             |
# |    fps                  | 822         |
# |    iterations           | 6           |
# |    time_elapsed         | 14          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.011269892 |
# |    clip_fraction        | 0.0974      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1          |
# |    explained_variance   | 0.163       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0101     |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.00416    |
# |    value_loss           | 0.000435    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.166       |
# | time/                   |             |
# |    fps                  | 817         |
# |    iterations           | 7           |
# |    time_elapsed         | 17          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.011619076 |
# |    clip_fraction        | 0.128       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.97       |
# |    explained_variance   | 0.359       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00731    |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.00957    |
# |    value_loss           | 0.000398    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 335        |
# |    ep_rew_mean          | 0.208      |
# | time/                   |            |
# |    fps                  | 815        |
# |    iterations           | 8          |
# |    time_elapsed         | 20         |
# |    total_timesteps      | 16384      |
# | train/                  |            |
# |    approx_kl            | 0.01135104 |
# |    clip_fraction        | 0.102      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.947     |
# |    explained_variance   | 0.453      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.00555   |
# |    n_updates            | 70         |
# |    policy_gradient_loss | -0.00803   |
# |    value_loss           | 0.000535   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.249       |
# | time/                   |             |
# |    fps                  | 804         |
# |    iterations           | 9           |
# |    time_elapsed         | 22          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.008621272 |
# |    clip_fraction        | 0.103       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.901      |
# |    explained_variance   | 0.574       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00459    |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.00657    |
# |    value_loss           | 0.000473    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 335          |
# |    ep_rew_mean          | 0.293        |
# | time/                   |              |
# |    fps                  | 790          |
# |    iterations           | 10           |
# |    time_elapsed         | 25           |
# |    total_timesteps      | 20480        |
# | train/                  |              |
# |    approx_kl            | 0.0074098664 |
# |    clip_fraction        | 0.0942       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.835       |
# |    explained_variance   | 0.643        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00324     |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -0.00584     |
# |    value_loss           | 0.000376     |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 335        |
# |    ep_rew_mean          | 0.33       |
# | time/                   |            |
# |    fps                  | 785        |
# |    iterations           | 11         |
# |    time_elapsed         | 28         |
# |    total_timesteps      | 22528      |
# | train/                  |            |
# |    approx_kl            | 0.00867757 |
# |    clip_fraction        | 0.108      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.81      |
# |    explained_variance   | 0.553      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.022     |
# |    n_updates            | 100        |
# |    policy_gradient_loss | -0.00716   |
# |    value_loss           | 0.000572   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.372       |
# | time/                   |             |
# |    fps                  | 779         |
# |    iterations           | 12          |
# |    time_elapsed         | 31          |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.012264011 |
# |    clip_fraction        | 0.14        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.767      |
# |    explained_variance   | 0.657       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00252    |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.00598    |
# |    value_loss           | 0.000474    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.412       |
# | time/                   |             |
# |    fps                  | 777         |
# |    iterations           | 13          |
# |    time_elapsed         | 34          |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.011194265 |
# |    clip_fraction        | 0.127       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.717      |
# |    explained_variance   | 0.828       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00637     |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.00886    |
# |    value_loss           | 0.000289    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.451       |
# | time/                   |             |
# |    fps                  | 776         |
# |    iterations           | 14          |
# |    time_elapsed         | 36          |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.007928085 |
# |    clip_fraction        | 0.116       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.677      |
# |    explained_variance   | 0.857       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00285     |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.00206    |
# |    value_loss           | 0.000312    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.487       |
# | time/                   |             |
# |    fps                  | 773         |
# |    iterations           | 15          |
# |    time_elapsed         | 39          |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.022140343 |
# |    clip_fraction        | 0.159       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.67       |
# |    explained_variance   | 0.891       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0384     |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.00207    |
# |    value_loss           | 0.00034     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.521       |
# | time/                   |             |
# |    fps                  | 775         |
# |    iterations           | 16          |
# |    time_elapsed         | 42          |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.013559215 |
# |    clip_fraction        | 0.156       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.656      |
# |    explained_variance   | 0.922       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.000588   |
# |    n_updates            | 150         |
# |    policy_gradient_loss | 0.00193     |
# |    value_loss           | 0.000337    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.571       |
# | time/                   |             |
# |    fps                  | 786         |
# |    iterations           | 17          |
# |    time_elapsed         | 44          |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.011250598 |
# |    clip_fraction        | 0.16        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.65       |
# |    explained_variance   | 0.942       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00796    |
# |    n_updates            | 160         |
# |    policy_gradient_loss | 0.000735    |
# |    value_loss           | 0.000433    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.641       |
# | time/                   |             |
# |    fps                  | 796         |
# |    iterations           | 18          |
# |    time_elapsed         | 46          |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.008898572 |
# |    clip_fraction        | 0.15        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.607      |
# |    explained_variance   | 0.937       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0134     |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.000599   |
# |    value_loss           | 0.000438    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.71        |
# | time/                   |             |
# |    fps                  | 805         |
# |    iterations           | 19          |
# |    time_elapsed         | 48          |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.013884373 |
# |    clip_fraction        | 0.183       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.573      |
# |    explained_variance   | 0.959       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0126     |
# |    n_updates            | 180         |
# |    policy_gradient_loss | 0.00365     |
# |    value_loss           | 0.000271    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.776       |
# | time/                   |             |
# |    fps                  | 814         |
# |    iterations           | 20          |
# |    time_elapsed         | 50          |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.026963625 |
# |    clip_fraction        | 0.157       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.551      |
# |    explained_variance   | 0.964       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0105      |
# |    n_updates            | 190         |
# |    policy_gradient_loss | 0.0023      |
# |    value_loss           | 0.000357    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.833       |
# | time/                   |             |
# |    fps                  | 821         |
# |    iterations           | 21          |
# |    time_elapsed         | 52          |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.011585142 |
# |    clip_fraction        | 0.165       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.511      |
# |    explained_variance   | 0.97        |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0168     |
# |    n_updates            | 200         |
# |    policy_gradient_loss | 0.00384     |
# |    value_loss           | 0.000634    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.892       |
# | time/                   |             |
# |    fps                  | 822         |
# |    iterations           | 22          |
# |    time_elapsed         | 54          |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.017166063 |
# |    clip_fraction        | 0.15        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.484      |
# |    explained_variance   | 0.974       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0106     |
# |    n_updates            | 210         |
# |    policy_gradient_loss | 0.00286     |
# |    value_loss           | 0.000148    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.942       |
# | time/                   |             |
# |    fps                  | 816         |
# |    iterations           | 23          |
# |    time_elapsed         | 57          |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.024043817 |
# |    clip_fraction        | 0.15        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.485      |
# |    explained_variance   | 0.976       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00849    |
# |    n_updates            | 220         |
# |    policy_gradient_loss | 0.00417     |
# |    value_loss           | 0.000209    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.991       |
# | time/                   |             |
# |    fps                  | 821         |
# |    iterations           | 24          |
# |    time_elapsed         | 59          |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.041577008 |
# |    clip_fraction        | 0.182       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.445      |
# |    explained_variance   | 0.983       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0255     |
# |    n_updates            | 230         |
# |    policy_gradient_loss | 0.0119      |
# |    value_loss           | 0.000151    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 1.04        |
# | time/                   |             |
# |    fps                  | 826         |
# |    iterations           | 25          |
# |    time_elapsed         | 61          |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.012264107 |
# |    clip_fraction        | 0.154       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.435      |
# |    explained_variance   | 0.985       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0273      |
# |    n_updates            | 240         |
# |    policy_gradient_loss | 0.00574     |
# |    value_loss           | 0.000345    |
# -----------------------------------------
#          Method  Cumulative Return  Sharpe Ratio  Sortino Ratio  Max Drawdown
# 0   Bi-LSTM PPO           2.594173      0.629342       1.824538     -0.011161
# 1    Simple PPO           2.426499      0.558060       1.536001     -0.010412
# 2  Buy-and-Hold          -0.599080           NaN            NaN           NaN
