# %%
import pandas as pd
import numpy as np
import torch
import torch.nn as nn
from sklearn.preprocessing import MinMaxScaler
from torch.utils.data import DataLoader, TensorDataset
from stable_baselines3 import PPO
from gym import spaces, Env
import matplotlib.pyplot as plt
import random

# Set seed for reproducibility
SEED = 42
random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)
if torch.cuda.is_available():
    torch.cuda.manual_seed_all(SEED)

# Load and preprocess data
def load_and_preprocess(file_name):
    data = pd.read_csv(file_name)
    data["Date"] = pd.to_datetime(data["Date"])
    data = data.sort_values(by="Date")
    
    numeric_data = data.drop(columns=["Date"])
    numeric_data = numeric_data[['Close'] + [col for col in numeric_data.columns if col != 'Close']]
    
    scaler = MinMaxScaler()
    normalized_data = scaler.fit_transform(numeric_data)
    data[numeric_data.columns] = normalized_data
    
    return data, scaler

# Create sequences for time series modeling
def create_sequences(data, sequence_length=30):
    sequences = []
    targets = []
    for i in range(len(data) - sequence_length):
        seq = data[i:i+sequence_length]
        target = data[i+sequence_length, 0]  # Assuming the target is the first column (e.g., Close price)
        sequences.append(seq)
        targets.append(target)
    return np.array(sequences), np.array(targets)

# Define Bi-LSTM model
class BiLSTMModel(nn.Module):
    def __init__(self, input_dim, hidden_dim, num_layers, dropout):
        super(BiLSTMModel, self).__init__()
        self.bilstm = nn.LSTM(input_dim, hidden_dim, num_layers, batch_first=True, dropout=dropout, bidirectional=True)
        self.fc = nn.Linear(hidden_dim * 2, 1)

    def forward(self, x):
        bilstm_out, _ = self.bilstm(x)
        return self.fc(bilstm_out[:, -1, :])

# Custom trading environment
class TradingEnv(Env):
    def __init__(self, data, sequence_length=30):
        super(TradingEnv, self).__init__()
        self.data = data
        self.sequence_length = sequence_length
        self.current_step = 0
        self.total_steps = len(data) - sequence_length
        self.portfolio_value = 1.0

        # Action and observation space
        self.action_space = spaces.Discrete(3)  # 0: Hold, 1: Buy, 2: Sell
        self.observation_space = spaces.Box(low=0, high=1, shape=(sequence_length, data.shape[1]), dtype=np.float32)

    def reset(self):
        self.current_step = 0
        self.portfolio_value = 1.0
        return self._next_observation()

    def _next_observation(self):
        return self.data[self.current_step:self.current_step + self.sequence_length]

    def step(self, action):
        self.current_step += 1
        reward = 0
        done = self.current_step >= self.total_steps

        if not done:
            current_price = self.data[self.current_step, 0]
            prev_price = self.data[self.current_step - 1, 0]

            if action == 1:  # Buy
                reward = current_price - prev_price
            elif action == 2:  # Sell
                reward = prev_price - current_price

        self.portfolio_value += reward
        obs = self._next_observation() if not done else None
        return obs, reward, done, {"portfolio_value": self.portfolio_value}

# Evaluate trading strategy
def evaluate_trading_strategy(env, model):
    obs = env.reset()
    done = False
    portfolio_values = [1.0]

    while not done:
        action, _ = model.predict(obs, deterministic=True)
        obs, reward, done, info = env.step(action)
        portfolio_values.append(info.get("portfolio_value", 1.0))

    return portfolio_values

# Performance metrics
def calculate_metrics(portfolio_values):
    daily_returns = np.diff(portfolio_values) / portfolio_values[:-1]
    cumulative_return = portfolio_values[-1] / portfolio_values[0] - 1
    sharpe_ratio = np.mean(daily_returns) / np.std(daily_returns) if np.std(daily_returns) > 0 else 0
    sortino_ratio = np.mean(daily_returns) / np.std([r for r in daily_returns if r < 0]) if np.std([r for r in daily_returns if r < 0]) > 0 else 0
    max_drawdown = np.min(portfolio_values / np.maximum.accumulate(portfolio_values) - 1)
    return cumulative_return, sharpe_ratio, sortino_ratio, max_drawdown

# Main execution
if __name__ == "__main__":
    # Load data
    data, scaler = load_and_preprocess("Book2.csv")
    train_data = data[(data["Date"].dt.year >= 2017) & (data["Date"].dt.year <= 2023)].drop(columns=["Date"]).values
    test_data = data[data["Date"].dt.year == 2024].drop(columns=["Date"]).values

    X_train, y_train = create_sequences(train_data)
    X_test, y_test = create_sequences(test_data)

    # Train Bi-LSTM model
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    bilstm_model = BiLSTMModel(input_dim=X_train.shape[2], hidden_dim=224, num_layers=1, dropout=0.14).to(device)
    criterion = nn.MSELoss()
    optimizer = torch.optim.Adam(bilstm_model.parameters(), lr=0.0019)

    train_loader = DataLoader(TensorDataset(torch.tensor(X_train, dtype=torch.float32), torch.tensor(y_train, dtype=torch.float32)), batch_size=32, shuffle=True)

    for epoch in range(50):
        bilstm_model.train()
        train_loss = 0.0
        for X_batch, y_batch in train_loader:
            X_batch, y_batch = X_batch.to(device), y_batch.to(device)
            optimizer.zero_grad()
            predictions = bilstm_model(X_batch).squeeze()
            loss = criterion(predictions, y_batch)
            loss.backward()
            optimizer.step()
            train_loss += loss.item()

    # Create environments for PPO
    bilstm_env = TradingEnv(test_data)
    simple_env = TradingEnv(test_data)

    # Train PPO models
    ppo_bilstm_model = PPO("MlpPolicy", bilstm_env, learning_rate=0.0014, batch_size=160, n_steps=1280, gamma=0.9005911776350177, verbose=1)
    ppo_bilstm_model.learn(total_timesteps=50000)

    ppo_simple_model = PPO("MlpPolicy", simple_env, verbose=1)
    ppo_simple_model.learn(total_timesteps=50000)

    # Evaluate strategies
    portfolio_values_bilstm = evaluate_trading_strategy(bilstm_env, ppo_bilstm_model)
    portfolio_values_simple = evaluate_trading_strategy(simple_env, ppo_simple_model)

    cumulative_return_bilstm, sharpe_bilstm, sortino_bilstm, max_drawdown_bilstm = calculate_metrics(portfolio_values_bilstm)
    cumulative_return_simple, sharpe_simple, sortino_simple, max_drawdown_simple = calculate_metrics(portfolio_values_simple)

    # Buy-and-Hold strategy
    buy_hold_return = test_data[-1, 0] / test_data[0, 0] - 1

    # Generate date range for 2022
    test_dates = pd.date_range(start="2024-01-01", periods=len(portfolio_values_bilstm))

    # Calculate cumulative returns
    cumulative_returns_bilstm = np.cumprod([1 + r for r in np.diff(portfolio_values_bilstm) / portfolio_values_bilstm[:-1]])
    cumulative_returns_simple = np.cumprod([1 + r for r in np.diff(portfolio_values_simple) / portfolio_values_simple[:-1]])

    # Plot cumulative returns
    plt.figure(figsize=(12, 6))
    plt.plot(test_dates[1:], cumulative_returns_bilstm, label="Bi-LSTM PPO")
    plt.plot(test_dates[1:], cumulative_returns_simple, label="Simple PPO")
    plt.gca().xaxis.set_major_formatter(plt.matplotlib.dates.DateFormatter("%b %Y"))
    plt.gca().xaxis.set_major_locator(plt.matplotlib.dates.MonthLocator())

    plt.legend()
    plt.title("Cumulative Returns")
    plt.xlabel("Date")
    plt.ylabel("Cumulative Return")
    plt.grid()
    plt.show()

    # Print results
    results = pd.DataFrame({
        "Method": ["Bi-LSTM PPO", "Simple PPO", "Buy-and-Hold"],
        "Cumulative Return": [cumulative_returns_bilstm[-1], cumulative_returns_simple[-1], buy_hold_return],
        "Sharpe Ratio": [sharpe_bilstm, sharpe_simple, None],
        "Sortino Ratio": [sortino_bilstm, sortino_simple, None],
        "Max Drawdown": [max_drawdown_bilstm, max_drawdown_simple, None]
    })
    print(results)
# Out:
# C:\Users\User\anaconda3\envs\RL\Lib\site-packages\torch\nn\modules\rnn.py:123: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.14 and num_layers=1
#   warnings.warn(
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# C:\Users\User\anaconda3\envs\RL\Lib\site-packages\stable_baselines3\common\vec_env\patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 335      |
# |    ep_rew_mean     | 0.00782  |
# | time/              |          |
# |    fps             | 877      |
# |    iterations      | 1        |
# |    time_elapsed    | 1        |
# |    total_timesteps | 1280     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.0377      |
# | time/                   |             |
# |    fps                  | 783         |
# |    iterations           | 2           |
# |    time_elapsed         | 3           |
# |    total_timesteps      | 2560        |
# | train/                  |             |
# |    approx_kl            | 0.009396594 |
# |    clip_fraction        | 0.0772      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | -5.09       |
# |    learning_rate        | 0.0014      |
# |    loss                 | -0.0221     |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.009      |
# |    value_loss           | 0.025       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.0493      |
# | time/                   |             |
# |    fps                  | 772         |
# |    iterations           | 3           |
# |    time_elapsed         | 4           |
# |    total_timesteps      | 3840        |
# | train/                  |             |
# |    approx_kl            | 0.007400861 |
# |    clip_fraction        | 0.0626      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | -0.487      |
# |    learning_rate        | 0.0014      |
# |    loss                 | -0.0104     |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.00905    |
# |    value_loss           | 0.00079     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.0903      |
# | time/                   |             |
# |    fps                  | 776         |
# |    iterations           | 4           |
# |    time_elapsed         | 6           |
# |    total_timesteps      | 5120        |
# | train/                  |             |
# |    approx_kl            | 0.017531237 |
# |    clip_fraction        | 0.112       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.07       |
# |    explained_variance   | -0.944      |
# |    learning_rate        | 0.0014      |
# |    loss                 | 0.00165     |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.00978    |
# |    value_loss           | 0.000324    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.127       |
# | time/                   |             |
# |    fps                  | 781         |
# |    iterations           | 5           |
# |    time_elapsed         | 8           |
# |    total_timesteps      | 6400        |
# | train/                  |             |
# |    approx_kl            | 0.012050109 |
# |    clip_fraction        | 0.132       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.05       |
# |    explained_variance   | -0.0307     |
# |    learning_rate        | 0.0014      |
# |    loss                 | -0.0302     |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0159     |
# |    value_loss           | 0.000385    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 335        |
# |    ep_rew_mean          | 0.167      |
# | time/                   |            |
# |    fps                  | 781        |
# |    iterations           | 6          |
# |    time_elapsed         | 9          |
# |    total_timesteps      | 7680       |
# | train/                  |            |
# |    approx_kl            | 0.01719355 |
# |    clip_fraction        | 0.234      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.01      |
# |    explained_variance   | 0.477      |
# |    learning_rate        | 0.0014     |
# |    loss                 | 0.0168     |
# |    n_updates            | 50         |
# |    policy_gradient_loss | -0.0116    |
# |    value_loss           | 0.000193   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.223       |
# | time/                   |             |
# |    fps                  | 783         |
# |    iterations           | 7           |
# |    time_elapsed         | 11          |
# |    total_timesteps      | 8960        |
# | train/                  |             |
# |    approx_kl            | 0.009665046 |
# |    clip_fraction        | 0.206       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.996      |
# |    explained_variance   | 0.59        |
# |    learning_rate        | 0.0014      |
# |    loss                 | -0.00958    |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.00895    |
# |    value_loss           | 0.000192    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.291       |
# | time/                   |             |
# |    fps                  | 783         |
# |    iterations           | 8           |
# |    time_elapsed         | 13          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.015877549 |
# |    clip_fraction        | 0.26        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.932      |
# |    explained_variance   | 0.727       |
# |    learning_rate        | 0.0014      |
# |    loss                 | -0.0347     |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0175     |
# |    value_loss           | 0.000199    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.351       |
# | time/                   |             |
# |    fps                  | 781         |
# |    iterations           | 9           |
# |    time_elapsed         | 14          |
# |    total_timesteps      | 11520       |
# | train/                  |             |
# |    approx_kl            | 0.023640573 |
# |    clip_fraction        | 0.339       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.896      |
# |    explained_variance   | 0.811       |
# |    learning_rate        | 0.0014      |
# |    loss                 | -0.0307     |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.0199     |
# |    value_loss           | 0.000142    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.413       |
# | time/                   |             |
# |    fps                  | 766         |
# |    iterations           | 10          |
# |    time_elapsed         | 16          |
# |    total_timesteps      | 12800       |
# | train/                  |             |
# |    approx_kl            | 0.038523614 |
# |    clip_fraction        | 0.254       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.825      |
# |    explained_variance   | 0.899       |
# |    learning_rate        | 0.0014      |
# |    loss                 | -0.00454    |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.0084     |
# |    value_loss           | 0.000272    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.476       |
# | time/                   |             |
# |    fps                  | 764         |
# |    iterations           | 11          |
# |    time_elapsed         | 18          |
# |    total_timesteps      | 14080       |
# | train/                  |             |
# |    approx_kl            | 0.037980933 |
# |    clip_fraction        | 0.285       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.729      |
# |    explained_variance   | 0.932       |
# |    learning_rate        | 0.0014      |
# |    loss                 | 0.0139      |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.00884    |
# |    value_loss           | 0.000134    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 335        |
# |    ep_rew_mean          | 0.523      |
# | time/                   |            |
# |    fps                  | 764        |
# |    iterations           | 12         |
# |    time_elapsed         | 20         |
# |    total_timesteps      | 15360      |
# | train/                  |            |
# |    approx_kl            | 0.03420911 |
# |    clip_fraction        | 0.301      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.648     |
# |    explained_variance   | 0.941      |
# |    learning_rate        | 0.0014     |
# |    loss                 | -0.037     |
# |    n_updates            | 110        |
# |    policy_gradient_loss | -0.00356   |
# |    value_loss           | 0.000104   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 335        |
# |    ep_rew_mean          | 0.573      |
# | time/                   |            |
# |    fps                  | 769        |
# |    iterations           | 13         |
# |    time_elapsed         | 21         |
# |    total_timesteps      | 16640      |
# | train/                  |            |
# |    approx_kl            | 0.16246492 |
# |    clip_fraction        | 0.361      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.619     |
# |    explained_variance   | 0.94       |
# |    learning_rate        | 0.0014     |
# |    loss                 | 0.0721     |
# |    n_updates            | 120        |
# |    policy_gradient_loss | 0.0369     |
# |    value_loss           | 0.00066    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.617       |
# | time/                   |             |
# |    fps                  | 774         |
# |    iterations           | 14          |
# |    time_elapsed         | 23          |
# |    total_timesteps      | 17920       |
# | train/                  |             |
# |    approx_kl            | 0.031067293 |
# |    clip_fraction        | 0.305       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.51       |
# |    explained_variance   | 0.941       |
# |    learning_rate        | 0.0014      |
# |    loss                 | -0.0285     |
# |    n_updates            | 130         |
# |    policy_gradient_loss | 0.0205      |
# |    value_loss           | 0.00077     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.655       |
# | time/                   |             |
# |    fps                  | 777         |
# |    iterations           | 15          |
# |    time_elapsed         | 24          |
# |    total_timesteps      | 19200       |
# | train/                  |             |
# |    approx_kl            | 0.039910078 |
# |    clip_fraction        | 0.217       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.483      |
# |    explained_variance   | 0.947       |
# |    learning_rate        | 0.0014      |
# |    loss                 | -0.021      |
# |    n_updates            | 140         |
# |    policy_gradient_loss | 0.008       |
# |    value_loss           | 0.00503     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.69        |
# | time/                   |             |
# |    fps                  | 781         |
# |    iterations           | 16          |
# |    time_elapsed         | 26          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.048703205 |
# |    clip_fraction        | 0.232       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.456      |
# |    explained_variance   | 0.929       |
# |    learning_rate        | 0.0014      |
# |    loss                 | -0.0112     |
# |    n_updates            | 150         |
# |    policy_gradient_loss | 0.00234     |
# |    value_loss           | 0.000177    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 335        |
# |    ep_rew_mean          | 0.71       |
# | time/                   |            |
# |    fps                  | 785        |
# |    iterations           | 17         |
# |    time_elapsed         | 27         |
# |    total_timesteps      | 21760      |
# | train/                  |            |
# |    approx_kl            | 0.03168705 |
# |    clip_fraction        | 0.197      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.42      |
# |    explained_variance   | 0.947      |
# |    learning_rate        | 0.0014     |
# |    loss                 | 0.00295    |
# |    n_updates            | 160        |
# |    policy_gradient_loss | -0.00186   |
# |    value_loss           | 9.19e-05   |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 335       |
# |    ep_rew_mean          | 0.734     |
# | time/                   |           |
# |    fps                  | 788       |
# |    iterations           | 18        |
# |    time_elapsed         | 29        |
# |    total_timesteps      | 23040     |
# | train/                  |           |
# |    approx_kl            | 0.0759842 |
# |    clip_fraction        | 0.251     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.385    |
# |    explained_variance   | 0.936     |
# |    learning_rate        | 0.0014    |
# |    loss                 | -0.0134   |
# |    n_updates            | 170       |
# |    policy_gradient_loss | 0.0164    |
# |    value_loss           | 0.00011   |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 335        |
# |    ep_rew_mean          | 0.762      |
# | time/                   |            |
# |    fps                  | 787        |
# |    iterations           | 19         |
# |    time_elapsed         | 30         |
# |    total_timesteps      | 24320      |
# | train/                  |            |
# |    approx_kl            | 0.08806144 |
# |    clip_fraction        | 0.258      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.337     |
# |    explained_variance   | 0.916      |
# |    learning_rate        | 0.0014     |
# |    loss                 | -0.021     |
# |    n_updates            | 180        |
# |    policy_gradient_loss | 0.00607    |
# |    value_loss           | 0.000112   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.788       |
# | time/                   |             |
# |    fps                  | 781         |
# |    iterations           | 20          |
# |    time_elapsed         | 32          |
# |    total_timesteps      | 25600       |
# | train/                  |             |
# |    approx_kl            | 0.091960914 |
# |    clip_fraction        | 0.204       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.317      |
# |    explained_variance   | 0.944       |
# |    learning_rate        | 0.0014      |
# |    loss                 | 0.0106      |
# |    n_updates            | 190         |
# |    policy_gradient_loss | 0.0176      |
# |    value_loss           | 0.00017     |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 335       |
# |    ep_rew_mean          | 0.811     |
# | time/                   |           |
# |    fps                  | 780       |
# |    iterations           | 21        |
# |    time_elapsed         | 34        |
# |    total_timesteps      | 26880     |
# | train/                  |           |
# |    approx_kl            | 0.1124032 |
# |    clip_fraction        | 0.228     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.321    |
# |    explained_variance   | 0.952     |
# |    learning_rate        | 0.0014    |
# |    loss                 | -0.0045   |
# |    n_updates            | 200       |
# |    policy_gradient_loss | 0.0165    |
# |    value_loss           | 0.000108  |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 335       |
# |    ep_rew_mean          | 0.836     |
# | time/                   |           |
# |    fps                  | 780       |
# |    iterations           | 22        |
# |    time_elapsed         | 36        |
# |    total_timesteps      | 28160     |
# | train/                  |           |
# |    approx_kl            | 0.0893533 |
# |    clip_fraction        | 0.207     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.292    |
# |    explained_variance   | 0.955     |
# |    learning_rate        | 0.0014    |
# |    loss                 | -0.0114   |
# |    n_updates            | 210       |
# |    policy_gradient_loss | 0.0185    |
# |    value_loss           | 6.18e-05  |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.855       |
# | time/                   |             |
# |    fps                  | 782         |
# |    iterations           | 23          |
# |    time_elapsed         | 37          |
# |    total_timesteps      | 29440       |
# | train/                  |             |
# |    approx_kl            | 0.022802833 |
# |    clip_fraction        | 0.235       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.315      |
# |    explained_variance   | 0.962       |
# |    learning_rate        | 0.0014      |
# |    loss                 | 0.00768     |
# |    n_updates            | 220         |
# |    policy_gradient_loss | 0.0293      |
# |    value_loss           | 5.6e-05     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 335        |
# |    ep_rew_mean          | 0.877      |
# | time/                   |            |
# |    fps                  | 785        |
# |    iterations           | 24         |
# |    time_elapsed         | 39         |
# |    total_timesteps      | 30720      |
# | train/                  |            |
# |    approx_kl            | 0.42579648 |
# |    clip_fraction        | 0.246      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.281     |
# |    explained_variance   | 0.956      |
# |    learning_rate        | 0.0014     |
# |    loss                 | 0.0365     |
# |    n_updates            | 230        |
# |    policy_gradient_loss | 0.0419     |
# |    value_loss           | 6.22e-05   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 335        |
# |    ep_rew_mean          | 0.897      |
# | time/                   |            |
# |    fps                  | 787        |
# |    iterations           | 25         |
# |    time_elapsed         | 40         |
# |    total_timesteps      | 32000      |
# | train/                  |            |
# |    approx_kl            | 0.07757573 |
# |    clip_fraction        | 0.283      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.325     |
# |    explained_variance   | 0.966      |
# |    learning_rate        | 0.0014     |
# |    loss                 | -0.0157    |
# |    n_updates            | 240        |
# |    policy_gradient_loss | 0.0456     |
# |    value_loss           | 6.68e-05   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.917       |
# | time/                   |             |
# |    fps                  | 789         |
# |    iterations           | 26          |
# |    time_elapsed         | 42          |
# |    total_timesteps      | 33280       |
# | train/                  |             |
# |    approx_kl            | 0.059013586 |
# |    clip_fraction        | 0.243       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.336      |
# |    explained_variance   | 0.961       |
# |    learning_rate        | 0.0014      |
# |    loss                 | 0.00997     |
# |    n_updates            | 250         |
# |    policy_gradient_loss | 0.0254      |
# |    value_loss           | 5.75e-05    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 335        |
# |    ep_rew_mean          | 0.966      |
# | time/                   |            |
# |    fps                  | 791        |
# |    iterations           | 27         |
# |    time_elapsed         | 43         |
# |    total_timesteps      | 34560      |
# | train/                  |            |
# |    approx_kl            | 0.06077961 |
# |    clip_fraction        | 0.26       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.337     |
# |    explained_variance   | 0.964      |
# |    learning_rate        | 0.0014     |
# |    loss                 | -0.015     |
# |    n_updates            | 260        |
# |    policy_gradient_loss | 0.0236     |
# |    value_loss           | 9.74e-05   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 335        |
# |    ep_rew_mean          | 1.01       |
# | time/                   |            |
# |    fps                  | 793        |
# |    iterations           | 28         |
# |    time_elapsed         | 45         |
# |    total_timesteps      | 35840      |
# | train/                  |            |
# |    approx_kl            | 0.03622415 |
# |    clip_fraction        | 0.239      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.303     |
# |    explained_variance   | 0.967      |
# |    learning_rate        | 0.0014     |
# |    loss                 | -0.00337   |
# |    n_updates            | 270        |
# |    policy_gradient_loss | 0.0335     |
# |    value_loss           | 0.000229   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 335        |
# |    ep_rew_mean          | 1.06       |
# | time/                   |            |
# |    fps                  | 792        |
# |    iterations           | 29         |
# |    time_elapsed         | 46         |
# |    total_timesteps      | 37120      |
# | train/                  |            |
# |    approx_kl            | 0.10083896 |
# |    clip_fraction        | 0.22       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.308     |
# |    explained_variance   | 0.964      |
# |    learning_rate        | 0.0014     |
# |    loss                 | -0.00471   |
# |    n_updates            | 280        |
# |    policy_gradient_loss | 0.0124     |
# |    value_loss           | 0.000107   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 335        |
# |    ep_rew_mean          | 1.11       |
# | time/                   |            |
# |    fps                  | 787        |
# |    iterations           | 30         |
# |    time_elapsed         | 48         |
# |    total_timesteps      | 38400      |
# | train/                  |            |
# |    approx_kl            | 0.03486626 |
# |    clip_fraction        | 0.203      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.284     |
# |    explained_variance   | 0.961      |
# |    learning_rate        | 0.0014     |
# |    loss                 | 0.0268     |
# |    n_updates            | 290        |
# |    policy_gradient_loss | 0.0184     |
# |    value_loss           | 0.000151   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 335        |
# |    ep_rew_mean          | 1.16       |
# | time/                   |            |
# |    fps                  | 786        |
# |    iterations           | 31         |
# |    time_elapsed         | 50         |
# |    total_timesteps      | 39680      |
# | train/                  |            |
# |    approx_kl            | 0.02509846 |
# |    clip_fraction        | 0.161      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.28      |
# |    explained_variance   | 0.964      |
# |    learning_rate        | 0.0014     |
# |    loss                 | 0.0184     |
# |    n_updates            | 300        |
# |    policy_gradient_loss | 0.00798    |
# |    value_loss           | 0.000743   |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 335       |
# |    ep_rew_mean          | 1.2       |
# | time/                   |           |
# |    fps                  | 786       |
# |    iterations           | 32        |
# |    time_elapsed         | 52        |
# |    total_timesteps      | 40960     |
# | train/                  |           |
# |    approx_kl            | 0.1042162 |
# |    clip_fraction        | 0.219     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.289    |
# |    explained_variance   | 0.958     |
# |    learning_rate        | 0.0014    |
# |    loss                 | 0.0394    |
# |    n_updates            | 310       |
# |    policy_gradient_loss | 0.0335    |
# |    value_loss           | 6.71e-05  |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 335        |
# |    ep_rew_mean          | 1.23       |
# | time/                   |            |
# |    fps                  | 787        |
# |    iterations           | 33         |
# |    time_elapsed         | 53         |
# |    total_timesteps      | 42240      |
# | train/                  |            |
# |    approx_kl            | 0.11229576 |
# |    clip_fraction        | 0.24       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.296     |
# |    explained_variance   | 0.934      |
# |    learning_rate        | 0.0014     |
# |    loss                 | 0.018      |
# |    n_updates            | 320        |
# |    policy_gradient_loss | 0.00843    |
# |    value_loss           | 8.07e-05   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 335        |
# |    ep_rew_mean          | 1.25       |
# | time/                   |            |
# |    fps                  | 788        |
# |    iterations           | 34         |
# |    time_elapsed         | 55         |
# |    total_timesteps      | 43520      |
# | train/                  |            |
# |    approx_kl            | 0.08884307 |
# |    clip_fraction        | 0.242      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.316     |
# |    explained_variance   | 0.95       |
# |    learning_rate        | 0.0014     |
# |    loss                 | 0.013      |
# |    n_updates            | 330        |
# |    policy_gradient_loss | 0.0455     |
# |    value_loss           | 7.02e-05   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 335        |
# |    ep_rew_mean          | 1.27       |
# | time/                   |            |
# |    fps                  | 790        |
# |    iterations           | 35         |
# |    time_elapsed         | 56         |
# |    total_timesteps      | 44800      |
# | train/                  |            |
# |    approx_kl            | 0.05307672 |
# |    clip_fraction        | 0.236      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.281     |
# |    explained_variance   | 0.942      |
# |    learning_rate        | 0.0014     |
# |    loss                 | -0.0194    |
# |    n_updates            | 340        |
# |    policy_gradient_loss | 0.0221     |
# |    value_loss           | 0.00017    |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 335        |
# |    ep_rew_mean          | 1.29       |
# | time/                   |            |
# |    fps                  | 795        |
# |    iterations           | 36         |
# |    time_elapsed         | 57         |
# |    total_timesteps      | 46080      |
# | train/                  |            |
# |    approx_kl            | 0.05034272 |
# |    clip_fraction        | 0.26       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.316     |
# |    explained_variance   | 0.957      |
# |    learning_rate        | 0.0014     |
# |    loss                 | 0.00776    |
# |    n_updates            | 350        |
# |    policy_gradient_loss | 0.0406     |
# |    value_loss           | 0.00279    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 1.31        |
# | time/                   |             |
# |    fps                  | 802         |
# |    iterations           | 37          |
# |    time_elapsed         | 59          |
# |    total_timesteps      | 47360       |
# | train/                  |             |
# |    approx_kl            | 0.121399514 |
# |    clip_fraction        | 0.224       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.326      |
# |    explained_variance   | 0.787       |
# |    learning_rate        | 0.0014      |
# |    loss                 | 0.0161      |
# |    n_updates            | 360         |
# |    policy_gradient_loss | 0.0221      |
# |    value_loss           | 0.0027      |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 335        |
# |    ep_rew_mean          | 1.32       |
# | time/                   |            |
# |    fps                  | 809        |
# |    iterations           | 38         |
# |    time_elapsed         | 60         |
# |    total_timesteps      | 48640      |
# | train/                  |            |
# |    approx_kl            | 0.14560172 |
# |    clip_fraction        | 0.209      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.292     |
# |    explained_variance   | 0.908      |
# |    learning_rate        | 0.0014     |
# |    loss                 | 0.0582     |
# |    n_updates            | 370        |
# |    policy_gradient_loss | 0.0171     |
# |    value_loss           | 8.79e-05   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 1.33        |
# | time/                   |             |
# |    fps                  | 815         |
# |    iterations           | 39          |
# |    time_elapsed         | 61          |
# |    total_timesteps      | 49920       |
# | train/                  |             |
# |    approx_kl            | 0.118816435 |
# |    clip_fraction        | 0.223       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.32       |
# |    explained_variance   | 0.945       |
# |    learning_rate        | 0.0014      |
# |    loss                 | -0.00488    |
# |    n_updates            | 380         |
# |    policy_gradient_loss | 0.0236      |
# |    value_loss           | 6.96e-05    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 335        |
# |    ep_rew_mean          | 1.34       |
# | time/                   |            |
# |    fps                  | 821        |
# |    iterations           | 40         |
# |    time_elapsed         | 62         |
# |    total_timesteps      | 51200      |
# | train/                  |            |
# |    approx_kl            | 0.07465577 |
# |    clip_fraction        | 0.188      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.313     |
# |    explained_variance   | 0.959      |
# |    learning_rate        | 0.0014     |
# |    loss                 | 0.0304     |
# |    n_updates            | 390        |
# |    policy_gradient_loss | 0.0161     |
# |    value_loss           | 6.83e-05   |
# ----------------------------------------
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 335      |
# |    ep_rew_mean     | 0.0495   |
# | time/              |          |
# |    fps             | 1366     |
# |    iterations      | 1        |
# |    time_elapsed    | 1        |
# |    total_timesteps | 2048     |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 335          |
# |    ep_rew_mean          | 0.101        |
# | time/                   |              |
# |    fps                  | 957          |
# |    iterations           | 2            |
# |    time_elapsed         | 4            |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0064891605 |
# |    clip_fraction        | 0.0227       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.09        |
# |    explained_variance   | -3           |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00687      |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.00237     |
# |    value_loss           | 0.00253      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.094       |
# | time/                   |             |
# |    fps                  | 917         |
# |    iterations           | 3           |
# |    time_elapsed         | 6           |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.008253086 |
# |    clip_fraction        | 0.0442      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | -1.66       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0174     |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.00486    |
# |    value_loss           | 0.000795    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 335          |
# |    ep_rew_mean          | 0.0976       |
# | time/                   |              |
# |    fps                  | 895          |
# |    iterations           | 4            |
# |    time_elapsed         | 9            |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 0.0057742256 |
# |    clip_fraction        | 0.0624       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.08        |
# |    explained_variance   | 0.00345      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0524       |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.00561     |
# |    value_loss           | 0.000635     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.133       |
# | time/                   |             |
# |    fps                  | 879         |
# |    iterations           | 5           |
# |    time_elapsed         | 11          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.009356735 |
# |    clip_fraction        | 0.0783      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.07       |
# |    explained_variance   | 0.284       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0149     |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.00695    |
# |    value_loss           | 0.000488    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.175       |
# | time/                   |             |
# |    fps                  | 864         |
# |    iterations           | 6           |
# |    time_elapsed         | 14          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.008878939 |
# |    clip_fraction        | 0.0722      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.04       |
# |    explained_variance   | 0.628       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0107     |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.00554    |
# |    value_loss           | 0.000631    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 335          |
# |    ep_rew_mean          | 0.207        |
# | time/                   |              |
# |    fps                  | 845          |
# |    iterations           | 7            |
# |    time_elapsed         | 16           |
# |    total_timesteps      | 14336        |
# | train/                  |              |
# |    approx_kl            | 0.0071295686 |
# |    clip_fraction        | 0.0758       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.01        |
# |    explained_variance   | 0.806        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0015      |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.00512     |
# |    value_loss           | 0.000573     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.244       |
# | time/                   |             |
# |    fps                  | 825         |
# |    iterations           | 8           |
# |    time_elapsed         | 19          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.009965494 |
# |    clip_fraction        | 0.122       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.966      |
# |    explained_variance   | 0.796       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0368     |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.013      |
# |    value_loss           | 0.000603    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 335          |
# |    ep_rew_mean          | 0.283        |
# | time/                   |              |
# |    fps                  | 825          |
# |    iterations           | 9            |
# |    time_elapsed         | 22           |
# |    total_timesteps      | 18432        |
# | train/                  |              |
# |    approx_kl            | 0.0100536095 |
# |    clip_fraction        | 0.105        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.935       |
# |    explained_variance   | 0.853        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0178      |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.00496     |
# |    value_loss           | 0.000497     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.327       |
# | time/                   |             |
# |    fps                  | 826         |
# |    iterations           | 10          |
# |    time_elapsed         | 24          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.012765991 |
# |    clip_fraction        | 0.169       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.871      |
# |    explained_variance   | 0.886       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0335     |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.00935    |
# |    value_loss           | 0.000557    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.368       |
# | time/                   |             |
# |    fps                  | 824         |
# |    iterations           | 11          |
# |    time_elapsed         | 27          |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.012959363 |
# |    clip_fraction        | 0.141       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.827      |
# |    explained_variance   | 0.915       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.000296   |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.0052     |
# |    value_loss           | 0.000437    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.398       |
# | time/                   |             |
# |    fps                  | 825         |
# |    iterations           | 12          |
# |    time_elapsed         | 29          |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.009238069 |
# |    clip_fraction        | 0.108       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.807      |
# |    explained_variance   | 0.911       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00645     |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.00636    |
# |    value_loss           | 0.000482    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.418       |
# | time/                   |             |
# |    fps                  | 819         |
# |    iterations           | 13          |
# |    time_elapsed         | 32          |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.012490288 |
# |    clip_fraction        | 0.136       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.776      |
# |    explained_variance   | 0.893       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0298     |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.00864    |
# |    value_loss           | 0.000484    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.443       |
# | time/                   |             |
# |    fps                  | 807         |
# |    iterations           | 14          |
# |    time_elapsed         | 35          |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.014744851 |
# |    clip_fraction        | 0.128       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.746      |
# |    explained_variance   | 0.638       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.015      |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.0039     |
# |    value_loss           | 0.000888    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 335        |
# |    ep_rew_mean          | 0.469      |
# | time/                   |            |
# |    fps                  | 803        |
# |    iterations           | 15         |
# |    time_elapsed         | 38         |
# |    total_timesteps      | 30720      |
# | train/                  |            |
# |    approx_kl            | 0.01213951 |
# |    clip_fraction        | 0.0995     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.713     |
# |    explained_variance   | 0.807      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0307    |
# |    n_updates            | 140        |
# |    policy_gradient_loss | -0.00663   |
# |    value_loss           | 0.00057    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.494       |
# | time/                   |             |
# |    fps                  | 803         |
# |    iterations           | 16          |
# |    time_elapsed         | 40          |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.016374987 |
# |    clip_fraction        | 0.12        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.644      |
# |    explained_variance   | 0.859       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00347     |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.00685    |
# |    value_loss           | 0.000308    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 335        |
# |    ep_rew_mean          | 0.534      |
# | time/                   |            |
# |    fps                  | 800        |
# |    iterations           | 17         |
# |    time_elapsed         | 43         |
# |    total_timesteps      | 34816      |
# | train/                  |            |
# |    approx_kl            | 0.01570293 |
# |    clip_fraction        | 0.131      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.605     |
# |    explained_variance   | 0.89       |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.01       |
# |    n_updates            | 160        |
# |    policy_gradient_loss | -0.00117   |
# |    value_loss           | 0.000713   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.603       |
# | time/                   |             |
# |    fps                  | 799         |
# |    iterations           | 18          |
# |    time_elapsed         | 46          |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.027349364 |
# |    clip_fraction        | 0.154       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.576      |
# |    explained_variance   | 0.876       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00557     |
# |    n_updates            | 170         |
# |    policy_gradient_loss | 0.00623     |
# |    value_loss           | 0.000319    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 335        |
# |    ep_rew_mean          | 0.656      |
# | time/                   |            |
# |    fps                  | 793        |
# |    iterations           | 19         |
# |    time_elapsed         | 49         |
# |    total_timesteps      | 38912      |
# | train/                  |            |
# |    approx_kl            | 0.01079877 |
# |    clip_fraction        | 0.121      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.563     |
# |    explained_variance   | 0.937      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0313     |
# |    n_updates            | 180        |
# |    policy_gradient_loss | 0.000677   |
# |    value_loss           | 0.00018    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.713       |
# | time/                   |             |
# |    fps                  | 787         |
# |    iterations           | 20          |
# |    time_elapsed         | 52          |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.008787638 |
# |    clip_fraction        | 0.15        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.543      |
# |    explained_variance   | 0.954       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0091      |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.000444   |
# |    value_loss           | 0.000171    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 335        |
# |    ep_rew_mean          | 0.763      |
# | time/                   |            |
# |    fps                  | 786        |
# |    iterations           | 21         |
# |    time_elapsed         | 54         |
# |    total_timesteps      | 43008      |
# | train/                  |            |
# |    approx_kl            | 0.01123702 |
# |    clip_fraction        | 0.139      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.544     |
# |    explained_variance   | 0.942      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.000468  |
# |    n_updates            | 200        |
# |    policy_gradient_loss | -0.000428  |
# |    value_loss           | 0.00036    |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 335        |
# |    ep_rew_mean          | 0.803      |
# | time/                   |            |
# |    fps                  | 786        |
# |    iterations           | 22         |
# |    time_elapsed         | 57         |
# |    total_timesteps      | 45056      |
# | train/                  |            |
# |    approx_kl            | 0.01126023 |
# |    clip_fraction        | 0.132      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.541     |
# |    explained_variance   | 0.958      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.00249   |
# |    n_updates            | 210        |
# |    policy_gradient_loss | -1.53e-06  |
# |    value_loss           | 0.000362   |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 335          |
# |    ep_rew_mean          | 0.85         |
# | time/                   |              |
# |    fps                  | 787          |
# |    iterations           | 23           |
# |    time_elapsed         | 59           |
# |    total_timesteps      | 47104        |
# | train/                  |              |
# |    approx_kl            | 0.0154546965 |
# |    clip_fraction        | 0.137        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.506       |
# |    explained_variance   | 0.876        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00434     |
# |    n_updates            | 220          |
# |    policy_gradient_loss | 0.00125      |
# |    value_loss           | 0.000352     |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 335        |
# |    ep_rew_mean          | 0.888      |
# | time/                   |            |
# |    fps                  | 787        |
# |    iterations           | 24         |
# |    time_elapsed         | 62         |
# |    total_timesteps      | 49152      |
# | train/                  |            |
# |    approx_kl            | 0.01416953 |
# |    clip_fraction        | 0.162      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.464     |
# |    explained_variance   | 0.941      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.00493   |
# |    n_updates            | 230        |
# |    policy_gradient_loss | -0.000597  |
# |    value_loss           | 0.000162   |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 335          |
# |    ep_rew_mean          | 0.929        |
# | time/                   |              |
# |    fps                  | 784          |
# |    iterations           | 25           |
# |    time_elapsed         | 65           |
# |    total_timesteps      | 51200        |
# | train/                  |              |
# |    approx_kl            | 0.0112067405 |
# |    clip_fraction        | 0.154        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.479       |
# |    explained_variance   | 0.946        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0149      |
# |    n_updates            | 240          |
# |    policy_gradient_loss | 0.00249      |
# |    value_loss           | 0.000154     |
# ------------------------------------------
#          Method  Cumulative Return  Sharpe Ratio  Sortino Ratio  Max Drawdown
# 0   Bi-LSTM PPO           2.509399      0.579005       1.896211     -0.009037
# 1    Simple PPO           2.359377      0.491515       1.744324     -0.010978
# 2  Buy-and-Hold           2.910587           NaN            NaN           NaN
