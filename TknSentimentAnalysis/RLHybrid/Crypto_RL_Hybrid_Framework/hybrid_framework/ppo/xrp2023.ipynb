# %%
import pandas as pd
import numpy as np
import torch
import torch.nn as nn
from sklearn.preprocessing import MinMaxScaler
from torch.utils.data import DataLoader, TensorDataset
from stable_baselines3 import PPO
from gym import spaces, Env
import matplotlib.pyplot as plt
import random

# Set seed for reproducibility
SEED = 42
random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)
if torch.cuda.is_available():
    torch.cuda.manual_seed_all(SEED)

# Load and preprocess data
def load_and_preprocess(file_name):
    data = pd.read_csv(file_name)
    data["Date"] = pd.to_datetime(data["Date"])
    data = data.sort_values(by="Date")
    
    numeric_data = data.drop(columns=["Date"])
    numeric_data = numeric_data[['Close'] + [col for col in numeric_data.columns if col != 'Close']]
    
    scaler = MinMaxScaler()
    normalized_data = scaler.fit_transform(numeric_data)
    data[numeric_data.columns] = normalized_data
    
    return data, scaler

# Create sequences for time series modeling
def create_sequences(data, sequence_length=30):
    sequences = []
    targets = []
    for i in range(len(data) - sequence_length):
        seq = data[i:i+sequence_length]
        target = data[i+sequence_length, 0]  # Assuming the target is the first column (e.g., Close price)
        sequences.append(seq)
        targets.append(target)
    return np.array(sequences), np.array(targets)

# Define Bi-LSTM model
class BiLSTMModel(nn.Module):
    def __init__(self, input_dim, hidden_dim, num_layers, dropout):
        super(BiLSTMModel, self).__init__()
        self.bilstm = nn.LSTM(input_dim, hidden_dim, num_layers, batch_first=True, dropout=dropout, bidirectional=True)
        self.fc = nn.Linear(hidden_dim * 2, 1)

    def forward(self, x):
        bilstm_out, _ = self.bilstm(x)
        return self.fc(bilstm_out[:, -1, :])

# Custom trading environment
class TradingEnv(Env):
    def __init__(self, data, sequence_length=30):
        super(TradingEnv, self).__init__()
        self.data = data
        self.sequence_length = sequence_length
        self.current_step = 0
        self.total_steps = len(data) - sequence_length
        self.portfolio_value = 1.0

        # Action and observation space
        self.action_space = spaces.Discrete(3)  # 0: Hold, 1: Buy, 2: Sell
        self.observation_space = spaces.Box(low=0, high=1, shape=(sequence_length, data.shape[1]), dtype=np.float32)

    def reset(self):
        self.current_step = 0
        self.portfolio_value = 1.0
        return self._next_observation()

    def _next_observation(self):
        return self.data[self.current_step:self.current_step + self.sequence_length]

    def step(self, action):
        self.current_step += 1
        reward = 0
        done = self.current_step >= self.total_steps

        if not done:
            current_price = self.data[self.current_step, 0]
            prev_price = self.data[self.current_step - 1, 0]

            if action == 1:  # Buy
                reward = current_price - prev_price
            elif action == 2:  # Sell
                reward = prev_price - current_price

        self.portfolio_value += reward
        obs = self._next_observation() if not done else None
        return obs, reward, done, {"portfolio_value": self.portfolio_value}

# Evaluate trading strategy
def evaluate_trading_strategy(env, model):
    obs = env.reset()
    done = False
    portfolio_values = [1.0]

    while not done:
        action, _ = model.predict(obs, deterministic=True)
        obs, reward, done, info = env.step(action)
        portfolio_values.append(info.get("portfolio_value", 1.0))

    return portfolio_values

# Performance metrics
def calculate_metrics(portfolio_values):
    daily_returns = np.diff(portfolio_values) / portfolio_values[:-1]
    cumulative_return = portfolio_values[-1] / portfolio_values[0] - 1
    sharpe_ratio = np.mean(daily_returns) / np.std(daily_returns) if np.std(daily_returns) > 0 else 0
    sortino_ratio = np.mean(daily_returns) / np.std([r for r in daily_returns if r < 0]) if np.std([r for r in daily_returns if r < 0]) > 0 else 0
    max_drawdown = np.min(portfolio_values / np.maximum.accumulate(portfolio_values) - 1)
    return cumulative_return, sharpe_ratio, sortino_ratio, max_drawdown

# Main execution
if __name__ == "__main__":
    # Load data
    data, scaler = load_and_preprocess("Book2.csv")
    train_data = data[(data["Date"].dt.year >= 2017) & (data["Date"].dt.year <= 2022)].drop(columns=["Date"]).values
    test_data = data[data["Date"].dt.year == 2023].drop(columns=["Date"]).values

    X_train, y_train = create_sequences(train_data)
    X_test, y_test = create_sequences(test_data)

    # Train Bi-LSTM model
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    bilstm_model = BiLSTMModel(input_dim=X_train.shape[2], hidden_dim=224, num_layers=1, dropout=0.14).to(device)
    criterion = nn.MSELoss()
    optimizer = torch.optim.Adam(bilstm_model.parameters(), lr=0.0019)

    train_loader = DataLoader(TensorDataset(torch.tensor(X_train, dtype=torch.float32), torch.tensor(y_train, dtype=torch.float32)), batch_size=32, shuffle=True)

    for epoch in range(50):
        bilstm_model.train()
        train_loss = 0.0
        for X_batch, y_batch in train_loader:
            X_batch, y_batch = X_batch.to(device), y_batch.to(device)
            optimizer.zero_grad()
            predictions = bilstm_model(X_batch).squeeze()
            loss = criterion(predictions, y_batch)
            loss.backward()
            optimizer.step()
            train_loss += loss.item()

    # Create environments for PPO
    bilstm_env = TradingEnv(test_data)
    simple_env = TradingEnv(test_data)

    # Train PPO models
    ppo_bilstm_model = PPO("MlpPolicy", bilstm_env, learning_rate=0.0014, batch_size=160, n_steps=1280, gamma=0.9005911776350177, verbose=1)
    ppo_bilstm_model.learn(total_timesteps=50000)

    ppo_simple_model = PPO("MlpPolicy", simple_env, verbose=1)
    ppo_simple_model.learn(total_timesteps=50000)

    # Evaluate strategies
    portfolio_values_bilstm = evaluate_trading_strategy(bilstm_env, ppo_bilstm_model)
    portfolio_values_simple = evaluate_trading_strategy(simple_env, ppo_simple_model)

    cumulative_return_bilstm, sharpe_bilstm, sortino_bilstm, max_drawdown_bilstm = calculate_metrics(portfolio_values_bilstm)
    cumulative_return_simple, sharpe_simple, sortino_simple, max_drawdown_simple = calculate_metrics(portfolio_values_simple)

    # Buy-and-Hold strategy
    buy_hold_return = test_data[-1, 0] / test_data[0, 0] - 1

    # Generate date range for 2022
    test_dates = pd.date_range(start="2023-01-01", periods=len(portfolio_values_bilstm))

    # Calculate cumulative returns
    cumulative_returns_bilstm = np.cumprod([1 + r for r in np.diff(portfolio_values_bilstm) / portfolio_values_bilstm[:-1]])
    cumulative_returns_simple = np.cumprod([1 + r for r in np.diff(portfolio_values_simple) / portfolio_values_simple[:-1]])

    # Plot cumulative returns
    plt.figure(figsize=(12, 6))
    plt.plot(test_dates[1:], cumulative_returns_bilstm, label="Bi-LSTM PPO")
    plt.plot(test_dates[1:], cumulative_returns_simple, label="Simple PPO")
    plt.gca().xaxis.set_major_formatter(plt.matplotlib.dates.DateFormatter("%b %Y"))
    plt.gca().xaxis.set_major_locator(plt.matplotlib.dates.MonthLocator())

    plt.legend()
    plt.title("Cumulative Returns")
    plt.xlabel("Date")
    plt.ylabel("Cumulative Return")
    plt.grid()
    plt.show()

    # Print results
    results = pd.DataFrame({
        "Method": ["Bi-LSTM PPO", "Simple PPO", "Buy-and-Hold"],
        "Cumulative Return": [cumulative_returns_bilstm[-1], cumulative_returns_simple[-1], buy_hold_return],
        "Sharpe Ratio": [sharpe_bilstm, sharpe_simple, None],
        "Sortino Ratio": [sortino_bilstm, sortino_simple, None],
        "Max Drawdown": [max_drawdown_bilstm, max_drawdown_simple, None]
    })
    print(results)
# Out:
# C:\Users\User\anaconda3\envs\RL\Lib\site-packages\torch\nn\modules\rnn.py:123: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.14 and num_layers=1
#   warnings.warn(
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# C:\Users\User\anaconda3\envs\RL\Lib\site-packages\stable_baselines3\common\vec_env\patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 335      |
# |    ep_rew_mean     | 0.0733   |
# | time/              |          |
# |    fps             | 1536     |
# |    iterations      | 1        |
# |    time_elapsed    | 0        |
# |    total_timesteps | 1280     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.0599      |
# | time/                   |             |
# |    fps                  | 1273        |
# |    iterations           | 2           |
# |    time_elapsed         | 2           |
# |    total_timesteps      | 2560        |
# | train/                  |             |
# |    approx_kl            | 0.007263583 |
# |    clip_fraction        | 0.093       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | -7.28       |
# |    learning_rate        | 0.0014      |
# |    loss                 | -0.0258     |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.00806    |
# |    value_loss           | 0.024       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 335          |
# |    ep_rew_mean          | 0.0507       |
# | time/                   |              |
# |    fps                  | 1205         |
# |    iterations           | 3            |
# |    time_elapsed         | 3            |
# |    total_timesteps      | 3840         |
# | train/                  |              |
# |    approx_kl            | 0.0085571185 |
# |    clip_fraction        | 0.0648       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.08        |
# |    explained_variance   | -4.36        |
# |    learning_rate        | 0.0014       |
# |    loss                 | 0.0102       |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.00401     |
# |    value_loss           | 0.000526     |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 335        |
# |    ep_rew_mean          | 0.0435     |
# | time/                   |            |
# |    fps                  | 1177       |
# |    iterations           | 4          |
# |    time_elapsed         | 4          |
# |    total_timesteps      | 5120       |
# | train/                  |            |
# |    approx_kl            | 0.00943616 |
# |    clip_fraction        | 0.0974     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.06      |
# |    explained_variance   | -0.753     |
# |    learning_rate        | 0.0014     |
# |    loss                 | -0.00925   |
# |    n_updates            | 30         |
# |    policy_gradient_loss | -0.0125    |
# |    value_loss           | 0.000236   |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 335          |
# |    ep_rew_mean          | 0.0745       |
# | time/                   |              |
# |    fps                  | 1154         |
# |    iterations           | 5            |
# |    time_elapsed         | 5            |
# |    total_timesteps      | 6400         |
# | train/                  |              |
# |    approx_kl            | 0.0067353635 |
# |    clip_fraction        | 0.0874       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.03        |
# |    explained_variance   | -0.612       |
# |    learning_rate        | 0.0014       |
# |    loss                 | -0.0122      |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.00531     |
# |    value_loss           | 0.000137     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 335          |
# |    ep_rew_mean          | 0.0824       |
# | time/                   |              |
# |    fps                  | 1144         |
# |    iterations           | 6            |
# |    time_elapsed         | 6            |
# |    total_timesteps      | 7680         |
# | train/                  |              |
# |    approx_kl            | 0.0132082915 |
# |    clip_fraction        | 0.219        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.04        |
# |    explained_variance   | -0.198       |
# |    learning_rate        | 0.0014       |
# |    loss                 | -0.0296      |
# |    n_updates            | 50           |
# |    policy_gradient_loss | -0.00803     |
# |    value_loss           | 0.000241     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.11        |
# | time/                   |             |
# |    fps                  | 1101        |
# |    iterations           | 7           |
# |    time_elapsed         | 8           |
# |    total_timesteps      | 8960        |
# | train/                  |             |
# |    approx_kl            | 0.009568076 |
# |    clip_fraction        | 0.164       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.01       |
# |    explained_variance   | -0.0649     |
# |    learning_rate        | 0.0014      |
# |    loss                 | -0.0183     |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0143     |
# |    value_loss           | 0.000101    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.136       |
# | time/                   |             |
# |    fps                  | 1081        |
# |    iterations           | 8           |
# |    time_elapsed         | 9           |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.019202419 |
# |    clip_fraction        | 0.183       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.97       |
# |    explained_variance   | 0.238       |
# |    learning_rate        | 0.0014      |
# |    loss                 | 0.0247      |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0031     |
# |    value_loss           | 0.000128    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.167       |
# | time/                   |             |
# |    fps                  | 1058        |
# |    iterations           | 9           |
# |    time_elapsed         | 10          |
# |    total_timesteps      | 11520       |
# | train/                  |             |
# |    approx_kl            | 0.013149703 |
# |    clip_fraction        | 0.209       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.934      |
# |    explained_variance   | 0.471       |
# |    learning_rate        | 0.0014      |
# |    loss                 | -0.0255     |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.0117     |
# |    value_loss           | 8.85e-05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.193       |
# | time/                   |             |
# |    fps                  | 1059        |
# |    iterations           | 10          |
# |    time_elapsed         | 12          |
# |    total_timesteps      | 12800       |
# | train/                  |             |
# |    approx_kl            | 0.019368341 |
# |    clip_fraction        | 0.244       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.876      |
# |    explained_variance   | 0.545       |
# |    learning_rate        | 0.0014      |
# |    loss                 | -0.0273     |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.011      |
# |    value_loss           | 8.25e-05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.218       |
# | time/                   |             |
# |    fps                  | 1063        |
# |    iterations           | 11          |
# |    time_elapsed         | 13          |
# |    total_timesteps      | 14080       |
# | train/                  |             |
# |    approx_kl            | 0.032191735 |
# |    clip_fraction        | 0.28        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.816      |
# |    explained_variance   | 0.62        |
# |    learning_rate        | 0.0014      |
# |    loss                 | -0.0207     |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.00735    |
# |    value_loss           | 0.00133     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.236       |
# | time/                   |             |
# |    fps                  | 1067        |
# |    iterations           | 12          |
# |    time_elapsed         | 14          |
# |    total_timesteps      | 15360       |
# | train/                  |             |
# |    approx_kl            | 0.059071463 |
# |    clip_fraction        | 0.336       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.774      |
# |    explained_variance   | 0.476       |
# |    learning_rate        | 0.0014      |
# |    loss                 | 0.0356      |
# |    n_updates            | 110         |
# |    policy_gradient_loss | 0.0202      |
# |    value_loss           | 0.00369     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.256       |
# | time/                   |             |
# |    fps                  | 1069        |
# |    iterations           | 13          |
# |    time_elapsed         | 15          |
# |    total_timesteps      | 16640       |
# | train/                  |             |
# |    approx_kl            | 0.026084617 |
# |    clip_fraction        | 0.209       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.699      |
# |    explained_variance   | 0.5         |
# |    learning_rate        | 0.0014      |
# |    loss                 | -0.0172     |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.00451    |
# |    value_loss           | 0.000134    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.278       |
# | time/                   |             |
# |    fps                  | 1071        |
# |    iterations           | 14          |
# |    time_elapsed         | 16          |
# |    total_timesteps      | 17920       |
# | train/                  |             |
# |    approx_kl            | 0.074341476 |
# |    clip_fraction        | 0.323       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.661      |
# |    explained_variance   | 0.613       |
# |    learning_rate        | 0.0014      |
# |    loss                 | 0.00227     |
# |    n_updates            | 130         |
# |    policy_gradient_loss | 0.0171      |
# |    value_loss           | 8.37e-05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.302       |
# | time/                   |             |
# |    fps                  | 1073        |
# |    iterations           | 15          |
# |    time_elapsed         | 17          |
# |    total_timesteps      | 19200       |
# | train/                  |             |
# |    approx_kl            | 0.024822328 |
# |    clip_fraction        | 0.237       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.614      |
# |    explained_variance   | 0.648       |
# |    learning_rate        | 0.0014      |
# |    loss                 | -0.00143    |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.00239    |
# |    value_loss           | 7.29e-05    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 335        |
# |    ep_rew_mean          | 0.33       |
# | time/                   |            |
# |    fps                  | 1075       |
# |    iterations           | 16         |
# |    time_elapsed         | 19         |
# |    total_timesteps      | 20480      |
# | train/                  |            |
# |    approx_kl            | 0.05446033 |
# |    clip_fraction        | 0.316      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.578     |
# |    explained_variance   | 0.701      |
# |    learning_rate        | 0.0014     |
# |    loss                 | 0.0537     |
# |    n_updates            | 150        |
# |    policy_gradient_loss | 0.011      |
# |    value_loss           | 8.87e-05   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.351       |
# | time/                   |             |
# |    fps                  | 1078        |
# |    iterations           | 17          |
# |    time_elapsed         | 20          |
# |    total_timesteps      | 21760       |
# | train/                  |             |
# |    approx_kl            | 0.023439946 |
# |    clip_fraction        | 0.258       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.609      |
# |    explained_variance   | 0.759       |
# |    learning_rate        | 0.0014      |
# |    loss                 | -0.0112     |
# |    n_updates            | 160         |
# |    policy_gradient_loss | 0.0067      |
# |    value_loss           | 0.000138    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.378       |
# | time/                   |             |
# |    fps                  | 1080        |
# |    iterations           | 18          |
# |    time_elapsed         | 21          |
# |    total_timesteps      | 23040       |
# | train/                  |             |
# |    approx_kl            | 0.044270188 |
# |    clip_fraction        | 0.33        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.556      |
# |    explained_variance   | 0.787       |
# |    learning_rate        | 0.0014      |
# |    loss                 | 0.00423     |
# |    n_updates            | 170         |
# |    policy_gradient_loss | 0.0186      |
# |    value_loss           | 7.7e-05     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 335        |
# |    ep_rew_mean          | 0.399      |
# | time/                   |            |
# |    fps                  | 1083       |
# |    iterations           | 19         |
# |    time_elapsed         | 22         |
# |    total_timesteps      | 24320      |
# | train/                  |            |
# |    approx_kl            | 0.13980901 |
# |    clip_fraction        | 0.357      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.509     |
# |    explained_variance   | 0.817      |
# |    learning_rate        | 0.0014     |
# |    loss                 | 0.0971     |
# |    n_updates            | 180        |
# |    policy_gradient_loss | 0.024      |
# |    value_loss           | 8.56e-05   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 335        |
# |    ep_rew_mean          | 0.417      |
# | time/                   |            |
# |    fps                  | 1077       |
# |    iterations           | 20         |
# |    time_elapsed         | 23         |
# |    total_timesteps      | 25600      |
# | train/                  |            |
# |    approx_kl            | 0.04040821 |
# |    clip_fraction        | 0.239      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.425     |
# |    explained_variance   | 0.84       |
# |    learning_rate        | 0.0014     |
# |    loss                 | 0.00385    |
# |    n_updates            | 190        |
# |    policy_gradient_loss | 0.0146     |
# |    value_loss           | 0.000392   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.429       |
# | time/                   |             |
# |    fps                  | 1070        |
# |    iterations           | 21          |
# |    time_elapsed         | 25          |
# |    total_timesteps      | 26880       |
# | train/                  |             |
# |    approx_kl            | 0.032007985 |
# |    clip_fraction        | 0.251       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.409      |
# |    explained_variance   | 0.754       |
# |    learning_rate        | 0.0014      |
# |    loss                 | 0.0179      |
# |    n_updates            | 200         |
# |    policy_gradient_loss | 0.028       |
# |    value_loss           | 0.00193     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.448       |
# | time/                   |             |
# |    fps                  | 1061        |
# |    iterations           | 22          |
# |    time_elapsed         | 26          |
# |    total_timesteps      | 28160       |
# | train/                  |             |
# |    approx_kl            | 0.039606426 |
# |    clip_fraction        | 0.244       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.395      |
# |    explained_variance   | 0.728       |
# |    learning_rate        | 0.0014      |
# |    loss                 | -0.0225     |
# |    n_updates            | 210         |
# |    policy_gradient_loss | 0.0121      |
# |    value_loss           | 7.9e-05     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.461       |
# | time/                   |             |
# |    fps                  | 1059        |
# |    iterations           | 23          |
# |    time_elapsed         | 27          |
# |    total_timesteps      | 29440       |
# | train/                  |             |
# |    approx_kl            | 0.087261796 |
# |    clip_fraction        | 0.294       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.412      |
# |    explained_variance   | 0.812       |
# |    learning_rate        | 0.0014      |
# |    loss                 | 0.0189      |
# |    n_updates            | 220         |
# |    policy_gradient_loss | 0.0235      |
# |    value_loss           | 6.75e-05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.479       |
# | time/                   |             |
# |    fps                  | 1061        |
# |    iterations           | 24          |
# |    time_elapsed         | 28          |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.039790362 |
# |    clip_fraction        | 0.292       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.432      |
# |    explained_variance   | 0.831       |
# |    learning_rate        | 0.0014      |
# |    loss                 | 0.000707    |
# |    n_updates            | 230         |
# |    policy_gradient_loss | 0.0291      |
# |    value_loss           | 7.02e-05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.496       |
# | time/                   |             |
# |    fps                  | 1063        |
# |    iterations           | 25          |
# |    time_elapsed         | 30          |
# |    total_timesteps      | 32000       |
# | train/                  |             |
# |    approx_kl            | 0.060235035 |
# |    clip_fraction        | 0.25        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.406      |
# |    explained_variance   | 0.835       |
# |    learning_rate        | 0.0014      |
# |    loss                 | 0.0196      |
# |    n_updates            | 240         |
# |    policy_gradient_loss | 0.0194      |
# |    value_loss           | 6.54e-05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.513       |
# | time/                   |             |
# |    fps                  | 1064        |
# |    iterations           | 26          |
# |    time_elapsed         | 31          |
# |    total_timesteps      | 33280       |
# | train/                  |             |
# |    approx_kl            | 0.101101674 |
# |    clip_fraction        | 0.308       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.37       |
# |    explained_variance   | 0.842       |
# |    learning_rate        | 0.0014      |
# |    loss                 | 0.0432      |
# |    n_updates            | 250         |
# |    policy_gradient_loss | 0.037       |
# |    value_loss           | 5.43e-05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.542       |
# | time/                   |             |
# |    fps                  | 1066        |
# |    iterations           | 27          |
# |    time_elapsed         | 32          |
# |    total_timesteps      | 34560       |
# | train/                  |             |
# |    approx_kl            | 0.060910203 |
# |    clip_fraction        | 0.253       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.363      |
# |    explained_variance   | 0.875       |
# |    learning_rate        | 0.0014      |
# |    loss                 | 0.00869     |
# |    n_updates            | 260         |
# |    policy_gradient_loss | 0.021       |
# |    value_loss           | 6.19e-05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.568       |
# | time/                   |             |
# |    fps                  | 1067        |
# |    iterations           | 28          |
# |    time_elapsed         | 33          |
# |    total_timesteps      | 35840       |
# | train/                  |             |
# |    approx_kl            | 0.034289498 |
# |    clip_fraction        | 0.258       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.352      |
# |    explained_variance   | 0.854       |
# |    learning_rate        | 0.0014      |
# |    loss                 | -0.00973    |
# |    n_updates            | 270         |
# |    policy_gradient_loss | 0.021       |
# |    value_loss           | 0.00196     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.605       |
# | time/                   |             |
# |    fps                  | 1069        |
# |    iterations           | 29          |
# |    time_elapsed         | 34          |
# |    total_timesteps      | 37120       |
# | train/                  |             |
# |    approx_kl            | 0.021144286 |
# |    clip_fraction        | 0.296       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.386      |
# |    explained_variance   | 0.75        |
# |    learning_rate        | 0.0014      |
# |    loss                 | 0.00191     |
# |    n_updates            | 280         |
# |    policy_gradient_loss | 0.0422      |
# |    value_loss           | 0.000142    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.638       |
# | time/                   |             |
# |    fps                  | 1069        |
# |    iterations           | 30          |
# |    time_elapsed         | 35          |
# |    total_timesteps      | 38400       |
# | train/                  |             |
# |    approx_kl            | 0.059782486 |
# |    clip_fraction        | 0.24        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.381      |
# |    explained_variance   | 0.844       |
# |    learning_rate        | 0.0014      |
# |    loss                 | -0.00453    |
# |    n_updates            | 290         |
# |    policy_gradient_loss | 0.0159      |
# |    value_loss           | 0.000623    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.667       |
# | time/                   |             |
# |    fps                  | 1067        |
# |    iterations           | 31          |
# |    time_elapsed         | 37          |
# |    total_timesteps      | 39680       |
# | train/                  |             |
# |    approx_kl            | 0.019006055 |
# |    clip_fraction        | 0.242       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.375      |
# |    explained_variance   | 0.819       |
# |    learning_rate        | 0.0014      |
# |    loss                 | -0.0117     |
# |    n_updates            | 300         |
# |    policy_gradient_loss | 0.0188      |
# |    value_loss           | 0.000106    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 335        |
# |    ep_rew_mean          | 0.7        |
# | time/                   |            |
# |    fps                  | 1069       |
# |    iterations           | 32         |
# |    time_elapsed         | 38         |
# |    total_timesteps      | 40960      |
# | train/                  |            |
# |    approx_kl            | 0.23999797 |
# |    clip_fraction        | 0.246      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.356     |
# |    explained_variance   | 0.85       |
# |    learning_rate        | 0.0014     |
# |    loss                 | 0.116      |
# |    n_updates            | 310        |
# |    policy_gradient_loss | 0.029      |
# |    value_loss           | 5.39e-05   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.727       |
# | time/                   |             |
# |    fps                  | 1067        |
# |    iterations           | 33          |
# |    time_elapsed         | 39          |
# |    total_timesteps      | 42240       |
# | train/                  |             |
# |    approx_kl            | 0.035768557 |
# |    clip_fraction        | 0.278       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.337      |
# |    explained_variance   | 0.86        |
# |    learning_rate        | 0.0014      |
# |    loss                 | 0.00781     |
# |    n_updates            | 320         |
# |    policy_gradient_loss | 0.0301      |
# |    value_loss           | 5.42e-05    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 335        |
# |    ep_rew_mean          | 0.746      |
# | time/                   |            |
# |    fps                  | 1061       |
# |    iterations           | 34         |
# |    time_elapsed         | 40         |
# |    total_timesteps      | 43520      |
# | train/                  |            |
# |    approx_kl            | 0.08953394 |
# |    clip_fraction        | 0.286      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.355     |
# |    explained_variance   | 0.878      |
# |    learning_rate        | 0.0014     |
# |    loss                 | 0.00856    |
# |    n_updates            | 330        |
# |    policy_gradient_loss | 0.0305     |
# |    value_loss           | 4.5e-05    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.769       |
# | time/                   |             |
# |    fps                  | 1057        |
# |    iterations           | 35          |
# |    time_elapsed         | 42          |
# |    total_timesteps      | 44800       |
# | train/                  |             |
# |    approx_kl            | 0.046687543 |
# |    clip_fraction        | 0.214       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.359      |
# |    explained_variance   | 0.831       |
# |    learning_rate        | 0.0014      |
# |    loss                 | -0.0108     |
# |    n_updates            | 340         |
# |    policy_gradient_loss | 0.00453     |
# |    value_loss           | 6.35e-05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.789       |
# | time/                   |             |
# |    fps                  | 1055        |
# |    iterations           | 36          |
# |    time_elapsed         | 43          |
# |    total_timesteps      | 46080       |
# | train/                  |             |
# |    approx_kl            | 0.106838584 |
# |    clip_fraction        | 0.238       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.344      |
# |    explained_variance   | 0.876       |
# |    learning_rate        | 0.0014      |
# |    loss                 | 0.0331      |
# |    n_updates            | 350         |
# |    policy_gradient_loss | 0.0304      |
# |    value_loss           | 4.66e-05    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 335        |
# |    ep_rew_mean          | 0.81       |
# | time/                   |            |
# |    fps                  | 1056       |
# |    iterations           | 37         |
# |    time_elapsed         | 44         |
# |    total_timesteps      | 47360      |
# | train/                  |            |
# |    approx_kl            | 0.03682232 |
# |    clip_fraction        | 0.223      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.32      |
# |    explained_variance   | 0.886      |
# |    learning_rate        | 0.0014     |
# |    loss                 | -0.00373   |
# |    n_updates            | 360        |
# |    policy_gradient_loss | 0.00707    |
# |    value_loss           | 0.000229   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 335        |
# |    ep_rew_mean          | 0.83       |
# | time/                   |            |
# |    fps                  | 1056       |
# |    iterations           | 38         |
# |    time_elapsed         | 46         |
# |    total_timesteps      | 48640      |
# | train/                  |            |
# |    approx_kl            | 0.04847621 |
# |    clip_fraction        | 0.27       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.328     |
# |    explained_variance   | 0.848      |
# |    learning_rate        | 0.0014     |
# |    loss                 | -0.00203   |
# |    n_updates            | 370        |
# |    policy_gradient_loss | 0.0414     |
# |    value_loss           | 0.000436   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 335        |
# |    ep_rew_mean          | 0.846      |
# | time/                   |            |
# |    fps                  | 1057       |
# |    iterations           | 39         |
# |    time_elapsed         | 47         |
# |    total_timesteps      | 49920      |
# | train/                  |            |
# |    approx_kl            | 0.11038551 |
# |    clip_fraction        | 0.243      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.314     |
# |    explained_variance   | 0.87       |
# |    learning_rate        | 0.0014     |
# |    loss                 | -0.0138    |
# |    n_updates            | 380        |
# |    policy_gradient_loss | 0.0341     |
# |    value_loss           | 6.15e-05   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.857       |
# | time/                   |             |
# |    fps                  | 1058        |
# |    iterations           | 40          |
# |    time_elapsed         | 48          |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.044876218 |
# |    clip_fraction        | 0.237       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.281      |
# |    explained_variance   | 0.887       |
# |    learning_rate        | 0.0014      |
# |    loss                 | 0.0221      |
# |    n_updates            | 390         |
# |    policy_gradient_loss | 0.0103      |
# |    value_loss           | 6.63e-05    |
# -----------------------------------------
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 335      |
# |    ep_rew_mean     | 0.0389   |
# | time/              |          |
# |    fps             | 1576     |
# |    iterations      | 1        |
# |    time_elapsed    | 1        |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | -0.0265     |
# | time/                   |             |
# |    fps                  | 1063        |
# |    iterations           | 2           |
# |    time_elapsed         | 3           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.011559797 |
# |    clip_fraction        | 0.0904      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | -4.14       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0154      |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.00471    |
# |    value_loss           | 0.00218     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | -0.0246     |
# | time/                   |             |
# |    fps                  | 944         |
# |    iterations           | 3           |
# |    time_elapsed         | 6           |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.005046338 |
# |    clip_fraction        | 0.0102      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.08       |
# |    explained_variance   | -0.541      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00949    |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.00181    |
# |    value_loss           | 0.000786    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | -0.0279     |
# | time/                   |             |
# |    fps                  | 855         |
# |    iterations           | 4           |
# |    time_elapsed         | 9           |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.011198322 |
# |    clip_fraction        | 0.108       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | -0.314      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0281     |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.00652    |
# |    value_loss           | 0.000318    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 335          |
# |    ep_rew_mean          | -0.0239      |
# | time/                   |              |
# |    fps                  | 862          |
# |    iterations           | 5            |
# |    time_elapsed         | 11           |
# |    total_timesteps      | 10240        |
# | train/                  |              |
# |    approx_kl            | 0.0048791873 |
# |    clip_fraction        | 0.0191       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.09        |
# |    explained_variance   | 0.32         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0159       |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.0033      |
# |    value_loss           | 0.000373     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | -0.0139     |
# | time/                   |             |
# |    fps                  | 878         |
# |    iterations           | 6           |
# |    time_elapsed         | 13          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.009529425 |
# |    clip_fraction        | 0.0942      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.08       |
# |    explained_variance   | 0.497       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0167     |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.00684    |
# |    value_loss           | 0.000263    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 335        |
# |    ep_rew_mean          | 0.006      |
# | time/                   |            |
# |    fps                  | 889        |
# |    iterations           | 7          |
# |    time_elapsed         | 16         |
# |    total_timesteps      | 14336      |
# | train/                  |            |
# |    approx_kl            | 0.01005716 |
# |    clip_fraction        | 0.0736     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.07      |
# |    explained_variance   | 0.312      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.023     |
# |    n_updates            | 60         |
# |    policy_gradient_loss | -0.0063    |
# |    value_loss           | 0.000477   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.0191      |
# | time/                   |             |
# |    fps                  | 901         |
# |    iterations           | 8           |
# |    time_elapsed         | 18          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.006022152 |
# |    clip_fraction        | 0.0745      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.05       |
# |    explained_variance   | 0.436       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0101     |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.00434    |
# |    value_loss           | 0.000217    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.0432      |
# | time/                   |             |
# |    fps                  | 912         |
# |    iterations           | 9           |
# |    time_elapsed         | 20          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.010989012 |
# |    clip_fraction        | 0.134       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.02       |
# |    explained_variance   | 0.462       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00702     |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.0109     |
# |    value_loss           | 0.000247    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.0717      |
# | time/                   |             |
# |    fps                  | 918         |
# |    iterations           | 10          |
# |    time_elapsed         | 22          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.009976399 |
# |    clip_fraction        | 0.126       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.964      |
# |    explained_variance   | 0.43        |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0152     |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.00862    |
# |    value_loss           | 0.00027     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 335          |
# |    ep_rew_mean          | 0.0968       |
# | time/                   |              |
# |    fps                  | 893          |
# |    iterations           | 11           |
# |    time_elapsed         | 25           |
# |    total_timesteps      | 22528        |
# | train/                  |              |
# |    approx_kl            | 0.0064738384 |
# |    clip_fraction        | 0.125        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.929       |
# |    explained_variance   | 0.457        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00225     |
# |    n_updates            | 100          |
# |    policy_gradient_loss | -0.007       |
# |    value_loss           | 0.000259     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.123       |
# | time/                   |             |
# |    fps                  | 881         |
# |    iterations           | 12          |
# |    time_elapsed         | 27          |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.012598274 |
# |    clip_fraction        | 0.141       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.882      |
# |    explained_variance   | 0.54        |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00299    |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.00668    |
# |    value_loss           | 0.000283    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.145       |
# | time/                   |             |
# |    fps                  | 878         |
# |    iterations           | 13          |
# |    time_elapsed         | 30          |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.008340251 |
# |    clip_fraction        | 0.118       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.839      |
# |    explained_variance   | 0.668       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00105    |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.00531    |
# |    value_loss           | 0.000287    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 335        |
# |    ep_rew_mean          | 0.172      |
# | time/                   |            |
# |    fps                  | 878        |
# |    iterations           | 14         |
# |    time_elapsed         | 32         |
# |    total_timesteps      | 28672      |
# | train/                  |            |
# |    approx_kl            | 0.01663746 |
# |    clip_fraction        | 0.125      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.782     |
# |    explained_variance   | 0.731      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.00934   |
# |    n_updates            | 130        |
# |    policy_gradient_loss | -0.0032    |
# |    value_loss           | 0.000331   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.196       |
# | time/                   |             |
# |    fps                  | 879         |
# |    iterations           | 15          |
# |    time_elapsed         | 34          |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.011426108 |
# |    clip_fraction        | 0.125       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.764      |
# |    explained_variance   | 0.84        |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0201     |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.00206    |
# |    value_loss           | 0.00029     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.22        |
# | time/                   |             |
# |    fps                  | 879         |
# |    iterations           | 16          |
# |    time_elapsed         | 37          |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.020897161 |
# |    clip_fraction        | 0.126       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.722      |
# |    explained_variance   | 0.813       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00837    |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.0017     |
# |    value_loss           | 0.000269    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.248       |
# | time/                   |             |
# |    fps                  | 869         |
# |    iterations           | 17          |
# |    time_elapsed         | 40          |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.014954114 |
# |    clip_fraction        | 0.171       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.713      |
# |    explained_variance   | 0.851       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.017       |
# |    n_updates            | 160         |
# |    policy_gradient_loss | 0.0042      |
# |    value_loss           | 0.000305    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 335        |
# |    ep_rew_mean          | 0.295      |
# | time/                   |            |
# |    fps                  | 860        |
# |    iterations           | 18         |
# |    time_elapsed         | 42         |
# |    total_timesteps      | 36864      |
# | train/                  |            |
# |    approx_kl            | 0.02728482 |
# |    clip_fraction        | 0.144      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.723     |
# |    explained_variance   | 0.837      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0376    |
# |    n_updates            | 170        |
# |    policy_gradient_loss | -0.00151   |
# |    value_loss           | 0.000871   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.34        |
# | time/                   |             |
# |    fps                  | 860         |
# |    iterations           | 19          |
# |    time_elapsed         | 45          |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.012694426 |
# |    clip_fraction        | 0.123       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.673      |
# |    explained_variance   | 0.894       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.000164   |
# |    n_updates            | 180         |
# |    policy_gradient_loss | 0.00414     |
# |    value_loss           | 0.000204    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.384       |
# | time/                   |             |
# |    fps                  | 860         |
# |    iterations           | 20          |
# |    time_elapsed         | 47          |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.011644695 |
# |    clip_fraction        | 0.151       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.647      |
# |    explained_variance   | 0.931       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00359    |
# |    n_updates            | 190         |
# |    policy_gradient_loss | 0.00168     |
# |    value_loss           | 0.000208    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.429       |
# | time/                   |             |
# |    fps                  | 863         |
# |    iterations           | 21          |
# |    time_elapsed         | 49          |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.013777357 |
# |    clip_fraction        | 0.166       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.613      |
# |    explained_variance   | 0.944       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00118     |
# |    n_updates            | 200         |
# |    policy_gradient_loss | 0.00422     |
# |    value_loss           | 0.000176    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 335        |
# |    ep_rew_mean          | 0.471      |
# | time/                   |            |
# |    fps                  | 867        |
# |    iterations           | 22         |
# |    time_elapsed         | 51         |
# |    total_timesteps      | 45056      |
# | train/                  |            |
# |    approx_kl            | 0.01640137 |
# |    clip_fraction        | 0.154      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.595     |
# |    explained_variance   | 0.957      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.017     |
# |    n_updates            | 210        |
# |    policy_gradient_loss | 0.00342    |
# |    value_loss           | 0.000266   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.513       |
# | time/                   |             |
# |    fps                  | 871         |
# |    iterations           | 23          |
# |    time_elapsed         | 54          |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.010597862 |
# |    clip_fraction        | 0.182       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.556      |
# |    explained_variance   | 0.966       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0246      |
# |    n_updates            | 220         |
# |    policy_gradient_loss | 0.00724     |
# |    value_loss           | 0.000772    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 0.554       |
# | time/                   |             |
# |    fps                  | 866         |
# |    iterations           | 24          |
# |    time_elapsed         | 56          |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.022477116 |
# |    clip_fraction        | 0.166       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.555      |
# |    explained_variance   | 0.953       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0154     |
# |    n_updates            | 230         |
# |    policy_gradient_loss | 0.00505     |
# |    value_loss           | 0.000165    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 335        |
# |    ep_rew_mean          | 0.59       |
# | time/                   |            |
# |    fps                  | 862        |
# |    iterations           | 25         |
# |    time_elapsed         | 59         |
# |    total_timesteps      | 51200      |
# | train/                  |            |
# |    approx_kl            | 0.03000503 |
# |    clip_fraction        | 0.167      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.538     |
# |    explained_variance   | 0.962      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0148    |
# |    n_updates            | 240        |
# |    policy_gradient_loss | 0.00553    |
# |    value_loss           | 0.000129   |
# ----------------------------------------
#          Method  Cumulative Return  Sharpe Ratio  Sortino Ratio  Max Drawdown
# 0   Bi-LSTM PPO           1.911471      0.377045       1.865255     -0.006237
# 1    Simple PPO           1.925070      0.389380       1.869994     -0.005867
# 2  Buy-and-Hold           1.386937           NaN            NaN           NaN
